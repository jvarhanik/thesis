# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE     = 100
N_EVALS      = 100000
N_REPLICATES = 30
MIN_LEN      = 3
MAX_LEN      = 100
gene_low, gene_high = -2.0, 2.0
SIGMA_INIT    = 0.5
P_DIM_CHANGE  = 0.01

target_map = {
    'Sphere':    30,
    'Rastrigin': 30,
    'Griewank':  30,
    'Ackley':    30,
    'Koza':      10,
    'Knapsack':  20,
    'Parity':    64,
    'SantaFe':   100
}

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir   = f'CMA_ES_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_summary = os.path.join(out_dir, 'CMA_ES_results.csv')
csv_history = os.path.join(out_dir, 'CMA_ES_history.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=5):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x*x for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x*x - 10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        s = sum(x*x for x in ind)
        p = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + s/4000.0 - p + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        s = sum(x*x for x in ind)
        c = sum(cos(2*pi*x) for x in ind)
        return -20*exp(-0.2*sqrt(s/d)) - exp(c/d) + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    xs = np.linspace(-1,1,20)
    def f(ind):
        err = 0.0
        for x in xs:
            t = x**4 + x**3 + x**2 + x
            p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (p - t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, capacity):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel = [int(round(x))%2 for x in ind[:len(items)]]
        w_sum = sum(w for (w,v),s in zip(items, sel) if s)
        v_sum = sum(v for (w,v),s in zip(items, sel) if s)
        over = max(0, w_sum - capacity)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target = 2**N
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        table = [int(round(x))%2 for x in ind[:d_target]]
        errs = 0
        for i in range(d_target):
            target = bin(i).count('1')%2
            errs += 0 if (i < len(table) and table[i]==target) else 1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    world=[]; sx=sy=0
    with open('santafe_trail.txt') as f:
        for y,line in enumerate(f):
            for x,c in enumerate(line.rstrip('\n')):
                if c=='#': world.append(1)
                elif c in ('.','S'):
                    world.append(0)
                    if c=='S': sx,sy = x,y
    W = len(open('santafe_trail.txt').readline().rstrip('\n'))
    H = len(world)//W
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        dir_ = 0; x,y = sx,sy; food=0
        visited = world.copy()
        idx = lambda xx,yy: (yy%H)*W+(xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)]==1:
                food +=1; visited[idx(x,y)]=0
            act = int(abs(ind[i]))%3
            if act==0:
                dx,dy=[(0,1),(1,0),(0,-1),(-1,0)][dir_]
                x+=dx; y+=dy
            elif act==1:
                dir_=(dir_+1)%4
            else:
                dir_=(dir_-1)%4
        return -food + pen(ind)
    return f

# %%
def computeHyperparams(n_dim, mu):
    w = np.log(mu+0.5) - np.log(np.arange(1,mu+1))
    w /= np.sum(w)
    mu_eff = 1.0/np.sum(w**2)
    c_c  = (4+mu_eff/n_dim)/(n_dim+4+2*mu_eff/n_dim)
    c_s  = (mu_eff+2)/(n_dim+mu_eff+5)
    c1   = 2/((n_dim+1.3)**2 + mu_eff)
    c_mu = min(1-c1, 2*(mu_eff-2+1/mu_eff)/((n_dim+2)**2+mu_eff))
    d_s  = 1 + 2*max(0, sqrt((mu_eff-1)/(n_dim+1))-1) + c_s
    chi_n= sqrt(n_dim)*(1 - 1/(4*n_dim) + 1/(21*n_dim**2))
    return w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n

# %%
def runCMAES(fit, name):
    n     = target_map[name]
    m     = np.random.uniform(gene_low, gene_high, size=n)
    C     = np.eye(n)
    sigma = SIGMA_INIT
    p_c   = np.zeros(n)
    p_s   = np.zeros(n)
    evals = 0
    best_hist = []
    mu = POP_SIZE // 2
    w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n = computeHyperparams(n, mu)

    while evals < N_EVALS:
        if random.random() < P_DIM_CHANGE:
            if random.random() < 0.5 and len(m) < MAX_LEN:
                m = np.append(m, random.uniform(gene_low, gene_high))
                C = np.pad(C, ((0,1),(0,1)), constant_values=0); C[-1,-1]=1.0
                p_c = np.append(p_c, 0.0); p_s = np.append(p_s, 0.0)
            elif len(m) > MIN_LEN:
                m = m[:-1]; C = C[:-1,:-1]; p_c = p_c[:-1]; p_s = p_s[:-1]
            n = len(m)
            w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n = computeHyperparams(n, mu)

        D2, B = np.linalg.eigh(C)
        D    = np.sqrt(np.abs(D2))
        arz  = np.random.randn(POP_SIZE, n)
        arx  = m + sigma * (arz @ (B * D).T)
        fits = [fit(x.tolist()) for x in arx]
        evals += POP_SIZE

        idx = np.argsort(fits)
        arx, arz = arx[idx], arz[idx]
        fits = [fits[i] for i in idx]
        best = fits[0]
        best_hist.append(best)

        if evals % (POP_SIZE * 10) == 0:
            print(f'{name} Evals {evals}: Best = {best:.6f}, Len = {len(m)}')

        old_m = m.copy()
        m = np.dot(w, arx[:mu])
        y = (m - old_m) / sigma
        inv_sqrtC = B @ np.diag(1.0/D) @ B.T
        p_s = (1-c_s)*p_s + sqrt(c_s*(2-c_s)*mu_eff) * (inv_sqrtC @ y)
        norm_ps = np.linalg.norm(p_s)
        h_sigma = int(norm_ps < (1.4+2/(n+1)) * sqrt(1 - (1-c_s)**(2*evals/POP_SIZE)))
        p_c = (1-c_c)*p_c + h_sigma*sqrt(c_c*(2-c_c)*mu_eff) * y
        artmp = (arz[:mu].T * w).T
        C = ((1-c1-c_mu)*C
             + c1*(np.outer(p_c, p_c) + (1-h_sigma)*c_c*(2-c_c)*C)
             + c_mu*(artmp.T @ artmp))
        C = (C + C.T)/2
        diag = np.clip(np.diag(C), 1e-8, 1e8)
        C[np.diag_indices(len(C))] = diag
        expnt = (c_s/d_s)*(norm_ps/chi_n - 1)
        expnt = np.clip(expnt, -10, 10)
        sigma *= math.exp(expnt)
        sigma = float(np.clip(sigma, 1e-8, 1e+1))

    return m, best_hist

# %%
with open(csv_summary, 'w', newline='') as fs, open(csv_history, 'w', newline='') as fh:
    writer_sum = csv.DictWriter(fs, fieldnames=['run_id','benchmark','replicate','seed','best','len_final','cpu_s'])
    writer_hist = csv.DictWriter(fh, fieldnames=['run_id','benchmark','replicate','seed','evals','fitness'])
    writer_sum.writeheader()
    writer_hist.writeheader()

    tmp_items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        'Sphere':    sphere(30,10),
        'Rastrigin': rastrigin(30,10),
        'Griewank':  griewank(30,10),
        'Ackley':    ackley(30,10),
        'Koza':      koza(10,10),
        'Knapsack':  knapsack(20,0,tmp_items,50),
        'Parity':    parity(6,10),
        'SantaFe':   santaFe(100,10),
    }

    for name, func in benchmarks.items():
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed); np.random.seed(seed)
            start = time.perf_counter()
            best_vec, history = runCMAES(func, name)
            cpu = time.perf_counter() - start
            best_val = round(func(best_vec.tolist()), 6)
            run_id = uuid.uuid4()
            writer_sum.writerow({
                'run_id': run_id,
                'benchmark': name,
                'replicate': rep,
                'seed': seed,
                'best': best_val,
                'len_final': len(best_vec),
                'cpu_s': round(cpu,4)
            })
            for i, fitval in enumerate(history):
                ev = (i+1) * POP_SIZE
                writer_hist.writerow({
                    'run_id': run_id,
                    'benchmark': name,
                    'replicate': rep,
                    'seed': seed,
                    'evals': ev,
                    'fitness': fitval
                })
print(f'Results written to {csv_summary} and history to {csv_history}')
# Out:
# Sphere Evals 1000: Best = 42.765252, Len = 30
# Sphere Evals 2000: Best = 5.034142, Len = 30
# Sphere Evals 3000: Best = 0.932350, Len = 30
# Sphere Evals 4000: Best = 0.150378, Len = 30
# Sphere Evals 5000: Best = 0.034916, Len = 30
# Sphere Evals 6000: Best = 0.009177, Len = 30
# Sphere Evals 7000: Best = 0.002063, Len = 30
# Sphere Evals 8000: Best = 0.000479, Len = 29
# Sphere Evals 9000: Best = 0.000162, Len = 29
# Sphere Evals 10000: Best = 0.000026, Len = 29
# Sphere Evals 11000: Best = 0.000007, Len = 29
# Sphere Evals 12000: Best = 0.000002, Len = 29
# Sphere Evals 13000: Best = 0.000001, Len = 29
# Sphere Evals 14000: Best = 0.000000, Len = 29
# Sphere Evals 15000: Best = 1.848064, Len = 30
# Sphere Evals 16000: Best = 0.368842, Len = 30
# Sphere Evals 17000: Best = 0.165593, Len = 30
# Sphere Evals 18000: Best = 0.041029, Len = 30
# Sphere Evals 19000: Best = 0.006598, Len = 30
# Sphere Evals 20000: Best = 0.002201, Len = 30
# Sphere Evals 21000: Best = 0.082067, Len = 31
# Sphere Evals 22000: Best = 0.027545, Len = 31
# Sphere Evals 23000: Best = 0.005280, Len = 31
# Sphere Evals 24000: Best = 0.002279, Len = 31
# Sphere Evals 25000: Best = 0.000534, Len = 31
# Sphere Evals 26000: Best = 0.000142, Len = 31
# Sphere Evals 27000: Best = 0.000041, Len = 31
# Sphere Evals 28000: Best = 0.000010, Len = 31
# Sphere Evals 29000: Best = 0.000003, Len = 31
# Sphere Evals 30000: Best = 0.000002, Len = 31
# Sphere Evals 31000: Best = 0.000000, Len = 31
# Sphere Evals 32000: Best = 0.000000, Len = 31
# Sphere Evals 33000: Best = 0.000000, Len = 31
# Sphere Evals 34000: Best = 0.000000, Len = 31
# Sphere Evals 35000: Best = 0.000000, Len = 31
# Sphere Evals 36000: Best = 0.000000, Len = 31
# Sphere Evals 37000: Best = 0.000000, Len = 31
# Sphere Evals 38000: Best = 0.000000, Len = 31
# Sphere Evals 39000: Best = 0.000000, Len = 30
# Sphere Evals 40000: Best = 0.000480, Len = 31
# Sphere Evals 41000: Best = 0.000271, Len = 31
# Sphere Evals 42000: Best = 0.000087, Len = 31
# Sphere Evals 43000: Best = 0.000025, Len = 31
# Sphere Evals 44000: Best = 0.000004, Len = 31
# Sphere Evals 45000: Best = 0.000001, Len = 31
# Sphere Evals 46000: Best = 0.000000, Len = 31
# Sphere Evals 47000: Best = 0.000000, Len = 31
# Sphere Evals 48000: Best = 0.000000, Len = 30
# Sphere Evals 49000: Best = 0.000000, Len = 30
# Sphere Evals 50000: Best = 0.000000, Len = 30
# Sphere Evals 51000: Best = 0.000000, Len = 30
# Sphere Evals 52000: Best = 0.000000, Len = 30
# Sphere Evals 53000: Best = 0.000000, Len = 30
# Sphere Evals 54000: Best = 0.000000, Len = 29
# Sphere Evals 55000: Best = 0.000000, Len = 29
# Sphere Evals 56000: Best = 0.000000, Len = 29
# Sphere Evals 57000: Best = 0.000000, Len = 29
# Sphere Evals 58000: Best = 0.000000, Len = 29
# Sphere Evals 59000: Best = 0.000000, Len = 29
# Sphere Evals 60000: Best = 0.000000, Len = 29
# Sphere Evals 61000: Best = 0.000000, Len = 29
# Sphere Evals 62000: Best = 0.000000, Len = 29
# Sphere Evals 63000: Best = 0.000000, Len = 29
# Sphere Evals 64000: Best = 0.807188, Len = 30
# Sphere Evals 65000: Best = 4.297406, Len = 31
# Sphere Evals 66000: Best = 4.296381, Len = 31
# Sphere Evals 67000: Best = 4.225252, Len = 31
# Sphere Evals 68000: Best = 1.107932, Len = 31
# Sphere Evals 69000: Best = 0.672553, Len = 30
# Sphere Evals 70000: Best = 0.156185, Len = 30
# Sphere Evals 71000: Best = 0.041377, Len = 30
# Sphere Evals 72000: Best = 0.008179, Len = 30
# Sphere Evals 73000: Best = 0.001477, Len = 30
# Sphere Evals 74000: Best = 0.000339, Len = 30
# Sphere Evals 75000: Best = 0.000080, Len = 30
# Sphere Evals 76000: Best = 0.000028, Len = 30
# Sphere Evals 77000: Best = 0.000006, Len = 30
# Sphere Evals 78000: Best = 0.012868, Len = 31
# Sphere Evals 79000: Best = 0.017493, Len = 31
# Sphere Evals 80000: Best = 0.007955, Len = 31
# Sphere Evals 81000: Best = 0.002585, Len = 31
# Sphere Evals 82000: Best = 0.000465, Len = 31
# Sphere Evals 83000: Best = 0.000174, Len = 31
# Sphere Evals 84000: Best = 0.000077, Len = 31
# Sphere Evals 85000: Best = 0.000025, Len = 31
# Sphere Evals 86000: Best = 0.000005, Len = 31
# Sphere Evals 87000: Best = 0.000002, Len = 31
# Sphere Evals 88000: Best = 0.000000, Len = 31
# Sphere Evals 89000: Best = 0.000000, Len = 31
# Sphere Evals 90000: Best = 0.000000, Len = 31
# Sphere Evals 91000: Best = 0.000000, Len = 31
# Sphere Evals 92000: Best = 0.000000, Len = 31
# Sphere Evals 93000: Best = 2.757132, Len = 32
# Sphere Evals 94000: Best = 1.692660, Len = 32
# Sphere Evals 95000: Best = 0.565857, Len = 33
# Sphere Evals 96000: Best = 0.511489, Len = 34
# Sphere Evals 97000: Best = 0.131186, Len = 34
# Sphere Evals 98000: Best = 0.084698, Len = 34
# Sphere Evals 99000: Best = 0.025330, Len = 34
# Sphere Evals 100000: Best = 0.005369, Len = 34
# Sphere Evals 1000: Best = 38.016720, Len = 30
# Sphere Evals 2000: Best = 6.504895, Len = 30
# Sphere Evals 3000: Best = 1.682837, Len = 30
# Sphere Evals 4000: Best = 0.232859, Len = 30
# Sphere Evals 5000: Best = 0.045724, Len = 30
# Sphere Evals 6000: Best = 0.006965, Len = 30
# Sphere Evals 7000: Best = 0.002646, Len = 30
# Sphere Evals 8000: Best = 0.000576, Len = 30
# Sphere Evals 9000: Best = 0.000145, Len = 30
# Sphere Evals 10000: Best = 0.000023, Len = 30
# Sphere Evals 11000: Best = 0.000008, Len = 30
# Sphere Evals 12000: Best = 0.000002, Len = 30
# Sphere Evals 13000: Best = 0.000001, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 30
# Sphere Evals 20000: Best = 0.000000, Len = 30
# Sphere Evals 21000: Best = 0.000000, Len = 30
# Sphere Evals 22000: Best = 0.000000, Len = 30
# Sphere Evals 23000: Best = 1.507642, Len = 31
# Sphere Evals 24000: Best = 1.484809, Len = 31
# Sphere Evals 25000: Best = 0.402364, Len = 31
# Sphere Evals 26000: Best = 0.320075, Len = 31
# Sphere Evals 27000: Best = 0.108925, Len = 31
# Sphere Evals 28000: Best = 0.030267, Len = 31
# Sphere Evals 29000: Best = 0.007615, Len = 31
# Sphere Evals 30000: Best = 0.001987, Len = 31
# Sphere Evals 31000: Best = 0.000463, Len = 31
# Sphere Evals 32000: Best = 0.000115, Len = 31
# Sphere Evals 33000: Best = 0.000016, Len = 31
# Sphere Evals 34000: Best = 0.000005, Len = 31
# Sphere Evals 35000: Best = 0.000001, Len = 31
# Sphere Evals 36000: Best = 0.000000, Len = 31
# Sphere Evals 37000: Best = 0.000000, Len = 31
# Sphere Evals 38000: Best = 0.000000, Len = 31
# Sphere Evals 39000: Best = 0.000000, Len = 31
# Sphere Evals 40000: Best = 0.000000, Len = 31
# Sphere Evals 41000: Best = 0.000000, Len = 31
# Sphere Evals 42000: Best = 0.000000, Len = 31
# Sphere Evals 43000: Best = 0.000000, Len = 31
# Sphere Evals 44000: Best = 0.000000, Len = 31
# Sphere Evals 45000: Best = 0.000000, Len = 31
# Sphere Evals 46000: Best = 0.000000, Len = 31
# Sphere Evals 47000: Best = 0.000000, Len = 31
# Sphere Evals 48000: Best = 0.000000, Len = 31
# Sphere Evals 49000: Best = 0.000000, Len = 31
# Sphere Evals 50000: Best = 0.000000, Len = 31
# Sphere Evals 51000: Best = 0.000000, Len = 31
# Sphere Evals 52000: Best = 0.000000, Len = 31
# Sphere Evals 53000: Best = 0.000000, Len = 31
# Sphere Evals 54000: Best = 0.000000, Len = 31
# Sphere Evals 55000: Best = 0.000000, Len = 31
# Sphere Evals 56000: Best = 0.000000, Len = 30
# Sphere Evals 57000: Best = 0.000000, Len = 29
# Sphere Evals 58000: Best = 0.000000, Len = 29
# Sphere Evals 59000: Best = 0.000000, Len = 29
# Sphere Evals 60000: Best = 0.000000, Len = 29
# Sphere Evals 61000: Best = 0.000000, Len = 29
# Sphere Evals 62000: Best = 0.000000, Len = 28
# Sphere Evals 63000: Best = 0.000000, Len = 28
# Sphere Evals 64000: Best = 0.000000, Len = 28
# Sphere Evals 65000: Best = 0.000000, Len = 28
# Sphere Evals 66000: Best = 0.000000, Len = 28
# Sphere Evals 67000: Best = 0.000000, Len = 28
# Sphere Evals 68000: Best = 0.000000, Len = 28
# Sphere Evals 69000: Best = 0.000000, Len = 28
# Sphere Evals 70000: Best = 0.000000, Len = 28
# Sphere Evals 71000: Best = 0.000000, Len = 28
# Sphere Evals 72000: Best = 0.000000, Len = 28
# Sphere Evals 73000: Best = 0.000000, Len = 28
# Sphere Evals 74000: Best = 0.000000, Len = 28
# Sphere Evals 75000: Best = 0.000000, Len = 28
# Sphere Evals 76000: Best = 0.000000, Len = 28
# Sphere Evals 77000: Best = 0.000000, Len = 28
# Sphere Evals 78000: Best = 0.000000, Len = 28
# Sphere Evals 79000: Best = 0.000000, Len = 28
# Sphere Evals 80000: Best = 0.000000, Len = 28
# Sphere Evals 81000: Best = 0.000000, Len = 28
# Sphere Evals 82000: Best = 0.000000, Len = 28
# Sphere Evals 83000: Best = 0.000000, Len = 28
# Sphere Evals 84000: Best = 0.000000, Len = 28
# Sphere Evals 85000: Best = 0.000000, Len = 28
# Sphere Evals 86000: Best = 0.000000, Len = 28
# Sphere Evals 87000: Best = 0.000000, Len = 28
# Sphere Evals 88000: Best = 0.000000, Len = 28
# Sphere Evals 89000: Best = 0.000000, Len = 28
# Sphere Evals 90000: Best = 0.000000, Len = 27
# Sphere Evals 91000: Best = 0.000000, Len = 27
# Sphere Evals 92000: Best = 0.000000, Len = 27
# Sphere Evals 93000: Best = 0.000000, Len = 27
# Sphere Evals 94000: Best = 0.000000, Len = 27
# Sphere Evals 95000: Best = 0.000000, Len = 27
# Sphere Evals 96000: Best = 0.000000, Len = 27
# Sphere Evals 97000: Best = 0.000000, Len = 27
# Sphere Evals 98000: Best = 0.000000, Len = 27
# Sphere Evals 99000: Best = 0.000000, Len = 26
# Sphere Evals 100000: Best = 0.000000, Len = 26
# Sphere Evals 1000: Best = 51.416116, Len = 30
# Sphere Evals 2000: Best = 8.973624, Len = 30
# Sphere Evals 3000: Best = 1.764807, Len = 30
# Sphere Evals 4000: Best = 0.247067, Len = 30
# Sphere Evals 5000: Best = 0.044591, Len = 30
# Sphere Evals 6000: Best = 0.008303, Len = 30
# Sphere Evals 7000: Best = 0.001733, Len = 30
# Sphere Evals 8000: Best = 0.000261, Len = 30
# Sphere Evals 9000: Best = 0.000046, Len = 30
# Sphere Evals 10000: Best = 1.751580, Len = 31
# Sphere Evals 11000: Best = 0.737614, Len = 32
# Sphere Evals 12000: Best = 0.417278, Len = 33
# Sphere Evals 13000: Best = 0.161991, Len = 33
# Sphere Evals 14000: Best = 0.079397, Len = 33
# Sphere Evals 15000: Best = 0.033443, Len = 33
# Sphere Evals 16000: Best = 0.016065, Len = 33
# Sphere Evals 17000: Best = 0.005181, Len = 33
# Sphere Evals 18000: Best = 0.001481, Len = 33
# Sphere Evals 19000: Best = 0.008760, Len = 34
# Sphere Evals 20000: Best = 0.001774, Len = 34
# Sphere Evals 21000: Best = 0.000613, Len = 34
# Sphere Evals 22000: Best = 0.000264, Len = 34
# Sphere Evals 23000: Best = 0.000091, Len = 34
# Sphere Evals 24000: Best = 0.000029, Len = 34
# Sphere Evals 25000: Best = 0.000005, Len = 34
# Sphere Evals 26000: Best = 0.000002, Len = 34
# Sphere Evals 27000: Best = 0.000001, Len = 34
# Sphere Evals 28000: Best = 0.000000, Len = 34
# Sphere Evals 29000: Best = 0.019725, Len = 35
# Sphere Evals 30000: Best = 0.003435, Len = 35
# Sphere Evals 31000: Best = 0.216724, Len = 35
# Sphere Evals 32000: Best = 0.029301, Len = 35
# Sphere Evals 33000: Best = 0.012078, Len = 35
# Sphere Evals 34000: Best = 0.002785, Len = 35
# Sphere Evals 35000: Best = 0.000857, Len = 35
# Sphere Evals 36000: Best = 0.000330, Len = 35
# Sphere Evals 37000: Best = 0.000115, Len = 35
# Sphere Evals 38000: Best = 0.000027, Len = 35
# Sphere Evals 39000: Best = 0.000011, Len = 35
# Sphere Evals 40000: Best = 0.000004, Len = 35
# Sphere Evals 41000: Best = 0.000001, Len = 35
# Sphere Evals 42000: Best = 0.000001, Len = 34
# Sphere Evals 43000: Best = 0.000000, Len = 34
# Sphere Evals 44000: Best = 0.000000, Len = 34
# Sphere Evals 45000: Best = 0.000000, Len = 34
# Sphere Evals 46000: Best = 0.000000, Len = 34
# Sphere Evals 47000: Best = 0.000000, Len = 34
# Sphere Evals 48000: Best = 0.306551, Len = 35
# Sphere Evals 49000: Best = 0.292956, Len = 35
# Sphere Evals 50000: Best = 0.025268, Len = 35
# Sphere Evals 51000: Best = 0.019582, Len = 35
# Sphere Evals 52000: Best = 0.006958, Len = 35
# Sphere Evals 53000: Best = 0.002262, Len = 35
# Sphere Evals 54000: Best = 0.000535, Len = 35
# Sphere Evals 55000: Best = 0.000174, Len = 35
# Sphere Evals 56000: Best = 0.000041, Len = 35
# Sphere Evals 57000: Best = 0.000009, Len = 35
# Sphere Evals 58000: Best = 0.000004, Len = 35
# Sphere Evals 59000: Best = 0.000001, Len = 35
# Sphere Evals 60000: Best = 60.251546, Len = 36
# Sphere Evals 61000: Best = 60.159384, Len = 36
# Sphere Evals 62000: Best = 60.030082, Len = 36
# Sphere Evals 63000: Best = 60.006472, Len = 36
# Sphere Evals 64000: Best = 60.001967, Len = 36
# Sphere Evals 65000: Best = 60.000657, Len = 36
# Sphere Evals 66000: Best = 60.000115, Len = 36
# Sphere Evals 67000: Best = 60.000058, Len = 36
# Sphere Evals 68000: Best = 60.000012, Len = 36
# Sphere Evals 69000: Best = 60.000004, Len = 36
# Sphere Evals 70000: Best = 60.000001, Len = 36
# Sphere Evals 71000: Best = 60.000000, Len = 36
# Sphere Evals 72000: Best = 60.000000, Len = 36
# Sphere Evals 73000: Best = 60.000000, Len = 36
# Sphere Evals 74000: Best = 73.787014, Len = 37
# Sphere Evals 75000: Best = 73.678044, Len = 37
# Sphere Evals 76000: Best = 70.362433, Len = 37
# Sphere Evals 77000: Best = 70.549306, Len = 37
# Sphere Evals 78000: Best = 70.199908, Len = 37
# Sphere Evals 79000: Best = 70.061838, Len = 37
# Sphere Evals 80000: Best = 70.020752, Len = 37
# Sphere Evals 81000: Best = 70.004839, Len = 37
# Sphere Evals 82000: Best = 70.001435, Len = 37
# Sphere Evals 83000: Best = 70.000439, Len = 37
# Sphere Evals 84000: Best = 70.000155, Len = 37
# Sphere Evals 85000: Best = 70.000028, Len = 37
# Sphere Evals 86000: Best = 70.000010, Len = 37
# Sphere Evals 87000: Best = 70.000003, Len = 37
# Sphere Evals 88000: Best = 70.000001, Len = 37
# Sphere Evals 89000: Best = 60.000000, Len = 36
# Sphere Evals 90000: Best = 60.000000, Len = 36
# Sphere Evals 91000: Best = 60.000000, Len = 36
# Sphere Evals 92000: Best = 60.000000, Len = 36
# Sphere Evals 93000: Best = 60.000000, Len = 36
# Sphere Evals 94000: Best = 60.000000, Len = 36
# Sphere Evals 95000: Best = 60.000000, Len = 36
# Sphere Evals 96000: Best = 0.000000, Len = 35
# Sphere Evals 97000: Best = 0.000000, Len = 35
# Sphere Evals 98000: Best = 0.000000, Len = 35
# Sphere Evals 99000: Best = 0.000000, Len = 35
# Sphere Evals 100000: Best = 0.000000, Len = 35
# Sphere Evals 1000: Best = 22.951566, Len = 30
# Sphere Evals 2000: Best = 3.773715, Len = 30
# Sphere Evals 3000: Best = 0.693414, Len = 30
# Sphere Evals 4000: Best = 0.157173, Len = 30
# Sphere Evals 5000: Best = 0.029807, Len = 30
# Sphere Evals 6000: Best = 0.006520, Len = 30
# Sphere Evals 7000: Best = 0.001343, Len = 30
# Sphere Evals 8000: Best = 0.000387, Len = 30
# Sphere Evals 9000: Best = 0.000091, Len = 30
# Sphere Evals 10000: Best = 0.000020, Len = 30
# Sphere Evals 11000: Best = 0.000006, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 29
# Sphere Evals 16000: Best = 0.000000, Len = 29
# Sphere Evals 17000: Best = 0.000000, Len = 29
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 29
# Sphere Evals 20000: Best = 0.000000, Len = 29
# Sphere Evals 21000: Best = 0.000000, Len = 29
# Sphere Evals 22000: Best = 2.122949, Len = 30
# Sphere Evals 23000: Best = 2.052640, Len = 30
# Sphere Evals 24000: Best = 0.235739, Len = 30
# Sphere Evals 25000: Best = 0.210527, Len = 30
# Sphere Evals 26000: Best = 0.048639, Len = 30
# Sphere Evals 27000: Best = 0.014927, Len = 30
# Sphere Evals 28000: Best = 0.003303, Len = 30
# Sphere Evals 29000: Best = 0.001205, Len = 30
# Sphere Evals 30000: Best = 0.000348, Len = 30
# Sphere Evals 31000: Best = 0.000085, Len = 30
# Sphere Evals 32000: Best = 0.000023, Len = 30
# Sphere Evals 33000: Best = 0.043687, Len = 31
# Sphere Evals 34000: Best = 0.005564, Len = 31
# Sphere Evals 35000: Best = 0.002227, Len = 31
# Sphere Evals 36000: Best = 0.919319, Len = 32
# Sphere Evals 37000: Best = 0.383659, Len = 33
# Sphere Evals 38000: Best = 0.075118, Len = 32
# Sphere Evals 39000: Best = 0.037312, Len = 32
# Sphere Evals 40000: Best = 0.012015, Len = 32
# Sphere Evals 41000: Best = 0.003657, Len = 32
# Sphere Evals 42000: Best = 0.000808, Len = 32
# Sphere Evals 43000: Best = 0.000174, Len = 32
# Sphere Evals 44000: Best = 3.419763, Len = 34
# Sphere Evals 45000: Best = 0.633066, Len = 34
# Sphere Evals 46000: Best = 0.332365, Len = 34
# Sphere Evals 47000: Best = 0.097175, Len = 34
# Sphere Evals 48000: Best = 0.046094, Len = 34
# Sphere Evals 49000: Best = 0.020462, Len = 34
# Sphere Evals 50000: Best = 0.007002, Len = 34
# Sphere Evals 51000: Best = 0.001733, Len = 34
# Sphere Evals 52000: Best = 0.000431, Len = 34
# Sphere Evals 53000: Best = 0.000071, Len = 34
# Sphere Evals 54000: Best = 0.000029, Len = 34
# Sphere Evals 55000: Best = 0.000004, Len = 34
# Sphere Evals 56000: Best = 0.000001, Len = 34
# Sphere Evals 57000: Best = 0.350451, Len = 35
# Sphere Evals 58000: Best = 60.266224, Len = 36
# Sphere Evals 59000: Best = 60.342487, Len = 36
# Sphere Evals 60000: Best = 60.135368, Len = 36
# Sphere Evals 61000: Best = 60.039454, Len = 36
# Sphere Evals 62000: Best = 60.015220, Len = 36
# Sphere Evals 63000: Best = 60.005367, Len = 36
# Sphere Evals 64000: Best = 60.001882, Len = 36
# Sphere Evals 65000: Best = 60.000653, Len = 36
# Sphere Evals 66000: Best = 60.000215, Len = 36
# Sphere Evals 67000: Best = 60.000064, Len = 36
# Sphere Evals 68000: Best = 60.000019, Len = 36
# Sphere Evals 69000: Best = 60.000006, Len = 36
# Sphere Evals 70000: Best = 60.000002, Len = 36
# Sphere Evals 71000: Best = 60.000001, Len = 36
# Sphere Evals 72000: Best = 60.000000, Len = 36
# Sphere Evals 73000: Best = 60.000000, Len = 36
# Sphere Evals 74000: Best = 60.000000, Len = 36
# Sphere Evals 75000: Best = 60.000000, Len = 36
# Sphere Evals 76000: Best = 60.000000, Len = 36
# Sphere Evals 77000: Best = 60.000000, Len = 36
# Sphere Evals 78000: Best = 60.000000, Len = 36
# Sphere Evals 79000: Best = 60.000000, Len = 36
# Sphere Evals 80000: Best = 60.000000, Len = 36
# Sphere Evals 81000: Best = 60.000000, Len = 36
# Sphere Evals 82000: Best = 60.000000, Len = 36
# Sphere Evals 83000: Best = 60.000000, Len = 36
# Sphere Evals 84000: Best = 60.000000, Len = 36
# Sphere Evals 85000: Best = 60.000000, Len = 36
# Sphere Evals 86000: Best = 60.000000, Len = 36
# Sphere Evals 87000: Best = 60.000000, Len = 36
# Sphere Evals 88000: Best = 71.630437, Len = 37
# Sphere Evals 89000: Best = 71.629686, Len = 37
# Sphere Evals 90000: Best = 71.576455, Len = 37
# Sphere Evals 91000: Best = 70.270432, Len = 37
# Sphere Evals 92000: Best = 70.215503, Len = 37
# Sphere Evals 93000: Best = 70.064186, Len = 37
# Sphere Evals 94000: Best = 70.021274, Len = 37
# Sphere Evals 95000: Best = 60.006997, Len = 36
# Sphere Evals 96000: Best = 60.002442, Len = 36
# Sphere Evals 97000: Best = 0.000878, Len = 34
# Sphere Evals 98000: Best = 0.000226, Len = 34
# Sphere Evals 99000: Best = 2.234495, Len = 35
# Sphere Evals 100000: Best = 0.513060, Len = 35
# Sphere Evals 1000: Best = 22.671033, Len = 30
# Sphere Evals 2000: Best = 5.478447, Len = 30
# Sphere Evals 3000: Best = 1.220429, Len = 30
# Sphere Evals 4000: Best = 0.180699, Len = 29
# Sphere Evals 5000: Best = 0.032868, Len = 29
# Sphere Evals 6000: Best = 0.006359, Len = 29
# Sphere Evals 7000: Best = 0.001264, Len = 29
# Sphere Evals 8000: Best = 0.000216, Len = 29
# Sphere Evals 9000: Best = 0.000057, Len = 29
# Sphere Evals 10000: Best = 0.000014, Len = 29
# Sphere Evals 11000: Best = 0.000005, Len = 29
# Sphere Evals 12000: Best = 0.000001, Len = 29
# Sphere Evals 13000: Best = 0.000000, Len = 29
# Sphere Evals 14000: Best = 0.000000, Len = 29
# Sphere Evals 15000: Best = 0.000000, Len = 29
# Sphere Evals 16000: Best = 0.000000, Len = 29
# Sphere Evals 17000: Best = 0.000000, Len = 29
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 29
# Sphere Evals 20000: Best = 0.000000, Len = 29
# Sphere Evals 21000: Best = 0.000000, Len = 29
# Sphere Evals 22000: Best = 0.000000, Len = 28
# Sphere Evals 23000: Best = 0.000000, Len = 28
# Sphere Evals 24000: Best = 0.000000, Len = 28
# Sphere Evals 25000: Best = 0.000000, Len = 28
# Sphere Evals 26000: Best = 0.000000, Len = 28
# Sphere Evals 27000: Best = 0.000000, Len = 28
# Sphere Evals 28000: Best = 0.000000, Len = 28
# Sphere Evals 29000: Best = 0.000000, Len = 27
# Sphere Evals 30000: Best = 0.000000, Len = 27
# Sphere Evals 31000: Best = 0.000000, Len = 27
# Sphere Evals 32000: Best = 0.037173, Len = 28
# Sphere Evals 33000: Best = 0.000000, Len = 27
# Sphere Evals 34000: Best = 0.000000, Len = 27
# Sphere Evals 35000: Best = 0.000000, Len = 27
# Sphere Evals 36000: Best = 0.000000, Len = 27
# Sphere Evals 37000: Best = 0.000000, Len = 27
# Sphere Evals 38000: Best = 0.000000, Len = 27
# Sphere Evals 39000: Best = 0.000000, Len = 27
# Sphere Evals 40000: Best = 0.000000, Len = 27
# Sphere Evals 41000: Best = 0.000000, Len = 27
# Sphere Evals 42000: Best = 0.000000, Len = 27
# Sphere Evals 43000: Best = 0.000000, Len = 27
# Sphere Evals 44000: Best = 0.000000, Len = 27
# Sphere Evals 45000: Best = 0.000000, Len = 27
# Sphere Evals 46000: Best = 0.000000, Len = 27
# Sphere Evals 47000: Best = 0.000000, Len = 26
# Sphere Evals 48000: Best = 0.000000, Len = 26
# Sphere Evals 49000: Best = 0.000000, Len = 26
# Sphere Evals 50000: Best = 0.000000, Len = 26
# Sphere Evals 51000: Best = 0.000000, Len = 26
# Sphere Evals 52000: Best = 0.000000, Len = 26
# Sphere Evals 53000: Best = 0.000000, Len = 26
# Sphere Evals 54000: Best = 0.000000, Len = 26
# Sphere Evals 55000: Best = 0.000000, Len = 26
# Sphere Evals 56000: Best = 0.000000, Len = 26
# Sphere Evals 57000: Best = 0.000000, Len = 26
# Sphere Evals 58000: Best = 0.000000, Len = 26
# Sphere Evals 59000: Best = 0.000000, Len = 26
# Sphere Evals 60000: Best = 0.000000, Len = 26
# Sphere Evals 61000: Best = 0.000000, Len = 26
# Sphere Evals 62000: Best = 0.000000, Len = 26
# Sphere Evals 63000: Best = 0.000000, Len = 26
# Sphere Evals 64000: Best = 0.000000, Len = 26
# Sphere Evals 65000: Best = 0.000000, Len = 25
# Sphere Evals 66000: Best = 0.000000, Len = 25
# Sphere Evals 67000: Best = 0.000000, Len = 25
# Sphere Evals 68000: Best = 0.000000, Len = 25
# Sphere Evals 69000: Best = 0.000000, Len = 25
# Sphere Evals 70000: Best = 0.000000, Len = 25
# Sphere Evals 71000: Best = 0.000000, Len = 25
# Sphere Evals 72000: Best = 0.000000, Len = 25
# Sphere Evals 73000: Best = 0.000000, Len = 25
# Sphere Evals 74000: Best = 0.000000, Len = 25
# Sphere Evals 75000: Best = 0.000000, Len = 25
# Sphere Evals 76000: Best = 0.000000, Len = 25
# Sphere Evals 77000: Best = 0.000000, Len = 25
# Sphere Evals 78000: Best = 0.000000, Len = 25
# Sphere Evals 79000: Best = 0.000000, Len = 25
# Sphere Evals 80000: Best = 0.000000, Len = 25
# Sphere Evals 81000: Best = 0.000000, Len = 25
# Sphere Evals 82000: Best = 0.000000, Len = 25
# Sphere Evals 83000: Best = 0.000000, Len = 25
# Sphere Evals 84000: Best = 0.000000, Len = 25
# Sphere Evals 85000: Best = 0.000000, Len = 25
# Sphere Evals 86000: Best = 0.000000, Len = 25
# Sphere Evals 87000: Best = 0.000000, Len = 25
# Sphere Evals 88000: Best = 0.000000, Len = 25
# Sphere Evals 89000: Best = 0.000000, Len = 25
# Sphere Evals 90000: Best = 0.000000, Len = 25
# Sphere Evals 91000: Best = 0.000000, Len = 25
# Sphere Evals 92000: Best = 0.000000, Len = 25
# Sphere Evals 93000: Best = 0.000000, Len = 25
# Sphere Evals 94000: Best = 0.000000, Len = 25
# Sphere Evals 95000: Best = 0.000000, Len = 25
# Sphere Evals 96000: Best = 0.000000, Len = 25
# Sphere Evals 97000: Best = 0.000000, Len = 25
# Sphere Evals 98000: Best = 0.000000, Len = 25
# Sphere Evals 99000: Best = 0.000000, Len = 25
# Sphere Evals 100000: Best = 0.000000, Len = 25
# Sphere Evals 1000: Best = 30.022805, Len = 30
# Sphere Evals 2000: Best = 5.546236, Len = 30
# Sphere Evals 3000: Best = 1.195344, Len = 30
# Sphere Evals 4000: Best = 0.207734, Len = 30
# Sphere Evals 5000: Best = 0.024260, Len = 30
# Sphere Evals 6000: Best = 0.005515, Len = 30
# Sphere Evals 7000: Best = 0.001355, Len = 30
# Sphere Evals 8000: Best = 0.000222, Len = 30
# Sphere Evals 9000: Best = 0.000046, Len = 30
# Sphere Evals 10000: Best = 0.000010, Len = 30
# Sphere Evals 11000: Best = 0.000003, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 29
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 29
# Sphere Evals 20000: Best = 0.918258, Len = 30
# Sphere Evals 21000: Best = 0.851074, Len = 30
# Sphere Evals 22000: Best = 0.247294, Len = 30
# Sphere Evals 23000: Best = 0.041715, Len = 30
# Sphere Evals 24000: Best = 0.010443, Len = 30
# Sphere Evals 25000: Best = 0.002872, Len = 30
# Sphere Evals 26000: Best = 0.000859, Len = 30
# Sphere Evals 27000: Best = 0.000125, Len = 30
# Sphere Evals 28000: Best = 0.000033, Len = 30
# Sphere Evals 29000: Best = 0.000008, Len = 30
# Sphere Evals 30000: Best = 0.000002, Len = 30
# Sphere Evals 31000: Best = 0.000001, Len = 30
# Sphere Evals 32000: Best = 0.000000, Len = 30
# Sphere Evals 33000: Best = 0.000000, Len = 30
# Sphere Evals 34000: Best = 0.000000, Len = 30
# Sphere Evals 35000: Best = 0.000000, Len = 30
# Sphere Evals 36000: Best = 0.000000, Len = 30
# Sphere Evals 37000: Best = 0.000000, Len = 30
# Sphere Evals 38000: Best = 0.000000, Len = 30
# Sphere Evals 39000: Best = 0.000000, Len = 30
# Sphere Evals 40000: Best = 0.000000, Len = 30
# Sphere Evals 41000: Best = 0.000000, Len = 29
# Sphere Evals 42000: Best = 0.000000, Len = 29
# Sphere Evals 43000: Best = 0.000000, Len = 29
# Sphere Evals 44000: Best = 0.000000, Len = 29
# Sphere Evals 45000: Best = 0.000000, Len = 29
# Sphere Evals 46000: Best = 0.000000, Len = 29
# Sphere Evals 47000: Best = 0.000000, Len = 29
# Sphere Evals 48000: Best = 0.000000, Len = 29
# Sphere Evals 49000: Best = 0.000000, Len = 29
# Sphere Evals 50000: Best = 0.000000, Len = 29
# Sphere Evals 51000: Best = 0.000000, Len = 29
# Sphere Evals 52000: Best = 0.000104, Len = 30
# Sphere Evals 53000: Best = 0.000104, Len = 30
# Sphere Evals 54000: Best = 0.004854, Len = 31
# Sphere Evals 55000: Best = 1.165676, Len = 32
# Sphere Evals 56000: Best = 0.334865, Len = 32
# Sphere Evals 57000: Best = 0.203337, Len = 32
# Sphere Evals 58000: Best = 0.054420, Len = 31
# Sphere Evals 59000: Best = 0.023007, Len = 31
# Sphere Evals 60000: Best = 0.006125, Len = 31
# Sphere Evals 61000: Best = 0.001822, Len = 31
# Sphere Evals 62000: Best = 0.000541, Len = 31
# Sphere Evals 63000: Best = 0.000147, Len = 31
# Sphere Evals 64000: Best = 0.000035, Len = 31
# Sphere Evals 65000: Best = 0.000010, Len = 30
# Sphere Evals 66000: Best = 0.000001, Len = 30
# Sphere Evals 67000: Best = 0.004148, Len = 31
# Sphere Evals 68000: Best = 0.000004, Len = 30
# Sphere Evals 69000: Best = 0.000001, Len = 30
# Sphere Evals 70000: Best = 0.000000, Len = 30
# Sphere Evals 71000: Best = 0.000000, Len = 29
# Sphere Evals 72000: Best = 0.000000, Len = 29
# Sphere Evals 73000: Best = 3.339253, Len = 30
# Sphere Evals 74000: Best = 3.132080, Len = 30
# Sphere Evals 75000: Best = 0.860599, Len = 30
# Sphere Evals 76000: Best = 0.336808, Len = 30
# Sphere Evals 77000: Best = 0.083315, Len = 30
# Sphere Evals 78000: Best = 0.037606, Len = 30
# Sphere Evals 79000: Best = 0.008934, Len = 30
# Sphere Evals 80000: Best = 0.001463, Len = 30
# Sphere Evals 81000: Best = 0.000362, Len = 30
# Sphere Evals 82000: Best = 0.000090, Len = 30
# Sphere Evals 83000: Best = 0.000014, Len = 30
# Sphere Evals 84000: Best = 0.000006, Len = 30
# Sphere Evals 85000: Best = 0.000002, Len = 30
# Sphere Evals 86000: Best = 0.000000, Len = 30
# Sphere Evals 87000: Best = 0.000000, Len = 30
# Sphere Evals 88000: Best = 0.000000, Len = 30
# Sphere Evals 89000: Best = 0.000000, Len = 30
# Sphere Evals 90000: Best = 0.938890, Len = 31
# Sphere Evals 91000: Best = 0.878215, Len = 32
# Sphere Evals 92000: Best = 0.223805, Len = 32
# Sphere Evals 93000: Best = 0.083576, Len = 32
# Sphere Evals 94000: Best = 0.033148, Len = 32
# Sphere Evals 95000: Best = 0.014368, Len = 32
# Sphere Evals 96000: Best = 0.002320, Len = 32
# Sphere Evals 97000: Best = 0.000912, Len = 32
# Sphere Evals 98000: Best = 0.000197, Len = 32
# Sphere Evals 99000: Best = 0.000057, Len = 32
# Sphere Evals 100000: Best = 2.115613, Len = 33
# Sphere Evals 1000: Best = 29.483345, Len = 29
# Sphere Evals 2000: Best = 3.801168, Len = 29
# Sphere Evals 3000: Best = 1.194657, Len = 29
# Sphere Evals 4000: Best = 0.270716, Len = 29
# Sphere Evals 5000: Best = 0.043554, Len = 29
# Sphere Evals 6000: Best = 0.007884, Len = 29
# Sphere Evals 7000: Best = 0.001188, Len = 29
# Sphere Evals 8000: Best = 0.000271, Len = 29
# Sphere Evals 9000: Best = 0.000066, Len = 29
# Sphere Evals 10000: Best = 0.000015, Len = 29
# Sphere Evals 11000: Best = 0.000007, Len = 29
# Sphere Evals 12000: Best = 0.000001, Len = 29
# Sphere Evals 13000: Best = 0.000001, Len = 29
# Sphere Evals 14000: Best = 0.000000, Len = 29
# Sphere Evals 15000: Best = 0.000000, Len = 29
# Sphere Evals 16000: Best = 0.000000, Len = 29
# Sphere Evals 17000: Best = 0.000000, Len = 29
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 29
# Sphere Evals 20000: Best = 0.000000, Len = 29
# Sphere Evals 21000: Best = 0.000000, Len = 29
# Sphere Evals 22000: Best = 0.000000, Len = 29
# Sphere Evals 23000: Best = 0.000000, Len = 29
# Sphere Evals 24000: Best = 0.000000, Len = 29
# Sphere Evals 25000: Best = 0.000000, Len = 29
# Sphere Evals 26000: Best = 0.000000, Len = 29
# Sphere Evals 27000: Best = 0.000000, Len = 29
# Sphere Evals 28000: Best = 0.000000, Len = 29
# Sphere Evals 29000: Best = 0.000000, Len = 29
# Sphere Evals 30000: Best = 0.000000, Len = 29
# Sphere Evals 31000: Best = 0.000000, Len = 29
# Sphere Evals 32000: Best = 0.000000, Len = 29
# Sphere Evals 33000: Best = 0.000000, Len = 29
# Sphere Evals 34000: Best = 0.000000, Len = 29
# Sphere Evals 35000: Best = 0.000000, Len = 29
# Sphere Evals 36000: Best = 0.000000, Len = 29
# Sphere Evals 37000: Best = 0.000000, Len = 29
# Sphere Evals 38000: Best = 0.000000, Len = 29
# Sphere Evals 39000: Best = 0.000000, Len = 29
# Sphere Evals 40000: Best = 0.000000, Len = 29
# Sphere Evals 41000: Best = 0.000000, Len = 29
# Sphere Evals 42000: Best = 0.000000, Len = 29
# Sphere Evals 43000: Best = 0.000000, Len = 29
# Sphere Evals 44000: Best = 0.000000, Len = 29
# Sphere Evals 45000: Best = 0.000000, Len = 29
# Sphere Evals 46000: Best = 0.000000, Len = 29
# Sphere Evals 47000: Best = 0.000000, Len = 29
# Sphere Evals 48000: Best = 0.000000, Len = 29
# Sphere Evals 49000: Best = 0.000000, Len = 29
# Sphere Evals 50000: Best = 0.000000, Len = 29
# Sphere Evals 51000: Best = 0.000000, Len = 29
# Sphere Evals 52000: Best = 0.000000, Len = 29
# Sphere Evals 53000: Best = 0.000000, Len = 28
# Sphere Evals 54000: Best = 1.571462, Len = 29
# Sphere Evals 55000: Best = 1.571294, Len = 29
# Sphere Evals 56000: Best = 1.550359, Len = 29
# Sphere Evals 57000: Best = 0.173290, Len = 29
# Sphere Evals 58000: Best = 0.342595, Len = 29
# Sphere Evals 59000: Best = 0.063458, Len = 29
# Sphere Evals 60000: Best = 0.009304, Len = 29
# Sphere Evals 61000: Best = 0.190492, Len = 31
# Sphere Evals 62000: Best = 0.109544, Len = 31
# Sphere Evals 63000: Best = 0.043736, Len = 31
# Sphere Evals 64000: Best = 0.028814, Len = 31
# Sphere Evals 65000: Best = 0.009705, Len = 31
# Sphere Evals 66000: Best = 0.001872, Len = 31
# Sphere Evals 67000: Best = 0.000543, Len = 31
# Sphere Evals 68000: Best = 0.000134, Len = 31
# Sphere Evals 69000: Best = 0.000036, Len = 31
# Sphere Evals 70000: Best = 0.000013, Len = 31
# Sphere Evals 71000: Best = 0.000004, Len = 31
# Sphere Evals 72000: Best = 0.000002, Len = 31
# Sphere Evals 73000: Best = 0.000000, Len = 31
# Sphere Evals 74000: Best = 0.000000, Len = 31
# Sphere Evals 75000: Best = 0.000000, Len = 31
# Sphere Evals 76000: Best = 0.000000, Len = 31
# Sphere Evals 77000: Best = 0.000000, Len = 31
# Sphere Evals 78000: Best = 0.000000, Len = 30
# Sphere Evals 79000: Best = 0.000000, Len = 30
# Sphere Evals 80000: Best = 0.000000, Len = 30
# Sphere Evals 81000: Best = 0.000000, Len = 29
# Sphere Evals 82000: Best = 0.000000, Len = 28
# Sphere Evals 83000: Best = 0.000000, Len = 28
# Sphere Evals 84000: Best = 0.000000, Len = 28
# Sphere Evals 85000: Best = 0.000000, Len = 28
# Sphere Evals 86000: Best = 0.000000, Len = 28
# Sphere Evals 87000: Best = 0.000000, Len = 28
# Sphere Evals 88000: Best = 0.000000, Len = 27
# Sphere Evals 89000: Best = 0.000000, Len = 27
# Sphere Evals 90000: Best = 0.000000, Len = 27
# Sphere Evals 91000: Best = 0.000000, Len = 27
# Sphere Evals 92000: Best = 0.000000, Len = 27
# Sphere Evals 93000: Best = 0.000000, Len = 27
# Sphere Evals 94000: Best = 0.000000, Len = 27
# Sphere Evals 95000: Best = 0.000000, Len = 27
# Sphere Evals 96000: Best = 0.000000, Len = 27
# Sphere Evals 97000: Best = 0.000000, Len = 27
# Sphere Evals 98000: Best = 0.000000, Len = 27
# Sphere Evals 99000: Best = 0.000000, Len = 27
# Sphere Evals 100000: Best = 0.000000, Len = 27
# Sphere Evals 1000: Best = 36.108806, Len = 30
# Sphere Evals 2000: Best = 3.996827, Len = 30
# Sphere Evals 3000: Best = 1.134546, Len = 30
# Sphere Evals 4000: Best = 0.213856, Len = 30
# Sphere Evals 5000: Best = 0.054666, Len = 30
# Sphere Evals 6000: Best = 0.008871, Len = 30
# Sphere Evals 7000: Best = 0.002617, Len = 30
# Sphere Evals 8000: Best = 0.000788, Len = 30
# Sphere Evals 9000: Best = 0.000160, Len = 30
# Sphere Evals 10000: Best = 0.000032, Len = 30
# Sphere Evals 11000: Best = 0.000006, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 30
# Sphere Evals 20000: Best = 0.000000, Len = 30
# Sphere Evals 21000: Best = 0.000000, Len = 30
# Sphere Evals 22000: Best = 0.000000, Len = 30
# Sphere Evals 23000: Best = 0.000000, Len = 30
# Sphere Evals 24000: Best = 0.000000, Len = 30
# Sphere Evals 25000: Best = 0.000000, Len = 30
# Sphere Evals 26000: Best = 0.000000, Len = 30
# Sphere Evals 27000: Best = 0.000000, Len = 30
# Sphere Evals 28000: Best = 0.000000, Len = 29
# Sphere Evals 29000: Best = 0.000000, Len = 29
# Sphere Evals 30000: Best = 0.000000, Len = 29
# Sphere Evals 31000: Best = 0.000000, Len = 29
# Sphere Evals 32000: Best = 0.000000, Len = 29
# Sphere Evals 33000: Best = 0.000000, Len = 29
# Sphere Evals 34000: Best = 0.000000, Len = 29
# Sphere Evals 35000: Best = 0.000000, Len = 29
# Sphere Evals 36000: Best = 0.000000, Len = 29
# Sphere Evals 37000: Best = 0.000000, Len = 29
# Sphere Evals 38000: Best = 0.000000, Len = 28
# Sphere Evals 39000: Best = 0.000000, Len = 28
# Sphere Evals 40000: Best = 0.000000, Len = 28
# Sphere Evals 41000: Best = 1.196799, Len = 29
# Sphere Evals 42000: Best = 1.196487, Len = 29
# Sphere Evals 43000: Best = 1.166289, Len = 29
# Sphere Evals 44000: Best = 0.002773, Len = 28
# Sphere Evals 45000: Best = 0.000948, Len = 28
# Sphere Evals 46000: Best = 0.000215, Len = 28
# Sphere Evals 47000: Best = 0.000063, Len = 28
# Sphere Evals 48000: Best = 0.000017, Len = 28
# Sphere Evals 49000: Best = 0.000003, Len = 28
# Sphere Evals 50000: Best = 0.000001, Len = 28
# Sphere Evals 51000: Best = 0.000000, Len = 28
# Sphere Evals 52000: Best = 0.000000, Len = 28
# Sphere Evals 53000: Best = 0.000000, Len = 28
# Sphere Evals 54000: Best = 0.000000, Len = 28
# Sphere Evals 55000: Best = 0.000000, Len = 28
# Sphere Evals 56000: Best = 0.000000, Len = 28
# Sphere Evals 57000: Best = 0.000000, Len = 28
# Sphere Evals 58000: Best = 0.000000, Len = 28
# Sphere Evals 59000: Best = 0.000000, Len = 28
# Sphere Evals 60000: Best = 0.000000, Len = 28
# Sphere Evals 61000: Best = 0.000000, Len = 28
# Sphere Evals 62000: Best = 0.000000, Len = 28
# Sphere Evals 63000: Best = 0.000000, Len = 28
# Sphere Evals 64000: Best = 0.000000, Len = 28
# Sphere Evals 65000: Best = 0.000000, Len = 28
# Sphere Evals 66000: Best = 0.000000, Len = 28
# Sphere Evals 67000: Best = 0.000000, Len = 28
# Sphere Evals 68000: Best = 0.000000, Len = 28
# Sphere Evals 69000: Best = 0.000000, Len = 27
# Sphere Evals 70000: Best = 0.000000, Len = 27
# Sphere Evals 71000: Best = 0.000000, Len = 27
# Sphere Evals 72000: Best = 0.000000, Len = 27
# Sphere Evals 73000: Best = 0.278126, Len = 28
# Sphere Evals 74000: Best = 0.278053, Len = 28
# Sphere Evals 75000: Best = 0.267733, Len = 28
# Sphere Evals 76000: Best = 0.065399, Len = 28
# Sphere Evals 77000: Best = 0.034678, Len = 28
# Sphere Evals 78000: Best = 0.006720, Len = 28
# Sphere Evals 79000: Best = 0.001689, Len = 28
# Sphere Evals 80000: Best = 0.000325, Len = 28
# Sphere Evals 81000: Best = 0.000106, Len = 28
# Sphere Evals 82000: Best = 0.000033, Len = 28
# Sphere Evals 83000: Best = 0.000006, Len = 28
# Sphere Evals 84000: Best = 0.000002, Len = 28
# Sphere Evals 85000: Best = 0.000000, Len = 28
# Sphere Evals 86000: Best = 0.187304, Len = 29
# Sphere Evals 87000: Best = 0.009491, Len = 29
# Sphere Evals 88000: Best = 0.012644, Len = 29
# Sphere Evals 89000: Best = 0.003323, Len = 29
# Sphere Evals 90000: Best = 0.000968, Len = 29
# Sphere Evals 91000: Best = 0.000211, Len = 29
# Sphere Evals 92000: Best = 1.072348, Len = 30
# Sphere Evals 93000: Best = 0.189504, Len = 30
# Sphere Evals 94000: Best = 0.046518, Len = 29
# Sphere Evals 95000: Best = 0.014504, Len = 29
# Sphere Evals 96000: Best = 0.003269, Len = 28
# Sphere Evals 97000: Best = 0.000811, Len = 28
# Sphere Evals 98000: Best = 0.000255, Len = 28
# Sphere Evals 99000: Best = 0.000063, Len = 28
# Sphere Evals 100000: Best = 0.000013, Len = 28
# Sphere Evals 1000: Best = 52.531071, Len = 30
# Sphere Evals 2000: Best = 12.147926, Len = 30
# Sphere Evals 3000: Best = 1.720847, Len = 30
# Sphere Evals 4000: Best = 0.310268, Len = 30
# Sphere Evals 5000: Best = 0.083707, Len = 30
# Sphere Evals 6000: Best = 0.012690, Len = 30
# Sphere Evals 7000: Best = 0.001827, Len = 30
# Sphere Evals 8000: Best = 0.000245, Len = 30
# Sphere Evals 9000: Best = 0.000050, Len = 30
# Sphere Evals 10000: Best = 0.000009, Len = 29
# Sphere Evals 11000: Best = 0.000002, Len = 29
# Sphere Evals 12000: Best = 0.000001, Len = 29
# Sphere Evals 13000: Best = 0.000000, Len = 29
# Sphere Evals 14000: Best = 0.000000, Len = 29
# Sphere Evals 15000: Best = 0.000000, Len = 29
# Sphere Evals 16000: Best = 0.000000, Len = 29
# Sphere Evals 17000: Best = 0.000000, Len = 29
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 28
# Sphere Evals 20000: Best = 0.000000, Len = 28
# Sphere Evals 21000: Best = 0.000000, Len = 28
# Sphere Evals 22000: Best = 0.000000, Len = 28
# Sphere Evals 23000: Best = 0.000000, Len = 28
# Sphere Evals 24000: Best = 0.000000, Len = 28
# Sphere Evals 25000: Best = 0.000000, Len = 28
# Sphere Evals 26000: Best = 0.000000, Len = 28
# Sphere Evals 27000: Best = 0.000000, Len = 28
# Sphere Evals 28000: Best = 0.000000, Len = 28
# Sphere Evals 29000: Best = 0.000000, Len = 28
# Sphere Evals 30000: Best = 0.000000, Len = 28
# Sphere Evals 31000: Best = 0.000000, Len = 28
# Sphere Evals 32000: Best = 0.000000, Len = 28
# Sphere Evals 33000: Best = 0.000000, Len = 28
# Sphere Evals 34000: Best = 0.000000, Len = 28
# Sphere Evals 35000: Best = 0.000000, Len = 28
# Sphere Evals 36000: Best = 0.000000, Len = 28
# Sphere Evals 37000: Best = 0.000000, Len = 28
# Sphere Evals 38000: Best = 0.000000, Len = 28
# Sphere Evals 39000: Best = 0.000000, Len = 28
# Sphere Evals 40000: Best = 0.000000, Len = 28
# Sphere Evals 41000: Best = 0.000000, Len = 28
# Sphere Evals 42000: Best = 0.000000, Len = 28
# Sphere Evals 43000: Best = 0.000000, Len = 28
# Sphere Evals 44000: Best = 0.000000, Len = 28
# Sphere Evals 45000: Best = 0.000000, Len = 28
# Sphere Evals 46000: Best = 0.000000, Len = 28
# Sphere Evals 47000: Best = 0.000000, Len = 28
# Sphere Evals 48000: Best = 0.000000, Len = 28
# Sphere Evals 49000: Best = 0.000000, Len = 28
# Sphere Evals 50000: Best = 0.000000, Len = 28
# Sphere Evals 51000: Best = 0.000000, Len = 28
# Sphere Evals 52000: Best = 0.000000, Len = 28
# Sphere Evals 53000: Best = 0.000000, Len = 28
# Sphere Evals 54000: Best = 0.000000, Len = 28
# Sphere Evals 55000: Best = 0.000000, Len = 28
# Sphere Evals 56000: Best = 0.000000, Len = 28
# Sphere Evals 57000: Best = 0.000000, Len = 28
# Sphere Evals 58000: Best = 0.000000, Len = 28
# Sphere Evals 59000: Best = 0.000000, Len = 28
# Sphere Evals 60000: Best = 0.000000, Len = 28
# Sphere Evals 61000: Best = 0.000000, Len = 28
# Sphere Evals 62000: Best = 0.000000, Len = 28
# Sphere Evals 63000: Best = 0.000000, Len = 28
# Sphere Evals 64000: Best = 0.000000, Len = 28
# Sphere Evals 65000: Best = 0.185432, Len = 29
# Sphere Evals 66000: Best = 0.185420, Len = 29
# Sphere Evals 67000: Best = 0.183933, Len = 29
# Sphere Evals 68000: Best = 0.073276, Len = 29
# Sphere Evals 69000: Best = 0.045535, Len = 29
# Sphere Evals 70000: Best = 0.006097, Len = 29
# Sphere Evals 71000: Best = 0.001772, Len = 29
# Sphere Evals 72000: Best = 0.000644, Len = 29
# Sphere Evals 73000: Best = 0.000165, Len = 29
# Sphere Evals 74000: Best = 0.000052, Len = 29
# Sphere Evals 75000: Best = 0.000015, Len = 29
# Sphere Evals 76000: Best = 0.000003, Len = 29
# Sphere Evals 77000: Best = 1.313361, Len = 30
# Sphere Evals 78000: Best = 0.174630, Len = 30
# Sphere Evals 79000: Best = 0.098611, Len = 30
# Sphere Evals 80000: Best = 0.026280, Len = 30
# Sphere Evals 81000: Best = 0.005813, Len = 30
# Sphere Evals 82000: Best = 0.002099, Len = 30
# Sphere Evals 83000: Best = 0.000377, Len = 30
# Sphere Evals 84000: Best = 0.000089, Len = 30
# Sphere Evals 85000: Best = 0.000017, Len = 30
# Sphere Evals 86000: Best = 0.000005, Len = 30
# Sphere Evals 87000: Best = 0.000002, Len = 30
# Sphere Evals 88000: Best = 0.000001, Len = 30
# Sphere Evals 89000: Best = 0.000000, Len = 30
# Sphere Evals 90000: Best = 0.000000, Len = 30
# Sphere Evals 91000: Best = 0.000000, Len = 30
# Sphere Evals 92000: Best = 0.000000, Len = 30
# Sphere Evals 93000: Best = 0.000000, Len = 30
# Sphere Evals 94000: Best = 0.000000, Len = 30
# Sphere Evals 95000: Best = 0.000000, Len = 30
# Sphere Evals 96000: Best = 0.000000, Len = 30
# Sphere Evals 97000: Best = 0.000000, Len = 30
# Sphere Evals 98000: Best = 0.000000, Len = 30
# Sphere Evals 99000: Best = 0.000000, Len = 30
# Sphere Evals 100000: Best = 0.000000, Len = 30
# Sphere Evals 1000: Best = 45.245865, Len = 30
# Sphere Evals 2000: Best = 8.478193, Len = 30
# Sphere Evals 3000: Best = 1.844916, Len = 30
# Sphere Evals 4000: Best = 0.325321, Len = 30
# Sphere Evals 5000: Best = 0.036862, Len = 30
# Sphere Evals 6000: Best = 0.012691, Len = 30
# Sphere Evals 7000: Best = 0.002426, Len = 30
# Sphere Evals 8000: Best = 0.000574, Len = 30
# Sphere Evals 9000: Best = 0.000140, Len = 30
# Sphere Evals 10000: Best = 0.000035, Len = 30
# Sphere Evals 11000: Best = 0.000007, Len = 30
# Sphere Evals 12000: Best = 0.000002, Len = 30
# Sphere Evals 13000: Best = 0.000001, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 30
# Sphere Evals 20000: Best = 0.000000, Len = 30
# Sphere Evals 21000: Best = 0.000000, Len = 30
# Sphere Evals 22000: Best = 0.000000, Len = 30
# Sphere Evals 23000: Best = 0.000000, Len = 30
# Sphere Evals 24000: Best = 0.000000, Len = 30
# Sphere Evals 25000: Best = 0.000000, Len = 30
# Sphere Evals 26000: Best = 0.000000, Len = 30
# Sphere Evals 27000: Best = 0.000000, Len = 30
# Sphere Evals 28000: Best = 0.000000, Len = 30
# Sphere Evals 29000: Best = 0.000000, Len = 30
# Sphere Evals 30000: Best = 0.000000, Len = 30
# Sphere Evals 31000: Best = 0.223935, Len = 31
# Sphere Evals 32000: Best = 0.223700, Len = 31
# Sphere Evals 33000: Best = 0.201276, Len = 31
# Sphere Evals 34000: Best = 0.062167, Len = 31
# Sphere Evals 35000: Best = 0.026612, Len = 31
# Sphere Evals 36000: Best = 0.004541, Len = 31
# Sphere Evals 37000: Best = 0.001398, Len = 31
# Sphere Evals 38000: Best = 0.000465, Len = 31
# Sphere Evals 39000: Best = 0.000130, Len = 31
# Sphere Evals 40000: Best = 0.000023, Len = 31
# Sphere Evals 41000: Best = 0.000004, Len = 31
# Sphere Evals 42000: Best = 0.000001, Len = 31
# Sphere Evals 43000: Best = 0.000000, Len = 31
# Sphere Evals 44000: Best = 0.000000, Len = 31
# Sphere Evals 45000: Best = 0.000000, Len = 31
# Sphere Evals 46000: Best = 0.000000, Len = 31
# Sphere Evals 47000: Best = 0.000000, Len = 31
# Sphere Evals 48000: Best = 0.000000, Len = 31
# Sphere Evals 49000: Best = 0.000000, Len = 31
# Sphere Evals 50000: Best = 0.000000, Len = 31
# Sphere Evals 51000: Best = 0.000000, Len = 31
# Sphere Evals 52000: Best = 0.000000, Len = 31
# Sphere Evals 53000: Best = 0.000000, Len = 31
# Sphere Evals 54000: Best = 0.000000, Len = 30
# Sphere Evals 55000: Best = 0.000000, Len = 30
# Sphere Evals 56000: Best = 5.375447, Len = 32
# Sphere Evals 57000: Best = 5.375101, Len = 32
# Sphere Evals 58000: Best = 5.346670, Len = 32
# Sphere Evals 59000: Best = 2.938477, Len = 32
# Sphere Evals 60000: Best = 1.434929, Len = 32
# Sphere Evals 61000: Best = 0.435310, Len = 32
# Sphere Evals 62000: Best = 0.099020, Len = 32
# Sphere Evals 63000: Best = 0.030410, Len = 32
# Sphere Evals 64000: Best = 0.005119, Len = 32
# Sphere Evals 65000: Best = 0.002016, Len = 32
# Sphere Evals 66000: Best = 0.000528, Len = 32
# Sphere Evals 67000: Best = 0.000221, Len = 32
# Sphere Evals 68000: Best = 0.000047, Len = 32
# Sphere Evals 69000: Best = 0.000025, Len = 32
# Sphere Evals 70000: Best = 0.000006, Len = 32
# Sphere Evals 71000: Best = 0.000002, Len = 32
# Sphere Evals 72000: Best = 0.000001, Len = 32
# Sphere Evals 73000: Best = 0.000000, Len = 32
# Sphere Evals 74000: Best = 0.000000, Len = 32
# Sphere Evals 75000: Best = 0.000000, Len = 32
# Sphere Evals 76000: Best = 0.000000, Len = 32
# Sphere Evals 77000: Best = 0.000000, Len = 32
# Sphere Evals 78000: Best = 0.000000, Len = 32
# Sphere Evals 79000: Best = 0.000000, Len = 32
# Sphere Evals 80000: Best = 0.000000, Len = 32
# Sphere Evals 81000: Best = 0.000000, Len = 32
# Sphere Evals 82000: Best = 0.000000, Len = 32
# Sphere Evals 83000: Best = 0.000000, Len = 32
# Sphere Evals 84000: Best = 0.000000, Len = 32
# Sphere Evals 85000: Best = 0.000000, Len = 32
# Sphere Evals 86000: Best = 0.000000, Len = 32
# Sphere Evals 87000: Best = 0.000000, Len = 32
# Sphere Evals 88000: Best = 0.000000, Len = 32
# Sphere Evals 89000: Best = 0.000000, Len = 31
# Sphere Evals 90000: Best = 0.000000, Len = 31
# Sphere Evals 91000: Best = 0.000000, Len = 31
# Sphere Evals 92000: Best = 0.000000, Len = 31
# Sphere Evals 93000: Best = 0.000000, Len = 31
# Sphere Evals 94000: Best = 0.000000, Len = 31
# Sphere Evals 95000: Best = 0.000000, Len = 31
# Sphere Evals 96000: Best = 0.000000, Len = 31
# Sphere Evals 97000: Best = 0.000000, Len = 31
# Sphere Evals 98000: Best = 0.000000, Len = 31
# Sphere Evals 99000: Best = 0.000000, Len = 31
# Sphere Evals 100000: Best = 0.000000, Len = 31
# Sphere Evals 1000: Best = 66.014960, Len = 30
# Sphere Evals 2000: Best = 12.112490, Len = 30
# Sphere Evals 3000: Best = 3.248185, Len = 30
# Sphere Evals 4000: Best = 0.527849, Len = 30
# Sphere Evals 5000: Best = 0.066253, Len = 30
# Sphere Evals 6000: Best = 0.010606, Len = 30
# Sphere Evals 7000: Best = 0.003620, Len = 30
# Sphere Evals 8000: Best = 0.001600, Len = 30
# Sphere Evals 9000: Best = 0.000252, Len = 30
# Sphere Evals 10000: Best = 0.000060, Len = 30
# Sphere Evals 11000: Best = 0.000013, Len = 30
# Sphere Evals 12000: Best = 0.000003, Len = 30
# Sphere Evals 13000: Best = 0.000001, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 2.193904, Len = 31
# Sphere Evals 20000: Best = 0.672133, Len = 31
# Sphere Evals 21000: Best = 0.297154, Len = 31
# Sphere Evals 22000: Best = 0.073956, Len = 31
# Sphere Evals 23000: Best = 0.021260, Len = 31
# Sphere Evals 24000: Best = 0.005768, Len = 31
# Sphere Evals 25000: Best = 0.000870, Len = 31
# Sphere Evals 26000: Best = 0.000413, Len = 31
# Sphere Evals 27000: Best = 0.000110, Len = 31
# Sphere Evals 28000: Best = 0.000052, Len = 31
# Sphere Evals 29000: Best = 0.000011, Len = 31
# Sphere Evals 30000: Best = 0.000004, Len = 29
# Sphere Evals 31000: Best = 0.000001, Len = 29
# Sphere Evals 32000: Best = 0.000000, Len = 29
# Sphere Evals 33000: Best = 0.000000, Len = 29
# Sphere Evals 34000: Best = 0.000000, Len = 29
# Sphere Evals 35000: Best = 0.000000, Len = 29
# Sphere Evals 36000: Best = 0.000000, Len = 29
# Sphere Evals 37000: Best = 0.000000, Len = 28
# Sphere Evals 38000: Best = 0.000000, Len = 27
# Sphere Evals 39000: Best = 0.000000, Len = 27
# Sphere Evals 40000: Best = 0.000000, Len = 27
# Sphere Evals 41000: Best = 0.000000, Len = 27
# Sphere Evals 42000: Best = 0.000000, Len = 27
# Sphere Evals 43000: Best = 0.000000, Len = 27
# ...
# SantaFe Evals 79000: Best = -34.000000, Len = 98
# SantaFe Evals 80000: Best = -34.000000, Len = 98
# SantaFe Evals 81000: Best = -34.000000, Len = 98
# SantaFe Evals 82000: Best = -34.000000, Len = 98
# SantaFe Evals 83000: Best = -34.000000, Len = 98
# SantaFe Evals 84000: Best = -34.000000, Len = 98
# SantaFe Evals 85000: Best = -34.000000, Len = 98
# SantaFe Evals 86000: Best = -34.000000, Len = 98
# SantaFe Evals 87000: Best = -34.000000, Len = 98
# SantaFe Evals 88000: Best = -34.000000, Len = 98
# SantaFe Evals 89000: Best = -34.000000, Len = 98
# SantaFe Evals 90000: Best = -34.000000, Len = 98
# SantaFe Evals 91000: Best = -34.000000, Len = 98
# SantaFe Evals 92000: Best = -34.000000, Len = 98
# SantaFe Evals 93000: Best = -34.000000, Len = 98
# SantaFe Evals 94000: Best = -34.000000, Len = 98
# SantaFe Evals 95000: Best = -34.000000, Len = 98
# SantaFe Evals 96000: Best = -34.000000, Len = 98
# SantaFe Evals 97000: Best = -34.000000, Len = 98
# SantaFe Evals 98000: Best = -34.000000, Len = 97
# SantaFe Evals 99000: Best = -34.000000, Len = 97
# SantaFe Evals 100000: Best = -34.000000, Len = 97
# SantaFe Evals 1000: Best = -10.000000, Len = 100
# SantaFe Evals 2000: Best = -17.000000, Len = 99
# SantaFe Evals 3000: Best = -11.000000, Len = 99
# SantaFe Evals 4000: Best = -13.000000, Len = 99
# SantaFe Evals 5000: Best = -16.000000, Len = 99
# SantaFe Evals 6000: Best = -14.000000, Len = 99
# SantaFe Evals 7000: Best = -18.000000, Len = 99
# SantaFe Evals 8000: Best = -16.000000, Len = 99
# SantaFe Evals 9000: Best = -17.000000, Len = 99
# SantaFe Evals 10000: Best = -18.000000, Len = 99
# SantaFe Evals 11000: Best = -16.000000, Len = 99
# SantaFe Evals 12000: Best = -24.000000, Len = 100
# SantaFe Evals 13000: Best = -22.000000, Len = 99
# SantaFe Evals 14000: Best = -21.000000, Len = 99
# SantaFe Evals 15000: Best = -24.000000, Len = 99
# SantaFe Evals 16000: Best = -30.000000, Len = 99
# SantaFe Evals 17000: Best = -29.000000, Len = 100
# SantaFe Evals 18000: Best = -34.000000, Len = 100
# SantaFe Evals 19000: Best = -36.000000, Len = 100
# SantaFe Evals 20000: Best = -39.000000, Len = 100
# SantaFe Evals 21000: Best = -41.000000, Len = 100
# SantaFe Evals 22000: Best = -41.000000, Len = 100
# SantaFe Evals 23000: Best = -42.000000, Len = 100
# SantaFe Evals 24000: Best = -42.000000, Len = 100
# SantaFe Evals 25000: Best = -42.000000, Len = 100
# SantaFe Evals 26000: Best = -42.000000, Len = 99
# SantaFe Evals 27000: Best = -42.000000, Len = 99
# SantaFe Evals 28000: Best = -42.000000, Len = 99
# SantaFe Evals 29000: Best = -42.000000, Len = 99
# SantaFe Evals 30000: Best = -42.000000, Len = 99
# SantaFe Evals 31000: Best = -42.000000, Len = 99
# SantaFe Evals 32000: Best = -42.000000, Len = 99
# SantaFe Evals 33000: Best = -42.000000, Len = 99
# SantaFe Evals 34000: Best = -42.000000, Len = 99
# SantaFe Evals 35000: Best = -42.000000, Len = 99
# SantaFe Evals 36000: Best = -42.000000, Len = 99
# SantaFe Evals 37000: Best = -42.000000, Len = 99
# SantaFe Evals 38000: Best = -42.000000, Len = 99
# SantaFe Evals 39000: Best = -42.000000, Len = 99
# SantaFe Evals 40000: Best = -42.000000, Len = 99
# SantaFe Evals 41000: Best = -42.000000, Len = 99
# SantaFe Evals 42000: Best = -42.000000, Len = 99
# SantaFe Evals 43000: Best = -42.000000, Len = 99
# SantaFe Evals 44000: Best = -42.000000, Len = 99
# SantaFe Evals 45000: Best = -42.000000, Len = 99
# SantaFe Evals 46000: Best = -42.000000, Len = 100
# SantaFe Evals 47000: Best = -42.000000, Len = 100
# SantaFe Evals 48000: Best = -42.000000, Len = 100
# SantaFe Evals 49000: Best = -42.000000, Len = 100
# SantaFe Evals 50000: Best = -42.000000, Len = 100
# SantaFe Evals 51000: Best = -42.000000, Len = 100
# SantaFe Evals 52000: Best = -42.000000, Len = 100
# SantaFe Evals 53000: Best = -42.000000, Len = 100
# SantaFe Evals 54000: Best = -42.000000, Len = 100
# SantaFe Evals 55000: Best = -42.000000, Len = 100
# SantaFe Evals 56000: Best = -42.000000, Len = 100
# SantaFe Evals 57000: Best = -42.000000, Len = 100
# SantaFe Evals 58000: Best = -42.000000, Len = 100
# SantaFe Evals 59000: Best = -42.000000, Len = 100
# SantaFe Evals 60000: Best = -42.000000, Len = 100
# SantaFe Evals 61000: Best = -42.000000, Len = 100
# SantaFe Evals 62000: Best = -42.000000, Len = 100
# SantaFe Evals 63000: Best = -42.000000, Len = 100
# SantaFe Evals 64000: Best = -42.000000, Len = 100
# SantaFe Evals 65000: Best = -42.000000, Len = 100
# SantaFe Evals 66000: Best = -42.000000, Len = 100
# SantaFe Evals 67000: Best = -42.000000, Len = 100
# SantaFe Evals 68000: Best = -42.000000, Len = 100
# SantaFe Evals 69000: Best = -42.000000, Len = 100
# SantaFe Evals 70000: Best = -42.000000, Len = 100
# SantaFe Evals 71000: Best = -42.000000, Len = 100
# SantaFe Evals 72000: Best = -42.000000, Len = 100
# SantaFe Evals 73000: Best = -42.000000, Len = 100
# SantaFe Evals 74000: Best = -42.000000, Len = 100
# SantaFe Evals 75000: Best = -42.000000, Len = 100
# SantaFe Evals 76000: Best = -42.000000, Len = 100
# SantaFe Evals 77000: Best = -42.000000, Len = 100
# SantaFe Evals 78000: Best = -42.000000, Len = 99
# SantaFe Evals 79000: Best = -42.000000, Len = 99
# SantaFe Evals 80000: Best = -42.000000, Len = 99
# SantaFe Evals 81000: Best = -42.000000, Len = 99
# SantaFe Evals 82000: Best = -42.000000, Len = 100
# SantaFe Evals 83000: Best = -42.000000, Len = 100
# SantaFe Evals 84000: Best = -42.000000, Len = 100
# SantaFe Evals 85000: Best = -42.000000, Len = 100
# SantaFe Evals 86000: Best = -42.000000, Len = 100
# SantaFe Evals 87000: Best = -42.000000, Len = 99
# SantaFe Evals 88000: Best = -42.000000, Len = 99
# SantaFe Evals 89000: Best = -42.000000, Len = 99
# SantaFe Evals 90000: Best = -42.000000, Len = 99
# SantaFe Evals 91000: Best = -42.000000, Len = 99
# SantaFe Evals 92000: Best = -42.000000, Len = 99
# SantaFe Evals 93000: Best = -42.000000, Len = 99
# SantaFe Evals 94000: Best = -42.000000, Len = 98
# SantaFe Evals 95000: Best = -42.000000, Len = 98
# SantaFe Evals 96000: Best = -42.000000, Len = 98
# SantaFe Evals 97000: Best = -42.000000, Len = 98
# SantaFe Evals 98000: Best = -42.000000, Len = 99
# SantaFe Evals 99000: Best = -42.000000, Len = 99
# SantaFe Evals 100000: Best = -42.000000, Len = 99
# SantaFe Evals 1000: Best = -15.000000, Len = 100
# SantaFe Evals 2000: Best = -15.000000, Len = 100
# SantaFe Evals 3000: Best = -15.000000, Len = 100
# SantaFe Evals 4000: Best = -17.000000, Len = 100
# SantaFe Evals 5000: Best = -14.000000, Len = 100
# SantaFe Evals 6000: Best = -16.000000, Len = 100
# SantaFe Evals 7000: Best = -23.000000, Len = 100
# SantaFe Evals 8000: Best = -19.000000, Len = 100
# SantaFe Evals 9000: Best = -17.000000, Len = 100
# SantaFe Evals 10000: Best = -18.000000, Len = 100
# SantaFe Evals 11000: Best = -24.000000, Len = 100
# SantaFe Evals 12000: Best = -18.000000, Len = 100
# SantaFe Evals 13000: Best = -23.000000, Len = 100
# SantaFe Evals 14000: Best = -23.000000, Len = 100
# SantaFe Evals 15000: Best = -22.000000, Len = 100
# SantaFe Evals 16000: Best = -24.000000, Len = 100
# SantaFe Evals 17000: Best = -22.000000, Len = 99
# SantaFe Evals 18000: Best = -24.000000, Len = 99
# SantaFe Evals 19000: Best = -26.000000, Len = 99
# SantaFe Evals 20000: Best = -25.000000, Len = 99
# SantaFe Evals 21000: Best = -26.000000, Len = 99
# SantaFe Evals 22000: Best = -28.000000, Len = 98
# SantaFe Evals 23000: Best = -30.000000, Len = 98
# SantaFe Evals 24000: Best = -29.000000, Len = 98
# SantaFe Evals 25000: Best = -29.000000, Len = 99
# SantaFe Evals 26000: Best = -29.000000, Len = 99
# SantaFe Evals 27000: Best = -29.000000, Len = 99
# SantaFe Evals 28000: Best = -29.000000, Len = 99
# SantaFe Evals 29000: Best = -28.000000, Len = 98
# SantaFe Evals 30000: Best = -28.000000, Len = 98
# SantaFe Evals 31000: Best = -28.000000, Len = 98
# SantaFe Evals 32000: Best = -28.000000, Len = 98
# SantaFe Evals 33000: Best = -28.000000, Len = 98
# SantaFe Evals 34000: Best = -28.000000, Len = 98
# SantaFe Evals 35000: Best = -28.000000, Len = 98
# SantaFe Evals 36000: Best = -28.000000, Len = 98
# SantaFe Evals 37000: Best = -27.000000, Len = 97
# SantaFe Evals 38000: Best = -27.000000, Len = 97
# SantaFe Evals 39000: Best = -28.000000, Len = 97
# SantaFe Evals 40000: Best = -28.000000, Len = 97
# SantaFe Evals 41000: Best = -28.000000, Len = 97
# SantaFe Evals 42000: Best = -28.000000, Len = 97
# SantaFe Evals 43000: Best = -28.000000, Len = 97
# SantaFe Evals 44000: Best = -28.000000, Len = 97
# SantaFe Evals 45000: Best = -28.000000, Len = 97
# SantaFe Evals 46000: Best = -28.000000, Len = 97
# SantaFe Evals 47000: Best = -28.000000, Len = 97
# SantaFe Evals 48000: Best = -28.000000, Len = 97
# SantaFe Evals 49000: Best = -28.000000, Len = 97
# SantaFe Evals 50000: Best = -28.000000, Len = 97
# SantaFe Evals 51000: Best = -28.000000, Len = 97
# SantaFe Evals 52000: Best = -28.000000, Len = 97
# SantaFe Evals 53000: Best = -28.000000, Len = 97
# SantaFe Evals 54000: Best = -28.000000, Len = 97
# SantaFe Evals 55000: Best = -28.000000, Len = 97
# SantaFe Evals 56000: Best = -28.000000, Len = 97
# SantaFe Evals 57000: Best = -28.000000, Len = 95
# SantaFe Evals 58000: Best = -28.000000, Len = 95
# SantaFe Evals 59000: Best = -28.000000, Len = 95
# SantaFe Evals 60000: Best = -28.000000, Len = 95
# SantaFe Evals 61000: Best = -28.000000, Len = 95
# SantaFe Evals 62000: Best = -28.000000, Len = 95
# SantaFe Evals 63000: Best = -28.000000, Len = 95
# SantaFe Evals 64000: Best = -28.000000, Len = 95
# SantaFe Evals 65000: Best = -28.000000, Len = 95
# SantaFe Evals 66000: Best = -28.000000, Len = 95
# SantaFe Evals 67000: Best = -28.000000, Len = 95
# SantaFe Evals 68000: Best = -28.000000, Len = 95
# SantaFe Evals 69000: Best = -28.000000, Len = 95
# SantaFe Evals 70000: Best = -28.000000, Len = 95
# SantaFe Evals 71000: Best = -28.000000, Len = 95
# SantaFe Evals 72000: Best = -28.000000, Len = 95
# SantaFe Evals 73000: Best = -28.000000, Len = 95
# SantaFe Evals 74000: Best = -28.000000, Len = 95
# SantaFe Evals 75000: Best = -28.000000, Len = 95
# SantaFe Evals 76000: Best = -28.000000, Len = 95
# SantaFe Evals 77000: Best = 32.000000, Len = 94
# SantaFe Evals 78000: Best = 32.000000, Len = 94
# SantaFe Evals 79000: Best = 32.000000, Len = 94
# SantaFe Evals 80000: Best = -28.000000, Len = 95
# SantaFe Evals 81000: Best = -28.000000, Len = 96
# SantaFe Evals 82000: Best = -28.000000, Len = 96
# SantaFe Evals 83000: Best = -28.000000, Len = 96
# SantaFe Evals 84000: Best = -28.000000, Len = 96
# SantaFe Evals 85000: Best = -28.000000, Len = 96
# SantaFe Evals 86000: Best = -28.000000, Len = 96
# SantaFe Evals 87000: Best = -28.000000, Len = 96
# SantaFe Evals 88000: Best = -28.000000, Len = 96
# SantaFe Evals 89000: Best = -28.000000, Len = 96
# SantaFe Evals 90000: Best = -28.000000, Len = 96
# SantaFe Evals 91000: Best = -28.000000, Len = 96
# SantaFe Evals 92000: Best = -28.000000, Len = 96
# SantaFe Evals 93000: Best = -28.000000, Len = 96
# SantaFe Evals 94000: Best = -28.000000, Len = 95
# SantaFe Evals 95000: Best = -28.000000, Len = 95
# SantaFe Evals 96000: Best = -28.000000, Len = 95
# SantaFe Evals 97000: Best = -28.000000, Len = 96
# SantaFe Evals 98000: Best = -28.000000, Len = 96
# SantaFe Evals 99000: Best = -28.000000, Len = 96
# SantaFe Evals 100000: Best = -28.000000, Len = 96
# SantaFe Evals 1000: Best = -12.000000, Len = 100
# SantaFe Evals 2000: Best = -16.000000, Len = 100
# SantaFe Evals 3000: Best = -14.000000, Len = 100
# SantaFe Evals 4000: Best = -17.000000, Len = 100
# SantaFe Evals 5000: Best = -15.000000, Len = 100
# SantaFe Evals 6000: Best = -14.000000, Len = 100
# SantaFe Evals 7000: Best = -20.000000, Len = 100
# SantaFe Evals 8000: Best = -17.000000, Len = 100
# SantaFe Evals 9000: Best = -19.000000, Len = 100
# SantaFe Evals 10000: Best = -21.000000, Len = 100
# SantaFe Evals 11000: Best = -23.000000, Len = 100
# SantaFe Evals 12000: Best = -24.000000, Len = 100
# SantaFe Evals 13000: Best = -22.000000, Len = 100
# SantaFe Evals 14000: Best = -28.000000, Len = 100
# SantaFe Evals 15000: Best = -27.000000, Len = 100
# SantaFe Evals 16000: Best = -27.000000, Len = 100
# SantaFe Evals 17000: Best = -28.000000, Len = 100
# SantaFe Evals 18000: Best = -32.000000, Len = 100
# SantaFe Evals 19000: Best = -31.000000, Len = 100
# SantaFe Evals 20000: Best = -36.000000, Len = 100
# SantaFe Evals 21000: Best = -33.000000, Len = 100
# SantaFe Evals 22000: Best = -31.000000, Len = 100
# SantaFe Evals 23000: Best = -31.000000, Len = 100
# SantaFe Evals 24000: Best = -31.000000, Len = 100
# SantaFe Evals 25000: Best = -31.000000, Len = 100
# SantaFe Evals 26000: Best = -31.000000, Len = 99
# SantaFe Evals 27000: Best = -31.000000, Len = 99
# SantaFe Evals 28000: Best = -31.000000, Len = 99
# SantaFe Evals 29000: Best = -31.000000, Len = 99
# SantaFe Evals 30000: Best = -31.000000, Len = 99
# SantaFe Evals 31000: Best = -31.000000, Len = 99
# SantaFe Evals 32000: Best = -31.000000, Len = 99
# SantaFe Evals 33000: Best = -31.000000, Len = 98
# SantaFe Evals 34000: Best = -31.000000, Len = 98
# SantaFe Evals 35000: Best = -31.000000, Len = 97
# SantaFe Evals 36000: Best = -31.000000, Len = 97
# SantaFe Evals 37000: Best = -31.000000, Len = 97
# SantaFe Evals 38000: Best = -30.000000, Len = 96
# SantaFe Evals 39000: Best = -30.000000, Len = 96
# SantaFe Evals 40000: Best = -30.000000, Len = 96
# SantaFe Evals 41000: Best = -30.000000, Len = 96
# SantaFe Evals 42000: Best = -30.000000, Len = 96
# SantaFe Evals 43000: Best = -30.000000, Len = 96
# SantaFe Evals 44000: Best = -30.000000, Len = 96
# SantaFe Evals 45000: Best = -30.000000, Len = 96
# SantaFe Evals 46000: Best = -30.000000, Len = 96
# SantaFe Evals 47000: Best = -30.000000, Len = 96
# SantaFe Evals 48000: Best = -30.000000, Len = 96
# SantaFe Evals 49000: Best = -30.000000, Len = 96
# SantaFe Evals 50000: Best = -30.000000, Len = 96
# SantaFe Evals 51000: Best = -30.000000, Len = 96
# SantaFe Evals 52000: Best = -30.000000, Len = 96
# SantaFe Evals 53000: Best = -30.000000, Len = 96
# SantaFe Evals 54000: Best = -30.000000, Len = 96
# SantaFe Evals 55000: Best = -30.000000, Len = 96
# SantaFe Evals 56000: Best = -30.000000, Len = 95
# SantaFe Evals 57000: Best = -30.000000, Len = 95
# SantaFe Evals 58000: Best = -30.000000, Len = 95
# SantaFe Evals 59000: Best = -30.000000, Len = 95
# SantaFe Evals 60000: Best = -30.000000, Len = 95
# SantaFe Evals 61000: Best = -30.000000, Len = 95
# SantaFe Evals 62000: Best = -30.000000, Len = 95
# SantaFe Evals 63000: Best = -30.000000, Len = 95
# SantaFe Evals 64000: Best = -30.000000, Len = 95
# SantaFe Evals 65000: Best = -30.000000, Len = 95
# SantaFe Evals 66000: Best = -30.000000, Len = 95
# SantaFe Evals 67000: Best = -30.000000, Len = 95
# SantaFe Evals 68000: Best = -30.000000, Len = 95
# SantaFe Evals 69000: Best = -30.000000, Len = 95
# SantaFe Evals 70000: Best = -30.000000, Len = 95
# SantaFe Evals 71000: Best = -30.000000, Len = 95
# SantaFe Evals 72000: Best = -30.000000, Len = 95
# SantaFe Evals 73000: Best = -30.000000, Len = 95
# SantaFe Evals 74000: Best = -30.000000, Len = 95
# SantaFe Evals 75000: Best = -30.000000, Len = 95
# SantaFe Evals 76000: Best = -30.000000, Len = 95
# SantaFe Evals 77000: Best = -30.000000, Len = 95
# SantaFe Evals 78000: Best = -30.000000, Len = 95
# SantaFe Evals 79000: Best = -30.000000, Len = 95
# SantaFe Evals 80000: Best = -30.000000, Len = 95
# SantaFe Evals 81000: Best = 30.000000, Len = 94
# SantaFe Evals 82000: Best = 30.000000, Len = 94
# SantaFe Evals 83000: Best = 30.000000, Len = 94
# SantaFe Evals 84000: Best = 30.000000, Len = 94
# SantaFe Evals 85000: Best = -30.000000, Len = 95
# SantaFe Evals 86000: Best = -30.000000, Len = 95
# SantaFe Evals 87000: Best = -30.000000, Len = 95
# SantaFe Evals 88000: Best = -30.000000, Len = 95
# SantaFe Evals 89000: Best = -30.000000, Len = 95
# SantaFe Evals 90000: Best = -30.000000, Len = 95
# SantaFe Evals 91000: Best = -30.000000, Len = 95
# SantaFe Evals 92000: Best = -30.000000, Len = 95
# SantaFe Evals 93000: Best = -30.000000, Len = 95
# SantaFe Evals 94000: Best = -30.000000, Len = 95
# SantaFe Evals 95000: Best = -30.000000, Len = 95
# SantaFe Evals 96000: Best = -30.000000, Len = 95
# SantaFe Evals 97000: Best = -30.000000, Len = 95
# SantaFe Evals 98000: Best = -30.000000, Len = 95
# SantaFe Evals 99000: Best = -30.000000, Len = 95
# SantaFe Evals 100000: Best = -30.000000, Len = 95
# Results written to CMA_ES_results_20250527_125054\CMA_ES_results.csv and history to CMA_ES_results_20250527_125054\CMA_ES_history.csv
