# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE = 100
N_EVALS = 100000
N_REPLICATES = 30
MIN_LEN = 3
MAX_LEN = 100
gene_low, gene_high = -2.0, 2.0

F_INIT = 0.8
CR_INIT = 0.9
P_LEN_CHANGE = 0.05

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir = f'DE_VarialbeDimensions_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_path = os.path.join(out_dir, 'DE_VariableDimensions_results.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=2):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

def loadSantaFeMap(path='santafe_trail.txt'):
    world_rows = []
    start_x = start_y = None
    with open(path) as f:
        for y,line in enumerate(f):
            row=[]
            for x,c in enumerate(line.rstrip("\n")):
                if c=='#': row.append(1)
                elif c in ('.','S'):
                    row.append(0)
                    if c=='S': start_x,start_y = x,y
            if row: world_rows.append(row)
    if not world_rows: raise ValueError(f'No valid rows in map: {path}')
    H=len(world_rows); W=len(world_rows[0])
    for r in world_rows:
        if len(r)!=W: raise ValueError('Inconsistent row lengths.')
    world=[c for row in world_rows for c in row]
    if start_x is None or start_y is None: start_x=start_y=0
    return world, W, H, start_x, start_y

world, W, H, START_X, START_Y = loadSantaFeMap()

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x*x for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x*x-10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        s = sum(x*x for x in ind)
        p = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + s/4000. - p + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        s = sum(x*x for x in ind)
        c = sum(cos(2*pi*x) for x in ind)
        return -20*exp(-0.2*sqrt(s/d)) - exp(c/d) + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    xs = np.linspace(-1,1,20)
    def f(ind):
        err=0
        for x in xs:
            t = x**4 + x**3 + x**2 + x
            p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (p-t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, cap):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel=[int(round(x))%2 for x in ind[:len(items)]]
        w_sum=sum(w for (w,v),s in zip(items,sel) if s)
        v_sum=sum(v for (w,v),s in zip(items,sel) if s)
        over=max(0,w_sum-cap)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target=2**N
    pen=mkPenalizer(d_target,lam)
    def f(ind):
        table=[int(round(x))%2 for x in ind[:d_target]]
        errs=0
        for i in range(d_target):
            target = bin(i).count('1')%2
            if i < len(table):
                if table[i]!=target: errs+=1
            else:
                errs+=1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        dir=0; x,y=START_X,START_Y; food=0
        visited = world.copy()
        idx=lambda xx,yy: (yy%H)*W + (xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)]==1:
                food+=1; visited[idx(x,y)]=0
            act = int(abs(ind[i]))%3
            if act==0:
                dx,dy=[(0,1),(1,0),(0,-1),(-1,0)][dir]; x+=dx; y+=dy
            elif act==1:
                dir=(dir+1)%4
            else:
                dir=(dir-1)%4
        return -food + pen(ind)
    return f

# %%
def generateInd():
    length = random.randint(MIN_LEN, MAX_LEN)
    return [random.uniform(gene_low, gene_high) for _ in range(length)]

def initPop():
    return [generateInd() for _ in range(POP_SIZE)]

# %%
def DEMutate(pop, j, F):
    idxs=list(range(len(pop)))
    idxs.remove(j)
    a,b,c = random.sample(idxs,3)
    va, vb, vc = pop[a], pop[b], pop[c]
    d_mut = min(len(va), len(vb), len(vc))
    mutant = [va[i] + F*(vb[i] - vc[i]) for i in range(d_mut)]
    if random.random() < P_LEN_CHANGE:
        if random.random() < 0.5 and len(mutant) < MAX_LEN:
            mutant.append(random.uniform(gene_low, gene_high))
        elif len(mutant) > MIN_LEN:
            mutant.pop(random.randrange(len(mutant)))
    while len(mutant) < MIN_LEN:
        mutant.append(random.uniform(gene_low, gene_high))
    return mutant[:MAX_LEN]

def DECrossover(target, mutant, CR):
    dt, dm = len(target), len(mutant)
    L = max(dt, dm)
    j_rand = random.randrange(L)
    trial = []
    for i in range(L):
        if random.random() < CR or i == j_rand:
            if i < dm:
                trial.append(mutant[i])
            else:
                trial.append(random.uniform(gene_low, gene_high))
        else:
            if i < dt:
                trial.append(target[i])
            else:
                trial.append(random.uniform(gene_low, gene_high))
    while len(trial) < MIN_LEN:
        trial.append(random.uniform(gene_low, gene_high))
    return trial[:MAX_LEN]

# %%
def run_de(fit_func, name):
    pop = initPop()
    evals = 0
    best_hist=[]
    while evals < N_EVALS:
        gen_idx = len(best_hist)
        F = F_INIT * (1 - gen_idx/(N_EVALS/POP_SIZE))
        CR = CR_INIT * (1 - 0.5*gen_idx/(N_EVALS/POP_SIZE))
        new_pop=[]
        for j,x in enumerate(pop):
            mutant = DEMutate(pop, j, F)
            trial = DECrossover(x, mutant, CR)
            if fit_func(trial) <= fit_func(x):
                new_pop.append(trial)
            else:
                new_pop.append(x)
        pop = new_pop
        evals += POP_SIZE
        best = fit_func(min(pop, key=fit_func))
        best_hist.append(best)
        if gen_idx % 10 == 0:
            elite = min(pop, key=fit_func)
            print(f'{name} Evals {evals}: Best = {best:.6f}, Len = {len(elite)}')
    return min(pop, key=fit_func), best_hist

# %%
with open(csv_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile,
                            fieldnames=['run_id','benchmark','replicate','seed','best','len_final','cpu_s'])
    writer.writeheader()

    items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        'Sphere': sphere(30,10),
        'Rastrigin': rastrigin(30,10),
        'Griewank': griewank(30,10),
        'Ackley': ackley(30,10),
        'Koza': koza(10,10),
        'Knapsack': knapsack(20,0,items,50),
        'Parity': parity(6,10),
        'SantaFe': santaFe(100,10)
    }

    for name, func in benchmarks.items():
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed); np.random.seed(seed)
            start = time.perf_counter()
            best_ind, hist = run_de(func, name)
            cpu = time.perf_counter() - start
            writer.writerow({
                'run_id': uuid.uuid4(),
                'benchmark': name,
                'replicate': rep,
                'seed': seed,
                'best': round(func(best_ind),6),
                'len_final': len(best_ind),
                'cpu_s': round(cpu,4)
            })
print(f'Results written to {csv_path}')
# Out:
# Sphere Evals 100: Best = 40.531684, Len = 30
# Sphere Evals 1100: Best = 40.531684, Len = 30
# Sphere Evals 2100: Best = 40.531684, Len = 30
# Sphere Evals 3100: Best = 36.378016, Len = 28
# Sphere Evals 4100: Best = 36.378016, Len = 28
# Sphere Evals 5100: Best = 36.378016, Len = 28
# Sphere Evals 6100: Best = 36.378016, Len = 28
# Sphere Evals 7100: Best = 36.378016, Len = 28
# Sphere Evals 8100: Best = 35.606977, Len = 30
# Sphere Evals 9100: Best = 28.610593, Len = 31
# Sphere Evals 10100: Best = 28.610593, Len = 31
# Sphere Evals 11100: Best = 28.610593, Len = 31
# Sphere Evals 12100: Best = 27.157937, Len = 31
# Sphere Evals 13100: Best = 25.722112, Len = 30
# Sphere Evals 14100: Best = 22.479062, Len = 31
# Sphere Evals 15100: Best = 22.479062, Len = 31
# Sphere Evals 16100: Best = 22.479062, Len = 31
# Sphere Evals 17100: Best = 22.479062, Len = 31
# Sphere Evals 18100: Best = 22.159311, Len = 30
# Sphere Evals 19100: Best = 22.159311, Len = 30
# Sphere Evals 20100: Best = 22.159311, Len = 30
# Sphere Evals 21100: Best = 22.159311, Len = 30
# Sphere Evals 22100: Best = 21.638551, Len = 31
# Sphere Evals 23100: Best = 21.638551, Len = 31
# Sphere Evals 24100: Best = 21.638551, Len = 31
# Sphere Evals 25100: Best = 20.713925, Len = 31
# Sphere Evals 26100: Best = 18.268093, Len = 31
# Sphere Evals 27100: Best = 18.268093, Len = 31
# Sphere Evals 28100: Best = 18.031281, Len = 31
# Sphere Evals 29100: Best = 12.075775, Len = 31
# Sphere Evals 30100: Best = 12.075775, Len = 31
# Sphere Evals 31100: Best = 12.075775, Len = 31
# Sphere Evals 32100: Best = 12.075775, Len = 31
# Sphere Evals 33100: Best = 9.448119, Len = 31
# Sphere Evals 34100: Best = 9.448119, Len = 31
# Sphere Evals 35100: Best = 9.448119, Len = 31
# Sphere Evals 36100: Best = 7.768748, Len = 31
# Sphere Evals 37100: Best = 7.768748, Len = 31
# Sphere Evals 38100: Best = 5.784445, Len = 31
# Sphere Evals 39100: Best = 5.784445, Len = 31
# Sphere Evals 40100: Best = 5.784445, Len = 31
# Sphere Evals 41100: Best = 5.751530, Len = 31
# Sphere Evals 42100: Best = 5.190221, Len = 31
# Sphere Evals 43100: Best = 5.190221, Len = 31
# Sphere Evals 44100: Best = 5.190221, Len = 31
# Sphere Evals 45100: Best = 5.190221, Len = 31
# Sphere Evals 46100: Best = 5.190221, Len = 31
# Sphere Evals 47100: Best = 4.674358, Len = 32
# Sphere Evals 48100: Best = 4.674358, Len = 32
# Sphere Evals 49100: Best = 4.674358, Len = 32
# Sphere Evals 50100: Best = 4.535790, Len = 32
# Sphere Evals 51100: Best = 4.131989, Len = 32
# Sphere Evals 52100: Best = 3.554969, Len = 32
# Sphere Evals 53100: Best = 3.338902, Len = 32
# Sphere Evals 54100: Best = 2.268424, Len = 32
# Sphere Evals 55100: Best = 2.268424, Len = 32
# Sphere Evals 56100: Best = 2.268424, Len = 32
# Sphere Evals 57100: Best = 2.074846, Len = 32
# Sphere Evals 58100: Best = 2.071640, Len = 32
# Sphere Evals 59100: Best = 2.021520, Len = 32
# Sphere Evals 60100: Best = 2.021520, Len = 32
# Sphere Evals 61100: Best = 2.021520, Len = 32
# Sphere Evals 62100: Best = 1.881728, Len = 32
# Sphere Evals 63100: Best = 1.881728, Len = 32
# Sphere Evals 64100: Best = 1.371313, Len = 32
# Sphere Evals 65100: Best = 0.995694, Len = 32
# Sphere Evals 66100: Best = 0.995694, Len = 32
# Sphere Evals 67100: Best = 0.807316, Len = 32
# Sphere Evals 68100: Best = 0.807316, Len = 32
# Sphere Evals 69100: Best = 0.807316, Len = 32
# Sphere Evals 70100: Best = 0.807316, Len = 32
# Sphere Evals 71100: Best = 0.737502, Len = 32
# Sphere Evals 72100: Best = 0.628701, Len = 32
# Sphere Evals 73100: Best = 0.550858, Len = 32
# Sphere Evals 74100: Best = 0.539952, Len = 32
# Sphere Evals 75100: Best = 0.539952, Len = 32
# Sphere Evals 76100: Best = 0.459786, Len = 32
# Sphere Evals 77100: Best = 0.459786, Len = 32
# Sphere Evals 78100: Best = 0.409500, Len = 32
# Sphere Evals 79100: Best = 0.373759, Len = 32
# Sphere Evals 80100: Best = 0.307425, Len = 32
# Sphere Evals 81100: Best = 0.258728, Len = 32
# Sphere Evals 82100: Best = 0.194248, Len = 32
# Sphere Evals 83100: Best = 0.150802, Len = 32
# Sphere Evals 84100: Best = 0.150802, Len = 32
# Sphere Evals 85100: Best = 0.150802, Len = 32
# Sphere Evals 86100: Best = 0.150802, Len = 32
# Sphere Evals 87100: Best = 0.124968, Len = 32
# Sphere Evals 88100: Best = 0.076759, Len = 32
# Sphere Evals 89100: Best = 0.076759, Len = 32
# Sphere Evals 90100: Best = 0.076759, Len = 32
# Sphere Evals 91100: Best = 0.076759, Len = 32
# Sphere Evals 92100: Best = 0.071720, Len = 32
# Sphere Evals 93100: Best = 0.056238, Len = 32
# Sphere Evals 94100: Best = 0.045920, Len = 32
# Sphere Evals 95100: Best = 0.044611, Len = 32
# Sphere Evals 96100: Best = 0.034351, Len = 32
# Sphere Evals 97100: Best = 0.033723, Len = 32
# Sphere Evals 98100: Best = 0.033723, Len = 32
# Sphere Evals 99100: Best = 0.024348, Len = 32
# Sphere Evals 100: Best = 31.076130, Len = 28
# Sphere Evals 1100: Best = 31.076130, Len = 28
# Sphere Evals 2100: Best = 31.076130, Len = 28
# Sphere Evals 3100: Best = 31.076130, Len = 28
# Sphere Evals 4100: Best = 31.076130, Len = 28
# Sphere Evals 5100: Best = 31.076130, Len = 28
# Sphere Evals 6100: Best = 31.076130, Len = 28
# Sphere Evals 7100: Best = 31.076130, Len = 28
# Sphere Evals 8100: Best = 31.076130, Len = 28
# Sphere Evals 9100: Best = 31.076130, Len = 28
# Sphere Evals 10100: Best = 31.076130, Len = 28
# Sphere Evals 11100: Best = 31.076130, Len = 28
# Sphere Evals 12100: Best = 31.076130, Len = 28
# Sphere Evals 13100: Best = 31.076130, Len = 28
# Sphere Evals 14100: Best = 25.267537, Len = 30
# Sphere Evals 15100: Best = 25.267537, Len = 30
# Sphere Evals 16100: Best = 25.267537, Len = 30
# Sphere Evals 17100: Best = 25.267537, Len = 30
# Sphere Evals 18100: Best = 25.267537, Len = 30
# Sphere Evals 19100: Best = 25.267537, Len = 30
# Sphere Evals 20100: Best = 25.267537, Len = 30
# Sphere Evals 21100: Best = 25.267537, Len = 30
# Sphere Evals 22100: Best = 22.469096, Len = 32
# Sphere Evals 23100: Best = 22.469096, Len = 32
# Sphere Evals 24100: Best = 22.469096, Len = 32
# Sphere Evals 25100: Best = 22.469096, Len = 32
# Sphere Evals 26100: Best = 22.469096, Len = 32
# Sphere Evals 27100: Best = 20.395440, Len = 32
# Sphere Evals 28100: Best = 20.395440, Len = 32
# Sphere Evals 29100: Best = 20.192758, Len = 32
# Sphere Evals 30100: Best = 12.254693, Len = 32
# Sphere Evals 31100: Best = 12.254693, Len = 32
# Sphere Evals 32100: Best = 12.254693, Len = 32
# Sphere Evals 33100: Best = 12.254693, Len = 32
# Sphere Evals 34100: Best = 10.531965, Len = 32
# Sphere Evals 35100: Best = 10.531965, Len = 32
# Sphere Evals 36100: Best = 9.802430, Len = 32
# Sphere Evals 37100: Best = 9.802430, Len = 32
# Sphere Evals 38100: Best = 9.802430, Len = 32
# Sphere Evals 39100: Best = 9.201775, Len = 32
# Sphere Evals 40100: Best = 7.754485, Len = 32
# Sphere Evals 41100: Best = 7.754485, Len = 32
# Sphere Evals 42100: Best = 5.224259, Len = 32
# Sphere Evals 43100: Best = 5.224259, Len = 32
# Sphere Evals 44100: Best = 5.224259, Len = 32
# Sphere Evals 45100: Best = 5.224259, Len = 32
# Sphere Evals 46100: Best = 5.224259, Len = 32
# Sphere Evals 47100: Best = 4.864288, Len = 32
# Sphere Evals 48100: Best = 4.495029, Len = 32
# Sphere Evals 49100: Best = 4.112562, Len = 32
# Sphere Evals 50100: Best = 4.112562, Len = 32
# Sphere Evals 51100: Best = 3.505689, Len = 32
# Sphere Evals 52100: Best = 3.505689, Len = 32
# Sphere Evals 53100: Best = 3.505689, Len = 32
# Sphere Evals 54100: Best = 2.844299, Len = 32
# Sphere Evals 55100: Best = 2.588525, Len = 32
# Sphere Evals 56100: Best = 2.521172, Len = 32
# Sphere Evals 57100: Best = 2.501536, Len = 32
# Sphere Evals 58100: Best = 2.061387, Len = 32
# Sphere Evals 59100: Best = 1.661455, Len = 32
# Sphere Evals 60100: Best = 1.661455, Len = 32
# Sphere Evals 61100: Best = 1.661455, Len = 32
# Sphere Evals 62100: Best = 1.578710, Len = 32
# Sphere Evals 63100: Best = 1.333087, Len = 32
# Sphere Evals 64100: Best = 0.972040, Len = 32
# Sphere Evals 65100: Best = 0.972040, Len = 32
# Sphere Evals 66100: Best = 0.848231, Len = 32
# Sphere Evals 67100: Best = 0.848231, Len = 32
# Sphere Evals 68100: Best = 0.798516, Len = 32
# Sphere Evals 69100: Best = 0.751938, Len = 32
# Sphere Evals 70100: Best = 0.657559, Len = 32
# Sphere Evals 71100: Best = 0.657559, Len = 32
# Sphere Evals 72100: Best = 0.657559, Len = 32
# Sphere Evals 73100: Best = 0.429334, Len = 32
# Sphere Evals 74100: Best = 0.429334, Len = 32
# Sphere Evals 75100: Best = 0.405061, Len = 32
# Sphere Evals 76100: Best = 0.405061, Len = 32
# Sphere Evals 77100: Best = 0.382455, Len = 32
# Sphere Evals 78100: Best = 0.323939, Len = 32
# Sphere Evals 79100: Best = 0.268973, Len = 32
# Sphere Evals 80100: Best = 0.254473, Len = 32
# Sphere Evals 81100: Best = 0.254473, Len = 32
# Sphere Evals 82100: Best = 0.181722, Len = 32
# Sphere Evals 83100: Best = 0.181722, Len = 32
# Sphere Evals 84100: Best = 0.154256, Len = 32
# Sphere Evals 85100: Best = 0.139914, Len = 32
# Sphere Evals 86100: Best = 0.134826, Len = 32
# Sphere Evals 87100: Best = 0.113456, Len = 32
# Sphere Evals 88100: Best = 0.113456, Len = 32
# Sphere Evals 89100: Best = 0.104268, Len = 32
# Sphere Evals 90100: Best = 0.076219, Len = 32
# Sphere Evals 91100: Best = 0.076219, Len = 32
# Sphere Evals 92100: Best = 0.064895, Len = 32
# Sphere Evals 93100: Best = 0.064895, Len = 32
# Sphere Evals 94100: Best = 0.048179, Len = 32
# Sphere Evals 95100: Best = 0.040986, Len = 32
# Sphere Evals 96100: Best = 0.037511, Len = 32
# Sphere Evals 97100: Best = 0.029355, Len = 32
# Sphere Evals 98100: Best = 0.023585, Len = 32
# Sphere Evals 99100: Best = 0.017237, Len = 32
# Sphere Evals 100: Best = 34.252294, Len = 31
# Sphere Evals 1100: Best = 34.252294, Len = 31
# Sphere Evals 2100: Best = 34.252294, Len = 31
# Sphere Evals 3100: Best = 34.252294, Len = 31
# Sphere Evals 4100: Best = 34.252294, Len = 31
# Sphere Evals 5100: Best = 34.252294, Len = 31
# Sphere Evals 6100: Best = 34.252294, Len = 31
# Sphere Evals 7100: Best = 34.252294, Len = 31
# Sphere Evals 8100: Best = 34.252294, Len = 31
# Sphere Evals 9100: Best = 34.252294, Len = 31
# Sphere Evals 10100: Best = 34.252294, Len = 31
# Sphere Evals 11100: Best = 34.252294, Len = 31
# Sphere Evals 12100: Best = 34.252294, Len = 31
# Sphere Evals 13100: Best = 34.252294, Len = 31
# Sphere Evals 14100: Best = 34.252294, Len = 31
# Sphere Evals 15100: Best = 34.252294, Len = 31
# Sphere Evals 16100: Best = 34.252294, Len = 31
# Sphere Evals 17100: Best = 34.252294, Len = 31
# Sphere Evals 18100: Best = 29.546763, Len = 32
# Sphere Evals 19100: Best = 29.546763, Len = 32
# Sphere Evals 20100: Best = 29.546763, Len = 32
# Sphere Evals 21100: Best = 29.546763, Len = 32
# Sphere Evals 22100: Best = 29.546763, Len = 32
# Sphere Evals 23100: Best = 29.546763, Len = 32
# Sphere Evals 24100: Best = 25.419429, Len = 32
# Sphere Evals 25100: Best = 25.419429, Len = 32
# Sphere Evals 26100: Best = 25.419429, Len = 32
# Sphere Evals 27100: Best = 25.179878, Len = 32
# Sphere Evals 28100: Best = 21.510995, Len = 32
# Sphere Evals 29100: Best = 15.429224, Len = 32
# Sphere Evals 30100: Best = 15.429224, Len = 32
# Sphere Evals 31100: Best = 15.429224, Len = 32
# Sphere Evals 32100: Best = 14.994652, Len = 32
# Sphere Evals 33100: Best = 14.994652, Len = 32
# Sphere Evals 34100: Best = 13.944645, Len = 32
# Sphere Evals 35100: Best = 13.944645, Len = 32
# Sphere Evals 36100: Best = 11.952239, Len = 32
# Sphere Evals 37100: Best = 11.952239, Len = 32
# Sphere Evals 38100: Best = 10.716104, Len = 32
# Sphere Evals 39100: Best = 10.716104, Len = 32
# Sphere Evals 40100: Best = 10.600471, Len = 32
# Sphere Evals 41100: Best = 8.460590, Len = 32
# Sphere Evals 42100: Best = 7.409009, Len = 32
# Sphere Evals 43100: Best = 6.257276, Len = 32
# Sphere Evals 44100: Best = 6.257276, Len = 32
# Sphere Evals 45100: Best = 5.253347, Len = 32
# Sphere Evals 46100: Best = 5.253347, Len = 32
# Sphere Evals 47100: Best = 5.253347, Len = 32
# Sphere Evals 48100: Best = 4.382182, Len = 32
# Sphere Evals 49100: Best = 3.608877, Len = 32
# Sphere Evals 50100: Best = 3.608877, Len = 32
# Sphere Evals 51100: Best = 3.302096, Len = 32
# Sphere Evals 52100: Best = 3.302096, Len = 32
# Sphere Evals 53100: Best = 2.573720, Len = 32
# Sphere Evals 54100: Best = 2.573720, Len = 32
# Sphere Evals 55100: Best = 2.573720, Len = 32
# Sphere Evals 56100: Best = 2.573720, Len = 32
# Sphere Evals 57100: Best = 2.573720, Len = 32
# Sphere Evals 58100: Best = 2.264688, Len = 32
# Sphere Evals 59100: Best = 1.587244, Len = 32
# Sphere Evals 60100: Best = 1.587244, Len = 32
# Sphere Evals 61100: Best = 1.386403, Len = 32
# Sphere Evals 62100: Best = 1.386403, Len = 32
# Sphere Evals 63100: Best = 1.386403, Len = 32
# Sphere Evals 64100: Best = 1.386403, Len = 32
# Sphere Evals 65100: Best = 1.162268, Len = 32
# Sphere Evals 66100: Best = 1.086103, Len = 32
# Sphere Evals 67100: Best = 1.086103, Len = 32
# Sphere Evals 68100: Best = 0.756079, Len = 32
# Sphere Evals 69100: Best = 0.756079, Len = 32
# Sphere Evals 70100: Best = 0.756079, Len = 32
# Sphere Evals 71100: Best = 0.755129, Len = 32
# Sphere Evals 72100: Best = 0.755129, Len = 32
# Sphere Evals 73100: Best = 0.700088, Len = 32
# Sphere Evals 74100: Best = 0.438887, Len = 32
# Sphere Evals 75100: Best = 0.438887, Len = 32
# Sphere Evals 76100: Best = 0.438887, Len = 32
# Sphere Evals 77100: Best = 0.438887, Len = 32
# Sphere Evals 78100: Best = 0.284905, Len = 32
# Sphere Evals 79100: Best = 0.284905, Len = 32
# Sphere Evals 80100: Best = 0.275577, Len = 32
# Sphere Evals 81100: Best = 0.263210, Len = 32
# Sphere Evals 82100: Best = 0.244097, Len = 32
# Sphere Evals 83100: Best = 0.244097, Len = 32
# Sphere Evals 84100: Best = 0.215521, Len = 32
# Sphere Evals 85100: Best = 0.190362, Len = 32
# Sphere Evals 86100: Best = 0.179450, Len = 32
# Sphere Evals 87100: Best = 0.151303, Len = 32
# Sphere Evals 88100: Best = 0.130790, Len = 32
# Sphere Evals 89100: Best = 0.125511, Len = 32
# Sphere Evals 90100: Best = 0.104233, Len = 32
# Sphere Evals 91100: Best = 0.089679, Len = 32
# Sphere Evals 92100: Best = 0.076057, Len = 32
# Sphere Evals 93100: Best = 0.076057, Len = 32
# Sphere Evals 94100: Best = 0.062384, Len = 32
# Sphere Evals 95100: Best = 0.051952, Len = 32
# Sphere Evals 96100: Best = 0.035855, Len = 32
# Sphere Evals 97100: Best = 0.030895, Len = 32
# Sphere Evals 98100: Best = 0.026240, Len = 32
# Sphere Evals 99100: Best = 0.026240, Len = 32
# Sphere Evals 100: Best = 33.466867, Len = 30
# Sphere Evals 1100: Best = 33.466867, Len = 30
# Sphere Evals 2100: Best = 33.466867, Len = 30
# Sphere Evals 3100: Best = 33.466867, Len = 30
# Sphere Evals 4100: Best = 33.466867, Len = 30
# Sphere Evals 5100: Best = 17.317508, Len = 30
# Sphere Evals 6100: Best = 17.317508, Len = 30
# Sphere Evals 7100: Best = 17.317508, Len = 30
# Sphere Evals 8100: Best = 17.317508, Len = 30
# Sphere Evals 9100: Best = 17.317508, Len = 30
# Sphere Evals 10100: Best = 17.317508, Len = 30
# Sphere Evals 11100: Best = 17.317508, Len = 30
# Sphere Evals 12100: Best = 17.317508, Len = 30
# Sphere Evals 13100: Best = 17.317508, Len = 30
# Sphere Evals 14100: Best = 17.317508, Len = 30
# Sphere Evals 15100: Best = 17.317508, Len = 30
# Sphere Evals 16100: Best = 17.317508, Len = 30
# Sphere Evals 17100: Best = 17.317508, Len = 30
# Sphere Evals 18100: Best = 17.317508, Len = 30
# Sphere Evals 19100: Best = 17.317508, Len = 30
# Sphere Evals 20100: Best = 17.317508, Len = 30
# Sphere Evals 21100: Best = 17.317508, Len = 30
# Sphere Evals 22100: Best = 17.317508, Len = 30
# Sphere Evals 23100: Best = 17.317508, Len = 30
# Sphere Evals 24100: Best = 17.317508, Len = 30
# Sphere Evals 25100: Best = 17.317508, Len = 30
# Sphere Evals 26100: Best = 17.317508, Len = 30
# Sphere Evals 27100: Best = 17.317508, Len = 30
# Sphere Evals 28100: Best = 16.386886, Len = 32
# Sphere Evals 29100: Best = 16.386886, Len = 32
# Sphere Evals 30100: Best = 16.386886, Len = 32
# Sphere Evals 31100: Best = 16.189137, Len = 31
# Sphere Evals 32100: Best = 15.874213, Len = 31
# Sphere Evals 33100: Best = 14.907293, Len = 31
# Sphere Evals 34100: Best = 13.943384, Len = 31
# Sphere Evals 35100: Best = 11.923573, Len = 32
# Sphere Evals 36100: Best = 10.792788, Len = 32
# Sphere Evals 37100: Best = 9.463716, Len = 32
# Sphere Evals 38100: Best = 9.463716, Len = 32
# Sphere Evals 39100: Best = 7.367470, Len = 32
# Sphere Evals 40100: Best = 7.367470, Len = 32
# Sphere Evals 41100: Best = 7.367470, Len = 32
# Sphere Evals 42100: Best = 6.375755, Len = 32
# Sphere Evals 43100: Best = 6.375755, Len = 32
# Sphere Evals 44100: Best = 4.495852, Len = 32
# Sphere Evals 45100: Best = 4.495852, Len = 32
# Sphere Evals 46100: Best = 4.495852, Len = 32
# Sphere Evals 47100: Best = 3.894108, Len = 32
# Sphere Evals 48100: Best = 3.894108, Len = 32
# Sphere Evals 49100: Best = 3.280270, Len = 32
# Sphere Evals 50100: Best = 3.280270, Len = 32
# Sphere Evals 51100: Best = 3.280270, Len = 32
# Sphere Evals 52100: Best = 2.992396, Len = 32
# Sphere Evals 53100: Best = 2.017046, Len = 32
# Sphere Evals 54100: Best = 2.017046, Len = 32
# Sphere Evals 55100: Best = 2.017046, Len = 32
# Sphere Evals 56100: Best = 2.017046, Len = 32
# Sphere Evals 57100: Best = 2.017046, Len = 32
# Sphere Evals 58100: Best = 2.017046, Len = 32
# Sphere Evals 59100: Best = 1.854812, Len = 32
# Sphere Evals 60100: Best = 1.854812, Len = 32
# Sphere Evals 61100: Best = 1.854812, Len = 32
# Sphere Evals 62100: Best = 1.520536, Len = 32
# Sphere Evals 63100: Best = 1.520536, Len = 32
# Sphere Evals 64100: Best = 1.485391, Len = 32
# Sphere Evals 65100: Best = 1.234315, Len = 32
# Sphere Evals 66100: Best = 1.227879, Len = 32
# Sphere Evals 67100: Best = 1.106812, Len = 32
# Sphere Evals 68100: Best = 0.978851, Len = 32
# Sphere Evals 69100: Best = 0.878106, Len = 32
# Sphere Evals 70100: Best = 0.878106, Len = 32
# Sphere Evals 71100: Best = 0.612946, Len = 32
# Sphere Evals 72100: Best = 0.578229, Len = 32
# Sphere Evals 73100: Best = 0.578229, Len = 32
# Sphere Evals 74100: Best = 0.472122, Len = 32
# Sphere Evals 75100: Best = 0.472122, Len = 32
# Sphere Evals 76100: Best = 0.472122, Len = 32
# Sphere Evals 77100: Best = 0.432687, Len = 32
# Sphere Evals 78100: Best = 0.384928, Len = 32
# Sphere Evals 79100: Best = 0.302174, Len = 32
# Sphere Evals 80100: Best = 0.259544, Len = 32
# Sphere Evals 81100: Best = 0.259544, Len = 32
# Sphere Evals 82100: Best = 0.259544, Len = 32
# Sphere Evals 83100: Best = 0.186195, Len = 32
# Sphere Evals 84100: Best = 0.186195, Len = 32
# Sphere Evals 85100: Best = 0.155874, Len = 32
# Sphere Evals 86100: Best = 0.155874, Len = 32
# Sphere Evals 87100: Best = 0.138446, Len = 32
# Sphere Evals 88100: Best = 0.134050, Len = 32
# Sphere Evals 89100: Best = 0.079220, Len = 32
# Sphere Evals 90100: Best = 0.079220, Len = 32
# Sphere Evals 91100: Best = 0.072763, Len = 32
# Sphere Evals 92100: Best = 0.072763, Len = 32
# Sphere Evals 93100: Best = 0.056469, Len = 32
# Sphere Evals 94100: Best = 0.056469, Len = 32
# Sphere Evals 95100: Best = 0.052890, Len = 32
# Sphere Evals 96100: Best = 0.052177, Len = 32
# Sphere Evals 97100: Best = 0.038932, Len = 32
# Sphere Evals 98100: Best = 0.029498, Len = 32
# Sphere Evals 99100: Best = 0.029498, Len = 32
# Sphere Evals 100: Best = 34.570180, Len = 30
# Sphere Evals 1100: Best = 34.570180, Len = 30
# Sphere Evals 2100: Best = 34.570180, Len = 30
# Sphere Evals 3100: Best = 34.570180, Len = 30
# Sphere Evals 4100: Best = 34.570180, Len = 30
# Sphere Evals 5100: Best = 34.570180, Len = 30
# Sphere Evals 6100: Best = 25.502145, Len = 30
# Sphere Evals 7100: Best = 25.502145, Len = 30
# Sphere Evals 8100: Best = 25.502145, Len = 30
# Sphere Evals 9100: Best = 25.502145, Len = 30
# Sphere Evals 10100: Best = 25.502145, Len = 30
# Sphere Evals 11100: Best = 25.502145, Len = 30
# Sphere Evals 12100: Best = 25.502145, Len = 30
# Sphere Evals 13100: Best = 25.502145, Len = 30
# Sphere Evals 14100: Best = 25.502145, Len = 30
# Sphere Evals 15100: Best = 25.502145, Len = 30
# Sphere Evals 16100: Best = 25.502145, Len = 30
# Sphere Evals 17100: Best = 24.416224, Len = 30
# Sphere Evals 18100: Best = 24.416224, Len = 30
# Sphere Evals 19100: Best = 21.047681, Len = 30
# Sphere Evals 20100: Best = 21.047681, Len = 30
# Sphere Evals 21100: Best = 21.047681, Len = 30
# Sphere Evals 22100: Best = 21.047681, Len = 30
# Sphere Evals 23100: Best = 21.047681, Len = 30
# Sphere Evals 24100: Best = 20.807454, Len = 31
# Sphere Evals 25100: Best = 18.044453, Len = 31
# Sphere Evals 26100: Best = 18.044453, Len = 31
# Sphere Evals 27100: Best = 18.044453, Len = 31
# Sphere Evals 28100: Best = 18.044453, Len = 31
# Sphere Evals 29100: Best = 16.760487, Len = 31
# Sphere Evals 30100: Best = 13.596821, Len = 31
# Sphere Evals 31100: Best = 13.596821, Len = 31
# Sphere Evals 32100: Best = 10.775343, Len = 31
# Sphere Evals 33100: Best = 10.775343, Len = 31
# Sphere Evals 34100: Best = 8.175286, Len = 31
# Sphere Evals 35100: Best = 8.175286, Len = 31
# Sphere Evals 36100: Best = 8.175286, Len = 31
# Sphere Evals 37100: Best = 8.175286, Len = 31
# Sphere Evals 38100: Best = 8.175286, Len = 31
# Sphere Evals 39100: Best = 7.392526, Len = 31
# Sphere Evals 40100: Best = 7.392526, Len = 31
# Sphere Evals 41100: Best = 7.101635, Len = 31
# Sphere Evals 42100: Best = 6.206691, Len = 31
# Sphere Evals 43100: Best = 5.348057, Len = 31
# Sphere Evals 44100: Best = 3.875407, Len = 32
# Sphere Evals 45100: Best = 3.875407, Len = 32
# Sphere Evals 46100: Best = 3.875407, Len = 32
# Sphere Evals 47100: Best = 3.875407, Len = 32
# Sphere Evals 48100: Best = 3.875407, Len = 32
# Sphere Evals 49100: Best = 3.875407, Len = 32
# Sphere Evals 50100: Best = 3.533811, Len = 32
# Sphere Evals 51100: Best = 3.533811, Len = 32
# Sphere Evals 52100: Best = 3.010502, Len = 31
# Sphere Evals 53100: Best = 3.010502, Len = 31
# Sphere Evals 54100: Best = 2.759891, Len = 32
# Sphere Evals 55100: Best = 2.133997, Len = 32
# Sphere Evals 56100: Best = 1.627139, Len = 32
# Sphere Evals 57100: Best = 1.585279, Len = 32
# Sphere Evals 58100: Best = 1.432094, Len = 32
# Sphere Evals 59100: Best = 1.432094, Len = 32
# Sphere Evals 60100: Best = 1.432094, Len = 32
# Sphere Evals 61100: Best = 1.383285, Len = 32
# Sphere Evals 62100: Best = 1.383285, Len = 32
# Sphere Evals 63100: Best = 1.077828, Len = 32
# Sphere Evals 64100: Best = 1.034975, Len = 32
# Sphere Evals 65100: Best = 1.006805, Len = 32
# Sphere Evals 66100: Best = 0.848564, Len = 32
# Sphere Evals 67100: Best = 0.767439, Len = 32
# Sphere Evals 68100: Best = 0.590656, Len = 32
# Sphere Evals 69100: Best = 0.590656, Len = 32
# Sphere Evals 70100: Best = 0.554296, Len = 32
# Sphere Evals 71100: Best = 0.503837, Len = 32
# Sphere Evals 72100: Best = 0.503837, Len = 32
# Sphere Evals 73100: Best = 0.503837, Len = 32
# Sphere Evals 74100: Best = 0.503837, Len = 32
# Sphere Evals 75100: Best = 0.365256, Len = 32
# Sphere Evals 76100: Best = 0.365256, Len = 32
# Sphere Evals 77100: Best = 0.305641, Len = 32
# Sphere Evals 78100: Best = 0.251445, Len = 32
# Sphere Evals 79100: Best = 0.250367, Len = 32
# Sphere Evals 80100: Best = 0.229986, Len = 32
# Sphere Evals 81100: Best = 0.170285, Len = 32
# Sphere Evals 82100: Best = 0.170285, Len = 32
# Sphere Evals 83100: Best = 0.170285, Len = 32
# Sphere Evals 84100: Best = 0.139097, Len = 32
# Sphere Evals 85100: Best = 0.108572, Len = 32
# Sphere Evals 86100: Best = 0.108572, Len = 32
# Sphere Evals 87100: Best = 0.105750, Len = 32
# Sphere Evals 88100: Best = 0.094465, Len = 32
# Sphere Evals 89100: Best = 0.072880, Len = 32
# Sphere Evals 90100: Best = 0.061605, Len = 32
# Sphere Evals 91100: Best = 0.041467, Len = 32
# Sphere Evals 92100: Best = 0.036029, Len = 32
# Sphere Evals 93100: Best = 0.032012, Len = 32
# Sphere Evals 94100: Best = 0.025970, Len = 32
# Sphere Evals 95100: Best = 0.025443, Len = 32
# Sphere Evals 96100: Best = 0.022256, Len = 32
# Sphere Evals 97100: Best = 0.018373, Len = 32
# Sphere Evals 98100: Best = 0.012605, Len = 32
# Sphere Evals 99100: Best = 0.011825, Len = 32
# Sphere Evals 100: Best = 29.110366, Len = 29
# Sphere Evals 1100: Best = 29.110366, Len = 29
# Sphere Evals 2100: Best = 29.110366, Len = 29
# Sphere Evals 3100: Best = 29.110366, Len = 29
# Sphere Evals 4100: Best = 29.110366, Len = 29
# Sphere Evals 5100: Best = 29.110366, Len = 29
# Sphere Evals 6100: Best = 29.110366, Len = 29
# Sphere Evals 7100: Best = 29.110366, Len = 29
# Sphere Evals 8100: Best = 29.110366, Len = 29
# Sphere Evals 9100: Best = 29.110366, Len = 29
# Sphere Evals 10100: Best = 29.110366, Len = 29
# Sphere Evals 11100: Best = 29.110366, Len = 29
# Sphere Evals 12100: Best = 29.110366, Len = 29
# Sphere Evals 13100: Best = 29.110366, Len = 29
# Sphere Evals 14100: Best = 29.110366, Len = 29
# Sphere Evals 15100: Best = 23.543487, Len = 29
# Sphere Evals 16100: Best = 23.543487, Len = 29
# Sphere Evals 17100: Best = 23.490531, Len = 32
# Sphere Evals 18100: Best = 20.359800, Len = 31
# Sphere Evals 19100: Best = 20.359800, Len = 31
# Sphere Evals 20100: Best = 18.035072, Len = 31
# Sphere Evals 21100: Best = 15.615603, Len = 31
# Sphere Evals 22100: Best = 15.615603, Len = 31
# Sphere Evals 23100: Best = 15.615603, Len = 31
# Sphere Evals 24100: Best = 15.615603, Len = 31
# Sphere Evals 25100: Best = 15.615603, Len = 31
# Sphere Evals 26100: Best = 11.691917, Len = 31
# Sphere Evals 27100: Best = 11.691917, Len = 31
# Sphere Evals 28100: Best = 11.691917, Len = 31
# Sphere Evals 29100: Best = 11.691917, Len = 31
# Sphere Evals 30100: Best = 11.691917, Len = 31
# Sphere Evals 31100: Best = 10.626494, Len = 32
# Sphere Evals 32100: Best = 9.904078, Len = 32
# Sphere Evals 33100: Best = 9.904078, Len = 32
# Sphere Evals 34100: Best = 7.520659, Len = 32
# Sphere Evals 35100: Best = 7.520659, Len = 32
# Sphere Evals 36100: Best = 7.520659, Len = 32
# Sphere Evals 37100: Best = 6.617029, Len = 32
# Sphere Evals 38100: Best = 5.162509, Len = 32
# Sphere Evals 39100: Best = 5.162509, Len = 32
# Sphere Evals 40100: Best = 5.162509, Len = 32
# Sphere Evals 41100: Best = 5.112539, Len = 32
# Sphere Evals 42100: Best = 4.647964, Len = 32
# Sphere Evals 43100: Best = 4.207591, Len = 32
# Sphere Evals 44100: Best = 3.189390, Len = 32
# Sphere Evals 45100: Best = 2.989607, Len = 32
# Sphere Evals 46100: Best = 2.989607, Len = 32
# Sphere Evals 47100: Best = 2.452767, Len = 32
# Sphere Evals 48100: Best = 2.264662, Len = 32
# Sphere Evals 49100: Best = 2.117299, Len = 32
# Sphere Evals 50100: Best = 2.115019, Len = 32
# Sphere Evals 51100: Best = 1.742376, Len = 32
# Sphere Evals 52100: Best = 1.281486, Len = 32
# Sphere Evals 53100: Best = 1.221503, Len = 32
# Sphere Evals 54100: Best = 1.221503, Len = 32
# Sphere Evals 55100: Best = 1.108267, Len = 32
# Sphere Evals 56100: Best = 0.835654, Len = 32
# Sphere Evals 57100: Best = 0.835654, Len = 32
# Sphere Evals 58100: Best = 0.748873, Len = 32
# Sphere Evals 59100: Best = 0.535624, Len = 32
# Sphere Evals 60100: Best = 0.535624, Len = 32
# Sphere Evals 61100: Best = 0.515706, Len = 32
# Sphere Evals 62100: Best = 0.419253, Len = 32
# Sphere Evals 63100: Best = 0.331155, Len = 32
# Sphere Evals 64100: Best = 0.291977, Len = 32
# Sphere Evals 65100: Best = 0.291977, Len = 32
# Sphere Evals 66100: Best = 0.246033, Len = 32
# Sphere Evals 67100: Best = 0.246033, Len = 32
# Sphere Evals 68100: Best = 0.241509, Len = 32
# Sphere Evals 69100: Best = 0.179852, Len = 32
# Sphere Evals 70100: Best = 0.178722, Len = 32
# Sphere Evals 71100: Best = 0.148771, Len = 32
# Sphere Evals 72100: Best = 0.116892, Len = 32
# Sphere Evals 73100: Best = 0.116892, Len = 32
# Sphere Evals 74100: Best = 0.088621, Len = 32
# Sphere Evals 75100: Best = 0.084605, Len = 32
# Sphere Evals 76100: Best = 0.084378, Len = 32
# Sphere Evals 77100: Best = 0.065203, Len = 32
# Sphere Evals 78100: Best = 0.052193, Len = 32
# Sphere Evals 79100: Best = 0.048749, Len = 32
# Sphere Evals 80100: Best = 0.033751, Len = 32
# Sphere Evals 81100: Best = 0.033751, Len = 32
# Sphere Evals 82100: Best = 0.032760, Len = 32
# Sphere Evals 83100: Best = 0.027936, Len = 32
# Sphere Evals 84100: Best = 0.022036, Len = 32
# Sphere Evals 85100: Best = 0.021683, Len = 32
# Sphere Evals 86100: Best = 0.017209, Len = 32
# Sphere Evals 87100: Best = 0.016731, Len = 32
# Sphere Evals 88100: Best = 0.014603, Len = 32
# Sphere Evals 89100: Best = 0.010535, Len = 32
# Sphere Evals 90100: Best = 0.009747, Len = 32
# Sphere Evals 91100: Best = 0.009044, Len = 32
# Sphere Evals 92100: Best = 0.006765, Len = 32
# Sphere Evals 93100: Best = 0.004607, Len = 32
# Sphere Evals 94100: Best = 0.004316, Len = 32
# Sphere Evals 95100: Best = 0.004272, Len = 32
# Sphere Evals 96100: Best = 0.003087, Len = 32
# Sphere Evals 97100: Best = 0.002724, Len = 32
# Sphere Evals 98100: Best = 0.002368, Len = 32
# Sphere Evals 99100: Best = 0.001582, Len = 32
# Sphere Evals 100: Best = 30.678955, Len = 28
# Sphere Evals 1100: Best = 30.678955, Len = 28
# Sphere Evals 2100: Best = 30.678955, Len = 28
# Sphere Evals 3100: Best = 30.678955, Len = 28
# Sphere Evals 4100: Best = 30.678955, Len = 28
# Sphere Evals 5100: Best = 30.678955, Len = 28
# Sphere Evals 6100: Best = 30.678955, Len = 28
# Sphere Evals 7100: Best = 30.678955, Len = 28
# Sphere Evals 8100: Best = 30.678955, Len = 28
# Sphere Evals 9100: Best = 30.678955, Len = 28
# Sphere Evals 10100: Best = 30.678955, Len = 28
# Sphere Evals 11100: Best = 30.678955, Len = 28
# Sphere Evals 12100: Best = 30.678955, Len = 28
# Sphere Evals 13100: Best = 30.678955, Len = 28
# Sphere Evals 14100: Best = 30.678955, Len = 28
# Sphere Evals 15100: Best = 30.678955, Len = 28
# Sphere Evals 16100: Best = 30.678955, Len = 28
# Sphere Evals 17100: Best = 30.678955, Len = 28
# Sphere Evals 18100: Best = 30.678955, Len = 28
# Sphere Evals 19100: Best = 26.108815, Len = 30
# Sphere Evals 20100: Best = 26.108815, Len = 30
# Sphere Evals 21100: Best = 26.108815, Len = 30
# Sphere Evals 22100: Best = 23.707785, Len = 30
# Sphere Evals 23100: Best = 23.707785, Len = 30
# Sphere Evals 24100: Best = 23.707785, Len = 30
# Sphere Evals 25100: Best = 23.707785, Len = 30
# Sphere Evals 26100: Best = 23.619080, Len = 30
# Sphere Evals 27100: Best = 15.217650, Len = 31
# Sphere Evals 28100: Best = 15.217650, Len = 31
# Sphere Evals 29100: Best = 15.217650, Len = 31
# Sphere Evals 30100: Best = 15.217650, Len = 31
# Sphere Evals 31100: Best = 15.217650, Len = 31
# Sphere Evals 32100: Best = 15.217650, Len = 31
# Sphere Evals 33100: Best = 15.217650, Len = 31
# Sphere Evals 34100: Best = 13.661354, Len = 31
# Sphere Evals 35100: Best = 13.316119, Len = 31
# Sphere Evals 36100: Best = 10.890874, Len = 31
# Sphere Evals 37100: Best = 10.890874, Len = 31
# Sphere Evals 38100: Best = 9.769828, Len = 32
# Sphere Evals 39100: Best = 9.636337, Len = 32
# Sphere Evals 40100: Best = 8.045171, Len = 32
# Sphere Evals 41100: Best = 8.045171, Len = 32
# Sphere Evals 42100: Best = 5.949420, Len = 32
# Sphere Evals 43100: Best = 5.949420, Len = 32
# Sphere Evals 44100: Best = 5.949420, Len = 32
# Sphere Evals 45100: Best = 5.327757, Len = 32
# Sphere Evals 46100: Best = 4.513438, Len = 32
# Sphere Evals 47100: Best = 4.513438, Len = 32
# Sphere Evals 48100: Best = 3.313635, Len = 32
# Sphere Evals 49100: Best = 3.313635, Len = 32
# Sphere Evals 50100: Best = 3.313635, Len = 32
# Sphere Evals 51100: Best = 3.105366, Len = 32
# Sphere Evals 52100: Best = 2.697822, Len = 32
# Sphere Evals 53100: Best = 2.697822, Len = 32
# Sphere Evals 54100: Best = 2.527553, Len = 32
# Sphere Evals 55100: Best = 2.152615, Len = 32
# Sphere Evals 56100: Best = 1.971656, Len = 32
# Sphere Evals 57100: Best = 1.561715, Len = 32
# Sphere Evals 58100: Best = 1.561715, Len = 32
# Sphere Evals 59100: Best = 1.561715, Len = 32
# Sphere Evals 60100: Best = 1.469382, Len = 32
# Sphere Evals 61100: Best = 1.469382, Len = 32
# Sphere Evals 62100: Best = 1.402207, Len = 32
# Sphere Evals 63100: Best = 1.096153, Len = 32
# Sphere Evals 64100: Best = 1.047505, Len = 32
# Sphere Evals 65100: Best = 1.047505, Len = 32
# Sphere Evals 66100: Best = 1.030366, Len = 32
# Sphere Evals 67100: Best = 0.812326, Len = 32
# Sphere Evals 68100: Best = 0.812326, Len = 32
# Sphere Evals 69100: Best = 0.812326, Len = 32
# Sphere Evals 70100: Best = 0.812326, Len = 32
# Sphere Evals 71100: Best = 0.678204, Len = 32
# Sphere Evals 72100: Best = 0.558118, Len = 32
# Sphere Evals 73100: Best = 0.325564, Len = 32
# Sphere Evals 74100: Best = 0.325564, Len = 32
# Sphere Evals 75100: Best = 0.319761, Len = 32
# Sphere Evals 76100: Best = 0.319761, Len = 32
# Sphere Evals 77100: Best = 0.283023, Len = 32
# Sphere Evals 78100: Best = 0.283023, Len = 32
# Sphere Evals 79100: Best = 0.269280, Len = 32
# Sphere Evals 80100: Best = 0.237891, Len = 32
# Sphere Evals 81100: Best = 0.236366, Len = 32
# Sphere Evals 82100: Best = 0.215259, Len = 32
# Sphere Evals 83100: Best = 0.200813, Len = 32
# Sphere Evals 84100: Best = 0.174179, Len = 32
# Sphere Evals 85100: Best = 0.174179, Len = 32
# Sphere Evals 86100: Best = 0.119767, Len = 32
# Sphere Evals 87100: Best = 0.119767, Len = 32
# Sphere Evals 88100: Best = 0.099141, Len = 32
# Sphere Evals 89100: Best = 0.073680, Len = 32
# Sphere Evals 90100: Best = 0.073680, Len = 32
# Sphere Evals 91100: Best = 0.073680, Len = 32
# Sphere Evals 92100: Best = 0.071524, Len = 32
# Sphere Evals 93100: Best = 0.052966, Len = 32
# Sphere Evals 94100: Best = 0.046787, Len = 32
# Sphere Evals 95100: Best = 0.025740, Len = 32
# Sphere Evals 96100: Best = 0.025740, Len = 32
# Sphere Evals 97100: Best = 0.015483, Len = 32
# Sphere Evals 98100: Best = 0.015483, Len = 32
# Sphere Evals 99100: Best = 0.015483, Len = 32
# Sphere Evals 100: Best = 33.278777, Len = 30
# Sphere Evals 1100: Best = 33.278777, Len = 30
# Sphere Evals 2100: Best = 33.278777, Len = 30
# Sphere Evals 3100: Best = 33.278777, Len = 30
# Sphere Evals 4100: Best = 33.278777, Len = 30
# Sphere Evals 5100: Best = 33.278777, Len = 30
# Sphere Evals 6100: Best = 33.278777, Len = 30
# Sphere Evals 7100: Best = 33.278777, Len = 30
# Sphere Evals 8100: Best = 33.278777, Len = 30
# Sphere Evals 9100: Best = 33.278777, Len = 30
# Sphere Evals 10100: Best = 33.278777, Len = 30
# Sphere Evals 11100: Best = 29.566460, Len = 31
# Sphere Evals 12100: Best = 29.566460, Len = 31
# Sphere Evals 13100: Best = 29.566460, Len = 31
# Sphere Evals 14100: Best = 29.566460, Len = 31
# Sphere Evals 15100: Best = 27.099232, Len = 31
# Sphere Evals 16100: Best = 27.099232, Len = 31
# Sphere Evals 17100: Best = 27.099232, Len = 31
# Sphere Evals 18100: Best = 27.099232, Len = 31
# Sphere Evals 19100: Best = 26.349207, Len = 31
# Sphere Evals 20100: Best = 26.349207, Len = 31
# Sphere Evals 21100: Best = 18.398961, Len = 32
# Sphere Evals 22100: Best = 18.398961, Len = 32
# Sphere Evals 23100: Best = 18.398961, Len = 32
# Sphere Evals 24100: Best = 18.398961, Len = 32
# Sphere Evals 25100: Best = 18.398961, Len = 32
# Sphere Evals 26100: Best = 18.398961, Len = 32
# Sphere Evals 27100: Best = 18.398961, Len = 32
# Sphere Evals 28100: Best = 17.937771, Len = 31
# Sphere Evals 29100: Best = 14.734697, Len = 31
# Sphere Evals 30100: Best = 13.655231, Len = 31
# Sphere Evals 31100: Best = 13.655231, Len = 31
# Sphere Evals 32100: Best = 13.655231, Len = 31
# Sphere Evals 33100: Best = 11.224518, Len = 31
# Sphere Evals 34100: Best = 11.224518, Len = 31
# Sphere Evals 35100: Best = 10.776931, Len = 32
# Sphere Evals 36100: Best = 10.062909, Len = 31
# Sphere Evals 37100: Best = 10.062909, Len = 31
# Sphere Evals 38100: Best = 9.300265, Len = 32
# Sphere Evals 39100: Best = 9.300265, Len = 32
# Sphere Evals 40100: Best = 8.960279, Len = 32
# Sphere Evals 41100: Best = 7.765984, Len = 32
# Sphere Evals 42100: Best = 5.772201, Len = 32
# Sphere Evals 43100: Best = 5.772201, Len = 32
# Sphere Evals 44100: Best = 5.693642, Len = 32
# Sphere Evals 45100: Best = 4.725312, Len = 32
# Sphere Evals 46100: Best = 3.862492, Len = 32
# Sphere Evals 47100: Best = 3.862492, Len = 32
# Sphere Evals 48100: Best = 3.862492, Len = 32
# Sphere Evals 49100: Best = 3.639677, Len = 32
# Sphere Evals 50100: Best = 2.803248, Len = 32
# Sphere Evals 51100: Best = 2.803248, Len = 32
# Sphere Evals 52100: Best = 2.633344, Len = 32
# Sphere Evals 53100: Best = 2.411712, Len = 32
# Sphere Evals 54100: Best = 2.148699, Len = 32
# Sphere Evals 55100: Best = 1.691197, Len = 32
# Sphere Evals 56100: Best = 1.474542, Len = 32
# Sphere Evals 57100: Best = 1.474542, Len = 32
# Sphere Evals 58100: Best = 0.998439, Len = 32
# Sphere Evals 59100: Best = 0.998439, Len = 32
# Sphere Evals 60100: Best = 0.998439, Len = 32
# Sphere Evals 61100: Best = 0.844071, Len = 32
# Sphere Evals 62100: Best = 0.844071, Len = 32
# Sphere Evals 63100: Best = 0.844071, Len = 32
# Sphere Evals 64100: Best = 0.678249, Len = 32
# Sphere Evals 65100: Best = 0.678249, Len = 32
# Sphere Evals 66100: Best = 0.481224, Len = 32
# Sphere Evals 67100: Best = 0.466723, Len = 32
# Sphere Evals 68100: Best = 0.466723, Len = 32
# Sphere Evals 69100: Best = 0.338980, Len = 32
# Sphere Evals 70100: Best = 0.338980, Len = 32
# Sphere Evals 71100: Best = 0.310348, Len = 32
# Sphere Evals 72100: Best = 0.227884, Len = 32
# Sphere Evals 73100: Best = 0.227884, Len = 32
# Sphere Evals 74100: Best = 0.195202, Len = 32
# Sphere Evals 75100: Best = 0.189488, Len = 32
# Sphere Evals 76100: Best = 0.155716, Len = 32
# Sphere Evals 77100: Best = 0.105702, Len = 32
# Sphere Evals 78100: Best = 0.100295, Len = 32
# Sphere Evals 79100: Best = 0.093758, Len = 32
# Sphere Evals 80100: Best = 0.089491, Len = 32
# Sphere Evals 81100: Best = 0.089352, Len = 32
# Sphere Evals 82100: Best = 0.074043, Len = 32
# Sphere Evals 83100: Best = 0.063363, Len = 32
# Sphere Evals 84100: Best = 0.055362, Len = 32
# Sphere Evals 85100: Best = 0.055362, Len = 32
# Sphere Evals 86100: Best = 0.045137, Len = 32
# Sphere Evals 87100: Best = 0.045137, Len = 32
# Sphere Evals 88100: Best = 0.035081, Len = 32
# Sphere Evals 89100: Best = 0.026838, Len = 32
# Sphere Evals 90100: Best = 0.018703, Len = 32
# Sphere Evals 91100: Best = 0.018703, Len = 32
# Sphere Evals 92100: Best = 0.018703, Len = 32
# Sphere Evals 93100: Best = 0.014384, Len = 32
# Sphere Evals 94100: Best = 0.012239, Len = 32
# Sphere Evals 95100: Best = 0.009054, Len = 32
# Sphere Evals 96100: Best = 0.007930, Len = 32
# Sphere Evals 97100: Best = 0.005996, Len = 32
# Sphere Evals 98100: Best = 0.005307, Len = 32
# Sphere Evals 99100: Best = 0.003976, Len = 32
# Sphere Evals 100: Best = 20.782541, Len = 28
# Sphere Evals 1100: Best = 20.782541, Len = 28
# Sphere Evals 2100: Best = 20.782541, Len = 28
# Sphere Evals 3100: Best = 20.782541, Len = 28
# Sphere Evals 4100: Best = 20.782541, Len = 28
# Sphere Evals 5100: Best = 20.782541, Len = 28
# Sphere Evals 6100: Best = 20.782541, Len = 28
# Sphere Evals 7100: Best = 20.782541, Len = 28
# Sphere Evals 8100: Best = 20.782541, Len = 28
# Sphere Evals 9100: Best = 20.782541, Len = 28
# Sphere Evals 10100: Best = 20.782541, Len = 28
# Sphere Evals 11100: Best = 20.782541, Len = 28
# Sphere Evals 12100: Best = 20.782541, Len = 28
# Sphere Evals 13100: Best = 17.688144, Len = 29
# Sphere Evals 14100: Best = 17.688144, Len = 29
# Sphere Evals 15100: Best = 17.688144, Len = 29
# Sphere Evals 16100: Best = 17.688144, Len = 29
# Sphere Evals 17100: Best = 17.688144, Len = 29
# Sphere Evals 18100: Best = 17.688144, Len = 29
# Sphere Evals 19100: Best = 17.688144, Len = 29
# Sphere Evals 20100: Best = 17.688144, Len = 29
# Sphere Evals 21100: Best = 17.688144, Len = 29
# Sphere Evals 22100: Best = 17.688144, Len = 29
# Sphere Evals 23100: Best = 17.664476, Len = 32
# Sphere Evals 24100: Best = 14.552363, Len = 32
# Sphere Evals 25100: Best = 14.552363, Len = 32
# Sphere Evals 26100: Best = 14.552363, Len = 32
# Sphere Evals 27100: Best = 13.749512, Len = 32
# Sphere Evals 28100: Best = 13.688518, Len = 32
# Sphere Evals 29100: Best = 12.443940, Len = 32
# Sphere Evals 30100: Best = 12.443940, Len = 32
# Sphere Evals 31100: Best = 12.058793, Len = 32
# Sphere Evals 32100: Best = 10.600325, Len = 32
# Sphere Evals 33100: Best = 10.600325, Len = 32
# Sphere Evals 34100: Best = 10.575007, Len = 32
# Sphere Evals 35100: Best = 8.517296, Len = 32
# Sphere Evals 36100: Best = 8.517296, Len = 32
# Sphere Evals 37100: Best = 7.260770, Len = 32
# Sphere Evals 38100: Best = 6.946832, Len = 32
# Sphere Evals 39100: Best = 6.946832, Len = 32
# Sphere Evals 40100: Best = 5.855439, Len = 32
# Sphere Evals 41100: Best = 5.735541, Len = 32
# Sphere Evals 42100: Best = 4.865859, Len = 32
# Sphere Evals 43100: Best = 4.787914, Len = 32
# Sphere Evals 44100: Best = 4.092186, Len = 32
# Sphere Evals 45100: Best = 3.778227, Len = 32
# Sphere Evals 46100: Best = 2.251056, Len = 32
# Sphere Evals 47100: Best = 2.251056, Len = 32
# Sphere Evals 48100: Best = 2.251056, Len = 32
# Sphere Evals 49100: Best = 2.251056, Len = 32
# Sphere Evals 50100: Best = 2.116508, Len = 32
# Sphere Evals 51100: Best = 1.876837, Len = 32
# Sphere Evals 52100: Best = 1.790638, Len = 32
# Sphere Evals 53100: Best = 1.273366, Len = 32
# Sphere Evals 54100: Best = 1.118740, Len = 32
# Sphere Evals 55100: Best = 1.118740, Len = 32
# Sphere Evals 56100: Best = 1.002881, Len = 32
# Sphere Evals 57100: Best = 0.998889, Len = 32
# Sphere Evals 58100: Best = 0.949254, Len = 32
# Sphere Evals 59100: Best = 0.949254, Len = 32
# Sphere Evals 60100: Best = 0.805944, Len = 32
# Sphere Evals 61100: Best = 0.667380, Len = 32
# Sphere Evals 62100: Best = 0.446283, Len = 32
# Sphere Evals 63100: Best = 0.446283, Len = 32
# Sphere Evals 64100: Best = 0.446283, Len = 32
# Sphere Evals 65100: Best = 0.446283, Len = 32
# Sphere Evals 66100: Best = 0.297798, Len = 32
# Sphere Evals 67100: Best = 0.242155, Len = 32
# Sphere Evals 68100: Best = 0.242155, Len = 32
# Sphere Evals 69100: Best = 0.242155, Len = 32
# Sphere Evals 70100: Best = 0.242155, Len = 32
# Sphere Evals 71100: Best = 0.192712, Len = 32
# Sphere Evals 72100: Best = 0.192712, Len = 32
# Sphere Evals 73100: Best = 0.181811, Len = 32
# Sphere Evals 74100: Best = 0.143768, Len = 32
# Sphere Evals 75100: Best = 0.132907, Len = 32
# Sphere Evals 76100: Best = 0.114475, Len = 32
# Sphere Evals 77100: Best = 0.101971, Len = 32
# Sphere Evals 78100: Best = 0.080813, Len = 32
# Sphere Evals 79100: Best = 0.070702, Len = 32
# Sphere Evals 80100: Best = 0.070702, Len = 32
# Sphere Evals 81100: Best = 0.059795, Len = 32
# Sphere Evals 82100: Best = 0.059795, Len = 32
# Sphere Evals 83100: Best = 0.045736, Len = 32
# Sphere Evals 84100: Best = 0.045736, Len = 32
# Sphere Evals 85100: Best = 0.031694, Len = 32
# Sphere Evals 86100: Best = 0.027983, Len = 32
# Sphere Evals 87100: Best = 0.027983, Len = 32
# Sphere Evals 88100: Best = 0.022124, Len = 32
# Sphere Evals 89100: Best = 0.020691, Len = 32
# Sphere Evals 90100: Best = 0.020691, Len = 32
# Sphere Evals 91100: Best = 0.018595, Len = 32
# Sphere Evals 92100: Best = 0.016885, Len = 32
# Sphere Evals 93100: Best = 0.011750, Len = 32
# Sphere Evals 94100: Best = 0.009469, Len = 32
# Sphere Evals 95100: Best = 0.006712, Len = 32
# Sphere Evals 96100: Best = 0.006712, Len = 32
# Sphere Evals 97100: Best = 0.004244, Len = 32
# Sphere Evals 98100: Best = 0.003566, Len = 32
# Sphere Evals 99100: Best = 0.002544, Len = 32
# Sphere Evals 100: Best = 31.942623, Len = 29
# Sphere Evals 1100: Best = 31.942623, Len = 29
# Sphere Evals 2100: Best = 31.942623, Len = 29
# Sphere Evals 3100: Best = 31.942623, Len = 29
# Sphere Evals 4100: Best = 31.942623, Len = 29
# Sphere Evals 5100: Best = 25.371736, Len = 29
# Sphere Evals 6100: Best = 25.371736, Len = 29
# Sphere Evals 7100: Best = 25.371736, Len = 29
# Sphere Evals 8100: Best = 25.371736, Len = 29
# Sphere Evals 9100: Best = 25.371736, Len = 29
# Sphere Evals 10100: Best = 25.371736, Len = 29
# Sphere Evals 11100: Best = 25.371736, Len = 29
# Sphere Evals 12100: Best = 25.371736, Len = 29
# Sphere Evals 13100: Best = 25.371736, Len = 29
# Sphere Evals 14100: Best = 25.371736, Len = 29
# Sphere Evals 15100: Best = 25.371736, Len = 29
# Sphere Evals 16100: Best = 25.371736, Len = 29
# Sphere Evals 17100: Best = 25.371736, Len = 29
# Sphere Evals 18100: Best = 25.371736, Len = 29
# Sphere Evals 19100: Best = 25.371736, Len = 29
# Sphere Evals 20100: Best = 25.371736, Len = 29
# Sphere Evals 21100: Best = 25.371736, Len = 29
# Sphere Evals 22100: Best = 17.619555, Len = 29
# Sphere Evals 23100: Best = 17.619555, Len = 29
# Sphere Evals 24100: Best = 17.619555, Len = 29
# Sphere Evals 25100: Best = 17.619555, Len = 29
# Sphere Evals 26100: Best = 17.619555, Len = 29
# Sphere Evals 27100: Best = 16.247882, Len = 30
# Sphere Evals 28100: Best = 16.247882, Len = 30
# Sphere Evals 29100: Best = 16.247882, Len = 30
# Sphere Evals 30100: Best = 14.910288, Len = 30
# Sphere Evals 31100: Best = 14.910288, Len = 30
# Sphere Evals 32100: Best = 14.180151, Len = 30
# Sphere Evals 33100: Best = 14.180151, Len = 30
# Sphere Evals 34100: Best = 14.180151, Len = 30
# Sphere Evals 35100: Best = 14.180151, Len = 30
# Sphere Evals 36100: Best = 13.144987, Len = 30
# Sphere Evals 37100: Best = 11.408451, Len = 30
# Sphere Evals 38100: Best = 11.104612, Len = 31
# Sphere Evals 39100: Best = 9.162634, Len = 31
# Sphere Evals 40100: Best = 9.162634, Len = 31
# Sphere Evals 41100: Best = 9.162634, Len = 31
# Sphere Evals 42100: Best = 6.499163, Len = 31
# Sphere Evals 43100: Best = 6.499163, Len = 31
# Sphere Evals 44100: Best = 6.499163, Len = 31
# Sphere Evals 45100: Best = 6.499163, Len = 31
# Sphere Evals 46100: Best = 6.499163, Len = 31
# Sphere Evals 47100: Best = 5.461129, Len = 31
# Sphere Evals 48100: Best = 4.383190, Len = 31
# Sphere Evals 49100: Best = 4.383190, Len = 31
# Sphere Evals 50100: Best = 3.905801, Len = 31
# Sphere Evals 51100: Best = 3.535780, Len = 31
# Sphere Evals 52100: Best = 3.535780, Len = 31
# Sphere Evals 53100: Best = 3.110098, Len = 32
# Sphere Evals 54100: Best = 3.110098, Len = 32
# Sphere Evals 55100: Best = 3.110098, Len = 32
# Sphere Evals 56100: Best = 2.612805, Len = 32
# Sphere Evals 57100: Best = 2.159288, Len = 31
# Sphere Evals 58100: Best = 2.035811, Len = 32
# Sphere Evals 59100: Best = 2.035811, Len = 32
# Sphere Evals 60100: Best = 2.035811, Len = 32
# Sphere Evals 61100: Best = 2.035811, Len = 32
# Sphere Evals 62100: Best = 1.921477, Len = 32
# Sphere Evals 63100: Best = 1.440512, Len = 32
# Sphere Evals 64100: Best = 1.440512, Len = 32
# Sphere Evals 65100: Best = 1.440512, Len = 32
# Sphere Evals 66100: Best = 1.219285, Len = 32
# Sphere Evals 67100: Best = 0.991905, Len = 32
# Sphere Evals 68100: Best = 0.991905, Len = 32
# Sphere Evals 69100: Best = 0.857764, Len = 32
# Sphere Evals 70100: Best = 0.622726, Len = 32
# Sphere Evals 71100: Best = 0.622726, Len = 32
# Sphere Evals 72100: Best = 0.621667, Len = 32
# Sphere Evals 73100: Best = 0.574806, Len = 32
# Sphere Evals 74100: Best = 0.574806, Len = 32
# Sphere Evals 75100: Best = 0.510004, Len = 32
# Sphere Evals 76100: Best = 0.507693, Len = 32
# Sphere Evals 77100: Best = 0.458688, Len = 32
# Sphere Evals 78100: Best = 0.343979, Len = 32
# Sphere Evals 79100: Best = 0.343979, Len = 32
# Sphere Evals 80100: Best = 0.330891, Len = 32
# Sphere Evals 81100: Best = 0.330891, Len = 32
# Sphere Evals 82100: Best = 0.283625, Len = 32
# Sphere Evals 83100: Best = 0.283625, Len = 32
# Sphere Evals 84100: Best = 0.209946, Len = 32
# Sphere Evals 85100: Best = 0.209946, Len = 32
# Sphere Evals 86100: Best = 0.199846, Len = 32
# Sphere Evals 87100: Best = 0.162424, Len = 32
# Sphere Evals 88100: Best = 0.117960, Len = 32
# Sphere Evals 89100: Best = 0.117960, Len = 32
# Sphere Evals 90100: Best = 0.104421, Len = 32
# Sphere Evals 91100: Best = 0.090636, Len = 32
# Sphere Evals 92100: Best = 0.090636, Len = 32
# Sphere Evals 93100: Best = 0.077686, Len = 32
# Sphere Evals 94100: Best = 0.050056, Len = 32
# Sphere Evals 95100: Best = 0.050056, Len = 32
# Sphere Evals 96100: Best = 0.035296, Len = 32
# Sphere Evals 97100: Best = 0.035296, Len = 32
# Sphere Evals 98100: Best = 0.030666, Len = 32
# Sphere Evals 99100: Best = 0.029422, Len = 32
# Sphere Evals 100: Best = 28.230375, Len = 32
# Sphere Evals 1100: Best = 28.230375, Len = 32
# Sphere Evals 2100: Best = 28.230375, Len = 32
# Sphere Evals 3100: Best = 28.230375, Len = 32
# Sphere Evals 4100: Best = 28.230375, Len = 32
# Sphere Evals 5100: Best = 28.230375, Len = 32
# Sphere Evals 6100: Best = 28.230375, Len = 32
# Sphere Evals 7100: Best = 28.230375, Len = 32
# Sphere Evals 8100: Best = 28.230375, Len = 32
# Sphere Evals 9100: Best = 28.230375, Len = 32
# Sphere Evals 10100: Best = 28.230375, Len = 32
# Sphere Evals 11100: Best = 28.230375, Len = 32
# Sphere Evals 12100: Best = 28.230375, Len = 32
# Sphere Evals 13100: Best = 28.230375, Len = 32
# Sphere Evals 14100: Best = 21.019323, Len = 32
# Sphere Evals 15100: Best = 21.019323, Len = 32
# Sphere Evals 16100: Best = 21.019323, Len = 32
# Sphere Evals 17100: Best = 21.019323, Len = 32
# Sphere Evals 18100: Best = 21.019323, Len = 32
# Sphere Evals 19100: Best = 21.019323, Len = 32
# Sphere Evals 20100: Best = 21.019323, Len = 32
# Sphere Evals 21100: Best = 21.019323, Len = 32
# Sphere Evals 22100: Best = 21.019323, Len = 32
# Sphere Evals 23100: Best = 20.599051, Len = 32
# Sphere Evals 24100: Best = 20.599051, Len = 32
# Sphere Evals 25100: Best = 17.390024, Len = 32
# Sphere Evals 26100: Best = 13.655544, Len = 32
# Sphere Evals 27100: Best = 13.655544, Len = 32
# Sphere Evals 28100: Best = 13.655544, Len = 32
# Sphere Evals 29100: Best = 13.655544, Len = 32
# Sphere Evals 30100: Best = 13.655544, Len = 32
