# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE = 100
N_EVALS = 100000
N_REPLICATES = 30
MIN_LEN = 3
MAX_LEN = 100
gene_low, gene_high = -2.0, 2.0

F_INIT = 0.8
CR_INIT = 0.9
P_LEN_CHANGE = 0.05

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir = f'DE_VariableDimensions_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_summary = os.path.join(out_dir, 'DE_results.csv')
csv_history = os.path.join(out_dir, 'DE_history.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=2):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

def loadSantaFeMap(path='santafe_trail.txt'):
    world_rows = []
    start_x = start_y = None
    with open(path) as f:
        for y,line in enumerate(f):
            row=[]
            for x,c in enumerate(line.rstrip("\n")):
                if c=='#': row.append(1)
                elif c in ('.','S'):
                    row.append(0)
                    if c=='S': start_x,start_y = x,y
            if row: world_rows.append(row)
    if not world_rows: raise ValueError(f'No valid rows in map: {path}')
    H=len(world_rows); W=len(world_rows[0])
    for r in world_rows:
        if len(r)!=W: raise ValueError('Inconsistent row lengths.')
    world=[c for row in world_rows for c in row]
    if start_x is None or start_y is None: start_x=start_y=0
    return world, W, H, start_x, start_y

world, W, H, START_X, START_Y = loadSantaFeMap()

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x*x for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x*x-10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        s = sum(x*x for x in ind)
        p = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + s/4000. - p + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        s = sum(x*x for x in ind)
        c = sum(cos(2*pi*x) for x in ind)
        return -20*exp(-0.2*sqrt(s/d)) - exp(c/d) + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    xs = np.linspace(-1,1,20)
    def f(ind):
        err=0
        for x in xs:
            t = x**4 + x**3 + x**2 + x
            p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (p-t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, cap):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel=[int(round(x))%2 for x in ind[:len(items)]]
        w_sum=sum(w for (w,v),s in zip(items,sel) if s)
        v_sum=sum(v for (w,v),s in zip(items,sel) if s)
        over=max(0,w_sum-cap)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target=2**N
    pen=mkPenalizer(d_target,lam)
    def f(ind):
        table=[int(round(x))%2 for x in ind[:d_target]]
        errs=0
        for i in range(d_target):
            target = bin(i).count('1')%2
            if i < len(table):
                if table[i]!=target: errs+=1
            else:
                errs+=1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        dir=0; x,y=START_X,START_Y; food=0
        visited = world.copy()
        idx=lambda xx,yy: (yy%H)*W + (xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)]==1:
                food+=1; visited[idx(x,y)]=0
            act = int(abs(ind[i]))%3
            if act==0:
                dx,dy=[(0,1),(1,0),(0,-1),(-1,0)][dir]; x+=dx; y+=dy
            elif act==1:
                dir=(dir+1)%4
            else:
                dir=(dir-1)%4
        return -food + pen(ind)
    return f

# %%
def generateInd():
    length = random.randint(MIN_LEN, MAX_LEN)
    return [random.uniform(gene_low, gene_high) for _ in range(length)]

def initPop():
    return [generateInd() for _ in range(POP_SIZE)]

# %%
def DEMutate(pop, j, F):
    idxs=list(range(len(pop)))
    idxs.remove(j)
    a,b,c = random.sample(idxs,3)
    va, vb, vc = pop[a], pop[b], pop[c]
    d_mut = min(len(va), len(vb), len(vc))
    mutant = [va[i] + F*(vb[i] - vc[i]) for i in range(d_mut)]
    if random.random() < P_LEN_CHANGE:
        if random.random() < 0.5 and len(mutant) < MAX_LEN:
            mutant.append(random.uniform(gene_low, gene_high))
        elif len(mutant) > MIN_LEN:
            mutant.pop(random.randrange(len(mutant)))
    while len(mutant) < MIN_LEN:
        mutant.append(random.uniform(gene_low, gene_high))
    return mutant[:MAX_LEN]

def DECrossover(target, mutant, CR):
    dt, dm = len(target), len(mutant)
    L = max(dt, dm)
    j_rand = random.randrange(L)
    trial = []
    for i in range(L):
        if random.random() < CR or i == j_rand:
            if i < dm:
                trial.append(mutant[i])
            else:
                trial.append(random.uniform(gene_low, gene_high))
        else:
            if i < dt:
                trial.append(target[i])
            else:
                trial.append(random.uniform(gene_low, gene_high))
    while len(trial) < MIN_LEN:
        trial.append(random.uniform(gene_low, gene_high))
    return trial[:MAX_LEN]

# %%
def runDE(fit_func, name):
    pop = initPop()
    evals = 0
    best_hist = []
    while evals < N_EVALS:
        gen_idx = len(best_hist)
        F = F_INIT * (1 - gen_idx/(N_EVALS/POP_SIZE))
        CR = CR_INIT * (1 - 0.5*gen_idx/(N_EVALS/POP_SIZE))
        new_pop = []
        for j, x in enumerate(pop):
            mutant = DEMutate(pop, j, F)
            trial = DECrossover(x, mutant, CR)
            new_pop.append(trial if fit_func(trial) <= fit_func(x) else x)
        pop = new_pop
        evals += POP_SIZE
        best = fit_func(min(pop, key=fit_func))
        best_hist.append((evals, best))
        if gen_idx % 10 == 0:
            elite = min(pop, key=fit_func)
            print(f'{name} Evals {evals}: Best = {best:.6f}, Len = {len(elite)}')
    best_ind = min(pop, key=fit_func)
    return best_ind, best_hist

# %%
with open(csv_summary, 'w', newline='') as fs, open(csv_history, 'w', newline='') as fh:
    writer_sum = csv.DictWriter(fs, fieldnames=['run_id','benchmark','replicate','seed','best','len_final','cpu_s'])
    writer_hist = csv.DictWriter(fh, fieldnames=['run_id','benchmark','replicate','seed','evals','fitness'])
    writer_sum.writeheader()
    writer_hist.writeheader()

    items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        'Sphere': sphere(30,10),
        'Rastrigin': rastrigin(30,10),
        'Griewank': griewank(30,10),
        'Ackley': ackley(30,10),
        'Koza': koza(10,10),
        'Knapsack': knapsack(20,0,items,50),
        'Parity': parity(6,10),
        'SantaFe': santaFe(100,10)
    }

    for name, func in benchmarks.items():
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed); np.random.seed(seed)
            start = time.perf_counter()
            best_ind, history = runDE(func, name)
            cpu = time.perf_counter() - start
            best_val = round(func(best_ind), 6)
            run_id = uuid.uuid4()
            writer_sum.writerow({
                'run_id': run_id,
                'benchmark': name,
                'replicate': rep,
                'seed': seed,
                'best': best_val,
                'len_final': len(best_ind),
                'cpu_s': round(cpu,4)
            })
            for ev, fitval in history:
                writer_hist.writerow({
                    'run_id': run_id,
                    'benchmark': name,
                    'replicate': rep,
                    'seed': seed,
                    'evals': ev,
                    'fitness': fitval
                })
print(f'Results written to {csv_summary} and history to {csv_history}')
# Out:
# Koza Evals 63100: Best = 1.259235, Len = 12
# Koza Evals 64100: Best = 1.259235, Len = 12
# Koza Evals 65100: Best = 1.259235, Len = 12
# Koza Evals 66100: Best = 1.259235, Len = 12
# Koza Evals 67100: Best = 1.259235, Len = 12
# Koza Evals 68100: Best = 1.259235, Len = 12
# Koza Evals 69100: Best = 1.259235, Len = 12
# Koza Evals 70100: Best = 1.259235, Len = 12
# Koza Evals 71100: Best = 1.259235, Len = 12
# Koza Evals 72100: Best = 1.259235, Len = 12
# Koza Evals 73100: Best = 1.259235, Len = 12
# Koza Evals 74100: Best = 1.259235, Len = 12
# Koza Evals 75100: Best = 1.259235, Len = 12
# Koza Evals 76100: Best = 1.259235, Len = 12
# Koza Evals 77100: Best = 1.259235, Len = 12
# Koza Evals 78100: Best = 1.259235, Len = 12
# Koza Evals 79100: Best = 1.259235, Len = 12
# Koza Evals 80100: Best = 1.259235, Len = 12
# Koza Evals 81100: Best = 1.259235, Len = 12
# Koza Evals 82100: Best = 1.259235, Len = 12
# Koza Evals 83100: Best = 1.259235, Len = 12
# Koza Evals 84100: Best = 1.259235, Len = 12
# Koza Evals 85100: Best = 1.259235, Len = 12
# Koza Evals 86100: Best = 1.259235, Len = 12
# Koza Evals 87100: Best = 1.259235, Len = 12
# Koza Evals 88100: Best = 1.259235, Len = 12
# Koza Evals 89100: Best = 1.259235, Len = 12
# Koza Evals 90100: Best = 1.259235, Len = 12
# Koza Evals 91100: Best = 1.259235, Len = 12
# Koza Evals 92100: Best = 1.259235, Len = 12
# Koza Evals 93100: Best = 1.259235, Len = 12
# Koza Evals 94100: Best = 1.259235, Len = 12
# Koza Evals 95100: Best = 1.259235, Len = 12
# Koza Evals 96100: Best = 1.259235, Len = 12
# Koza Evals 97100: Best = 1.259235, Len = 12
# Koza Evals 98100: Best = 1.259235, Len = 12
# Koza Evals 99100: Best = 1.259235, Len = 12
# Koza Evals 100: Best = 39.371864, Len = 12
# Koza Evals 1100: Best = 21.148173, Len = 12
# Koza Evals 2100: Best = 18.155089, Len = 12
# Koza Evals 3100: Best = 11.459750, Len = 12
# Koza Evals 4100: Best = 11.459750, Len = 12
# Koza Evals 5100: Best = 10.529637, Len = 12
# Koza Evals 6100: Best = 10.529637, Len = 12
# Koza Evals 7100: Best = 10.529637, Len = 12
# Koza Evals 8100: Best = 10.529637, Len = 12
# Koza Evals 9100: Best = 10.529637, Len = 12
# Koza Evals 10100: Best = 10.529637, Len = 12
# Koza Evals 11100: Best = 10.529637, Len = 12
# Koza Evals 12100: Best = 10.529637, Len = 12
# Koza Evals 13100: Best = 8.059498, Len = 12
# Koza Evals 14100: Best = 8.059498, Len = 12
# Koza Evals 15100: Best = 8.059498, Len = 12
# Koza Evals 16100: Best = 8.059498, Len = 12
# Koza Evals 17100: Best = 8.059498, Len = 12
# Koza Evals 18100: Best = 7.818516, Len = 12
# Koza Evals 19100: Best = 7.818516, Len = 12
# Koza Evals 20100: Best = 7.818516, Len = 12
# Koza Evals 21100: Best = 7.818516, Len = 12
# Koza Evals 22100: Best = 7.818516, Len = 12
# Koza Evals 23100: Best = 7.818516, Len = 12
# Koza Evals 24100: Best = 7.818516, Len = 12
# Koza Evals 25100: Best = 7.818516, Len = 12
# Koza Evals 26100: Best = 7.818516, Len = 12
# Koza Evals 27100: Best = 7.818516, Len = 12
# Koza Evals 28100: Best = 7.818516, Len = 12
# Koza Evals 29100: Best = 7.818516, Len = 12
# Koza Evals 30100: Best = 7.818516, Len = 12
# Koza Evals 31100: Best = 6.923458, Len = 12
# Koza Evals 32100: Best = 6.923458, Len = 12
# Koza Evals 33100: Best = 6.923458, Len = 12
# Koza Evals 34100: Best = 6.923458, Len = 12
# Koza Evals 35100: Best = 6.923458, Len = 12
# Koza Evals 36100: Best = 6.923458, Len = 12
# Koza Evals 37100: Best = 6.923458, Len = 12
# Koza Evals 38100: Best = 6.923458, Len = 12
# Koza Evals 39100: Best = 6.923458, Len = 12
# Koza Evals 40100: Best = 6.923458, Len = 12
# Koza Evals 41100: Best = 6.078472, Len = 12
# Koza Evals 42100: Best = 6.078472, Len = 12
# Koza Evals 43100: Best = 3.735094, Len = 12
# Koza Evals 44100: Best = 3.735094, Len = 12
# Koza Evals 45100: Best = 3.735094, Len = 12
# Koza Evals 46100: Best = 3.735094, Len = 12
# Koza Evals 47100: Best = 3.735094, Len = 12
# Koza Evals 48100: Best = 3.735094, Len = 12
# Koza Evals 49100: Best = 3.735094, Len = 12
# Koza Evals 50100: Best = 3.735094, Len = 12
# Koza Evals 51100: Best = 3.735094, Len = 12
# Koza Evals 52100: Best = 3.735094, Len = 12
# Koza Evals 53100: Best = 3.735094, Len = 12
# Koza Evals 54100: Best = 3.735094, Len = 12
# Koza Evals 55100: Best = 3.735094, Len = 12
# Koza Evals 56100: Best = 3.735094, Len = 12
# Koza Evals 57100: Best = 3.735094, Len = 12
# Koza Evals 58100: Best = 3.735094, Len = 12
# Koza Evals 59100: Best = 3.735094, Len = 12
# Koza Evals 60100: Best = 3.735094, Len = 12
# Koza Evals 61100: Best = 3.735094, Len = 12
# Koza Evals 62100: Best = 3.735094, Len = 12
# Koza Evals 63100: Best = 1.754348, Len = 12
# Koza Evals 64100: Best = 1.754348, Len = 12
# Koza Evals 65100: Best = 1.754348, Len = 12
# Koza Evals 66100: Best = 1.754348, Len = 12
# Koza Evals 67100: Best = 1.754348, Len = 12
# Koza Evals 68100: Best = 1.754348, Len = 12
# Koza Evals 69100: Best = 1.754348, Len = 12
# Koza Evals 70100: Best = 1.754348, Len = 12
# Koza Evals 71100: Best = 1.754348, Len = 12
# Koza Evals 72100: Best = 1.754348, Len = 12
# Koza Evals 73100: Best = 1.754348, Len = 12
# Koza Evals 74100: Best = 1.754348, Len = 12
# Koza Evals 75100: Best = 1.754348, Len = 12
# Koza Evals 76100: Best = 1.754348, Len = 12
# Koza Evals 77100: Best = 1.754348, Len = 12
# Koza Evals 78100: Best = 1.754348, Len = 12
# Koza Evals 79100: Best = 1.754348, Len = 12
# Koza Evals 80100: Best = 1.754348, Len = 12
# Koza Evals 81100: Best = 1.754348, Len = 12
# Koza Evals 82100: Best = 1.754348, Len = 12
# Koza Evals 83100: Best = 1.754348, Len = 12
# Koza Evals 84100: Best = 1.754348, Len = 12
# Koza Evals 85100: Best = 1.754348, Len = 12
# Koza Evals 86100: Best = 1.754348, Len = 12
# Koza Evals 87100: Best = 1.754348, Len = 12
# Koza Evals 88100: Best = 1.754348, Len = 12
# Koza Evals 89100: Best = 1.754348, Len = 12
# Koza Evals 90100: Best = 1.754348, Len = 12
# Koza Evals 91100: Best = 1.754348, Len = 12
# Koza Evals 92100: Best = 1.754348, Len = 12
# Koza Evals 93100: Best = 1.754348, Len = 12
# Koza Evals 94100: Best = 1.754348, Len = 12
# Koza Evals 95100: Best = 1.754348, Len = 12
# Koza Evals 96100: Best = 1.754348, Len = 12
# Koza Evals 97100: Best = 1.754348, Len = 12
# Koza Evals 98100: Best = 1.754348, Len = 12
# Koza Evals 99100: Best = 1.754348, Len = 12
# Koza Evals 100: Best = 13.378248, Len = 12
# Koza Evals 1100: Best = 13.378248, Len = 12
# Koza Evals 2100: Best = 9.985252, Len = 11
# Koza Evals 3100: Best = 9.985252, Len = 11
# Koza Evals 4100: Best = 9.985252, Len = 11
# Koza Evals 5100: Best = 9.985252, Len = 11
# Koza Evals 6100: Best = 9.985252, Len = 11
# Koza Evals 7100: Best = 8.790002, Len = 12
# Koza Evals 8100: Best = 8.790002, Len = 12
# Koza Evals 9100: Best = 8.790002, Len = 12
# Koza Evals 10100: Best = 8.790002, Len = 12
# Koza Evals 11100: Best = 8.790002, Len = 12
# Koza Evals 12100: Best = 7.136721, Len = 12
# Koza Evals 13100: Best = 7.136721, Len = 12
# Koza Evals 14100: Best = 7.136721, Len = 12
# Koza Evals 15100: Best = 7.136721, Len = 12
# Koza Evals 16100: Best = 7.136721, Len = 12
# Koza Evals 17100: Best = 6.326300, Len = 12
# Koza Evals 18100: Best = 6.326300, Len = 12
# Koza Evals 19100: Best = 6.326300, Len = 12
# Koza Evals 20100: Best = 6.326300, Len = 12
# Koza Evals 21100: Best = 6.326300, Len = 12
# Koza Evals 22100: Best = 5.923264, Len = 12
# Koza Evals 23100: Best = 5.923264, Len = 12
# Koza Evals 24100: Best = 5.923264, Len = 12
# Koza Evals 25100: Best = 5.923264, Len = 12
# Koza Evals 26100: Best = 5.923264, Len = 12
# Koza Evals 27100: Best = 5.923264, Len = 12
# Koza Evals 28100: Best = 5.923264, Len = 12
# Koza Evals 29100: Best = 5.681283, Len = 12
# Koza Evals 30100: Best = 5.681283, Len = 12
# Koza Evals 31100: Best = 5.681283, Len = 12
# Koza Evals 32100: Best = 5.681283, Len = 12
# Koza Evals 33100: Best = 5.681283, Len = 12
# Koza Evals 34100: Best = 4.980983, Len = 12
# Koza Evals 35100: Best = 4.980983, Len = 12
# Koza Evals 36100: Best = 4.980983, Len = 12
# Koza Evals 37100: Best = 4.980983, Len = 12
# Koza Evals 38100: Best = 4.980983, Len = 12
# Koza Evals 39100: Best = 4.900312, Len = 12
# Koza Evals 40100: Best = 4.900312, Len = 12
# Koza Evals 41100: Best = 4.900312, Len = 12
# Koza Evals 42100: Best = 4.900312, Len = 12
# Koza Evals 43100: Best = 4.900312, Len = 12
# Koza Evals 44100: Best = 4.900312, Len = 12
# Koza Evals 45100: Best = 4.900312, Len = 12
# Koza Evals 46100: Best = 4.900312, Len = 12
# Koza Evals 47100: Best = 4.837939, Len = 12
# Koza Evals 48100: Best = 4.837939, Len = 12
# Koza Evals 49100: Best = 4.837939, Len = 12
# Koza Evals 50100: Best = 4.837939, Len = 12
# Koza Evals 51100: Best = 4.837939, Len = 12
# Koza Evals 52100: Best = 4.837939, Len = 12
# Koza Evals 53100: Best = 4.837939, Len = 12
# Koza Evals 54100: Best = 4.837939, Len = 12
# Koza Evals 55100: Best = 4.837939, Len = 12
# Koza Evals 56100: Best = 4.837939, Len = 12
# Koza Evals 57100: Best = 4.837939, Len = 12
# Koza Evals 58100: Best = 4.837939, Len = 12
# Koza Evals 59100: Best = 4.837939, Len = 12
# Koza Evals 60100: Best = 4.837939, Len = 12
# Koza Evals 61100: Best = 4.837939, Len = 12
# Koza Evals 62100: Best = 3.308742, Len = 12
# Koza Evals 63100: Best = 3.308742, Len = 12
# Koza Evals 64100: Best = 3.308742, Len = 12
# Koza Evals 65100: Best = 3.308742, Len = 12
# Koza Evals 66100: Best = 3.308742, Len = 12
# Koza Evals 67100: Best = 3.308742, Len = 12
# Koza Evals 68100: Best = 3.308742, Len = 12
# Koza Evals 69100: Best = 3.308742, Len = 12
# Koza Evals 70100: Best = 1.101084, Len = 12
# Koza Evals 71100: Best = 1.101084, Len = 12
# Koza Evals 72100: Best = 1.101084, Len = 12
# Koza Evals 73100: Best = 1.101084, Len = 12
# Koza Evals 74100: Best = 1.101084, Len = 12
# Koza Evals 75100: Best = 1.101084, Len = 12
# Koza Evals 76100: Best = 1.101084, Len = 12
# Koza Evals 77100: Best = 1.101084, Len = 12
# Koza Evals 78100: Best = 1.101084, Len = 12
# Koza Evals 79100: Best = 1.101084, Len = 12
# Koza Evals 80100: Best = 1.101084, Len = 12
# Koza Evals 81100: Best = 1.101084, Len = 12
# Koza Evals 82100: Best = 1.101084, Len = 12
# Koza Evals 83100: Best = 1.101084, Len = 12
# Koza Evals 84100: Best = 1.101084, Len = 12
# Koza Evals 85100: Best = 1.101084, Len = 12
# Koza Evals 86100: Best = 1.101084, Len = 12
# Koza Evals 87100: Best = 1.101084, Len = 12
# Koza Evals 88100: Best = 1.101084, Len = 12
# Koza Evals 89100: Best = 1.101084, Len = 12
# Koza Evals 90100: Best = 1.101084, Len = 12
# Koza Evals 91100: Best = 1.101084, Len = 12
# Koza Evals 92100: Best = 1.101084, Len = 12
# Koza Evals 93100: Best = 1.101084, Len = 12
# Koza Evals 94100: Best = 1.101084, Len = 12
# Koza Evals 95100: Best = 1.101084, Len = 12
# Koza Evals 96100: Best = 1.101084, Len = 12
# Koza Evals 97100: Best = 1.101084, Len = 12
# Koza Evals 98100: Best = 1.101084, Len = 12
# Koza Evals 99100: Best = 1.101084, Len = 12
# Koza Evals 100: Best = 34.668069, Len = 12
# Koza Evals 1100: Best = 34.668069, Len = 12
# Koza Evals 2100: Best = 34.668069, Len = 12
# Koza Evals 3100: Best = 34.668069, Len = 12
# Koza Evals 4100: Best = 34.668069, Len = 12
# Koza Evals 5100: Best = 34.668069, Len = 12
# Koza Evals 6100: Best = 29.344968, Len = 12
# Koza Evals 7100: Best = 29.344968, Len = 12
# Koza Evals 8100: Best = 18.974432, Len = 12
# Koza Evals 9100: Best = 18.974432, Len = 12
# Koza Evals 10100: Best = 16.752237, Len = 12
# Koza Evals 11100: Best = 16.752237, Len = 12
# Koza Evals 12100: Best = 16.752237, Len = 12
# Koza Evals 13100: Best = 16.752237, Len = 12
# Koza Evals 14100: Best = 16.752237, Len = 12
# Koza Evals 15100: Best = 16.752237, Len = 12
# Koza Evals 16100: Best = 16.752237, Len = 12
# Koza Evals 17100: Best = 4.605639, Len = 12
# Koza Evals 18100: Best = 4.605639, Len = 12
# Koza Evals 19100: Best = 4.605639, Len = 12
# Koza Evals 20100: Best = 4.605639, Len = 12
# Koza Evals 21100: Best = 4.605639, Len = 12
# Koza Evals 22100: Best = 4.605639, Len = 12
# Koza Evals 23100: Best = 4.605639, Len = 12
# Koza Evals 24100: Best = 4.605639, Len = 12
# Koza Evals 25100: Best = 4.605639, Len = 12
# Koza Evals 26100: Best = 4.605639, Len = 12
# Koza Evals 27100: Best = 4.605639, Len = 12
# Koza Evals 28100: Best = 4.605639, Len = 12
# Koza Evals 29100: Best = 4.605639, Len = 12
# Koza Evals 30100: Best = 4.605639, Len = 12
# Koza Evals 31100: Best = 4.605639, Len = 12
# Koza Evals 32100: Best = 4.605639, Len = 12
# Koza Evals 33100: Best = 4.605639, Len = 12
# Koza Evals 34100: Best = 4.605639, Len = 12
# Koza Evals 35100: Best = 4.605639, Len = 12
# Koza Evals 36100: Best = 4.605639, Len = 12
# Koza Evals 37100: Best = 4.605639, Len = 12
# Koza Evals 38100: Best = 4.605639, Len = 12
# Koza Evals 39100: Best = 4.605639, Len = 12
# Koza Evals 40100: Best = 4.605639, Len = 12
# Koza Evals 41100: Best = 4.605639, Len = 12
# Koza Evals 42100: Best = 4.605639, Len = 12
# Koza Evals 43100: Best = 4.605639, Len = 12
# Koza Evals 44100: Best = 4.605639, Len = 12
# Koza Evals 45100: Best = 4.605639, Len = 12
# Koza Evals 46100: Best = 4.605639, Len = 12
# Koza Evals 47100: Best = 4.605639, Len = 12
# Koza Evals 48100: Best = 4.605639, Len = 12
# Koza Evals 49100: Best = 4.605639, Len = 12
# Koza Evals 50100: Best = 4.605639, Len = 12
# Koza Evals 51100: Best = 4.605639, Len = 12
# Koza Evals 52100: Best = 4.605639, Len = 12
# Koza Evals 53100: Best = 4.605639, Len = 12
# Koza Evals 54100: Best = 4.605639, Len = 12
# Koza Evals 55100: Best = 4.605639, Len = 12
# Koza Evals 56100: Best = 4.605639, Len = 12
# Koza Evals 57100: Best = 4.605639, Len = 12
# Koza Evals 58100: Best = 4.605639, Len = 12
# Koza Evals 59100: Best = 4.605639, Len = 12
# Koza Evals 60100: Best = 4.605639, Len = 12
# Koza Evals 61100: Best = 4.605639, Len = 12
# Koza Evals 62100: Best = 4.605639, Len = 12
# Koza Evals 63100: Best = 4.605639, Len = 12
# Koza Evals 64100: Best = 4.605639, Len = 12
# Koza Evals 65100: Best = 4.605639, Len = 12
# Koza Evals 66100: Best = 4.605639, Len = 12
# Koza Evals 67100: Best = 1.610841, Len = 12
# Koza Evals 68100: Best = 1.610841, Len = 12
# Koza Evals 69100: Best = 1.610841, Len = 12
# Koza Evals 70100: Best = 1.610841, Len = 12
# Koza Evals 71100: Best = 1.610841, Len = 12
# Koza Evals 72100: Best = 1.610841, Len = 12
# Koza Evals 73100: Best = 1.610841, Len = 12
# Koza Evals 74100: Best = 1.610841, Len = 12
# Koza Evals 75100: Best = 1.610841, Len = 12
# Koza Evals 76100: Best = 1.610841, Len = 12
# Koza Evals 77100: Best = 1.610841, Len = 12
# Koza Evals 78100: Best = 1.610841, Len = 12
# Koza Evals 79100: Best = 1.610841, Len = 12
# Koza Evals 80100: Best = 1.610841, Len = 12
# Koza Evals 81100: Best = 1.610841, Len = 12
# Koza Evals 82100: Best = 1.610841, Len = 12
# Koza Evals 83100: Best = 1.610841, Len = 12
# Koza Evals 84100: Best = 1.610841, Len = 12
# Koza Evals 85100: Best = 1.610841, Len = 12
# Koza Evals 86100: Best = 1.610841, Len = 12
# Koza Evals 87100: Best = 1.610841, Len = 12
# Koza Evals 88100: Best = 1.610841, Len = 12
# Koza Evals 89100: Best = 1.610841, Len = 12
# Koza Evals 90100: Best = 1.610841, Len = 12
# Koza Evals 91100: Best = 1.610841, Len = 12
# Koza Evals 92100: Best = 1.610841, Len = 12
# Koza Evals 93100: Best = 1.610841, Len = 12
# Koza Evals 94100: Best = 1.610841, Len = 12
# Koza Evals 95100: Best = 1.610841, Len = 12
# Koza Evals 96100: Best = 1.610841, Len = 12
# Koza Evals 97100: Best = 1.610841, Len = 12
# Koza Evals 98100: Best = 1.610841, Len = 12
# Koza Evals 99100: Best = 1.610841, Len = 12
# Koza Evals 100: Best = 68.666922, Len = 6
# Koza Evals 1100: Best = 64.907934, Len = 7
# Koza Evals 2100: Best = 44.744880, Len = 13
# Koza Evals 3100: Best = 44.744880, Len = 13
# Koza Evals 4100: Best = 44.744880, Len = 13
# Koza Evals 5100: Best = 44.744880, Len = 13
# Koza Evals 6100: Best = 44.744880, Len = 13
# Koza Evals 7100: Best = 44.744880, Len = 13
# Koza Evals 8100: Best = 44.744880, Len = 13
# Koza Evals 9100: Best = 44.744880, Len = 13
# Koza Evals 10100: Best = 44.744880, Len = 13
# Koza Evals 11100: Best = 44.744880, Len = 13
# Koza Evals 12100: Best = 44.744880, Len = 13
# Koza Evals 13100: Best = 44.744880, Len = 13
# Koza Evals 14100: Best = 44.744880, Len = 13
# Koza Evals 15100: Best = 44.744880, Len = 13
# Koza Evals 16100: Best = 44.744880, Len = 13
# Koza Evals 17100: Best = 44.744880, Len = 13
# Koza Evals 18100: Best = 44.744880, Len = 13
# Koza Evals 19100: Best = 44.744880, Len = 13
# Koza Evals 20100: Best = 44.744880, Len = 13
# Koza Evals 21100: Best = 44.744880, Len = 13
# Koza Evals 22100: Best = 44.744880, Len = 13
# Koza Evals 23100: Best = 44.744880, Len = 13
# Koza Evals 24100: Best = 44.744880, Len = 13
# Koza Evals 25100: Best = 44.744880, Len = 13
# Koza Evals 26100: Best = 44.744880, Len = 13
# Koza Evals 27100: Best = 44.744880, Len = 13
# Koza Evals 28100: Best = 44.744880, Len = 13
# Koza Evals 29100: Best = 44.744880, Len = 13
# Koza Evals 30100: Best = 44.744880, Len = 13
# Koza Evals 31100: Best = 44.744880, Len = 13
# Koza Evals 32100: Best = 44.744880, Len = 13
# Koza Evals 33100: Best = 44.744880, Len = 13
# Koza Evals 34100: Best = 44.744880, Len = 13
# Koza Evals 35100: Best = 44.744880, Len = 13
# Koza Evals 36100: Best = 44.744880, Len = 13
# Koza Evals 37100: Best = 44.744880, Len = 13
# Koza Evals 38100: Best = 44.744880, Len = 13
# Koza Evals 39100: Best = 44.744880, Len = 13
# Koza Evals 40100: Best = 44.744880, Len = 13
# Koza Evals 41100: Best = 44.744880, Len = 13
# Koza Evals 42100: Best = 44.744880, Len = 13
# Koza Evals 43100: Best = 44.744880, Len = 13
# Koza Evals 44100: Best = 44.744880, Len = 13
# Koza Evals 45100: Best = 44.744880, Len = 13
# Koza Evals 46100: Best = 44.744880, Len = 13
# Koza Evals 47100: Best = 44.744880, Len = 13
# Koza Evals 48100: Best = 44.744880, Len = 13
# Koza Evals 49100: Best = 44.744880, Len = 13
# Koza Evals 50100: Best = 38.916011, Len = 13
# Koza Evals 51100: Best = 38.916011, Len = 13
# Koza Evals 52100: Best = 38.916011, Len = 13
# Koza Evals 53100: Best = 38.014332, Len = 13
# Koza Evals 54100: Best = 38.014332, Len = 13
# Koza Evals 55100: Best = 38.014332, Len = 13
# Koza Evals 56100: Best = 38.014332, Len = 13
# Koza Evals 57100: Best = 38.014332, Len = 13
# Koza Evals 58100: Best = 38.014332, Len = 13
# Koza Evals 59100: Best = 38.014332, Len = 13
# Koza Evals 60100: Best = 38.014332, Len = 13
# Koza Evals 61100: Best = 38.014332, Len = 13
# Koza Evals 62100: Best = 38.014332, Len = 13
# Koza Evals 63100: Best = 38.014332, Len = 13
# Koza Evals 64100: Best = 38.014332, Len = 13
# Koza Evals 65100: Best = 38.014332, Len = 13
# Koza Evals 66100: Best = 38.014332, Len = 13
# Koza Evals 67100: Best = 38.014332, Len = 13
# Koza Evals 68100: Best = 38.014332, Len = 13
# Koza Evals 69100: Best = 38.014332, Len = 13
# Koza Evals 70100: Best = 38.014332, Len = 13
# Koza Evals 71100: Best = 38.014332, Len = 13
# Koza Evals 72100: Best = 38.014332, Len = 13
# Koza Evals 73100: Best = 38.014332, Len = 13
# Koza Evals 74100: Best = 38.014332, Len = 13
# Koza Evals 75100: Best = 38.014332, Len = 13
# Koza Evals 76100: Best = 38.014332, Len = 13
# Koza Evals 77100: Best = 38.014332, Len = 13
# Koza Evals 78100: Best = 38.014332, Len = 13
# Koza Evals 79100: Best = 38.014332, Len = 13
# Koza Evals 80100: Best = 38.014332, Len = 13
# Koza Evals 81100: Best = 38.014332, Len = 13
# Koza Evals 82100: Best = 38.014332, Len = 13
# Koza Evals 83100: Best = 38.014332, Len = 13
# Koza Evals 84100: Best = 38.014332, Len = 13
# Koza Evals 85100: Best = 38.014332, Len = 13
# Koza Evals 86100: Best = 38.014332, Len = 13
# Koza Evals 87100: Best = 38.014332, Len = 13
# Koza Evals 88100: Best = 38.014332, Len = 13
# Koza Evals 89100: Best = 38.014332, Len = 13
# Koza Evals 90100: Best = 38.014332, Len = 13
# Koza Evals 91100: Best = 38.014332, Len = 13
# Koza Evals 92100: Best = 38.014332, Len = 13
# Koza Evals 93100: Best = 38.014332, Len = 13
# Koza Evals 94100: Best = 38.014332, Len = 13
# Koza Evals 95100: Best = 38.014332, Len = 13
# Koza Evals 96100: Best = 38.014332, Len = 13
# Koza Evals 97100: Best = 38.014332, Len = 13
# Koza Evals 98100: Best = 38.014332, Len = 13
# Koza Evals 99100: Best = 38.014332, Len = 13
# Koza Evals 100: Best = 14.862077, Len = 12
# Koza Evals 1100: Best = 14.862077, Len = 12
# Koza Evals 2100: Best = 14.862077, Len = 12
# Koza Evals 3100: Best = 14.862077, Len = 12
# Koza Evals 4100: Best = 14.862077, Len = 12
# Koza Evals 5100: Best = 14.862077, Len = 12
# Koza Evals 6100: Best = 8.934184, Len = 8
# Koza Evals 7100: Best = 8.016905, Len = 9
# Koza Evals 8100: Best = 8.016905, Len = 9
# Koza Evals 9100: Best = 8.016905, Len = 9
# Koza Evals 10100: Best = 8.016905, Len = 9
# Koza Evals 11100: Best = 8.016905, Len = 9
# Koza Evals 12100: Best = 8.016905, Len = 9
# Koza Evals 13100: Best = 8.016905, Len = 9
# Koza Evals 14100: Best = 8.016905, Len = 9
# Koza Evals 15100: Best = 8.016905, Len = 9
# Koza Evals 16100: Best = 8.016905, Len = 9
# Koza Evals 17100: Best = 8.016905, Len = 9
# Koza Evals 18100: Best = 8.016905, Len = 9
# Koza Evals 19100: Best = 8.016905, Len = 9
# Koza Evals 20100: Best = 8.016905, Len = 9
# Koza Evals 21100: Best = 8.016905, Len = 9
# Koza Evals 22100: Best = 8.016905, Len = 9
# Koza Evals 23100: Best = 8.016905, Len = 9
# Koza Evals 24100: Best = 5.064845, Len = 12
# Koza Evals 25100: Best = 5.064845, Len = 12
# Koza Evals 26100: Best = 5.064845, Len = 12
# Koza Evals 27100: Best = 5.064845, Len = 12
# Koza Evals 28100: Best = 5.064845, Len = 12
# Koza Evals 29100: Best = 5.064845, Len = 12
# Koza Evals 30100: Best = 5.064845, Len = 12
# Koza Evals 31100: Best = 5.064845, Len = 12
# Koza Evals 32100: Best = 5.064845, Len = 12
# Koza Evals 33100: Best = 5.064845, Len = 12
# Koza Evals 34100: Best = 5.064845, Len = 12
# Koza Evals 35100: Best = 5.064845, Len = 12
# Koza Evals 36100: Best = 5.064845, Len = 12
# Koza Evals 37100: Best = 5.064845, Len = 12
# Koza Evals 38100: Best = 5.064845, Len = 12
# Koza Evals 39100: Best = 5.064845, Len = 12
# Koza Evals 40100: Best = 5.064845, Len = 12
# Koza Evals 41100: Best = 5.064845, Len = 12
# Koza Evals 42100: Best = 3.500749, Len = 12
# Koza Evals 43100: Best = 3.500749, Len = 12
# Koza Evals 44100: Best = 3.500749, Len = 12
# Koza Evals 45100: Best = 3.500749, Len = 12
# Koza Evals 46100: Best = 3.500749, Len = 12
# Koza Evals 47100: Best = 3.500749, Len = 12
# Koza Evals 48100: Best = 3.500749, Len = 12
# Koza Evals 49100: Best = 3.500749, Len = 12
# Koza Evals 50100: Best = 3.500749, Len = 12
# Koza Evals 51100: Best = 3.063051, Len = 12
# Koza Evals 52100: Best = 3.063051, Len = 12
# Koza Evals 53100: Best = 3.063051, Len = 12
# Koza Evals 54100: Best = 3.063051, Len = 12
# Koza Evals 55100: Best = 3.063051, Len = 12
# Koza Evals 56100: Best = 3.063051, Len = 12
# Koza Evals 57100: Best = 3.063051, Len = 12
# Koza Evals 58100: Best = 3.063051, Len = 12
# Koza Evals 59100: Best = 3.063051, Len = 12
# Koza Evals 60100: Best = 3.063051, Len = 12
# Koza Evals 61100: Best = 3.063051, Len = 12
# Koza Evals 62100: Best = 3.063051, Len = 12
# Koza Evals 63100: Best = 3.063051, Len = 12
# Koza Evals 64100: Best = 3.063051, Len = 12
# Koza Evals 65100: Best = 3.063051, Len = 12
# Koza Evals 66100: Best = 3.063051, Len = 12
# Koza Evals 67100: Best = 3.063051, Len = 12
# Koza Evals 68100: Best = 3.063051, Len = 12
# Koza Evals 69100: Best = 3.063051, Len = 12
# Koza Evals 70100: Best = 3.063051, Len = 12
# Koza Evals 71100: Best = 3.063051, Len = 12
# Koza Evals 72100: Best = 3.063051, Len = 12
# Koza Evals 73100: Best = 2.472812, Len = 12
# Koza Evals 74100: Best = 2.472812, Len = 12
# Koza Evals 75100: Best = 2.472812, Len = 12
# Koza Evals 76100: Best = 2.472812, Len = 12
# Koza Evals 77100: Best = 2.472812, Len = 12
# Koza Evals 78100: Best = 2.472812, Len = 12
# Koza Evals 79100: Best = 2.472812, Len = 12
# Koza Evals 80100: Best = 2.472812, Len = 12
# Koza Evals 81100: Best = 2.472812, Len = 12
# Koza Evals 82100: Best = 2.472812, Len = 12
# Koza Evals 83100: Best = 2.472812, Len = 12
# Koza Evals 84100: Best = 2.472812, Len = 12
# Koza Evals 85100: Best = 1.388176, Len = 12
# Koza Evals 86100: Best = 1.388176, Len = 12
# Koza Evals 87100: Best = 1.388176, Len = 12
# Koza Evals 88100: Best = 1.388176, Len = 12
# Koza Evals 89100: Best = 1.388176, Len = 12
# Koza Evals 90100: Best = 0.786951, Len = 12
# Koza Evals 91100: Best = 0.786951, Len = 12
# Koza Evals 92100: Best = 0.786951, Len = 12
# Koza Evals 93100: Best = 0.786951, Len = 12
# Koza Evals 94100: Best = 0.786951, Len = 12
# Koza Evals 95100: Best = 0.786951, Len = 12
# Koza Evals 96100: Best = 0.786951, Len = 12
# Koza Evals 97100: Best = 0.786951, Len = 12
# Koza Evals 98100: Best = 0.786951, Len = 12
# Koza Evals 99100: Best = 0.786951, Len = 12
# Koza Evals 100: Best = 36.288344, Len = 7
# Koza Evals 1100: Best = 14.759442, Len = 12
# Koza Evals 2100: Best = 14.759442, Len = 12
# Koza Evals 3100: Best = 14.759442, Len = 12
# Koza Evals 4100: Best = 14.759442, Len = 12
# Koza Evals 5100: Best = 14.759442, Len = 12
# Koza Evals 6100: Best = 14.759442, Len = 12
# Koza Evals 7100: Best = 14.759442, Len = 12
# Koza Evals 8100: Best = 14.759442, Len = 12
# Koza Evals 9100: Best = 10.150268, Len = 12
# Koza Evals 10100: Best = 9.848973, Len = 12
# Koza Evals 11100: Best = 9.848973, Len = 12
# Koza Evals 12100: Best = 9.848973, Len = 12
# Koza Evals 13100: Best = 7.151273, Len = 12
# Koza Evals 14100: Best = 7.151273, Len = 12
# Koza Evals 15100: Best = 6.864758, Len = 12
# Koza Evals 16100: Best = 6.864758, Len = 12
# Koza Evals 17100: Best = 6.864758, Len = 12
# Koza Evals 18100: Best = 6.864758, Len = 12
# Koza Evals 19100: Best = 6.864758, Len = 12
# Koza Evals 20100: Best = 6.864758, Len = 12
# Koza Evals 21100: Best = 6.864758, Len = 12
# Koza Evals 22100: Best = 6.864758, Len = 12
# Koza Evals 23100: Best = 6.864758, Len = 12
# Koza Evals 24100: Best = 6.864758, Len = 12
# Koza Evals 25100: Best = 6.864758, Len = 12
# Koza Evals 26100: Best = 6.864758, Len = 12
# Koza Evals 27100: Best = 6.864758, Len = 12
# Koza Evals 28100: Best = 6.864758, Len = 12
# Koza Evals 29100: Best = 6.864758, Len = 12
# Koza Evals 30100: Best = 6.864758, Len = 12
# Koza Evals 31100: Best = 6.864758, Len = 12
# Koza Evals 32100: Best = 6.864758, Len = 12
# Koza Evals 33100: Best = 4.160879, Len = 12
# Koza Evals 34100: Best = 4.160879, Len = 12
# Koza Evals 35100: Best = 4.160879, Len = 12
# Koza Evals 36100: Best = 4.160879, Len = 12
# Koza Evals 37100: Best = 4.160879, Len = 12
# Koza Evals 38100: Best = 4.160879, Len = 12
# Koza Evals 39100: Best = 4.160879, Len = 12
# Koza Evals 40100: Best = 4.160879, Len = 12
# Koza Evals 41100: Best = 4.160879, Len = 12
# Koza Evals 42100: Best = 4.160879, Len = 12
# Koza Evals 43100: Best = 4.160879, Len = 12
# Koza Evals 44100: Best = 4.160879, Len = 12
# Koza Evals 45100: Best = 4.160879, Len = 12
# Koza Evals 46100: Best = 4.160879, Len = 12
# Koza Evals 47100: Best = 4.160879, Len = 12
# Koza Evals 48100: Best = 4.160879, Len = 12
# Koza Evals 49100: Best = 4.160879, Len = 12
# Koza Evals 50100: Best = 4.160879, Len = 12
# Koza Evals 51100: Best = 4.160879, Len = 12
# Koza Evals 52100: Best = 4.160879, Len = 12
# Koza Evals 53100: Best = 4.160879, Len = 12
# Koza Evals 54100: Best = 4.160879, Len = 12
# Koza Evals 55100: Best = 4.160879, Len = 12
# Koza Evals 56100: Best = 4.160879, Len = 12
# Koza Evals 57100: Best = 4.160879, Len = 12
# Koza Evals 58100: Best = 4.160879, Len = 12
# Koza Evals 59100: Best = 4.160879, Len = 12
# Koza Evals 60100: Best = 4.160879, Len = 12
# Koza Evals 61100: Best = 4.160879, Len = 12
# Koza Evals 62100: Best = 4.160879, Len = 12
# Koza Evals 63100: Best = 4.160879, Len = 12
# Koza Evals 64100: Best = 4.160879, Len = 12
# Koza Evals 65100: Best = 4.160879, Len = 12
# Koza Evals 66100: Best = 4.160879, Len = 12
# Koza Evals 67100: Best = 4.160879, Len = 12
# Koza Evals 68100: Best = 4.160879, Len = 12
# Koza Evals 69100: Best = 4.160879, Len = 12
# Koza Evals 70100: Best = 4.160879, Len = 12
# Koza Evals 71100: Best = 4.160879, Len = 12
# Koza Evals 72100: Best = 4.160879, Len = 12
# Koza Evals 73100: Best = 4.160879, Len = 12
# Koza Evals 74100: Best = 4.160879, Len = 12
# Koza Evals 75100: Best = 4.160879, Len = 12
# Koza Evals 76100: Best = 4.160879, Len = 12
# Koza Evals 77100: Best = 4.160879, Len = 12
# Koza Evals 78100: Best = 4.160879, Len = 12
# Koza Evals 79100: Best = 4.160879, Len = 12
# Koza Evals 80100: Best = 4.160879, Len = 12
# Koza Evals 81100: Best = 4.160879, Len = 12
# Koza Evals 82100: Best = 4.160879, Len = 12
# Koza Evals 83100: Best = 4.160879, Len = 12
# Koza Evals 84100: Best = 4.160879, Len = 12
# Koza Evals 85100: Best = 4.160879, Len = 12
# Koza Evals 86100: Best = 4.160879, Len = 12
# Koza Evals 87100: Best = 4.160879, Len = 12
# Koza Evals 88100: Best = 4.160879, Len = 12
# Koza Evals 89100: Best = 4.160879, Len = 12
# Koza Evals 90100: Best = 4.160879, Len = 12
# Koza Evals 91100: Best = 4.160879, Len = 12
# Koza Evals 92100: Best = 4.160879, Len = 12
# Koza Evals 93100: Best = 4.160879, Len = 12
# Koza Evals 94100: Best = 4.160879, Len = 12
# Koza Evals 95100: Best = 4.160879, Len = 12
# Koza Evals 96100: Best = 4.160879, Len = 12
# Koza Evals 97100: Best = 4.160879, Len = 12
# Koza Evals 98100: Best = 4.160879, Len = 12
# Koza Evals 99100: Best = 4.160879, Len = 12
# Koza Evals 100: Best = 55.412252, Len = 14
# Koza Evals 1100: Best = 12.253154, Len = 10
# Koza Evals 2100: Best = 12.253154, Len = 10
# Koza Evals 3100: Best = 12.253154, Len = 10
# Koza Evals 4100: Best = 12.253154, Len = 10
# Koza Evals 5100: Best = 12.253154, Len = 10
# Koza Evals 6100: Best = 12.253154, Len = 10
# Koza Evals 7100: Best = 12.253154, Len = 10
# Koza Evals 8100: Best = 12.253154, Len = 10
# Koza Evals 9100: Best = 12.253154, Len = 10
# Koza Evals 10100: Best = 12.253154, Len = 10
# Koza Evals 11100: Best = 12.253154, Len = 10
# Koza Evals 12100: Best = 12.253154, Len = 10
# Koza Evals 13100: Best = 12.253154, Len = 10
# Koza Evals 14100: Best = 12.253154, Len = 10
# Koza Evals 15100: Best = 12.253154, Len = 10
# Koza Evals 16100: Best = 12.253154, Len = 10
# Koza Evals 17100: Best = 12.253154, Len = 10
# Koza Evals 18100: Best = 12.253154, Len = 10
# Koza Evals 19100: Best = 12.253154, Len = 10
# Koza Evals 20100: Best = 12.253154, Len = 10
# Koza Evals 21100: Best = 12.253154, Len = 10
# Koza Evals 22100: Best = 12.253154, Len = 10
# Koza Evals 23100: Best = 12.253154, Len = 10
# Koza Evals 24100: Best = 12.253154, Len = 10
# Koza Evals 25100: Best = 12.253154, Len = 10
# Koza Evals 26100: Best = 12.253154, Len = 10
# Koza Evals 27100: Best = 12.253154, Len = 10
# Koza Evals 28100: Best = 12.253154, Len = 10
# Koza Evals 29100: Best = 12.253154, Len = 10
# Koza Evals 30100: Best = 12.253154, Len = 10
# Koza Evals 31100: Best = 12.253154, Len = 10
# Koza Evals 32100: Best = 12.253154, Len = 10
# Koza Evals 33100: Best = 12.253154, Len = 10
# Koza Evals 34100: Best = 12.253154, Len = 10
# Koza Evals 35100: Best = 12.253154, Len = 10
# Koza Evals 36100: Best = 12.253154, Len = 10
# Koza Evals 37100: Best = 12.253154, Len = 10
# Koza Evals 38100: Best = 12.253154, Len = 10
# Koza Evals 39100: Best = 12.253154, Len = 10
# Koza Evals 40100: Best = 12.253154, Len = 10
# Koza Evals 41100: Best = 12.253154, Len = 10
# Koza Evals 42100: Best = 12.253154, Len = 10
# Koza Evals 43100: Best = 12.253154, Len = 10
# Koza Evals 44100: Best = 12.253154, Len = 10
# Koza Evals 45100: Best = 12.253154, Len = 10
# Koza Evals 46100: Best = 12.253154, Len = 10
# Koza Evals 47100: Best = 3.829180, Len = 10
# Koza Evals 48100: Best = 3.829180, Len = 10
# Koza Evals 49100: Best = 3.829180, Len = 10
# Koza Evals 50100: Best = 3.829180, Len = 10
# Koza Evals 51100: Best = 3.829180, Len = 10
# Koza Evals 52100: Best = 3.829180, Len = 10
# Koza Evals 53100: Best = 3.829180, Len = 10
# Koza Evals 54100: Best = 3.829180, Len = 10
# Koza Evals 55100: Best = 3.829180, Len = 10
# Koza Evals 56100: Best = 3.829180, Len = 10
# Koza Evals 57100: Best = 3.829180, Len = 10
# Koza Evals 58100: Best = 3.829180, Len = 10
# Koza Evals 59100: Best = 3.829180, Len = 10
# Koza Evals 60100: Best = 3.829180, Len = 10
# Koza Evals 61100: Best = 3.829180, Len = 10
# Koza Evals 62100: Best = 3.829180, Len = 10
# Koza Evals 63100: Best = 3.829180, Len = 10
# Koza Evals 64100: Best = 3.829180, Len = 10
# Koza Evals 65100: Best = 3.829180, Len = 10
# Koza Evals 66100: Best = 3.829180, Len = 10
# Koza Evals 67100: Best = 3.829180, Len = 10
# Koza Evals 68100: Best = 3.829180, Len = 10
# Koza Evals 69100: Best = 3.829180, Len = 10
# Koza Evals 70100: Best = 3.829180, Len = 10
# Koza Evals 71100: Best = 3.829180, Len = 10
# Koza Evals 72100: Best = 3.829180, Len = 10
# Koza Evals 73100: Best = 3.829180, Len = 10
# Koza Evals 74100: Best = 3.829180, Len = 10
# Koza Evals 75100: Best = 3.829180, Len = 10
# Koza Evals 76100: Best = 3.829180, Len = 10
# Koza Evals 77100: Best = 3.829180, Len = 10
# Koza Evals 78100: Best = 3.829180, Len = 10
# Koza Evals 79100: Best = 3.829180, Len = 10
# Koza Evals 80100: Best = 3.829180, Len = 10
# Koza Evals 81100: Best = 3.829180, Len = 10
# Koza Evals 82100: Best = 3.829180, Len = 10
# Koza Evals 83100: Best = 3.829180, Len = 10
# Koza Evals 84100: Best = 3.829180, Len = 10
# Koza Evals 85100: Best = 3.829180, Len = 10
# Koza Evals 86100: Best = 3.829180, Len = 10
# Koza Evals 87100: Best = 3.829180, Len = 10
# Koza Evals 88100: Best = 3.829180, Len = 10
# Koza Evals 89100: Best = 3.829180, Len = 10
# Koza Evals 90100: Best = 3.829180, Len = 10
# Koza Evals 91100: Best = 3.829180, Len = 10
# Koza Evals 92100: Best = 3.829180, Len = 10
# Koza Evals 93100: Best = 3.829180, Len = 10
# Koza Evals 94100: Best = 2.580934, Len = 10
# Koza Evals 95100: Best = 2.580934, Len = 10
# Koza Evals 96100: Best = 2.580934, Len = 10
# Koza Evals 97100: Best = 2.580934, Len = 10
# Koza Evals 98100: Best = 2.580934, Len = 10
# Koza Evals 99100: Best = 2.580934, Len = 10
# Koza Evals 100: Best = 18.450413, Len = 11
# Koza Evals 1100: Best = 2.097415, Len = 10
# Koza Evals 2100: Best = 2.097415, Len = 10
# Koza Evals 3100: Best = 2.097415, Len = 10
# Koza Evals 4100: Best = 2.097415, Len = 10
# Koza Evals 5100: Best = 2.097415, Len = 10
# Koza Evals 6100: Best = 2.097415, Len = 10
# Koza Evals 7100: Best = 2.097415, Len = 10
# Koza Evals 8100: Best = 2.097415, Len = 10
# Koza Evals 9100: Best = 2.097415, Len = 10
# Koza Evals 10100: Best = 2.097415, Len = 10
# Koza Evals 11100: Best = 2.097415, Len = 10
# Koza Evals 12100: Best = 2.097415, Len = 10
# Koza Evals 13100: Best = 2.097415, Len = 10
# Koza Evals 14100: Best = 2.097415, Len = 10
# Koza Evals 15100: Best = 2.097415, Len = 10
# Koza Evals 16100: Best = 2.097415, Len = 10
# Koza Evals 17100: Best = 2.097415, Len = 10
# Koza Evals 18100: Best = 2.097415, Len = 10
# Koza Evals 19100: Best = 2.097415, Len = 10
# Koza Evals 20100: Best = 2.097415, Len = 10
# Koza Evals 21100: Best = 2.097415, Len = 10
# Koza Evals 22100: Best = 2.097415, Len = 10
# Koza Evals 23100: Best = 2.097415, Len = 10
# Koza Evals 24100: Best = 2.097415, Len = 10
# Koza Evals 25100: Best = 2.097415, Len = 10
# Koza Evals 26100: Best = 2.097415, Len = 10
# Koza Evals 27100: Best = 2.097415, Len = 10
# Koza Evals 28100: Best = 2.097415, Len = 10
# Koza Evals 29100: Best = 2.097415, Len = 10
# Koza Evals 30100: Best = 2.097415, Len = 10
# Koza Evals 31100: Best = 2.097415, Len = 10
# Koza Evals 32100: Best = 2.097415, Len = 10
# Koza Evals 33100: Best = 2.097415, Len = 10
# Koza Evals 34100: Best = 2.097415, Len = 10
# Koza Evals 35100: Best = 2.097415, Len = 10
# Koza Evals 36100: Best = 2.097415, Len = 10
# Koza Evals 37100: Best = 2.097415, Len = 10
# Koza Evals 38100: Best = 2.097415, Len = 10
# Koza Evals 39100: Best = 2.097415, Len = 10
# Koza Evals 40100: Best = 2.097415, Len = 10
# Koza Evals 41100: Best = 2.097415, Len = 10
# Koza Evals 42100: Best = 2.097415, Len = 10
# Koza Evals 43100: Best = 2.097415, Len = 10
# Koza Evals 44100: Best = 2.097415, Len = 10
# Koza Evals 45100: Best = 1.839555, Len = 12
# Koza Evals 46100: Best = 1.839555, Len = 12
# Koza Evals 47100: Best = 1.839555, Len = 12
# Koza Evals 48100: Best = 1.839555, Len = 12
# Koza Evals 49100: Best = 1.839555, Len = 12
# Koza Evals 50100: Best = 1.839555, Len = 12
# Koza Evals 51100: Best = 1.839555, Len = 12
# Koza Evals 52100: Best = 1.839555, Len = 12
# Koza Evals 53100: Best = 1.839555, Len = 12
# Koza Evals 54100: Best = 1.839555, Len = 12
# Koza Evals 55100: Best = 1.839555, Len = 12
# Koza Evals 56100: Best = 1.839555, Len = 12
# Koza Evals 57100: Best = 1.839555, Len = 12
# Koza Evals 58100: Best = 1.839555, Len = 12
# Koza Evals 59100: Best = 1.839555, Len = 12
# Koza Evals 60100: Best = 1.839555, Len = 12
# Koza Evals 61100: Best = 1.839555, Len = 12
# Koza Evals 62100: Best = 1.839555, Len = 12
# Koza Evals 63100: Best = 1.839555, Len = 12
# Koza Evals 64100: Best = 1.839555, Len = 12
# Koza Evals 65100: Best = 1.839555, Len = 12
# Koza Evals 66100: Best = 1.839555, Len = 12
# Koza Evals 67100: Best = 1.839555, Len = 12
# Koza Evals 68100: Best = 1.839555, Len = 12
# Koza Evals 69100: Best = 1.839555, Len = 12
# Koza Evals 70100: Best = 1.839555, Len = 12
# Koza Evals 71100: Best = 1.839555, Len = 12
# Koza Evals 72100: Best = 1.839555, Len = 12
# Koza Evals 73100: Best = 1.839555, Len = 12
# Koza Evals 74100: Best = 1.839555, Len = 12
# Koza Evals 75100: Best = 1.839555, Len = 12
# Koza Evals 76100: Best = 1.839555, Len = 12
# Koza Evals 77100: Best = 1.839555, Len = 12
# Koza Evals 78100: Best = 1.839555, Len = 12
# Koza Evals 79100: Best = 1.839555, Len = 12
# Koza Evals 80100: Best = 1.839555, Len = 12
# Koza Evals 81100: Best = 1.839555, Len = 12
# Koza Evals 82100: Best = 1.839555, Len = 12
# Koza Evals 83100: Best = 1.839555, Len = 12
# Koza Evals 84100: Best = 1.839555, Len = 12
# Koza Evals 85100: Best = 1.839555, Len = 12
# Koza Evals 86100: Best = 1.839555, Len = 12
# Koza Evals 87100: Best = 1.839555, Len = 12
# Koza Evals 88100: Best = 1.839555, Len = 12
# Koza Evals 89100: Best = 1.839555, Len = 12
# Koza Evals 90100: Best = 1.839555, Len = 12
# Koza Evals 91100: Best = 1.839555, Len = 12
# Koza Evals 92100: Best = 1.839555, Len = 12
# Koza Evals 93100: Best = 1.839555, Len = 12
# Koza Evals 94100: Best = 1.839555, Len = 12
# Koza Evals 95100: Best = 1.839555, Len = 12
# Koza Evals 96100: Best = 1.839555, Len = 12
# Koza Evals 97100: Best = 1.839555, Len = 12
# Koza Evals 98100: Best = 1.839555, Len = 12
# Koza Evals 99100: Best = 1.839555, Len = 12
# Koza Evals 100: Best = 9.072105, Len = 11
# Koza Evals 1100: Best = 9.072105, Len = 11
# Koza Evals 2100: Best = 7.164115, Len = 10
# Koza Evals 3100: Best = 7.164115, Len = 10
# Koza Evals 4100: Best = 7.164115, Len = 10
# Koza Evals 5100: Best = 7.164115, Len = 10
# Koza Evals 6100: Best = 7.164115, Len = 10
# Koza Evals 7100: Best = 7.164115, Len = 10
# Koza Evals 8100: Best = 7.164115, Len = 10
# Koza Evals 9100: Best = 7.164115, Len = 10
# Koza Evals 10100: Best = 7.164115, Len = 10
# Koza Evals 11100: Best = 7.164115, Len = 10
# Koza Evals 12100: Best = 7.164115, Len = 10
# Koza Evals 13100: Best = 7.164115, Len = 10
# Koza Evals 14100: Best = 7.164115, Len = 10
# Koza Evals 15100: Best = 7.164115, Len = 10
# Koza Evals 16100: Best = 7.164115, Len = 10
# Koza Evals 17100: Best = 7.164115, Len = 10
# Koza Evals 18100: Best = 7.164115, Len = 10
# Koza Evals 19100: Best = 7.164115, Len = 10
# Koza Evals 20100: Best = 7.164115, Len = 10
# Koza Evals 21100: Best = 7.164115, Len = 10
# Koza Evals 22100: Best = 7.164115, Len = 10
# Koza Evals 23100: Best = 7.164115, Len = 10
# Koza Evals 24100: Best = 7.164115, Len = 10
# Koza Evals 25100: Best = 7.164115, Len = 10
# Koza Evals 26100: Best = 7.164115, Len = 10
# Koza Evals 27100: Best = 7.164115, Len = 10
# Koza Evals 28100: Best = 7.164115, Len = 10
# Koza Evals 29100: Best = 7.164115, Len = 10
# Koza Evals 30100: Best = 7.164115, Len = 10
# Koza Evals 31100: Best = 7.164115, Len = 10
# Koza Evals 32100: Best = 7.164115, Len = 10
# Koza Evals 33100: Best = 7.164115, Len = 10
# Koza Evals 34100: Best = 7.164115, Len = 10
# Koza Evals 35100: Best = 7.164115, Len = 10
# Koza Evals 36100: Best = 7.164115, Len = 10
# Koza Evals 37100: Best = 7.164115, Len = 10
# Koza Evals 38100: Best = 7.164115, Len = 10
# Koza Evals 39100: Best = 7.164115, Len = 10
# Koza Evals 40100: Best = 6.449660, Len = 11
# Koza Evals 41100: Best = 6.449660, Len = 11
# Koza Evals 42100: Best = 6.449660, Len = 11
# Koza Evals 43100: Best = 6.449660, Len = 11
# Koza Evals 44100: Best = 6.449660, Len = 11
# Koza Evals 45100: Best = 6.449660, Len = 11
# Koza Evals 46100: Best = 6.449660, Len = 11
# Koza Evals 47100: Best = 6.449660, Len = 11
# Koza Evals 48100: Best = 6.449660, Len = 11
# Koza Evals 49100: Best = 6.449660, Len = 11
# Koza Evals 50100: Best = 6.449660, Len = 11
# Koza Evals 51100: Best = 6.449660, Len = 11
# Koza Evals 52100: Best = 6.449660, Len = 11
# Koza Evals 53100: Best = 6.449660, Len = 11
# Koza Evals 54100: Best = 6.449660, Len = 11
# Koza Evals 55100: Best = 6.449660, Len = 11
# Koza Evals 56100: Best = 6.449660, Len = 11
# Koza Evals 57100: Best = 4.155964, Len = 11
# Koza Evals 58100: Best = 4.155964, Len = 11
# Koza Evals 59100: Best = 4.155964, Len = 11
# Koza Evals 60100: Best = 4.155964, Len = 11
# Koza Evals 61100: Best = 4.155964, Len = 11
# Koza Evals 62100: Best = 4.155964, Len = 11
# Koza Evals 63100: Best = 4.155964, Len = 11
# Koza Evals 64100: Best = 4.155964, Len = 11
# Koza Evals 65100: Best = 4.155964, Len = 11
# Koza Evals 66100: Best = 3.014101, Len = 11
# Koza Evals 67100: Best = 3.014101, Len = 11
# Koza Evals 68100: Best = 3.014101, Len = 11
# Koza Evals 69100: Best = 3.014101, Len = 11
# Koza Evals 70100: Best = 3.014101, Len = 11
# Koza Evals 71100: Best = 3.014101, Len = 11
# Koza Evals 72100: Best = 3.014101, Len = 11
# Koza Evals 73100: Best = 2.178089, Len = 12
# Koza Evals 74100: Best = 2.178089, Len = 12
# Koza Evals 75100: Best = 2.178089, Len = 12
# Koza Evals 76100: Best = 2.178089, Len = 12
# Koza Evals 77100: Best = 2.178089, Len = 12
# Koza Evals 78100: Best = 2.178089, Len = 12
# Koza Evals 79100: Best = 2.176943, Len = 12
# Koza Evals 80100: Best = 2.176943, Len = 12
# Koza Evals 81100: Best = 2.176943, Len = 12
# Koza Evals 82100: Best = 2.176943, Len = 12
# Koza Evals 83100: Best = 2.176943, Len = 12
# Koza Evals 84100: Best = 2.176943, Len = 12
# Koza Evals 85100: Best = 2.176943, Len = 12
# Koza Evals 86100: Best = 2.176943, Len = 12
# Koza Evals 87100: Best = 2.176943, Len = 12
# Koza Evals 88100: Best = 2.176943, Len = 12
# Koza Evals 89100: Best = 2.176943, Len = 12
# Koza Evals 90100: Best = 2.176943, Len = 12
# Koza Evals 91100: Best = 2.176943, Len = 12
# Koza Evals 92100: Best = 2.176943, Len = 12
# Koza Evals 93100: Best = 2.176943, Len = 12
# Koza Evals 94100: Best = 2.176943, Len = 12
# Koza Evals 95100: Best = 2.176943, Len = 12
# Koza Evals 96100: Best = 2.176943, Len = 12
# Koza Evals 97100: Best = 2.176943, Len = 12
# Koza Evals 98100: Best = 2.176943, Len = 12
# Koza Evals 99100: Best = 2.176943, Len = 12
# Koza Evals 100: Best = 70.237560, Len = 12
# Koza Evals 1100: Best = 24.195119, Len = 11
# Koza Evals 2100: Best = 24.195119, Len = 11
# Koza Evals 3100: Best = 24.195119, Len = 11
# Koza Evals 4100: Best = 24.195119, Len = 11
# Koza Evals 5100: Best = 24.195119, Len = 11
# Koza Evals 6100: Best = 24.195119, Len = 11
# Koza Evals 7100: Best = 24.195119, Len = 11
# Koza Evals 8100: Best = 24.195119, Len = 11
# Koza Evals 9100: Best = 24.195119, Len = 11
# Koza Evals 10100: Best = 24.195119, Len = 11
# Koza Evals 11100: Best = 24.195119, Len = 11
# Koza Evals 12100: Best = 24.195119, Len = 11
# Koza Evals 13100: Best = 24.195119, Len = 11
# Koza Evals 14100: Best = 24.195119, Len = 11
# Koza Evals 15100: Best = 24.195119, Len = 11
# Koza Evals 16100: Best = 20.169576, Len = 12
# Koza Evals 17100: Best = 20.169576, Len = 12
# Koza Evals 18100: Best = 20.169576, Len = 12
# Koza Evals 19100: Best = 20.169576, Len = 12
# Koza Evals 20100: Best = 20.169576, Len = 12
# Koza Evals 21100: Best = 20.169576, Len = 12
# Koza Evals 22100: Best = 15.008301, Len = 12
# Koza Evals 23100: Best = 15.008301, Len = 12
# Koza Evals 24100: Best = 15.008301, Len = 12
# Koza Evals 25100: Best = 15.008301, Len = 12
# Koza Evals 26100: Best = 15.008301, Len = 12
# Koza Evals 27100: Best = 15.008301, Len = 12
# Koza Evals 28100: Best = 15.008301, Len = 12
# Koza Evals 29100: Best = 15.008301, Len = 12
# Koza Evals 30100: Best = 15.008301, Len = 12
# Koza Evals 31100: Best = 15.008301, Len = 12
# Koza Evals 32100: Best = 15.008301, Len = 12
# Koza Evals 33100: Best = 15.008301, Len = 12
# Koza Evals 34100: Best = 15.008301, Len = 12
# Koza Evals 35100: Best = 15.008301, Len = 12
# Koza Evals 36100: Best = 15.008301, Len = 12
# Koza Evals 37100: Best = 15.008301, Len = 12
# Koza Evals 38100: Best = 15.008301, Len = 12
# Koza Evals 39100: Best = 15.008301, Len = 12
# Koza Evals 40100: Best = 15.008301, Len = 12
# Koza Evals 41100: Best = 15.008301, Len = 12
# Koza Evals 42100: Best = 15.008301, Len = 12
# Koza Evals 43100: Best = 15.008301, Len = 12
# Koza Evals 44100: Best = 15.008301, Len = 12
# Koza Evals 45100: Best = 15.008301, Len = 12
# Koza Evals 46100: Best = 15.008301, Len = 12
# Koza Evals 47100: Best = 15.008301, Len = 12
# Koza Evals 48100: Best = 12.386552, Len = 12
# Koza Evals 49100: Best = 12.386552, Len = 12
# Koza Evals 50100: Best = 12.386552, Len = 12
# Koza Evals 51100: Best = 12.386552, Len = 12
# Koza Evals 52100: Best = 12.386552, Len = 12
# Koza Evals 53100: Best = 12.386552, Len = 12
# Koza Evals 54100: Best = 12.386552, Len = 12
# Koza Evals 55100: Best = 12.386552, Len = 12
# Koza Evals 56100: Best = 12.386552, Len = 12
# Koza Evals 57100: Best = 12.386552, Len = 12
# Koza Evals 58100: Best = 12.386552, Len = 12
# Koza Evals 59100: Best = 12.386552, Len = 12
# Koza Evals 60100: Best = 12.386552, Len = 12
# Koza Evals 61100: Best = 12.386552, Len = 12
# Koza Evals 62100: Best = 12.386552, Len = 12
# Koza Evals 63100: Best = 12.386552, Len = 12
# Koza Evals 64100: Best = 12.386552, Len = 12
# Koza Evals 65100: Best = 10.898774, Len = 12
# Koza Evals 66100: Best = 10.898774, Len = 12
# Koza Evals 67100: Best = 10.898774, Len = 12
# Koza Evals 68100: Best = 10.898774, Len = 12
# Koza Evals 69100: Best = 10.898774, Len = 12
# Koza Evals 70100: Best = 10.898774, Len = 12
# Koza Evals 71100: Best = 10.898774, Len = 12
# Koza Evals 72100: Best = 10.898774, Len = 12
# Koza Evals 73100: Best = 10.898774, Len = 12
# Koza Evals 74100: Best = 10.898774, Len = 12
# Koza Evals 75100: Best = 10.898774, Len = 12
# Koza Evals 76100: Best = 10.898774, Len = 12
# Koza Evals 77100: Best = 10.898774, Len = 12
# Koza Evals 78100: Best = 10.898774, Len = 12
# Koza Evals 79100: Best = 10.898774, Len = 12
# Koza Evals 80100: Best = 10.898774, Len = 12
# Koza Evals 81100: Best = 10.898774, Len = 12
# Koza Evals 82100: Best = 10.898774, Len = 12
# Koza Evals 83100: Best = 10.898774, Len = 12
# Koza Evals 84100: Best = 6.935370, Len = 12
# Koza Evals 85100: Best = 6.935370, Len = 12
# Koza Evals 86100: Best = 6.935370, Len = 12
# Koza Evals 87100: Best = 6.935370, Len = 12
# Koza Evals 88100: Best = 6.935370, Len = 12
# Koza Evals 89100: Best = 6.935370, Len = 12
# Koza Evals 90100: Best = 6.935370, Len = 12
# Koza Evals 91100: Best = 6.935370, Len = 12
# Koza Evals 92100: Best = 6.935370, Len = 12
# Koza Evals 93100: Best = 6.935370, Len = 12
# Koza Evals 94100: Best = 6.935370, Len = 12
# Koza Evals 95100: Best = 6.935370, Len = 12
# Koza Evals 96100: Best = 6.935370, Len = 12
# Koza Evals 97100: Best = 6.935370, Len = 12
# Koza Evals 98100: Best = 6.935370, Len = 12
# Koza Evals 99100: Best = 6.935370, Len = 12
# Koza Evals 100: Best = 31.191759, Len = 12
# Koza Evals 1100: Best = 31.191759, Len = 12
# Koza Evals 2100: Best = 31.191759, Len = 12
# Koza Evals 3100: Best = 22.845373, Len = 12
# Koza Evals 4100: Best = 22.845373, Len = 12
# Koza Evals 5100: Best = 20.835139, Len = 12
# Koza Evals 6100: Best = 20.835139, Len = 12
# Koza Evals 7100: Best = 20.835139, Len = 12
# Koza Evals 8100: Best = 20.835139, Len = 12
# Koza Evals 9100: Best = 20.835139, Len = 12
# Koza Evals 10100: Best = 20.835139, Len = 12
# Koza Evals 11100: Best = 20.835139, Len = 12
# Koza Evals 12100: Best = 20.835139, Len = 12
# Koza Evals 13100: Best = 20.835139, Len = 12
# Koza Evals 14100: Best = 14.748422, Len = 12
# Koza Evals 15100: Best = 14.748422, Len = 12
# Koza Evals 16100: Best = 14.748422, Len = 12
# Koza Evals 17100: Best = 14.748422, Len = 12
# Koza Evals 18100: Best = 14.748422, Len = 12
# Koza Evals 19100: Best = 14.748422, Len = 12
# Koza Evals 20100: Best = 14.748422, Len = 12
# Koza Evals 21100: Best = 14.748422, Len = 12
# Koza Evals 22100: Best = 14.748422, Len = 12
# Koza Evals 23100: Best = 14.748422, Len = 12
# Koza Evals 24100: Best = 14.748422, Len = 12
# Koza Evals 25100: Best = 14.748422, Len = 12
# Koza Evals 26100: Best = 14.748422, Len = 12
# Koza Evals 27100: Best = 14.748422, Len = 12
# Koza Evals 28100: Best = 14.748422, Len = 12
# Koza Evals 29100: Best = 14.748422, Len = 12
# Koza Evals 30100: Best = 6.589680, Len = 12
# Koza Evals 31100: Best = 6.589680, Len = 12
# Koza Evals 32100: Best = 6.589680, Len = 12
# Koza Evals 33100: Best = 6.589680, Len = 12
# Koza Evals 34100: Best = 6.589680, Len = 12
# Koza Evals 35100: Best = 6.589680, Len = 12
# Koza Evals 36100: Best = 6.589680, Len = 12
# Koza Evals 37100: Best = 6.589680, Len = 12
# Koza Evals 38100: Best = 6.589680, Len = 12
# Koza Evals 39100: Best = 6.589680, Len = 12
# Koza Evals 40100: Best = 6.589680, Len = 12
# Koza Evals 41100: Best = 6.589680, Len = 12
# Koza Evals 42100: Best = 6.589680, Len = 12
# Koza Evals 43100: Best = 6.589680, Len = 12
# Koza Evals 44100: Best = 6.589680, Len = 12
# Koza Evals 45100: Best = 6.589680, Len = 12
# Koza Evals 46100: Best = 6.589680, Len = 12
# Koza Evals 47100: Best = 6.589680, Len = 12
# Koza Evals 48100: Best = 6.589680, Len = 12
# Koza Evals 49100: Best = 6.589680, Len = 12
# ...
# Rastrigin Evals 32100: Best = 212.894301, Len = 29
# Rastrigin Evals 33100: Best = 212.894301, Len = 29
# Rastrigin Evals 34100: Best = 212.894301, Len = 29
# Rastrigin Evals 35100: Best = 212.894301, Len = 29
# Rastrigin Evals 36100: Best = 212.894301, Len = 29
# Rastrigin Evals 37100: Best = 212.894301, Len = 29
# Rastrigin Evals 38100: Best = 212.894301, Len = 29
# Rastrigin Evals 39100: Best = 212.894301, Len = 29
# Rastrigin Evals 40100: Best = 212.894301, Len = 29
# Rastrigin Evals 41100: Best = 212.894301, Len = 29
# Rastrigin Evals 42100: Best = 197.677107, Len = 29
# Rastrigin Evals 43100: Best = 197.677107, Len = 29
# Rastrigin Evals 44100: Best = 197.677107, Len = 29
# Rastrigin Evals 45100: Best = 197.677107, Len = 29
# Rastrigin Evals 46100: Best = 197.677107, Len = 29
# Rastrigin Evals 47100: Best = 197.677107, Len = 29
# Rastrigin Evals 48100: Best = 197.677107, Len = 29
# Rastrigin Evals 49100: Best = 197.677107, Len = 29
# Rastrigin Evals 50100: Best = 197.677107, Len = 29
# Rastrigin Evals 51100: Best = 197.677107, Len = 29
# Rastrigin Evals 52100: Best = 176.362126, Len = 29
# Rastrigin Evals 53100: Best = 176.362126, Len = 29
# Rastrigin Evals 54100: Best = 176.362126, Len = 29
# Rastrigin Evals 55100: Best = 176.362126, Len = 29
# Rastrigin Evals 56100: Best = 176.362126, Len = 29
# Rastrigin Evals 57100: Best = 176.362126, Len = 29
# Rastrigin Evals 58100: Best = 176.362126, Len = 29
# Rastrigin Evals 59100: Best = 176.362126, Len = 29
# Rastrigin Evals 60100: Best = 176.362126, Len = 29
# Rastrigin Evals 61100: Best = 176.362126, Len = 29
# Rastrigin Evals 62100: Best = 176.362126, Len = 29
# Rastrigin Evals 63100: Best = 176.053912, Len = 29
# Rastrigin Evals 64100: Best = 176.053912, Len = 29
# Rastrigin Evals 65100: Best = 176.053912, Len = 29
# Rastrigin Evals 66100: Best = 176.053912, Len = 29
# Rastrigin Evals 67100: Best = 176.053912, Len = 29
# Rastrigin Evals 68100: Best = 176.053912, Len = 29
# Rastrigin Evals 69100: Best = 176.053912, Len = 29
# Rastrigin Evals 70100: Best = 176.053912, Len = 29
# Rastrigin Evals 71100: Best = 152.414678, Len = 29
# Rastrigin Evals 72100: Best = 152.414678, Len = 29
# Rastrigin Evals 73100: Best = 152.414678, Len = 29
# Rastrigin Evals 74100: Best = 152.414678, Len = 29
# Rastrigin Evals 75100: Best = 152.414678, Len = 29
# Rastrigin Evals 76100: Best = 152.414678, Len = 29
# Rastrigin Evals 77100: Best = 152.414678, Len = 29
# Rastrigin Evals 78100: Best = 152.414678, Len = 29
# Rastrigin Evals 79100: Best = 152.414678, Len = 29
# Rastrigin Evals 80100: Best = 152.414678, Len = 29
# Rastrigin Evals 81100: Best = 145.073159, Len = 29
# Rastrigin Evals 82100: Best = 145.073159, Len = 29
# Rastrigin Evals 83100: Best = 138.804161, Len = 32
# Rastrigin Evals 84100: Best = 138.804161, Len = 32
# Rastrigin Evals 85100: Best = 131.673758, Len = 29
# Rastrigin Evals 86100: Best = 131.673758, Len = 29
# Rastrigin Evals 87100: Best = 117.620604, Len = 30
# Rastrigin Evals 88100: Best = 112.222275, Len = 29
# Rastrigin Evals 89100: Best = 88.550731, Len = 29
# Rastrigin Evals 90100: Best = 88.550731, Len = 29
# Rastrigin Evals 91100: Best = 75.174836, Len = 30
# Rastrigin Evals 92100: Best = 75.174836, Len = 30
# Rastrigin Evals 93100: Best = 75.174836, Len = 30
# Rastrigin Evals 94100: Best = 62.647175, Len = 30
# Rastrigin Evals 95100: Best = 58.178122, Len = 32
# Rastrigin Evals 96100: Best = 44.673500, Len = 32
# Rastrigin Evals 97100: Best = 41.489534, Len = 32
# Rastrigin Evals 98100: Best = 28.994879, Len = 32
# Rastrigin Evals 99100: Best = 24.526900, Len = 32
# Rastrigin Evals 100: Best = 259.823162, Len = 9
# Rastrigin Evals 1100: Best = 243.561321, Len = 29
# Rastrigin Evals 2100: Best = 243.561321, Len = 29
# Rastrigin Evals 3100: Best = 243.561321, Len = 29
# Rastrigin Evals 4100: Best = 243.561321, Len = 29
# Rastrigin Evals 5100: Best = 230.050543, Len = 28
# Rastrigin Evals 6100: Best = 229.741964, Len = 29
# Rastrigin Evals 7100: Best = 229.741964, Len = 29
# Rastrigin Evals 8100: Best = 229.741964, Len = 29
# Rastrigin Evals 9100: Best = 229.741964, Len = 29
# Rastrigin Evals 10100: Best = 229.741964, Len = 29
# Rastrigin Evals 11100: Best = 229.741964, Len = 29
# Rastrigin Evals 12100: Best = 229.741964, Len = 29
# Rastrigin Evals 13100: Best = 229.741964, Len = 29
# Rastrigin Evals 14100: Best = 229.741964, Len = 29
# Rastrigin Evals 15100: Best = 229.741964, Len = 29
# Rastrigin Evals 16100: Best = 205.237370, Len = 28
# Rastrigin Evals 17100: Best = 205.237370, Len = 28
# Rastrigin Evals 18100: Best = 205.237370, Len = 28
# Rastrigin Evals 19100: Best = 205.237370, Len = 28
# Rastrigin Evals 20100: Best = 205.237370, Len = 28
# Rastrigin Evals 21100: Best = 205.237370, Len = 28
# Rastrigin Evals 22100: Best = 205.237370, Len = 28
# Rastrigin Evals 23100: Best = 205.237370, Len = 28
# Rastrigin Evals 24100: Best = 205.237370, Len = 28
# Rastrigin Evals 25100: Best = 205.237370, Len = 28
# Rastrigin Evals 26100: Best = 205.237370, Len = 28
# Rastrigin Evals 27100: Best = 205.237370, Len = 28
# Rastrigin Evals 28100: Best = 205.237370, Len = 28
# Rastrigin Evals 29100: Best = 205.237370, Len = 28
# Rastrigin Evals 30100: Best = 205.237370, Len = 28
# Rastrigin Evals 31100: Best = 205.237370, Len = 28
# Rastrigin Evals 32100: Best = 205.237370, Len = 28
# Rastrigin Evals 33100: Best = 205.237370, Len = 28
# Rastrigin Evals 34100: Best = 205.237370, Len = 28
# Rastrigin Evals 35100: Best = 205.237370, Len = 28
# Rastrigin Evals 36100: Best = 205.237370, Len = 28
# Rastrigin Evals 37100: Best = 205.237370, Len = 28
# Rastrigin Evals 38100: Best = 205.237370, Len = 28
# Rastrigin Evals 39100: Best = 205.237370, Len = 28
# Rastrigin Evals 40100: Best = 205.237370, Len = 28
# Rastrigin Evals 41100: Best = 205.237370, Len = 28
# Rastrigin Evals 42100: Best = 205.237370, Len = 28
# Rastrigin Evals 43100: Best = 205.237370, Len = 28
# Rastrigin Evals 44100: Best = 205.237370, Len = 28
# Rastrigin Evals 45100: Best = 205.237370, Len = 28
# Rastrigin Evals 46100: Best = 205.237370, Len = 28
# Rastrigin Evals 47100: Best = 193.190670, Len = 29
# Rastrigin Evals 48100: Best = 193.190670, Len = 29
# Rastrigin Evals 49100: Best = 193.190670, Len = 29
# Rastrigin Evals 50100: Best = 193.190670, Len = 29
# Rastrigin Evals 51100: Best = 193.190670, Len = 29
# Rastrigin Evals 52100: Best = 189.498671, Len = 29
# Rastrigin Evals 53100: Best = 189.498671, Len = 29
# Rastrigin Evals 54100: Best = 189.498671, Len = 29
# Rastrigin Evals 55100: Best = 189.498671, Len = 29
# Rastrigin Evals 56100: Best = 189.498671, Len = 29
# Rastrigin Evals 57100: Best = 189.498671, Len = 29
# Rastrigin Evals 58100: Best = 189.498671, Len = 29
# Rastrigin Evals 59100: Best = 189.498671, Len = 29
# Rastrigin Evals 60100: Best = 189.498671, Len = 29
# Rastrigin Evals 61100: Best = 189.498671, Len = 29
# Rastrigin Evals 62100: Best = 189.498671, Len = 29
# Rastrigin Evals 63100: Best = 188.063312, Len = 29
# Rastrigin Evals 64100: Best = 188.063312, Len = 29
# Rastrigin Evals 65100: Best = 188.063312, Len = 29
# Rastrigin Evals 66100: Best = 179.597823, Len = 30
# Rastrigin Evals 67100: Best = 152.888269, Len = 29
# Rastrigin Evals 68100: Best = 152.888269, Len = 29
# Rastrigin Evals 69100: Best = 152.888269, Len = 29
# Rastrigin Evals 70100: Best = 152.888269, Len = 29
# Rastrigin Evals 71100: Best = 152.888269, Len = 29
# Rastrigin Evals 72100: Best = 152.888269, Len = 29
# Rastrigin Evals 73100: Best = 152.888269, Len = 29
# Rastrigin Evals 74100: Best = 152.888269, Len = 29
# Rastrigin Evals 75100: Best = 152.888269, Len = 29
# Rastrigin Evals 76100: Best = 152.888269, Len = 29
# Rastrigin Evals 77100: Best = 152.888269, Len = 29
# Rastrigin Evals 78100: Best = 152.421250, Len = 29
# Rastrigin Evals 79100: Best = 152.421250, Len = 29
# Rastrigin Evals 80100: Best = 152.421250, Len = 29
# Rastrigin Evals 81100: Best = 145.890276, Len = 30
# Rastrigin Evals 82100: Best = 137.039436, Len = 31
# Rastrigin Evals 83100: Best = 137.039436, Len = 31
# Rastrigin Evals 84100: Best = 137.039436, Len = 31
# Rastrigin Evals 85100: Best = 133.899825, Len = 30
# Rastrigin Evals 86100: Best = 133.899825, Len = 30
# Rastrigin Evals 87100: Best = 133.899825, Len = 30
# Rastrigin Evals 88100: Best = 121.264383, Len = 31
# Rastrigin Evals 89100: Best = 120.883775, Len = 31
# Rastrigin Evals 90100: Best = 117.195054, Len = 30
# Rastrigin Evals 91100: Best = 113.864905, Len = 31
# Rastrigin Evals 92100: Best = 99.993149, Len = 31
# Rastrigin Evals 93100: Best = 78.784864, Len = 31
# Rastrigin Evals 94100: Best = 74.293523, Len = 31
# Rastrigin Evals 95100: Best = 56.626262, Len = 31
# Rastrigin Evals 96100: Best = 54.990546, Len = 31
# Rastrigin Evals 97100: Best = 42.820154, Len = 31
# Rastrigin Evals 98100: Best = 37.605215, Len = 31
# Rastrigin Evals 99100: Best = 29.555271, Len = 31
# Griewank Evals 100: Best = 0.869624, Len = 29
# Griewank Evals 1100: Best = 0.869624, Len = 29
# Griewank Evals 2100: Best = 0.869624, Len = 29
# Griewank Evals 3100: Best = 0.869624, Len = 29
# Griewank Evals 4100: Best = 0.825266, Len = 30
# Griewank Evals 5100: Best = 0.825266, Len = 30
# Griewank Evals 6100: Best = 0.815701, Len = 29
# Griewank Evals 7100: Best = 0.777954, Len = 29
# Griewank Evals 8100: Best = 0.777954, Len = 29
# Griewank Evals 9100: Best = 0.777954, Len = 29
# Griewank Evals 10100: Best = 0.777954, Len = 29
# Griewank Evals 11100: Best = 0.760004, Len = 29
# Griewank Evals 12100: Best = 0.760004, Len = 29
# Griewank Evals 13100: Best = 0.760004, Len = 29
# Griewank Evals 14100: Best = 0.760004, Len = 29
# Griewank Evals 15100: Best = 0.760004, Len = 29
# Griewank Evals 16100: Best = 0.760004, Len = 29
# Griewank Evals 17100: Best = 0.690169, Len = 29
# Griewank Evals 18100: Best = 0.690169, Len = 29
# Griewank Evals 19100: Best = 0.690169, Len = 29
# Griewank Evals 20100: Best = 0.515145, Len = 30
# Griewank Evals 21100: Best = 0.515145, Len = 30
# Griewank Evals 22100: Best = 0.515145, Len = 30
# Griewank Evals 23100: Best = 0.515145, Len = 30
# Griewank Evals 24100: Best = 0.495445, Len = 31
# Griewank Evals 25100: Best = 0.495445, Len = 31
# Griewank Evals 26100: Best = 0.495445, Len = 31
# Griewank Evals 27100: Best = 0.495445, Len = 31
# Griewank Evals 28100: Best = 0.393801, Len = 31
# Griewank Evals 29100: Best = 0.393801, Len = 31
# Griewank Evals 30100: Best = 0.393801, Len = 31
# Griewank Evals 31100: Best = 0.336276, Len = 31
# Griewank Evals 32100: Best = 0.270032, Len = 31
# Griewank Evals 33100: Best = 0.252487, Len = 31
# Griewank Evals 34100: Best = 0.203200, Len = 31
# Griewank Evals 35100: Best = 0.203200, Len = 31
# Griewank Evals 36100: Best = 0.203200, Len = 31
# Griewank Evals 37100: Best = 0.153069, Len = 31
# Griewank Evals 38100: Best = 0.153069, Len = 31
# Griewank Evals 39100: Best = 0.153069, Len = 31
# Griewank Evals 40100: Best = 0.153069, Len = 31
# Griewank Evals 41100: Best = 0.138782, Len = 32
# Griewank Evals 42100: Best = 0.124826, Len = 32
# Griewank Evals 43100: Best = 0.064356, Len = 32
# Griewank Evals 44100: Best = 0.064356, Len = 32
# Griewank Evals 45100: Best = 0.064356, Len = 32
# Griewank Evals 46100: Best = 0.064356, Len = 32
# Griewank Evals 47100: Best = 0.055149, Len = 32
# Griewank Evals 48100: Best = 0.055149, Len = 32
# Griewank Evals 49100: Best = 0.055149, Len = 32
# Griewank Evals 50100: Best = 0.055149, Len = 32
# Griewank Evals 51100: Best = 0.049155, Len = 32
# Griewank Evals 52100: Best = 0.033851, Len = 32
# Griewank Evals 53100: Best = 0.031713, Len = 32
# Griewank Evals 54100: Best = 0.031713, Len = 32
# Griewank Evals 55100: Best = 0.031713, Len = 32
# Griewank Evals 56100: Best = 0.028735, Len = 32
# Griewank Evals 57100: Best = 0.024514, Len = 32
# Griewank Evals 58100: Best = 0.024460, Len = 32
# Griewank Evals 59100: Best = 0.022821, Len = 32
# Griewank Evals 60100: Best = 0.022821, Len = 32
# Griewank Evals 61100: Best = 0.021139, Len = 32
# Griewank Evals 62100: Best = 0.014615, Len = 32
# Griewank Evals 63100: Best = 0.014615, Len = 32
# Griewank Evals 64100: Best = 0.013889, Len = 32
# Griewank Evals 65100: Best = 0.012651, Len = 32
# Griewank Evals 66100: Best = 0.008455, Len = 32
# Griewank Evals 67100: Best = 0.008455, Len = 32
# Griewank Evals 68100: Best = 0.008455, Len = 32
# Griewank Evals 69100: Best = 0.007749, Len = 32
# Griewank Evals 70100: Best = 0.007010, Len = 32
# Griewank Evals 71100: Best = 0.007010, Len = 32
# Griewank Evals 72100: Best = 0.006679, Len = 32
# Griewank Evals 73100: Best = 0.005182, Len = 32
# Griewank Evals 74100: Best = 0.005182, Len = 32
# Griewank Evals 75100: Best = 0.004669, Len = 32
# Griewank Evals 76100: Best = 0.004549, Len = 32
# Griewank Evals 77100: Best = 0.003856, Len = 32
# Griewank Evals 78100: Best = 0.003856, Len = 32
# Griewank Evals 79100: Best = 0.002781, Len = 32
# Griewank Evals 80100: Best = 0.002781, Len = 32
# Griewank Evals 81100: Best = 0.002338, Len = 32
# Griewank Evals 82100: Best = 0.002338, Len = 32
# Griewank Evals 83100: Best = 0.001584, Len = 32
# Griewank Evals 84100: Best = 0.001273, Len = 32
# Griewank Evals 85100: Best = 0.001249, Len = 32
# Griewank Evals 86100: Best = 0.001152, Len = 32
# Griewank Evals 87100: Best = 0.001114, Len = 32
# Griewank Evals 88100: Best = 0.000663, Len = 32
# Griewank Evals 89100: Best = 0.000663, Len = 32
# Griewank Evals 90100: Best = 0.000663, Len = 32
# Griewank Evals 91100: Best = 0.000598, Len = 32
# Griewank Evals 92100: Best = 0.000494, Len = 32
# Griewank Evals 93100: Best = 0.000346, Len = 32
# Griewank Evals 94100: Best = 0.000333, Len = 32
# Griewank Evals 95100: Best = 0.000333, Len = 32
# Griewank Evals 96100: Best = 0.000333, Len = 32
# Griewank Evals 97100: Best = 0.000254, Len = 32
# Griewank Evals 98100: Best = 0.000201, Len = 32
# Griewank Evals 99100: Best = 0.000166, Len = 32
# Griewank Evals 100: Best = 0.789586, Len = 31
# Griewank Evals 1100: Best = 0.789586, Len = 31
# Griewank Evals 2100: Best = 0.789586, Len = 31
# Griewank Evals 3100: Best = 0.789586, Len = 31
# Griewank Evals 4100: Best = 0.789586, Len = 31
# Griewank Evals 5100: Best = 0.789586, Len = 31
# Griewank Evals 6100: Best = 0.789586, Len = 31
# Griewank Evals 7100: Best = 0.789586, Len = 31
# Griewank Evals 8100: Best = 0.789586, Len = 31
# Griewank Evals 9100: Best = 0.789586, Len = 31
# Griewank Evals 10100: Best = 0.789586, Len = 31
# Griewank Evals 11100: Best = 0.789586, Len = 31
# Griewank Evals 12100: Best = 0.774132, Len = 31
# Griewank Evals 13100: Best = 0.774132, Len = 31
# Griewank Evals 14100: Best = 0.770826, Len = 32
# Griewank Evals 15100: Best = 0.770826, Len = 32
# Griewank Evals 16100: Best = 0.770826, Len = 32
# Griewank Evals 17100: Best = 0.770826, Len = 32
# Griewank Evals 18100: Best = 0.770826, Len = 32
# Griewank Evals 19100: Best = 0.770826, Len = 32
# Griewank Evals 20100: Best = 0.676906, Len = 32
# Griewank Evals 21100: Best = 0.676906, Len = 32
# Griewank Evals 22100: Best = 0.574621, Len = 32
# Griewank Evals 23100: Best = 0.574621, Len = 32
# Griewank Evals 24100: Best = 0.574621, Len = 32
# Griewank Evals 25100: Best = 0.574621, Len = 32
# Griewank Evals 26100: Best = 0.574621, Len = 32
# Griewank Evals 27100: Best = 0.574621, Len = 32
# Griewank Evals 28100: Best = 0.559347, Len = 32
# Griewank Evals 29100: Best = 0.472600, Len = 32
# Griewank Evals 30100: Best = 0.466277, Len = 32
# Griewank Evals 31100: Best = 0.407917, Len = 32
# Griewank Evals 32100: Best = 0.407917, Len = 32
# Griewank Evals 33100: Best = 0.244089, Len = 32
# Griewank Evals 34100: Best = 0.244089, Len = 32
# Griewank Evals 35100: Best = 0.244089, Len = 32
# Griewank Evals 36100: Best = 0.215661, Len = 32
# Griewank Evals 37100: Best = 0.212171, Len = 32
# Griewank Evals 38100: Best = 0.153836, Len = 32
# Griewank Evals 39100: Best = 0.153836, Len = 32
# Griewank Evals 40100: Best = 0.127631, Len = 32
# Griewank Evals 41100: Best = 0.127533, Len = 32
# Griewank Evals 42100: Best = 0.123320, Len = 32
# Griewank Evals 43100: Best = 0.123320, Len = 32
# Griewank Evals 44100: Best = 0.091101, Len = 32
# Griewank Evals 45100: Best = 0.091101, Len = 32
# Griewank Evals 46100: Best = 0.079310, Len = 32
# Griewank Evals 47100: Best = 0.076682, Len = 32
# Griewank Evals 48100: Best = 0.070223, Len = 32
# Griewank Evals 49100: Best = 0.061891, Len = 32
# Griewank Evals 50100: Best = 0.050368, Len = 32
# Griewank Evals 51100: Best = 0.049834, Len = 32
# Griewank Evals 52100: Best = 0.043777, Len = 32
# Griewank Evals 53100: Best = 0.041168, Len = 32
# Griewank Evals 54100: Best = 0.040720, Len = 32
