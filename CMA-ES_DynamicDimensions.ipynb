# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE     = 100
N_EVALS      = 100000
N_REPLICATES = 30
MIN_LEN      = 3
MAX_LEN      = 100
gene_low, gene_high = -2.0, 2.0
SIGMA_INIT    = 0.5
P_DIM_CHANGE  = 0.01

target_map = {
    'Sphere':    30,
    'Rastrigin': 30,
    'Griewank':  30,
    'Ackley':    30,
    'Koza':      10,
    'Knapsack':  20,
    'Parity':    64,
    'SantaFe':   100
}

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir   = f'CMA_ES_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_path  = os.path.join(out_dir, 'CMA_ES_results.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=5):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x*x for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x*x - 10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        s = sum(x*x for x in ind)
        p = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + s/4000.0 - p + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        s = sum(x*x for x in ind)
        c = sum(cos(2*pi*x) for x in ind)
        return -20*exp(-0.2*sqrt(s/d)) - exp(c/d) + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    xs = np.linspace(-1,1,20)
    def f(ind):
        err = 0.0
        for x in xs:
            t = x**4 + x**3 + x**2 + x
            p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (p - t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, capacity):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel = [int(round(x))%2 for x in ind[:len(items)]]
        w_sum = sum(w for (w,v),s in zip(items, sel) if s)
        v_sum = sum(v for (w,v),s in zip(items, sel) if s)
        over = max(0, w_sum - capacity)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target = 2**N
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        table = [int(round(x))%2 for x in ind[:d_target]]
        errs = 0
        for i in range(d_target):
            target = bin(i).count('1')%2
            errs += 0 if (i < len(table) and table[i]==target) else 1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    world=[]; sx=sy=0
    with open('santafe_trail.txt') as f:
        for y,line in enumerate(f):
            for x,c in enumerate(line.rstrip('\n')):
                if c=='#': world.append(1)
                elif c in ('.','S'):
                    world.append(0)
                    if c=='S': sx,sy = x,y
    W = len(open('santafe_trail.txt').readline().rstrip('\n'))
    H = len(world)//W
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        dir_ = 0; x,y = sx,sy; food=0
        visited = world.copy()
        idx = lambda xx,yy: (yy%H)*W+(xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)]==1:
                food +=1; visited[idx(x,y)]=0
            act = int(abs(ind[i]))%3
            if act==0:
                dx,dy=[(0,1),(1,0),(0,-1),(-1,0)][dir_]
                x+=dx; y+=dy
            elif act==1:
                dir_=(dir_+1)%4
            else:
                dir_=(dir_-1)%4
        return -food + pen(ind)
    return f

# %%
def computeHyperparams(n_dim, mu):
    w = np.log(mu+0.5) - np.log(np.arange(1,mu+1))
    w /= np.sum(w)
    mu_eff = 1.0/np.sum(w**2)
    c_c  = (4+mu_eff/n_dim)/(n_dim+4+2*mu_eff/n_dim)
    c_s  = (mu_eff+2)/(n_dim+mu_eff+5)
    c1   = 2/((n_dim+1.3)**2 + mu_eff)
    c_mu = min(1-c1, 2*(mu_eff-2+1/mu_eff)/((n_dim+2)**2+mu_eff))
    d_s  = 1 + 2*max(0, sqrt((mu_eff-1)/(n_dim+1))-1) + c_s
    chi_n= sqrt(n_dim)*(1 - 1/(4*n_dim) + 1/(21*n_dim**2))
    return w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n

# %%
def runCMAES(fit, name):
    n     = target_map[name]
    m     = np.random.uniform(gene_low, gene_high, size=n)
    C     = np.eye(n)
    sigma = SIGMA_INIT
    p_c   = np.zeros(n)
    p_s   = np.zeros(n)
    evals = 0
    best_hist=[]
    mu = POP_SIZE//2
    w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n = computeHyperparams(n, mu)

    while evals < N_EVALS:
        if random.random()<P_DIM_CHANGE:
            if random.random()<0.5 and len(m)<MAX_LEN:
                m = np.append(m, random.uniform(gene_low, gene_high))
                C = np.pad(C,((0,1),(0,1)),constant_values=0); C[-1,-1]=1.0
                p_c=np.append(p_c,0.0); p_s=np.append(p_s,0.0)
            elif len(m)>MIN_LEN:
                m=m[:-1]; C=C[:-1,:-1]; p_c=p_c[:-1]; p_s=p_s[:-1]
            n = len(m)
            w, mu_eff, c_c, c_s, c1, c_mu, d_s, chi_n = computeHyperparams(n, mu)

        D2,B = np.linalg.eigh(C)
        D    = np.sqrt(np.abs(D2))
        arz  = np.random.randn(POP_SIZE,n)
        arx  = m + sigma*(arz@(B*D).T)
        fits = [fit(x.tolist()) for x in arx]
        evals += POP_SIZE

        idx = np.argsort(fits)
        arx, arz = arx[idx], arz[idx]
        fits = [fits[i] for i in idx]
        best_hist.append(fits[0])

        old_m = m.copy()
        m     = np.dot(w, arx[:mu])
        y     = (m-old_m)/sigma

        inv_sqrtC = B @ np.diag(1.0/D) @ B.T
        p_s       = (1-c_s)*p_s + sqrt(c_s*(2-c_s)*mu_eff)*(inv_sqrtC@y)
        norm_ps   = np.linalg.norm(p_s)
        h_sigma   = int(norm_ps < (1.4+2/(n+1))*sqrt(1-(1-c_s)**(2*evals/POP_SIZE)))
        p_c       = (1-c_c)*p_c + h_sigma*sqrt(c_c*(2-c_c)*mu_eff)*y

        artmp = (arz[:mu].T * w).T
        C = ((1-c1-c_mu)*C
             + c1*(np.outer(p_c,p_c)+(1-h_sigma)*c_c*(2-c_c)*C)
             + c_mu*(artmp.T@artmp))

        C = (C + C.T)/2
        diag = np.diag(C)
        diag = np.clip(diag, 1e-8, 1e8)
        C[np.diag_indices(len(C))] = diag

        expnt = (c_s/d_s)*(norm_ps/chi_n - 1)
        expnt = np.clip(expnt, -10, 10)
        sigma *= math.exp(expnt)
        sigma = float(np.clip(sigma, 1e-8, 1e+1))

        if evals % (POP_SIZE*10) == 0:
            print(f'{name} Evals {evals}: Best = {best_hist[-1]:.6f}, Len = {len(m)}')

    return m, best_hist

# %%
with open(csv_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=[
        'run_id','benchmark','replicate','seed','best','len_final','cpu_s'
    ])
    writer.writeheader()

    tmp_items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        'Sphere':    sphere(30,10),
        'Rastrigin': rastrigin(30,10),
        'Griewank':  griewank(30,10),
        'Ackley':    ackley(30,10),
        'Koza':      koza(10,10),
        'Knapsack':  knapsack(20,0,tmp_items,50),
        'Parity':    parity(6,10),
        'SantaFe':   santaFe(100,10),
    }

    for name, func in benchmarks.items():
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed); np.random.seed(seed)
            start = time.perf_counter()
            best_vec, hist = runCMAES(func, name)
            cpu = time.perf_counter() - start
            writer.writerow({
                'run_id':    uuid.uuid4(),
                'benchmark': name,
                'replicate': rep,
                'seed':      seed,
                'best':      round(func(best_vec.tolist()),6),
                'len_final': len(best_vec),
                'cpu_s':     round(cpu,4)
            })
print(f'Results written to {csv_path}')
# Out:
# Sphere Evals 1000: Best = 34.199518, Len = 30
# Sphere Evals 2000: Best = 4.201167, Len = 30
# Sphere Evals 3000: Best = 1.011150, Len = 30
# Sphere Evals 4000: Best = 0.189751, Len = 30
# Sphere Evals 5000: Best = 0.027804, Len = 30
# Sphere Evals 6000: Best = 0.004164, Len = 29
# Sphere Evals 7000: Best = 0.000926, Len = 29
# Sphere Evals 8000: Best = 0.000145, Len = 29
# Sphere Evals 9000: Best = 0.000023, Len = 29
# Sphere Evals 10000: Best = 0.000010, Len = 29
# Sphere Evals 11000: Best = 0.000003, Len = 29
# Sphere Evals 12000: Best = 0.000001, Len = 29
# Sphere Evals 13000: Best = 2.466621, Len = 30
# Sphere Evals 14000: Best = 1.623523, Len = 30
# Sphere Evals 15000: Best = 0.364598, Len = 30
# Sphere Evals 16000: Best = 0.102258, Len = 30
# Sphere Evals 17000: Best = 0.025956, Len = 30
# Sphere Evals 18000: Best = 0.010809, Len = 30
# Sphere Evals 19000: Best = 0.001195, Len = 30
# Sphere Evals 20000: Best = 0.000322, Len = 30
# Sphere Evals 21000: Best = 0.000075, Len = 30
# Sphere Evals 22000: Best = 0.000022, Len = 30
# Sphere Evals 23000: Best = 0.000004, Len = 30
# Sphere Evals 24000: Best = 0.000001, Len = 30
# Sphere Evals 25000: Best = 1.470709, Len = 31
# Sphere Evals 26000: Best = 0.738426, Len = 31
# Sphere Evals 27000: Best = 0.291109, Len = 31
# Sphere Evals 28000: Best = 0.072488, Len = 31
# Sphere Evals 29000: Best = 0.013600, Len = 31
# Sphere Evals 30000: Best = 0.004741, Len = 31
# Sphere Evals 31000: Best = 0.927685, Len = 32
# Sphere Evals 32000: Best = 0.293592, Len = 32
# Sphere Evals 33000: Best = 0.111326, Len = 32
# Sphere Evals 34000: Best = 0.102447, Len = 33
# Sphere Evals 35000: Best = 0.070642, Len = 33
# Sphere Evals 36000: Best = 0.020438, Len = 33
# Sphere Evals 37000: Best = 0.006427, Len = 33
# Sphere Evals 38000: Best = 0.001627, Len = 33
# Sphere Evals 39000: Best = 0.000558, Len = 33
# Sphere Evals 40000: Best = 0.000121, Len = 33
# Sphere Evals 41000: Best = 0.000041, Len = 33
# Sphere Evals 42000: Best = 0.000010, Len = 33
# Sphere Evals 43000: Best = 0.000003, Len = 33
# Sphere Evals 44000: Best = 1.119918, Len = 34
# Sphere Evals 45000: Best = 0.209049, Len = 34
# Sphere Evals 46000: Best = 0.078536, Len = 34
# Sphere Evals 47000: Best = 0.019735, Len = 34
# Sphere Evals 48000: Best = 0.011057, Len = 34
# Sphere Evals 49000: Best = 0.003097, Len = 34
# Sphere Evals 50000: Best = 0.001040, Len = 33
# Sphere Evals 51000: Best = 0.000358, Len = 32
# Sphere Evals 52000: Best = 0.000064, Len = 32
# Sphere Evals 53000: Best = 0.000025, Len = 32
# Sphere Evals 54000: Best = 0.000004, Len = 32
# Sphere Evals 55000: Best = 0.000001, Len = 32
# Sphere Evals 56000: Best = 0.000000, Len = 32
# Sphere Evals 57000: Best = 0.000000, Len = 32
# Sphere Evals 58000: Best = 0.000000, Len = 32
# Sphere Evals 59000: Best = 0.000000, Len = 32
# Sphere Evals 60000: Best = 0.000000, Len = 32
# Sphere Evals 61000: Best = 0.000000, Len = 32
# Sphere Evals 62000: Best = 0.000000, Len = 32
# Sphere Evals 63000: Best = 0.000000, Len = 32
# Sphere Evals 64000: Best = 0.000000, Len = 32
# Sphere Evals 65000: Best = 0.000000, Len = 32
# Sphere Evals 66000: Best = 0.000000, Len = 32
# Sphere Evals 67000: Best = 0.000000, Len = 32
# Sphere Evals 68000: Best = 0.000000, Len = 32
# Sphere Evals 69000: Best = 0.000000, Len = 32
# Sphere Evals 70000: Best = 0.000000, Len = 32
# Sphere Evals 71000: Best = 0.000000, Len = 32
# Sphere Evals 72000: Best = 0.000000, Len = 31
# Sphere Evals 73000: Best = 0.000000, Len = 31
# Sphere Evals 74000: Best = 0.000000, Len = 31
# Sphere Evals 75000: Best = 0.000000, Len = 31
# Sphere Evals 76000: Best = 0.000000, Len = 31
# Sphere Evals 77000: Best = 0.000000, Len = 31
# Sphere Evals 78000: Best = 0.424338, Len = 32
# Sphere Evals 79000: Best = 0.424262, Len = 32
# Sphere Evals 80000: Best = 0.415111, Len = 32
# Sphere Evals 81000: Best = 0.039228, Len = 32
# Sphere Evals 82000: Best = 0.070078, Len = 32
# Sphere Evals 83000: Best = 0.027518, Len = 33
# Sphere Evals 84000: Best = 0.010946, Len = 33
# Sphere Evals 85000: Best = 0.003673, Len = 33
# Sphere Evals 86000: Best = 0.001442, Len = 33
# Sphere Evals 87000: Best = 0.000390, Len = 33
# Sphere Evals 88000: Best = 0.000136, Len = 33
# Sphere Evals 89000: Best = 0.000028, Len = 33
# Sphere Evals 90000: Best = 0.000008, Len = 33
# Sphere Evals 91000: Best = 0.000002, Len = 33
# Sphere Evals 92000: Best = 2.342235, Len = 34
# Sphere Evals 93000: Best = 0.664080, Len = 34
# Sphere Evals 94000: Best = 0.153670, Len = 34
# Sphere Evals 95000: Best = 0.043121, Len = 34
# Sphere Evals 96000: Best = 0.013321, Len = 34
# Sphere Evals 97000: Best = 0.005785, Len = 34
# Sphere Evals 98000: Best = 0.001444, Len = 33
# Sphere Evals 99000: Best = 0.000459, Len = 33
# Sphere Evals 100000: Best = 0.000122, Len = 33
# Sphere Evals 1000: Best = 36.953000, Len = 31
# Sphere Evals 2000: Best = 11.008219, Len = 31
# Sphere Evals 3000: Best = 1.508112, Len = 31
# Sphere Evals 4000: Best = 0.169432, Len = 31
# Sphere Evals 5000: Best = 0.036538, Len = 31
# Sphere Evals 6000: Best = 0.005682, Len = 31
# Sphere Evals 7000: Best = 0.001728, Len = 31
# Sphere Evals 8000: Best = 0.000522, Len = 31
# Sphere Evals 9000: Best = 0.000090, Len = 31
# Sphere Evals 10000: Best = 0.000022, Len = 31
# Sphere Evals 11000: Best = 0.000007, Len = 31
# Sphere Evals 12000: Best = 0.000001, Len = 31
# Sphere Evals 13000: Best = 0.000000, Len = 31
# Sphere Evals 14000: Best = 0.000000, Len = 31
# Sphere Evals 15000: Best = 0.000000, Len = 31
# Sphere Evals 16000: Best = 0.000000, Len = 31
# Sphere Evals 17000: Best = 0.483192, Len = 32
# Sphere Evals 18000: Best = 0.071573, Len = 33
# Sphere Evals 19000: Best = 0.056873, Len = 33
# Sphere Evals 20000: Best = 0.023316, Len = 33
# Sphere Evals 21000: Best = 0.007135, Len = 33
# Sphere Evals 22000: Best = 0.002818, Len = 33
# Sphere Evals 23000: Best = 0.001081, Len = 33
# Sphere Evals 24000: Best = 0.000223, Len = 33
# Sphere Evals 25000: Best = 0.000062, Len = 33
# Sphere Evals 26000: Best = 0.000023, Len = 33
# Sphere Evals 27000: Best = 0.000005, Len = 33
# Sphere Evals 28000: Best = 0.000001, Len = 33
# Sphere Evals 29000: Best = 0.000000, Len = 33
# Sphere Evals 30000: Best = 0.000000, Len = 33
# Sphere Evals 31000: Best = 0.000000, Len = 33
# Sphere Evals 32000: Best = 0.000000, Len = 33
# Sphere Evals 33000: Best = 0.000000, Len = 33
# Sphere Evals 34000: Best = 0.000000, Len = 33
# Sphere Evals 35000: Best = 0.000000, Len = 33
# Sphere Evals 36000: Best = 0.000000, Len = 33
# Sphere Evals 37000: Best = 0.000000, Len = 33
# Sphere Evals 38000: Best = 0.000000, Len = 33
# Sphere Evals 39000: Best = 0.000000, Len = 33
# Sphere Evals 40000: Best = 0.000000, Len = 33
# Sphere Evals 41000: Best = 0.000000, Len = 33
# Sphere Evals 42000: Best = 0.000000, Len = 33
# Sphere Evals 43000: Best = 0.000000, Len = 33
# Sphere Evals 44000: Best = 0.000000, Len = 33
# Sphere Evals 45000: Best = 0.000000, Len = 33
# Sphere Evals 46000: Best = 0.000000, Len = 33
# Sphere Evals 47000: Best = 0.000000, Len = 33
# Sphere Evals 48000: Best = 0.000000, Len = 33
# Sphere Evals 49000: Best = 0.000000, Len = 33
# Sphere Evals 50000: Best = 0.000000, Len = 32
# Sphere Evals 51000: Best = 0.000000, Len = 32
# Sphere Evals 52000: Best = 0.000000, Len = 31
# Sphere Evals 53000: Best = 0.000000, Len = 31
# Sphere Evals 54000: Best = 0.000000, Len = 31
# Sphere Evals 55000: Best = 0.000000, Len = 31
# Sphere Evals 56000: Best = 0.000000, Len = 31
# Sphere Evals 57000: Best = 0.000000, Len = 31
# Sphere Evals 58000: Best = 0.000000, Len = 31
# Sphere Evals 59000: Best = 0.000000, Len = 31
# Sphere Evals 60000: Best = 0.000000, Len = 31
# Sphere Evals 61000: Best = 0.000000, Len = 31
# Sphere Evals 62000: Best = 0.000000, Len = 31
# Sphere Evals 63000: Best = 0.000000, Len = 31
# Sphere Evals 64000: Best = 0.000000, Len = 31
# Sphere Evals 65000: Best = 0.000000, Len = 31
# Sphere Evals 66000: Best = 0.000000, Len = 31
# Sphere Evals 67000: Best = 0.000000, Len = 31
# Sphere Evals 68000: Best = 0.000000, Len = 31
# Sphere Evals 69000: Best = 0.000000, Len = 31
# Sphere Evals 70000: Best = 0.000000, Len = 31
# Sphere Evals 71000: Best = 0.000000, Len = 31
# Sphere Evals 72000: Best = 0.000000, Len = 31
# Sphere Evals 73000: Best = 0.000000, Len = 31
# Sphere Evals 74000: Best = 0.000000, Len = 31
# Sphere Evals 75000: Best = 0.000000, Len = 31
# Sphere Evals 76000: Best = 0.000000, Len = 31
# Sphere Evals 77000: Best = 0.000000, Len = 31
# Sphere Evals 78000: Best = 0.000000, Len = 31
# Sphere Evals 79000: Best = 0.000000, Len = 31
# Sphere Evals 80000: Best = 0.000000, Len = 31
# Sphere Evals 81000: Best = 0.000000, Len = 31
# Sphere Evals 82000: Best = 3.020199, Len = 32
# Sphere Evals 83000: Best = 3.019860, Len = 32
# Sphere Evals 84000: Best = 2.992834, Len = 32
# Sphere Evals 85000: Best = 1.046079, Len = 32
# Sphere Evals 86000: Best = 0.478177, Len = 32
# Sphere Evals 87000: Best = 0.095048, Len = 32
# Sphere Evals 88000: Best = 0.026786, Len = 32
# Sphere Evals 89000: Best = 0.008054, Len = 32
# Sphere Evals 90000: Best = 0.002832, Len = 32
# Sphere Evals 91000: Best = 0.000637, Len = 32
# Sphere Evals 92000: Best = 0.000155, Len = 32
# Sphere Evals 93000: Best = 0.000051, Len = 32
# Sphere Evals 94000: Best = 0.000017, Len = 32
# Sphere Evals 95000: Best = 0.000004, Len = 32
# Sphere Evals 96000: Best = 0.000001, Len = 32
# Sphere Evals 97000: Best = 0.000000, Len = 32
# Sphere Evals 98000: Best = 0.000000, Len = 32
# Sphere Evals 99000: Best = 0.000000, Len = 32
# Sphere Evals 100000: Best = 0.000000, Len = 32
# Sphere Evals 1000: Best = 46.271631, Len = 30
# Sphere Evals 2000: Best = 7.237311, Len = 30
# Sphere Evals 3000: Best = 1.286822, Len = 30
# Sphere Evals 4000: Best = 0.213643, Len = 30
# Sphere Evals 5000: Best = 0.270058, Len = 31
# Sphere Evals 6000: Best = 0.048943, Len = 31
# Sphere Evals 7000: Best = 0.015047, Len = 31
# Sphere Evals 8000: Best = 0.004442, Len = 31
# Sphere Evals 9000: Best = 0.000668, Len = 31
# Sphere Evals 10000: Best = 1.346832, Len = 32
# Sphere Evals 11000: Best = 0.197953, Len = 32
# Sphere Evals 12000: Best = 0.052543, Len = 32
# Sphere Evals 13000: Best = 0.015017, Len = 32
# Sphere Evals 14000: Best = 0.004549, Len = 31
# Sphere Evals 15000: Best = 0.001214, Len = 31
# Sphere Evals 16000: Best = 0.000343, Len = 31
# Sphere Evals 17000: Best = 0.105069, Len = 32
# Sphere Evals 18000: Best = 0.030592, Len = 32
# Sphere Evals 19000: Best = 0.007317, Len = 32
# Sphere Evals 20000: Best = 0.002802, Len = 32
# Sphere Evals 21000: Best = 0.001133, Len = 32
# Sphere Evals 22000: Best = 0.000397, Len = 32
# Sphere Evals 23000: Best = 0.000105, Len = 32
# Sphere Evals 24000: Best = 0.000018, Len = 32
# Sphere Evals 25000: Best = 0.000005, Len = 32
# Sphere Evals 26000: Best = 0.000002, Len = 32
# Sphere Evals 27000: Best = 0.000000, Len = 32
# Sphere Evals 28000: Best = 0.000000, Len = 32
# Sphere Evals 29000: Best = 0.000000, Len = 32
# Sphere Evals 30000: Best = 2.071338, Len = 33
# Sphere Evals 31000: Best = 0.154831, Len = 33
# Sphere Evals 32000: Best = 0.142389, Len = 33
# Sphere Evals 33000: Best = 0.047548, Len = 33
# Sphere Evals 34000: Best = 0.014845, Len = 32
# Sphere Evals 35000: Best = 0.003454, Len = 32
# Sphere Evals 36000: Best = 0.001064, Len = 32
# Sphere Evals 37000: Best = 0.000323, Len = 32
# Sphere Evals 38000: Best = 0.000049, Len = 32
# Sphere Evals 39000: Best = 0.052217, Len = 33
# Sphere Evals 40000: Best = 0.095511, Len = 33
# Sphere Evals 41000: Best = 0.027912, Len = 33
# Sphere Evals 42000: Best = 0.010225, Len = 33
# Sphere Evals 43000: Best = 0.004806, Len = 33
# Sphere Evals 44000: Best = 0.001029, Len = 33
# Sphere Evals 45000: Best = 0.000356, Len = 33
# Sphere Evals 46000: Best = 0.000080, Len = 33
# Sphere Evals 47000: Best = 0.000020, Len = 33
# Sphere Evals 48000: Best = 0.000005, Len = 33
# Sphere Evals 49000: Best = 0.000002, Len = 33
# Sphere Evals 50000: Best = 0.000000, Len = 33
# Sphere Evals 51000: Best = 0.000000, Len = 33
# Sphere Evals 52000: Best = 0.000000, Len = 33
# Sphere Evals 53000: Best = 0.000000, Len = 33
# Sphere Evals 54000: Best = 0.000000, Len = 33
# Sphere Evals 55000: Best = 0.000000, Len = 33
# Sphere Evals 56000: Best = 0.000000, Len = 33
# Sphere Evals 57000: Best = 0.000000, Len = 33
# Sphere Evals 58000: Best = 0.000000, Len = 33
# Sphere Evals 59000: Best = 0.000000, Len = 33
# Sphere Evals 60000: Best = 0.000000, Len = 33
# Sphere Evals 61000: Best = 0.327400, Len = 34
# Sphere Evals 62000: Best = 0.318915, Len = 34
# Sphere Evals 63000: Best = 0.028135, Len = 34
# Sphere Evals 64000: Best = 0.043006, Len = 34
# Sphere Evals 65000: Best = 0.015366, Len = 34
# Sphere Evals 66000: Best = 0.006443, Len = 34
# Sphere Evals 67000: Best = 0.002857, Len = 34
# Sphere Evals 68000: Best = 0.000741, Len = 34
# Sphere Evals 69000: Best = 0.000309, Len = 34
# Sphere Evals 70000: Best = 0.000116, Len = 34
# Sphere Evals 71000: Best = 0.000030, Len = 34
# Sphere Evals 72000: Best = 0.000005, Len = 34
# Sphere Evals 73000: Best = 0.000002, Len = 34
# Sphere Evals 74000: Best = 0.000001, Len = 33
# Sphere Evals 75000: Best = 0.000000, Len = 33
# Sphere Evals 76000: Best = 0.000000, Len = 32
# Sphere Evals 77000: Best = 0.000000, Len = 32
# Sphere Evals 78000: Best = 0.000000, Len = 32
# Sphere Evals 79000: Best = 0.000000, Len = 32
# Sphere Evals 80000: Best = 0.000000, Len = 32
# Sphere Evals 81000: Best = 0.000000, Len = 32
# Sphere Evals 82000: Best = 0.000000, Len = 32
# Sphere Evals 83000: Best = 0.000000, Len = 32
# Sphere Evals 84000: Best = 0.000000, Len = 32
# Sphere Evals 85000: Best = 2.191893, Len = 33
# Sphere Evals 86000: Best = 2.183020, Len = 33
# Sphere Evals 87000: Best = 1.594466, Len = 33
# Sphere Evals 88000: Best = 0.670761, Len = 33
# Sphere Evals 89000: Best = 0.155482, Len = 33
# Sphere Evals 90000: Best = 0.042134, Len = 33
# Sphere Evals 91000: Best = 0.013404, Len = 33
# Sphere Evals 92000: Best = 0.003665, Len = 33
# Sphere Evals 93000: Best = 0.001918, Len = 34
# Sphere Evals 94000: Best = 0.000542, Len = 33
# Sphere Evals 95000: Best = 0.000193, Len = 33
# Sphere Evals 96000: Best = 0.000059, Len = 32
# Sphere Evals 97000: Best = 0.000017, Len = 32
# Sphere Evals 98000: Best = 0.000004, Len = 32
# Sphere Evals 99000: Best = 0.000001, Len = 32
# Sphere Evals 100000: Best = 0.000000, Len = 32
# Sphere Evals 1000: Best = 29.320167, Len = 30
# Sphere Evals 2000: Best = 7.197268, Len = 29
# Sphere Evals 3000: Best = 1.204288, Len = 29
# Sphere Evals 4000: Best = 0.189677, Len = 28
# Sphere Evals 5000: Best = 0.038015, Len = 28
# Sphere Evals 6000: Best = 0.003933, Len = 28
# Sphere Evals 7000: Best = 0.000694, Len = 28
# Sphere Evals 8000: Best = 0.000192, Len = 28
# Sphere Evals 9000: Best = 0.000040, Len = 28
# Sphere Evals 10000: Best = 0.000009, Len = 28
# Sphere Evals 11000: Best = 0.000125, Len = 28
# Sphere Evals 12000: Best = 0.000026, Len = 28
# Sphere Evals 13000: Best = 0.000006, Len = 28
# Sphere Evals 14000: Best = 0.000001, Len = 28
# Sphere Evals 15000: Best = 0.000000, Len = 28
# Sphere Evals 16000: Best = 0.000000, Len = 28
# Sphere Evals 17000: Best = 0.000000, Len = 28
# Sphere Evals 18000: Best = 0.000000, Len = 27
# Sphere Evals 19000: Best = 0.000000, Len = 27
# Sphere Evals 20000: Best = 0.000000, Len = 27
# Sphere Evals 21000: Best = 0.000000, Len = 27
# Sphere Evals 22000: Best = 0.000000, Len = 27
# Sphere Evals 23000: Best = 0.000000, Len = 27
# Sphere Evals 24000: Best = 3.071858, Len = 28
# Sphere Evals 25000: Best = 3.067229, Len = 28
# Sphere Evals 26000: Best = 2.476837, Len = 28
# Sphere Evals 27000: Best = 0.721830, Len = 28
# Sphere Evals 28000: Best = 0.152840, Len = 28
# Sphere Evals 29000: Best = 0.021235, Len = 28
# Sphere Evals 30000: Best = 0.007150, Len = 28
# Sphere Evals 31000: Best = 0.001580, Len = 28
# Sphere Evals 32000: Best = 0.000261, Len = 28
# Sphere Evals 33000: Best = 0.000074, Len = 28
# Sphere Evals 34000: Best = 0.000018, Len = 28
# Sphere Evals 35000: Best = 0.000006, Len = 28
# Sphere Evals 36000: Best = 0.000001, Len = 28
# Sphere Evals 37000: Best = 0.000000, Len = 28
# Sphere Evals 38000: Best = 0.000000, Len = 28
# Sphere Evals 39000: Best = 0.000000, Len = 28
# Sphere Evals 40000: Best = 0.000000, Len = 28
# Sphere Evals 41000: Best = 0.000000, Len = 28
# Sphere Evals 42000: Best = 0.000000, Len = 28
# Sphere Evals 43000: Best = 0.000000, Len = 28
# Sphere Evals 44000: Best = 0.000000, Len = 28
# Sphere Evals 45000: Best = 0.000000, Len = 28
# Sphere Evals 46000: Best = 0.000000, Len = 28
# Sphere Evals 47000: Best = 0.000000, Len = 28
# Sphere Evals 48000: Best = 0.000000, Len = 28
# Sphere Evals 49000: Best = 0.000000, Len = 28
# Sphere Evals 50000: Best = 0.000000, Len = 28
# Sphere Evals 51000: Best = 0.000000, Len = 28
# Sphere Evals 52000: Best = 0.000000, Len = 28
# Sphere Evals 53000: Best = 0.000000, Len = 28
# Sphere Evals 54000: Best = 0.000000, Len = 28
# Sphere Evals 55000: Best = 0.000000, Len = 28
# Sphere Evals 56000: Best = 0.000000, Len = 28
# Sphere Evals 57000: Best = 0.000000, Len = 28
# Sphere Evals 58000: Best = 0.000000, Len = 28
# Sphere Evals 59000: Best = 0.000000, Len = 28
# Sphere Evals 60000: Best = 0.000000, Len = 28
# Sphere Evals 61000: Best = 0.000000, Len = 28
# Sphere Evals 62000: Best = 1.958178, Len = 29
# Sphere Evals 63000: Best = 1.958136, Len = 29
# Sphere Evals 64000: Best = 1.954272, Len = 29
# Sphere Evals 65000: Best = 1.493676, Len = 29
# Sphere Evals 66000: Best = 0.998088, Len = 29
# Sphere Evals 67000: Best = 0.205573, Len = 29
# Sphere Evals 68000: Best = 0.082037, Len = 29
# Sphere Evals 69000: Best = 0.019390, Len = 29
# Sphere Evals 70000: Best = 0.004792, Len = 29
# Sphere Evals 71000: Best = 0.000826, Len = 29
# Sphere Evals 72000: Best = 0.000341, Len = 29
# Sphere Evals 73000: Best = 0.000050, Len = 29
# Sphere Evals 74000: Best = 0.000014, Len = 29
# Sphere Evals 75000: Best = 0.000003, Len = 29
# Sphere Evals 76000: Best = 0.000001, Len = 29
# Sphere Evals 77000: Best = 0.000000, Len = 29
# Sphere Evals 78000: Best = 0.000000, Len = 29
# Sphere Evals 79000: Best = 0.000000, Len = 29
# Sphere Evals 80000: Best = 0.000000, Len = 29
# Sphere Evals 81000: Best = 0.000000, Len = 29
# Sphere Evals 82000: Best = 0.000000, Len = 29
# Sphere Evals 83000: Best = 0.000000, Len = 29
# Sphere Evals 84000: Best = 0.000000, Len = 29
# Sphere Evals 85000: Best = 0.000000, Len = 29
# Sphere Evals 86000: Best = 0.000000, Len = 29
# Sphere Evals 87000: Best = 0.000000, Len = 29
# Sphere Evals 88000: Best = 0.000000, Len = 29
# Sphere Evals 89000: Best = 0.000000, Len = 29
# Sphere Evals 90000: Best = 0.000000, Len = 29
# Sphere Evals 91000: Best = 0.000000, Len = 29
# Sphere Evals 92000: Best = 0.000000, Len = 29
# Sphere Evals 93000: Best = 0.000000, Len = 29
# Sphere Evals 94000: Best = 0.000000, Len = 29
# Sphere Evals 95000: Best = 0.000000, Len = 29
# Sphere Evals 96000: Best = 0.000000, Len = 28
# Sphere Evals 97000: Best = 0.000000, Len = 28
# Sphere Evals 98000: Best = 0.000000, Len = 28
# Sphere Evals 99000: Best = 0.000000, Len = 28
# Sphere Evals 100000: Best = 0.000000, Len = 28
# Sphere Evals 1000: Best = 26.335994, Len = 30
# Sphere Evals 2000: Best = 4.789529, Len = 30
# Sphere Evals 3000: Best = 0.593036, Len = 30
# Sphere Evals 4000: Best = 0.650440, Len = 31
# Sphere Evals 5000: Best = 0.143651, Len = 31
# Sphere Evals 6000: Best = 0.028143, Len = 30
# Sphere Evals 7000: Best = 0.006848, Len = 30
# Sphere Evals 8000: Best = 0.001700, Len = 30
# Sphere Evals 9000: Best = 0.000227, Len = 30
# Sphere Evals 10000: Best = 0.000087, Len = 30
# Sphere Evals 11000: Best = 0.000019, Len = 30
# Sphere Evals 12000: Best = 0.000004, Len = 30
# Sphere Evals 13000: Best = 0.000001, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 29
# Sphere Evals 19000: Best = 0.000000, Len = 28
# Sphere Evals 20000: Best = 0.000000, Len = 28
# Sphere Evals 21000: Best = 0.000000, Len = 28
# Sphere Evals 22000: Best = 0.000000, Len = 28
# Sphere Evals 23000: Best = 0.000000, Len = 28
# Sphere Evals 24000: Best = 0.000000, Len = 28
# Sphere Evals 25000: Best = 0.000000, Len = 28
# Sphere Evals 26000: Best = 0.000000, Len = 28
# Sphere Evals 27000: Best = 0.000000, Len = 28
# Sphere Evals 28000: Best = 0.000000, Len = 28
# Sphere Evals 29000: Best = 0.000000, Len = 28
# Sphere Evals 30000: Best = 0.000000, Len = 28
# Sphere Evals 31000: Best = 0.000000, Len = 27
# Sphere Evals 32000: Best = 0.000000, Len = 27
# Sphere Evals 33000: Best = 0.000000, Len = 27
# Sphere Evals 34000: Best = 0.000000, Len = 27
# Sphere Evals 35000: Best = 0.000000, Len = 27
# Sphere Evals 36000: Best = 0.000000, Len = 27
# Sphere Evals 37000: Best = 0.362202, Len = 28
# Sphere Evals 38000: Best = 0.362155, Len = 28
# Sphere Evals 39000: Best = 0.358464, Len = 28
# Sphere Evals 40000: Best = 0.105102, Len = 28
# Sphere Evals 41000: Best = 0.316745, Len = 28
# Sphere Evals 42000: Best = 0.262784, Len = 28
# Sphere Evals 43000: Best = 0.160772, Len = 29
# Sphere Evals 44000: Best = 0.044096, Len = 29
# Sphere Evals 45000: Best = 0.014669, Len = 28
# Sphere Evals 46000: Best = 0.002579, Len = 28
# Sphere Evals 47000: Best = 0.437862, Len = 29
# Sphere Evals 48000: Best = 0.073784, Len = 29
# Sphere Evals 49000: Best = 0.018683, Len = 29
# Sphere Evals 50000: Best = 0.009252, Len = 29
# Sphere Evals 51000: Best = 0.002311, Len = 29
# Sphere Evals 52000: Best = 0.000701, Len = 29
# Sphere Evals 53000: Best = 0.000152, Len = 29
# Sphere Evals 54000: Best = 0.000056, Len = 29
# Sphere Evals 55000: Best = 0.000013, Len = 29
# Sphere Evals 56000: Best = 0.000004, Len = 29
# Sphere Evals 57000: Best = 0.000001, Len = 29
# Sphere Evals 58000: Best = 0.000000, Len = 29
# Sphere Evals 59000: Best = 0.000000, Len = 29
# Sphere Evals 60000: Best = 3.216849, Len = 30
# Sphere Evals 61000: Best = 1.521612, Len = 30
# Sphere Evals 62000: Best = 0.517529, Len = 30
# Sphere Evals 63000: Best = 0.132323, Len = 30
# Sphere Evals 64000: Best = 0.034371, Len = 29
# Sphere Evals 65000: Best = 0.006196, Len = 29
# Sphere Evals 66000: Best = 0.002341, Len = 29
# Sphere Evals 67000: Best = 0.000738, Len = 29
# Sphere Evals 68000: Best = 0.000230, Len = 29
# Sphere Evals 69000: Best = 0.000040, Len = 29
# Sphere Evals 70000: Best = 0.000011, Len = 29
# Sphere Evals 71000: Best = 0.000003, Len = 29
# Sphere Evals 72000: Best = 0.000001, Len = 29
# Sphere Evals 73000: Best = 0.000000, Len = 29
# Sphere Evals 74000: Best = 0.000000, Len = 29
# Sphere Evals 75000: Best = 0.000000, Len = 29
# Sphere Evals 76000: Best = 0.000000, Len = 29
# Sphere Evals 77000: Best = 0.000000, Len = 29
# Sphere Evals 78000: Best = 1.544224, Len = 30
# Sphere Evals 79000: Best = 1.530451, Len = 30
# Sphere Evals 80000: Best = 0.342350, Len = 30
# Sphere Evals 81000: Best = 0.202273, Len = 30
# Sphere Evals 82000: Best = 0.066515, Len = 30
# Sphere Evals 83000: Best = 0.012397, Len = 30
# Sphere Evals 84000: Best = 0.003865, Len = 30
# Sphere Evals 85000: Best = 0.001148, Len = 30
# Sphere Evals 86000: Best = 0.000213, Len = 30
# Sphere Evals 87000: Best = 0.000053, Len = 30
# Sphere Evals 88000: Best = 0.000016, Len = 30
# Sphere Evals 89000: Best = 0.000003, Len = 30
# Sphere Evals 90000: Best = 0.000001, Len = 30
# Sphere Evals 91000: Best = 0.000000, Len = 30
# Sphere Evals 92000: Best = 0.410702, Len = 31
# Sphere Evals 93000: Best = 0.069199, Len = 31
# Sphere Evals 94000: Best = 0.017058, Len = 31
# Sphere Evals 95000: Best = 0.004429, Len = 31
# Sphere Evals 96000: Best = 0.001268, Len = 31
# Sphere Evals 97000: Best = 0.000626, Len = 31
# Sphere Evals 98000: Best = 0.000116, Len = 31
# Sphere Evals 99000: Best = 0.000028, Len = 31
# Sphere Evals 100000: Best = 0.000006, Len = 31
# Sphere Evals 1000: Best = 17.679509, Len = 30
# Sphere Evals 2000: Best = 2.099429, Len = 30
# Sphere Evals 3000: Best = 0.345699, Len = 30
# Sphere Evals 4000: Best = 0.040541, Len = 30
# Sphere Evals 5000: Best = 0.009510, Len = 30
# Sphere Evals 6000: Best = 0.001960, Len = 30
# Sphere Evals 7000: Best = 0.000289, Len = 30
# Sphere Evals 8000: Best = 0.000097, Len = 30
# Sphere Evals 9000: Best = 0.000015, Len = 30
# Sphere Evals 10000: Best = 0.000004, Len = 30
# Sphere Evals 11000: Best = 0.000001, Len = 30
# Sphere Evals 12000: Best = 0.000000, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 30
# Sphere Evals 20000: Best = 0.000000, Len = 30
# Sphere Evals 21000: Best = 0.000000, Len = 30
# Sphere Evals 22000: Best = 0.000000, Len = 30
# Sphere Evals 23000: Best = 0.000000, Len = 30
# Sphere Evals 24000: Best = 0.000000, Len = 30
# Sphere Evals 25000: Best = 0.000000, Len = 30
# Sphere Evals 26000: Best = 0.000000, Len = 30
# Sphere Evals 27000: Best = 0.000000, Len = 30
# Sphere Evals 28000: Best = 0.000000, Len = 30
# Sphere Evals 29000: Best = 0.000000, Len = 30
# Sphere Evals 30000: Best = 0.000000, Len = 30
# Sphere Evals 31000: Best = 0.000000, Len = 30
# Sphere Evals 32000: Best = 0.000000, Len = 30
# Sphere Evals 33000: Best = 0.000000, Len = 30
# Sphere Evals 34000: Best = 0.000000, Len = 30
# Sphere Evals 35000: Best = 0.000000, Len = 30
# Sphere Evals 36000: Best = 0.000000, Len = 30
# Sphere Evals 37000: Best = 0.000000, Len = 30
# Sphere Evals 38000: Best = 0.000000, Len = 30
# Sphere Evals 39000: Best = 0.000000, Len = 30
# Sphere Evals 40000: Best = 0.000000, Len = 30
# Sphere Evals 41000: Best = 0.000000, Len = 30
# Sphere Evals 42000: Best = 0.000000, Len = 30
# Sphere Evals 43000: Best = 0.000000, Len = 30
# Sphere Evals 44000: Best = 0.000000, Len = 30
# Sphere Evals 45000: Best = 0.000000, Len = 30
# Sphere Evals 46000: Best = 0.000000, Len = 30
# Sphere Evals 47000: Best = 0.000000, Len = 30
# Sphere Evals 48000: Best = 0.000000, Len = 30
# Sphere Evals 49000: Best = 0.000000, Len = 30
# Sphere Evals 50000: Best = 0.000000, Len = 30
# Sphere Evals 51000: Best = 0.000000, Len = 30
# Sphere Evals 52000: Best = 0.000000, Len = 30
# Sphere Evals 53000: Best = 0.000000, Len = 30
# Sphere Evals 54000: Best = 0.000000, Len = 30
# Sphere Evals 55000: Best = 0.000000, Len = 30
# Sphere Evals 56000: Best = 0.000000, Len = 30
# Sphere Evals 57000: Best = 0.000000, Len = 30
# Sphere Evals 58000: Best = 0.000000, Len = 30
# Sphere Evals 59000: Best = 0.000000, Len = 30
# Sphere Evals 60000: Best = 0.000000, Len = 30
# Sphere Evals 61000: Best = 0.000000, Len = 30
# Sphere Evals 62000: Best = 0.000000, Len = 30
# Sphere Evals 63000: Best = 0.000000, Len = 30
# Sphere Evals 64000: Best = 0.000000, Len = 30
# Sphere Evals 65000: Best = 0.000000, Len = 30
# Sphere Evals 66000: Best = 0.000000, Len = 30
# Sphere Evals 67000: Best = 0.000000, Len = 30
# Sphere Evals 68000: Best = 0.000000, Len = 30
# Sphere Evals 69000: Best = 0.000000, Len = 30
# Sphere Evals 70000: Best = 0.000000, Len = 30
# Sphere Evals 71000: Best = 0.000000, Len = 30
# Sphere Evals 72000: Best = 0.000000, Len = 30
# Sphere Evals 73000: Best = 0.000000, Len = 30
# Sphere Evals 74000: Best = 0.000000, Len = 29
# Sphere Evals 75000: Best = 0.000000, Len = 29
# Sphere Evals 76000: Best = 0.000000, Len = 29
# Sphere Evals 77000: Best = 0.000000, Len = 29
# Sphere Evals 78000: Best = 0.000000, Len = 29
# Sphere Evals 79000: Best = 0.000000, Len = 29
# Sphere Evals 80000: Best = 0.000000, Len = 29
# Sphere Evals 81000: Best = 0.000000, Len = 29
# Sphere Evals 82000: Best = 2.584726, Len = 30
# Sphere Evals 83000: Best = 2.584717, Len = 30
# Sphere Evals 84000: Best = 2.583956, Len = 30
# Sphere Evals 85000: Best = 2.492282, Len = 30
# Sphere Evals 86000: Best = 0.773546, Len = 30
# Sphere Evals 87000: Best = 0.314173, Len = 30
# Sphere Evals 88000: Best = 0.082483, Len = 30
# Sphere Evals 89000: Best = 0.019680, Len = 30
# Sphere Evals 90000: Best = 0.003321, Len = 30
# Sphere Evals 91000: Best = 0.001149, Len = 30
# Sphere Evals 92000: Best = 0.000219, Len = 29
# Sphere Evals 93000: Best = 0.000078, Len = 29
# Sphere Evals 94000: Best = 0.000018, Len = 29
# Sphere Evals 95000: Best = 0.000004, Len = 29
# Sphere Evals 96000: Best = 0.000001, Len = 29
# Sphere Evals 97000: Best = 0.000000, Len = 29
# Sphere Evals 98000: Best = 0.000000, Len = 29
# Sphere Evals 99000: Best = 0.000000, Len = 29
# Sphere Evals 100000: Best = 0.000000, Len = 29
# Sphere Evals 1000: Best = 30.254426, Len = 30
# Sphere Evals 2000: Best = 4.015751, Len = 30
# Sphere Evals 3000: Best = 0.850817, Len = 30
# Sphere Evals 4000: Best = 0.129341, Len = 30
# Sphere Evals 5000: Best = 0.022975, Len = 30
# Sphere Evals 6000: Best = 0.006679, Len = 30
# Sphere Evals 7000: Best = 0.000858, Len = 30
# Sphere Evals 8000: Best = 0.000186, Len = 30
# Sphere Evals 9000: Best = 0.000057, Len = 30
# Sphere Evals 10000: Best = 0.000015, Len = 30
# Sphere Evals 11000: Best = 0.000004, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.891548, Len = 31
# Sphere Evals 14000: Best = 0.660427, Len = 31
# Sphere Evals 15000: Best = 0.151242, Len = 31
# Sphere Evals 16000: Best = 0.059259, Len = 31
# Sphere Evals 17000: Best = 0.014765, Len = 31
# Sphere Evals 18000: Best = 0.003542, Len = 30
# Sphere Evals 19000: Best = 0.000925, Len = 30
# Sphere Evals 20000: Best = 0.000286, Len = 30
# Sphere Evals 21000: Best = 0.000073, Len = 30
# Sphere Evals 22000: Best = 0.000027, Len = 30
# Sphere Evals 23000: Best = 0.000007, Len = 30
# Sphere Evals 24000: Best = 0.000002, Len = 30
# Sphere Evals 25000: Best = 0.000001, Len = 30
# Sphere Evals 26000: Best = 0.000000, Len = 30
# Sphere Evals 27000: Best = 0.000000, Len = 30
# Sphere Evals 28000: Best = 0.000000, Len = 30
# Sphere Evals 29000: Best = 0.000000, Len = 30
# Sphere Evals 30000: Best = 0.000000, Len = 29
# Sphere Evals 31000: Best = 0.000000, Len = 29
# Sphere Evals 32000: Best = 0.000000, Len = 29
# Sphere Evals 33000: Best = 0.000000, Len = 29
# Sphere Evals 34000: Best = 0.000000, Len = 29
# Sphere Evals 35000: Best = 0.000000, Len = 29
# Sphere Evals 36000: Best = 0.000000, Len = 29
# Sphere Evals 37000: Best = 0.000000, Len = 29
# Sphere Evals 38000: Best = 0.000000, Len = 29
# Sphere Evals 39000: Best = 0.000000, Len = 29
# Sphere Evals 40000: Best = 0.000000, Len = 29
# Sphere Evals 41000: Best = 0.000000, Len = 29
# Sphere Evals 42000: Best = 0.000000, Len = 29
# Sphere Evals 43000: Best = 0.000000, Len = 29
# Sphere Evals 44000: Best = 0.000000, Len = 29
# Sphere Evals 45000: Best = 0.000000, Len = 29
# Sphere Evals 46000: Best = 0.000000, Len = 29
# Sphere Evals 47000: Best = 0.000000, Len = 29
# Sphere Evals 48000: Best = 0.000000, Len = 29
# Sphere Evals 49000: Best = 0.000000, Len = 29
# Sphere Evals 50000: Best = 0.000000, Len = 29
# Sphere Evals 51000: Best = 0.000000, Len = 29
# Sphere Evals 52000: Best = 0.000000, Len = 29
# Sphere Evals 53000: Best = 0.000000, Len = 29
# Sphere Evals 54000: Best = 0.000000, Len = 29
# Sphere Evals 55000: Best = 0.000000, Len = 28
# Sphere Evals 56000: Best = 0.000000, Len = 28
# Sphere Evals 57000: Best = 0.000000, Len = 28
# Sphere Evals 58000: Best = 0.000000, Len = 28
# Sphere Evals 59000: Best = 0.000000, Len = 28
# Sphere Evals 60000: Best = 0.000000, Len = 28
# Sphere Evals 61000: Best = 0.000000, Len = 28
# Sphere Evals 62000: Best = 0.000000, Len = 28
# Sphere Evals 63000: Best = 0.000000, Len = 28
# Sphere Evals 64000: Best = 0.000000, Len = 28
# Sphere Evals 65000: Best = 0.000000, Len = 28
# Sphere Evals 66000: Best = 0.000000, Len = 28
# Sphere Evals 67000: Best = 0.000000, Len = 28
# Sphere Evals 68000: Best = 0.000000, Len = 28
# Sphere Evals 69000: Best = 0.000000, Len = 28
# Sphere Evals 70000: Best = 0.000000, Len = 28
# Sphere Evals 71000: Best = 0.000000, Len = 28
# Sphere Evals 72000: Best = 0.000000, Len = 28
# Sphere Evals 73000: Best = 0.000000, Len = 28
# Sphere Evals 74000: Best = 0.000000, Len = 28
# Sphere Evals 75000: Best = 0.000000, Len = 28
# Sphere Evals 76000: Best = 0.000000, Len = 28
# Sphere Evals 77000: Best = 0.000000, Len = 28
# Sphere Evals 78000: Best = 0.000000, Len = 28
# Sphere Evals 79000: Best = 0.000000, Len = 28
# Sphere Evals 80000: Best = 0.000000, Len = 27
# Sphere Evals 81000: Best = 0.000000, Len = 27
# Sphere Evals 82000: Best = 0.000000, Len = 27
# Sphere Evals 83000: Best = 0.000000, Len = 27
# Sphere Evals 84000: Best = 0.000000, Len = 26
# Sphere Evals 85000: Best = 0.000000, Len = 26
# Sphere Evals 86000: Best = 0.000000, Len = 26
# Sphere Evals 87000: Best = 0.000000, Len = 26
# Sphere Evals 88000: Best = 0.000000, Len = 25
# Sphere Evals 89000: Best = 0.000000, Len = 25
# Sphere Evals 90000: Best = 0.000000, Len = 25
# Sphere Evals 91000: Best = 0.000000, Len = 25
# Sphere Evals 92000: Best = 0.000000, Len = 25
# Sphere Evals 93000: Best = 0.000000, Len = 25
# Sphere Evals 94000: Best = 0.000000, Len = 25
# Sphere Evals 95000: Best = 0.000000, Len = 25
# Sphere Evals 96000: Best = 0.000000, Len = 25
# Sphere Evals 97000: Best = 0.000000, Len = 25
# Sphere Evals 98000: Best = 0.000000, Len = 25
# Sphere Evals 99000: Best = 0.000000, Len = 25
# Sphere Evals 100000: Best = 0.000000, Len = 25
# Sphere Evals 1000: Best = 43.875495, Len = 30
# Sphere Evals 2000: Best = 6.523545, Len = 30
# Sphere Evals 3000: Best = 0.908533, Len = 30
# Sphere Evals 4000: Best = 0.203070, Len = 30
# Sphere Evals 5000: Best = 0.035722, Len = 30
# Sphere Evals 6000: Best = 0.011319, Len = 30
# Sphere Evals 7000: Best = 0.001736, Len = 30
# Sphere Evals 8000: Best = 0.000310, Len = 30
# Sphere Evals 9000: Best = 0.000099, Len = 30
# Sphere Evals 10000: Best = 0.000027, Len = 30
# Sphere Evals 11000: Best = 0.000009, Len = 30
# Sphere Evals 12000: Best = 0.000002, Len = 30
# Sphere Evals 13000: Best = 0.000001, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.096459, Len = 31
# Sphere Evals 17000: Best = 0.039176, Len = 31
# Sphere Evals 18000: Best = 0.014244, Len = 31
# Sphere Evals 19000: Best = 0.002527, Len = 31
# Sphere Evals 20000: Best = 0.001032, Len = 31
# Sphere Evals 21000: Best = 0.000219, Len = 31
# Sphere Evals 22000: Best = 0.000068, Len = 31
# Sphere Evals 23000: Best = 0.000014, Len = 31
# Sphere Evals 24000: Best = 0.000003, Len = 31
# Sphere Evals 25000: Best = 0.000001, Len = 31
# Sphere Evals 26000: Best = 0.000000, Len = 31
# Sphere Evals 27000: Best = 0.000000, Len = 31
# Sphere Evals 28000: Best = 0.000000, Len = 31
# Sphere Evals 29000: Best = 0.000000, Len = 31
# Sphere Evals 30000: Best = 0.000000, Len = 31
# Sphere Evals 31000: Best = 0.000000, Len = 31
# Sphere Evals 32000: Best = 0.000000, Len = 31
# Sphere Evals 33000: Best = 0.000000, Len = 31
# Sphere Evals 34000: Best = 0.000000, Len = 31
# Sphere Evals 35000: Best = 0.000000, Len = 30
# Sphere Evals 36000: Best = 0.000000, Len = 30
# Sphere Evals 37000: Best = 0.000000, Len = 30
# Sphere Evals 38000: Best = 0.000000, Len = 30
# Sphere Evals 39000: Best = 0.000000, Len = 30
# Sphere Evals 40000: Best = 0.000000, Len = 30
# Sphere Evals 41000: Best = 0.000000, Len = 30
# Sphere Evals 42000: Best = 0.000000, Len = 30
# Sphere Evals 43000: Best = 0.000000, Len = 30
# Sphere Evals 44000: Best = 0.000000, Len = 30
# Sphere Evals 45000: Best = 0.000000, Len = 30
# Sphere Evals 46000: Best = 0.000000, Len = 30
# Sphere Evals 47000: Best = 0.000000, Len = 30
# Sphere Evals 48000: Best = 0.000000, Len = 30
# Sphere Evals 49000: Best = 0.000000, Len = 30
# Sphere Evals 50000: Best = 0.000000, Len = 30
# Sphere Evals 51000: Best = 0.000000, Len = 30
# Sphere Evals 52000: Best = 0.000000, Len = 30
# Sphere Evals 53000: Best = 0.094314, Len = 31
# Sphere Evals 54000: Best = 0.094270, Len = 31
# Sphere Evals 55000: Best = 0.090964, Len = 31
# Sphere Evals 56000: Best = 0.019242, Len = 31
# Sphere Evals 57000: Best = 0.015965, Len = 31
# Sphere Evals 58000: Best = 0.004302, Len = 31
# Sphere Evals 59000: Best = 0.000952, Len = 31
# Sphere Evals 60000: Best = 0.000357, Len = 31
# Sphere Evals 61000: Best = 0.000070, Len = 31
# Sphere Evals 62000: Best = 0.000014, Len = 31
# Sphere Evals 63000: Best = 0.000005, Len = 31
# Sphere Evals 64000: Best = 0.000002, Len = 31
# Sphere Evals 65000: Best = 0.000000, Len = 31
# Sphere Evals 66000: Best = 0.000000, Len = 31
# Sphere Evals 67000: Best = 0.000000, Len = 31
# Sphere Evals 68000: Best = 0.000000, Len = 31
# Sphere Evals 69000: Best = 0.000000, Len = 31
# Sphere Evals 70000: Best = 0.000000, Len = 30
# Sphere Evals 71000: Best = 0.000000, Len = 30
# Sphere Evals 72000: Best = 0.000000, Len = 30
# Sphere Evals 73000: Best = 0.000000, Len = 30
# Sphere Evals 74000: Best = 0.000000, Len = 30
# Sphere Evals 75000: Best = 0.000000, Len = 30
# Sphere Evals 76000: Best = 0.000000, Len = 30
# Sphere Evals 77000: Best = 0.000000, Len = 30
# Sphere Evals 78000: Best = 0.000000, Len = 30
# Sphere Evals 79000: Best = 0.000000, Len = 30
# Sphere Evals 80000: Best = 0.000000, Len = 30
# Sphere Evals 81000: Best = 0.000000, Len = 29
# Sphere Evals 82000: Best = 0.000000, Len = 29
# Sphere Evals 83000: Best = 0.000000, Len = 29
# Sphere Evals 84000: Best = 0.000000, Len = 29
# Sphere Evals 85000: Best = 0.000000, Len = 29
# Sphere Evals 86000: Best = 0.000000, Len = 29
# Sphere Evals 87000: Best = 0.000000, Len = 29
# Sphere Evals 88000: Best = 0.000000, Len = 29
# Sphere Evals 89000: Best = 0.000000, Len = 29
# Sphere Evals 90000: Best = 0.000000, Len = 29
# Sphere Evals 91000: Best = 0.000000, Len = 29
# Sphere Evals 92000: Best = 0.000000, Len = 29
# Sphere Evals 93000: Best = 0.000000, Len = 29
# Sphere Evals 94000: Best = 0.000000, Len = 29
# Sphere Evals 95000: Best = 0.000000, Len = 29
# Sphere Evals 96000: Best = 0.000000, Len = 29
# Sphere Evals 97000: Best = 0.000000, Len = 29
# Sphere Evals 98000: Best = 0.000000, Len = 29
# Sphere Evals 99000: Best = 0.000000, Len = 29
# Sphere Evals 100000: Best = 0.000000, Len = 29
# Sphere Evals 1000: Best = 27.187535, Len = 30
# Sphere Evals 2000: Best = 5.909498, Len = 30
# Sphere Evals 3000: Best = 1.023353, Len = 30
# Sphere Evals 4000: Best = 0.140981, Len = 30
# Sphere Evals 5000: Best = 0.025766, Len = 30
# Sphere Evals 6000: Best = 0.005021, Len = 30
# Sphere Evals 7000: Best = 0.001005, Len = 30
# Sphere Evals 8000: Best = 0.000224, Len = 30
# Sphere Evals 9000: Best = 0.000039, Len = 30
# Sphere Evals 10000: Best = 0.000011, Len = 30
# Sphere Evals 11000: Best = 0.000003, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.000000, Len = 30
# Sphere Evals 16000: Best = 0.000000, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 30
# Sphere Evals 20000: Best = 0.000000, Len = 30
# Sphere Evals 21000: Best = 0.000000, Len = 30
# Sphere Evals 22000: Best = 0.000000, Len = 30
# Sphere Evals 23000: Best = 0.000000, Len = 30
# Sphere Evals 24000: Best = 0.000000, Len = 30
# Sphere Evals 25000: Best = 0.000000, Len = 30
# Sphere Evals 26000: Best = 0.000000, Len = 30
# Sphere Evals 27000: Best = 0.000000, Len = 30
# Sphere Evals 28000: Best = 0.000000, Len = 30
# Sphere Evals 29000: Best = 0.000000, Len = 30
# Sphere Evals 30000: Best = 0.000000, Len = 30
# Sphere Evals 31000: Best = 0.000000, Len = 30
# Sphere Evals 32000: Best = 0.000000, Len = 30
# Sphere Evals 33000: Best = 0.000000, Len = 30
# Sphere Evals 34000: Best = 0.000000, Len = 30
# Sphere Evals 35000: Best = 0.000000, Len = 30
# Sphere Evals 36000: Best = 0.000000, Len = 30
# Sphere Evals 37000: Best = 0.000000, Len = 30
# Sphere Evals 38000: Best = 0.000000, Len = 30
# Sphere Evals 39000: Best = 0.000000, Len = 30
# Sphere Evals 40000: Best = 0.000000, Len = 30
# Sphere Evals 41000: Best = 0.000000, Len = 30
# Sphere Evals 42000: Best = 0.000000, Len = 30
# Sphere Evals 43000: Best = 0.000000, Len = 30
# Sphere Evals 44000: Best = 0.000000, Len = 30
# Sphere Evals 45000: Best = 0.000000, Len = 30
# Sphere Evals 46000: Best = 0.808740, Len = 31
# Sphere Evals 47000: Best = 0.808610, Len = 31
# Sphere Evals 48000: Best = 0.793296, Len = 31
# Sphere Evals 49000: Best = 0.087663, Len = 31
# Sphere Evals 50000: Best = 0.123087, Len = 31
# Sphere Evals 51000: Best = 0.259421, Len = 32
# Sphere Evals 52000: Best = 0.093210, Len = 32
# Sphere Evals 53000: Best = 0.027701, Len = 32
# Sphere Evals 54000: Best = 0.014262, Len = 32
# Sphere Evals 55000: Best = 0.005710, Len = 32
# Sphere Evals 56000: Best = 0.002044, Len = 31
# Sphere Evals 57000: Best = 0.000438, Len = 31
# Sphere Evals 58000: Best = 0.157504, Len = 32
# Sphere Evals 59000: Best = 0.086313, Len = 31
# Sphere Evals 60000: Best = 0.026120, Len = 31
# Sphere Evals 61000: Best = 0.006553, Len = 31
# Sphere Evals 62000: Best = 0.001587, Len = 31
# Sphere Evals 63000: Best = 0.000568, Len = 31
# Sphere Evals 64000: Best = 0.000084, Len = 31
# Sphere Evals 65000: Best = 0.000027, Len = 31
# Sphere Evals 66000: Best = 0.000004, Len = 31
# Sphere Evals 67000: Best = 0.000001, Len = 31
# Sphere Evals 68000: Best = 0.000000, Len = 31
# Sphere Evals 69000: Best = 0.000000, Len = 31
# Sphere Evals 70000: Best = 0.000000, Len = 30
# Sphere Evals 71000: Best = 0.935373, Len = 31
# Sphere Evals 72000: Best = 0.722247, Len = 31
# Sphere Evals 73000: Best = 0.176862, Len = 31
# Sphere Evals 74000: Best = 0.039515, Len = 31
# Sphere Evals 75000: Best = 0.010987, Len = 31
# Sphere Evals 76000: Best = 0.003302, Len = 31
# Sphere Evals 77000: Best = 0.001022, Len = 31
# Sphere Evals 78000: Best = 0.000156, Len = 31
# Sphere Evals 79000: Best = 0.000062, Len = 31
# Sphere Evals 80000: Best = 0.000016, Len = 31
# Sphere Evals 81000: Best = 0.000004, Len = 31
# Sphere Evals 82000: Best = 2.702445, Len = 32
# Sphere Evals 83000: Best = 0.256284, Len = 32
# Sphere Evals 84000: Best = 0.314352, Len = 32
# Sphere Evals 85000: Best = 0.064146, Len = 32
# Sphere Evals 86000: Best = 0.024320, Len = 32
# Sphere Evals 87000: Best = 0.004181, Len = 32
# Sphere Evals 88000: Best = 0.000804, Len = 32
# Sphere Evals 89000: Best = 0.000368, Len = 32
# Sphere Evals 90000: Best = 0.000120, Len = 32
# Sphere Evals 91000: Best = 0.000027, Len = 32
# Sphere Evals 92000: Best = 0.000005, Len = 32
# Sphere Evals 93000: Best = 0.000001, Len = 32
# Sphere Evals 94000: Best = 0.000000, Len = 32
# Sphere Evals 95000: Best = 0.000000, Len = 32
# Sphere Evals 96000: Best = 0.000000, Len = 32
# Sphere Evals 97000: Best = 0.000000, Len = 32
# Sphere Evals 98000: Best = 0.000000, Len = 32
# Sphere Evals 99000: Best = 0.000000, Len = 32
# Sphere Evals 100000: Best = 0.000000, Len = 32
# Sphere Evals 1000: Best = 46.361336, Len = 30
# Sphere Evals 2000: Best = 7.820438, Len = 30
# Sphere Evals 3000: Best = 1.166550, Len = 30
# Sphere Evals 4000: Best = 0.254813, Len = 30
# Sphere Evals 5000: Best = 0.033474, Len = 30
# Sphere Evals 6000: Best = 0.146517, Len = 31
# Sphere Evals 7000: Best = 0.398822, Len = 31
# Sphere Evals 8000: Best = 0.095930, Len = 31
# Sphere Evals 9000: Best = 0.015700, Len = 30
# Sphere Evals 10000: Best = 0.003683, Len = 30
# Sphere Evals 11000: Best = 0.001492, Len = 30
# Sphere Evals 12000: Best = 0.000300, Len = 30
# Sphere Evals 13000: Best = 0.000089, Len = 30
# Sphere Evals 14000: Best = 0.000018, Len = 30
# Sphere Evals 15000: Best = 0.000006, Len = 30
# Sphere Evals 16000: Best = 0.000001, Len = 30
# Sphere Evals 17000: Best = 0.000000, Len = 30
# Sphere Evals 18000: Best = 0.000000, Len = 30
# Sphere Evals 19000: Best = 0.000000, Len = 29
# Sphere Evals 20000: Best = 0.000000, Len = 29
# Sphere Evals 21000: Best = 0.000000, Len = 29
# Sphere Evals 22000: Best = 0.000000, Len = 29
# Sphere Evals 23000: Best = 0.000000, Len = 28
# Sphere Evals 24000: Best = 0.000000, Len = 28
# Sphere Evals 25000: Best = 0.000000, Len = 28
# Sphere Evals 26000: Best = 0.000000, Len = 27
# Sphere Evals 27000: Best = 0.000000, Len = 26
# Sphere Evals 28000: Best = 0.000000, Len = 26
# Sphere Evals 29000: Best = 0.000000, Len = 26
# Sphere Evals 30000: Best = 0.000000, Len = 26
# Sphere Evals 31000: Best = 0.000000, Len = 26
# Sphere Evals 32000: Best = 0.000000, Len = 26
# Sphere Evals 33000: Best = 0.000000, Len = 26
# Sphere Evals 34000: Best = 0.000000, Len = 26
# Sphere Evals 35000: Best = 0.000000, Len = 26
# Sphere Evals 36000: Best = 0.000000, Len = 26
# Sphere Evals 37000: Best = 0.077285, Len = 27
# Sphere Evals 38000: Best = 0.077282, Len = 27
# Sphere Evals 39000: Best = 0.076686, Len = 27
# Sphere Evals 40000: Best = 0.014402, Len = 27
# Sphere Evals 41000: Best = 0.015312, Len = 27
# Sphere Evals 42000: Best = 0.003093, Len = 27
# Sphere Evals 43000: Best = 0.000559, Len = 27
# Sphere Evals 44000: Best = 0.000133, Len = 27
# Sphere Evals 45000: Best = 0.000041, Len = 27
# Sphere Evals 46000: Best = 0.000014, Len = 27
# Sphere Evals 47000: Best = 0.000003, Len = 27
# Sphere Evals 48000: Best = 0.000001, Len = 27
# Sphere Evals 49000: Best = 0.000000, Len = 27
# Sphere Evals 50000: Best = 0.000000, Len = 27
# Sphere Evals 51000: Best = 0.000000, Len = 26
# Sphere Evals 52000: Best = 0.000000, Len = 26
# Sphere Evals 53000: Best = 0.000000, Len = 26
# Sphere Evals 54000: Best = 0.000000, Len = 26
# Sphere Evals 55000: Best = 0.000000, Len = 26
# Sphere Evals 56000: Best = 0.000000, Len = 26
# Sphere Evals 57000: Best = 0.000000, Len = 26
# Sphere Evals 58000: Best = 0.000000, Len = 25
# Sphere Evals 59000: Best = 0.000000, Len = 25
# Sphere Evals 60000: Best = 0.000000, Len = 25
# Sphere Evals 61000: Best = 0.000000, Len = 25
# Sphere Evals 62000: Best = 0.000000, Len = 25
# Sphere Evals 63000: Best = 0.000000, Len = 25
# Sphere Evals 64000: Best = 0.000000, Len = 25
# Sphere Evals 65000: Best = 0.000000, Len = 25
# Sphere Evals 66000: Best = 0.000000, Len = 25
# Sphere Evals 67000: Best = 0.662007, Len = 26
# Sphere Evals 68000: Best = 0.662000, Len = 26
# Sphere Evals 69000: Best = 0.661095, Len = 26
# Sphere Evals 70000: Best = 0.493195, Len = 26
# Sphere Evals 71000: Best = 0.203819, Len = 26
# Sphere Evals 72000: Best = 0.203353, Len = 27
# Sphere Evals 73000: Best = 0.056169, Len = 27
# Sphere Evals 74000: Best = 0.027504, Len = 27
# Sphere Evals 75000: Best = 0.010744, Len = 27
# Sphere Evals 76000: Best = 0.002010, Len = 27
# Sphere Evals 77000: Best = 0.000399, Len = 27
# Sphere Evals 78000: Best = 0.000143, Len = 27
# Sphere Evals 79000: Best = 0.000028, Len = 27
# Sphere Evals 80000: Best = 0.000009, Len = 27
# Sphere Evals 81000: Best = 0.000001, Len = 27
# Sphere Evals 82000: Best = 0.000000, Len = 27
# Sphere Evals 83000: Best = 0.000000, Len = 27
# Sphere Evals 84000: Best = 0.000000, Len = 27
# Sphere Evals 85000: Best = 0.000000, Len = 27
# Sphere Evals 86000: Best = 0.000000, Len = 27
# Sphere Evals 87000: Best = 0.000000, Len = 27
# Sphere Evals 88000: Best = 0.000000, Len = 27
# Sphere Evals 89000: Best = 0.000000, Len = 27
# Sphere Evals 90000: Best = 0.000000, Len = 27
# Sphere Evals 91000: Best = 0.000000, Len = 26
# Sphere Evals 92000: Best = 0.000000, Len = 25
# Sphere Evals 93000: Best = 0.000000, Len = 25
# Sphere Evals 94000: Best = 0.000000, Len = 25
# Sphere Evals 95000: Best = 0.000000, Len = 25
# Sphere Evals 96000: Best = 0.000000, Len = 25
# Sphere Evals 97000: Best = 0.000000, Len = 25
# Sphere Evals 98000: Best = 0.000000, Len = 25
# Sphere Evals 99000: Best = 0.000000, Len = 25
# Sphere Evals 100000: Best = 0.000000, Len = 25
# Sphere Evals 1000: Best = 23.144553, Len = 30
# Sphere Evals 2000: Best = 5.120472, Len = 30
# Sphere Evals 3000: Best = 1.460953, Len = 30
# Sphere Evals 4000: Best = 0.155842, Len = 30
# Sphere Evals 5000: Best = 0.018597, Len = 30
# Sphere Evals 6000: Best = 0.004973, Len = 30
# Sphere Evals 7000: Best = 0.000860, Len = 30
# Sphere Evals 8000: Best = 0.000265, Len = 30
# Sphere Evals 9000: Best = 0.000072, Len = 30
# Sphere Evals 10000: Best = 0.000013, Len = 30
# Sphere Evals 11000: Best = 0.000003, Len = 30
# Sphere Evals 12000: Best = 0.000001, Len = 30
# Sphere Evals 13000: Best = 0.000000, Len = 30
# Sphere Evals 14000: Best = 0.000000, Len = 30
# Sphere Evals 15000: Best = 0.876057, Len = 31
# Sphere Evals 16000: Best = 0.199853, Len = 31
# Sphere Evals 17000: Best = 0.177029, Len = 31
# Sphere Evals 18000: Best = 0.030337, Len = 31
# Sphere Evals 19000: Best = 0.011966, Len = 31
# Sphere Evals 20000: Best = 0.003238, Len = 31
# Sphere Evals 21000: Best = 0.000677, Len = 31
# Sphere Evals 22000: Best = 0.000232, Len = 30
# Sphere Evals 23000: Best = 0.000129, Len = 30
# Sphere Evals 24000: Best = 0.000041, Len = 30
# Sphere Evals 25000: Best = 0.000011, Len = 30
# Sphere Evals 26000: Best = 0.000001, Len = 29
# Sphere Evals 27000: Best = 0.000001, Len = 29
# Sphere Evals 28000: Best = 0.000000, Len = 29
# Sphere Evals 29000: Best = 0.000000, Len = 29
# Sphere Evals 30000: Best = 0.000000, Len = 29
# Sphere Evals 31000: Best = 2.312417, Len = 30
# Sphere Evals 32000: Best = 2.262196, Len = 30
# Sphere Evals 33000: Best = 0.172945, Len = 30
# Sphere Evals 34000: Best = 0.168140, Len = 30
# Sphere Evals 35000: Best = 0.048534, Len = 30
