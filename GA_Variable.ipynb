# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE = 100
N_EVALS = 100000
N_REPLICATES = 30
MIN_LEN = 3
MAX_LEN = 100
gene_low, gene_high = -2.0, 2.0

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir = f'GA_Variable_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_path = os.path.join(out_dir, 'GA_Variable_results.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=2):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

def loadSantaFeMap(path='santafe_trail.txt'):
    world_rows = []
    start_x = start_y = None
    with open(path) as f:
        for y, line in enumerate(f):
            row = []
            for x, c in enumerate(line.rstrip("\n")):
                if c == '#':
                    row.append(1)
                elif c in ('.','S'):
                    row.append(0)
                    if c == 'S':
                        start_x, start_y = x, y
                else:
                    continue
            if row:
                world_rows.append(row)
    if not world_rows:
        raise ValueError(f'No valid rows in Santa Fe map: {path}')
    H = len(world_rows)
    W = len(world_rows[0])
    for r in world_rows:
        if len(r) != W:
            raise ValueError('Inconsistent row lengths in Santa Fe map')
    world = [c for row in world_rows for c in row]
    if start_x is None or start_y is None:
        start_x = start_y = 0
    return world, W, H, start_x, start_y

world, W, H, START_X, START_Y = loadSantaFeMap()

# %%
def generateInd():
    length = random.randint(MIN_LEN, MAX_LEN)
    return [random.uniform(gene_low, gene_high) for _ in range(length)]

def initPop():
    return [generateInd() for _ in range(POP_SIZE)]

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x**2 for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x**2 - 10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sum_sq = sum(x**2 for x in ind)
        prod_cos = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + sum_sq/4000.0 - prod_cos + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        sum_sq = sum(x**2 for x in ind)
        sum_cos = sum(cos(2*pi*x) for x in ind)
        term1 = -20 * exp(-0.2 * sqrt(sum_sq/d))
        term2 = -exp(sum_cos/d)
        return term1 + term2 + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    x_vals = np.linspace(-1,1,20)
    def f(ind):
        err = 0.0
        for x in x_vals:
            y_t = x**4 + x**3 + x**2 + x
            y_p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (y_p - y_t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, capacity):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel = [int(round(x))%2 for x in ind[:len(items)]]
        w_sum = sum(w for (w,v),s in zip(items, sel) if s)
        v_sum = sum(v for (w,v),s in zip(items, sel) if s)
        over = max(0, w_sum - capacity)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target = 2**N
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        table = [int(round(x))%2 for x in ind[:d_target]]
        errs = 0
        for i in range(d_target):
            target = bin(i).count('1') % 2
            if i < len(table):
                if table[i] != target:
                    errs += 1
            else:
                errs += 1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        direction = 0
        x,y = START_X, START_Y
        food = 0
        visited = world.copy()
        idx = lambda xx,yy: (yy%H)*W + (xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)] == 1:
                food += 1
                visited[idx(x,y)] = 0
            action = int(abs(ind[i])) % 3
            if action == 0:
                dx,dy = [(0,1),(1,0),(0,-1),(-1,0)][direction]
                x += dx; y += dy
            elif action == 1:
                direction = (direction + 1) % 4
            else:
                direction = (direction - 1) % 4
        return -food + pen(ind)
    return f

# %%
def tournamentSelection(pop, fit, k=3):
    sel = random.sample(pop, k)
    return min(sel, key=fit)

def rankSelection(pop, fit):
    spop = sorted(pop, key=fit)
    probs = np.linspace(1,0.1,POP_SIZE)
    probs /= probs.sum()
    return spop[np.random.choice(POP_SIZE, p=probs)]

def crossover(p1, p2, p_cross):
    if random.random() > p_cross:
        return p1[:], p2[:]
    cut1 = random.randint(1, len(p1)-1)
    cut2 = random.randint(1, len(p2)-1)
    c1 = p1[:cut1] + p2[cut2:]
    c2 = p2[:cut2] + p1[cut1:]
    for c in (c1,c2):
        while len(c) < MIN_LEN:
            c.append(random.uniform(gene_low, gene_high))
    return c1[:MAX_LEN], c2[:MAX_LEN]

def mutate(ind, p_mut):
    ind = ind[:]
    if random.random() < 0.3:
        if random.random() < 0.5 and len(ind) < MAX_LEN:
            ind.append(random.uniform(gene_low, gene_high))
        elif len(ind) > MIN_LEN:
            del ind[random.randrange(len(ind))]
    for i in range(len(ind)):
        if random.random() < p_mut:
            ind[i] += random.gauss(0,0.5)
            ind[i] = max(min(ind[i], gene_high), gene_low)
    return ind

# %%
def runGA(fit_func, name, selection='tournament'):
    pop = initPop()
    evals = 0
    best_hist = []
    while evals < N_EVALS:
        new_pop = []
        gen_idx = len(best_hist)
        p_mut = 0.05 * (1 - gen_idx/(N_EVALS/POP_SIZE))
        p_cross = 0.8 * (1 - 0.5*gen_idx/(N_EVALS/POP_SIZE))
        elite = min(pop, key=fit_func)
        new_pop.append(elite)
        while len(new_pop) < POP_SIZE and evals < N_EVALS:
            if selection=='tournament':
                p1 = tournamentSelection(pop, fit_func)
                p2 = tournamentSelection(pop, fit_func)
            else:
                p1 = rankSelection(pop, fit_func)
                p2 = rankSelection(pop, fit_func)
            c1, c2 = crossover(p1,p2,p_cross)
            new_pop.append(mutate(c1,p_mut))
            if len(new_pop)<POP_SIZE:
                new_pop.append(mutate(c2,p_mut))
        pop = sorted(new_pop, key=fit_func)[:POP_SIZE]
        evals += POP_SIZE
        best = fit_func(elite)
        best_hist.append(best)
        if gen_idx % 10 == 0:
            print(f'{name} Evals {evals}: Best = {best:.6f}, Length = {len(elite)}')
    return elite, best_hist

# %%
with open(csv_path, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=[
        'run_id','benchmark','replicate','seed','best','len_final','cpu_s'
    ])
    writer.writeheader()

    tmp_items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        'Sphere': sphere(30,10),
        'Rastrigin': rastrigin(30,10),
        'Griewank': griewank(30,10),
        'Ackley': ackley(30,10),
        'Koza': koza(10,10),
        'Knapsack': knapsack(20,0,tmp_items,50),
        'Parity': parity(6,10),
        'SantaFe': santaFe(100,10),
    }

    for name, func in benchmarks.items():
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed); np.random.seed(seed)
            start = time.perf_counter()
            best_ind, hist = runGA(func, name, selection='rank')
            cpu = time.perf_counter() - start
            writer.writerow({
                'run_id': uuid.uuid4(),
                'benchmark': name,
                'replicate': rep,
                'seed': seed,
                'best': round(func(best_ind),6),
                'len_final': len(best_ind),
                'cpu_s': round(cpu,4)
            })
print(f'Results written to {csv_path}')
# Out:
# Ackley Evals 100: Best = 4.709969, Length = 30
# Ackley Evals 1100: Best = 4.708416, Length = 30
# Ackley Evals 2100: Best = 4.514495, Length = 31
# Ackley Evals 3100: Best = 4.027076, Length = 30
# Ackley Evals 4100: Best = 3.898208, Length = 30
# Ackley Evals 5100: Best = 3.784830, Length = 29
# Ackley Evals 6100: Best = 3.639314, Length = 31
# Ackley Evals 7100: Best = 3.639314, Length = 31
# Ackley Evals 8100: Best = 3.429185, Length = 29
# Ackley Evals 9100: Best = 3.417615, Length = 31
# Ackley Evals 10100: Best = 3.164505, Length = 30
# Ackley Evals 11100: Best = 3.164505, Length = 30
# Ackley Evals 12100: Best = 3.164505, Length = 30
# Ackley Evals 13100: Best = 3.076198, Length = 28
# Ackley Evals 14100: Best = 3.026995, Length = 28
# Ackley Evals 15100: Best = 2.924823, Length = 29
# Ackley Evals 16100: Best = 2.814995, Length = 29
# Ackley Evals 17100: Best = 2.709962, Length = 31
# Ackley Evals 18100: Best = 2.679658, Length = 29
# Ackley Evals 19100: Best = 2.237040, Length = 32
# Ackley Evals 20100: Best = 2.143465, Length = 32
# Ackley Evals 21100: Best = 2.024453, Length = 32
# Ackley Evals 22100: Best = 2.024453, Length = 32
# Ackley Evals 23100: Best = 2.024453, Length = 32
# Ackley Evals 24100: Best = 2.024453, Length = 32
# Ackley Evals 25100: Best = 2.024453, Length = 32
# Ackley Evals 26100: Best = 2.013770, Length = 32
# Ackley Evals 27100: Best = 2.013770, Length = 32
# Ackley Evals 28100: Best = 1.934795, Length = 32
# Ackley Evals 29100: Best = 1.934795, Length = 32
# Ackley Evals 30100: Best = 1.934795, Length = 32
# Ackley Evals 31100: Best = 1.934795, Length = 32
# Ackley Evals 32100: Best = 1.724348, Length = 32
# Ackley Evals 33100: Best = 1.724348, Length = 32
# Ackley Evals 34100: Best = 1.465831, Length = 31
# Ackley Evals 35100: Best = 1.464288, Length = 31
# Ackley Evals 36100: Best = 1.334161, Length = 32
# Ackley Evals 37100: Best = 1.334161, Length = 32
# Ackley Evals 38100: Best = 1.334161, Length = 32
# Ackley Evals 39100: Best = 1.290300, Length = 32
# Ackley Evals 40100: Best = 1.290300, Length = 32
# Ackley Evals 41100: Best = 1.290300, Length = 32
# Ackley Evals 42100: Best = 1.290300, Length = 32
# Ackley Evals 43100: Best = 1.248486, Length = 32
# Ackley Evals 44100: Best = 1.237711, Length = 32
# Ackley Evals 45100: Best = 1.232192, Length = 32
# Ackley Evals 46100: Best = 0.950287, Length = 30
# Ackley Evals 47100: Best = 0.950174, Length = 30
# Ackley Evals 48100: Best = 0.566770, Length = 29
# Ackley Evals 49100: Best = 0.503903, Length = 29
# Ackley Evals 50100: Best = 0.503903, Length = 29
# Ackley Evals 51100: Best = 0.327528, Length = 28
# Ackley Evals 52100: Best = 0.304373, Length = 32
# Ackley Evals 53100: Best = 0.304373, Length = 32
# Ackley Evals 54100: Best = 0.287103, Length = 32
# Ackley Evals 55100: Best = 0.287103, Length = 32
# Ackley Evals 56100: Best = 0.255388, Length = 31
# Ackley Evals 57100: Best = 0.255388, Length = 31
# Ackley Evals 58100: Best = 0.252914, Length = 30
# Ackley Evals 59100: Best = 0.252914, Length = 30
# Ackley Evals 60100: Best = 0.252914, Length = 30
# Ackley Evals 61100: Best = 0.252914, Length = 30
# Ackley Evals 62100: Best = 0.231794, Length = 30
# Ackley Evals 63100: Best = 0.231794, Length = 30
# Ackley Evals 64100: Best = 0.228386, Length = 30
# Ackley Evals 65100: Best = 0.227261, Length = 30
# Ackley Evals 66100: Best = 0.227261, Length = 30
# Ackley Evals 67100: Best = 0.212061, Length = 29
# Ackley Evals 68100: Best = 0.212061, Length = 29
# Ackley Evals 69100: Best = 0.212061, Length = 29
# Ackley Evals 70100: Best = 0.200332, Length = 28
# Ackley Evals 71100: Best = 0.200332, Length = 28
# Ackley Evals 72100: Best = 0.200332, Length = 28
# Ackley Evals 73100: Best = 0.171358, Length = 29
# Ackley Evals 74100: Best = 0.158879, Length = 29
# Ackley Evals 75100: Best = 0.132566, Length = 28
# Ackley Evals 76100: Best = 0.132566, Length = 28
# Ackley Evals 77100: Best = 0.132566, Length = 28
# Ackley Evals 78100: Best = 0.132566, Length = 28
# Ackley Evals 79100: Best = 0.132566, Length = 28
# Ackley Evals 80100: Best = 0.119746, Length = 30
# Ackley Evals 81100: Best = 0.110954, Length = 29
# Ackley Evals 82100: Best = 0.108746, Length = 28
# Ackley Evals 83100: Best = 0.108746, Length = 28
# Ackley Evals 84100: Best = 0.098126, Length = 31
# Ackley Evals 85100: Best = 0.094993, Length = 28
# Ackley Evals 86100: Best = 0.094993, Length = 28
# Ackley Evals 87100: Best = 0.094993, Length = 28
# Ackley Evals 88100: Best = 0.081254, Length = 28
# Ackley Evals 89100: Best = 0.080256, Length = 30
# Ackley Evals 90100: Best = 0.077728, Length = 29
# Ackley Evals 91100: Best = 0.077674, Length = 30
# Ackley Evals 92100: Best = 0.077674, Length = 30
# Ackley Evals 93100: Best = 0.076865, Length = 31
# Ackley Evals 94100: Best = 0.056672, Length = 30
# Ackley Evals 95100: Best = 0.054979, Length = 28
# Ackley Evals 96100: Best = 0.054979, Length = 28
# Ackley Evals 97100: Best = 0.050848, Length = 28
# Ackley Evals 98100: Best = 0.049890, Length = 28
# Ackley Evals 99100: Best = 0.049080, Length = 30
# Ackley Evals 100: Best = 5.538900, Length = 32
# Ackley Evals 1100: Best = 4.672879, Length = 28
# Ackley Evals 2100: Best = 4.614273, Length = 28
# Ackley Evals 3100: Best = 4.329286, Length = 28
# Ackley Evals 4100: Best = 4.249599, Length = 29
# Ackley Evals 5100: Best = 3.809305, Length = 28
# Ackley Evals 6100: Best = 3.809305, Length = 28
# Ackley Evals 7100: Best = 3.809305, Length = 28
# Ackley Evals 8100: Best = 3.774237, Length = 28
# Ackley Evals 9100: Best = 3.586497, Length = 28
# Ackley Evals 10100: Best = 3.529156, Length = 28
# Ackley Evals 11100: Best = 2.988656, Length = 28
# Ackley Evals 12100: Best = 2.983405, Length = 28
# Ackley Evals 13100: Best = 2.914774, Length = 28
# Ackley Evals 14100: Best = 2.914774, Length = 28
# Ackley Evals 15100: Best = 2.914774, Length = 28
# Ackley Evals 16100: Best = 2.673774, Length = 30
# Ackley Evals 17100: Best = 2.581164, Length = 29
# Ackley Evals 18100: Best = 2.576160, Length = 28
# Ackley Evals 19100: Best = 2.477793, Length = 29
# Ackley Evals 20100: Best = 2.323712, Length = 28
# Ackley Evals 21100: Best = 2.219190, Length = 31
# Ackley Evals 22100: Best = 2.219190, Length = 31
# Ackley Evals 23100: Best = 2.219190, Length = 31
# Ackley Evals 24100: Best = 2.202769, Length = 31
# Ackley Evals 25100: Best = 1.993520, Length = 28
# Ackley Evals 26100: Best = 1.991869, Length = 28
# Ackley Evals 27100: Best = 1.991869, Length = 28
# Ackley Evals 28100: Best = 1.839889, Length = 28
# Ackley Evals 29100: Best = 1.839889, Length = 28
# Ackley Evals 30100: Best = 1.628300, Length = 28
# Ackley Evals 31100: Best = 1.628300, Length = 28
# Ackley Evals 32100: Best = 1.628300, Length = 28
# Ackley Evals 33100: Best = 1.612088, Length = 29
# Ackley Evals 34100: Best = 1.612088, Length = 29
# Ackley Evals 35100: Best = 1.612088, Length = 29
# Ackley Evals 36100: Best = 1.587100, Length = 29
# Ackley Evals 37100: Best = 1.448813, Length = 28
# Ackley Evals 38100: Best = 1.448813, Length = 28
# Ackley Evals 39100: Best = 1.437141, Length = 28
# Ackley Evals 40100: Best = 1.437141, Length = 28
# Ackley Evals 41100: Best = 1.343571, Length = 28
# Ackley Evals 42100: Best = 1.343571, Length = 28
# Ackley Evals 43100: Best = 1.343571, Length = 28
# Ackley Evals 44100: Best = 1.343571, Length = 28
# Ackley Evals 45100: Best = 1.311892, Length = 28
# Ackley Evals 46100: Best = 1.307325, Length = 28
# Ackley Evals 47100: Best = 1.292193, Length = 28
# Ackley Evals 48100: Best = 1.265460, Length = 32
# Ackley Evals 49100: Best = 1.265277, Length = 31
# Ackley Evals 50100: Best = 1.265277, Length = 31
# Ackley Evals 51100: Best = 1.265231, Length = 31
# Ackley Evals 52100: Best = 1.252976, Length = 31
# Ackley Evals 53100: Best = 1.252976, Length = 31
# Ackley Evals 54100: Best = 1.250661, Length = 31
# Ackley Evals 55100: Best = 1.250661, Length = 31
# Ackley Evals 56100: Best = 1.250661, Length = 31
# Ackley Evals 57100: Best = 1.231105, Length = 32
# Ackley Evals 58100: Best = 1.077357, Length = 31
# Ackley Evals 59100: Best = 0.719109, Length = 32
# Ackley Evals 60100: Best = 0.719109, Length = 32
# Ackley Evals 61100: Best = 0.719109, Length = 32
# Ackley Evals 62100: Best = 0.664553, Length = 28
# Ackley Evals 63100: Best = 0.655747, Length = 29
# Ackley Evals 64100: Best = 0.631605, Length = 29
# Ackley Evals 65100: Best = 0.608579, Length = 28
# Ackley Evals 66100: Best = 0.608579, Length = 28
# Ackley Evals 67100: Best = 0.581120, Length = 28
# Ackley Evals 68100: Best = 0.579780, Length = 28
# Ackley Evals 69100: Best = 0.574772, Length = 29
# Ackley Evals 70100: Best = 0.574772, Length = 29
# Ackley Evals 71100: Best = 0.574628, Length = 29
# Ackley Evals 72100: Best = 0.386468, Length = 30
# Ackley Evals 73100: Best = 0.366123, Length = 28
# Ackley Evals 74100: Best = 0.328972, Length = 31
# Ackley Evals 75100: Best = 0.292825, Length = 29
# Ackley Evals 76100: Best = 0.292825, Length = 29
# Ackley Evals 77100: Best = 0.292825, Length = 29
# Ackley Evals 78100: Best = 0.274635, Length = 32
# Ackley Evals 79100: Best = 0.274635, Length = 32
# Ackley Evals 80100: Best = 0.274466, Length = 31
# Ackley Evals 81100: Best = 0.228571, Length = 28
# Ackley Evals 82100: Best = 0.228571, Length = 28
# Ackley Evals 83100: Best = 0.228571, Length = 28
# Ackley Evals 84100: Best = 0.224342, Length = 29
# Ackley Evals 85100: Best = 0.224342, Length = 29
# Ackley Evals 86100: Best = 0.224342, Length = 29
# Ackley Evals 87100: Best = 0.221805, Length = 28
# Ackley Evals 88100: Best = 0.212675, Length = 30
# Ackley Evals 89100: Best = 0.181055, Length = 29
# Ackley Evals 90100: Best = 0.179098, Length = 28
# Ackley Evals 91100: Best = 0.179098, Length = 28
# Ackley Evals 92100: Best = 0.175655, Length = 29
# Ackley Evals 93100: Best = 0.140536, Length = 28
# Ackley Evals 94100: Best = 0.136275, Length = 30
# Ackley Evals 95100: Best = 0.111208, Length = 28
# Ackley Evals 96100: Best = 0.111208, Length = 28
# Ackley Evals 97100: Best = 0.096452, Length = 28
# Ackley Evals 98100: Best = 0.086682, Length = 28
# Ackley Evals 99100: Best = 0.081521, Length = 31
# Ackley Evals 100: Best = 5.122403, Length = 28
# Ackley Evals 1100: Best = 5.061459, Length = 28
# Ackley Evals 2100: Best = 4.757996, Length = 31
# Ackley Evals 3100: Best = 4.313174, Length = 28
# Ackley Evals 4100: Best = 4.230073, Length = 30
# Ackley Evals 5100: Best = 4.069423, Length = 29
# Ackley Evals 6100: Best = 3.859361, Length = 29
# Ackley Evals 7100: Best = 3.787621, Length = 29
# Ackley Evals 8100: Best = 3.759771, Length = 29
# Ackley Evals 9100: Best = 3.754469, Length = 30
# Ackley Evals 10100: Best = 3.696441, Length = 28
# Ackley Evals 11100: Best = 3.669363, Length = 29
# Ackley Evals 12100: Best = 3.445229, Length = 30
# Ackley Evals 13100: Best = 3.290844, Length = 29
# Ackley Evals 14100: Best = 3.177198, Length = 29
# Ackley Evals 15100: Best = 3.062600, Length = 29
# Ackley Evals 16100: Best = 3.062600, Length = 29
# Ackley Evals 17100: Best = 3.055127, Length = 29
# Ackley Evals 18100: Best = 2.973398, Length = 29
# Ackley Evals 19100: Best = 2.973398, Length = 29
# Ackley Evals 20100: Best = 2.973398, Length = 29
# Ackley Evals 21100: Best = 2.953714, Length = 29
# Ackley Evals 22100: Best = 2.837493, Length = 30
# Ackley Evals 23100: Best = 2.738163, Length = 30
# Ackley Evals 24100: Best = 2.686651, Length = 29
# Ackley Evals 25100: Best = 2.686651, Length = 29
# Ackley Evals 26100: Best = 2.679496, Length = 28
# Ackley Evals 27100: Best = 2.679496, Length = 28
# Ackley Evals 28100: Best = 2.672921, Length = 28
# Ackley Evals 29100: Best = 2.672921, Length = 28
# Ackley Evals 30100: Best = 2.672921, Length = 28
# Ackley Evals 31100: Best = 2.606509, Length = 30
# Ackley Evals 32100: Best = 2.482556, Length = 30
# Ackley Evals 33100: Best = 2.373827, Length = 29
# Ackley Evals 34100: Best = 2.101777, Length = 28
# Ackley Evals 35100: Best = 2.081434, Length = 28
# Ackley Evals 36100: Best = 2.052753, Length = 28
# Ackley Evals 37100: Best = 2.052753, Length = 28
# Ackley Evals 38100: Best = 2.052753, Length = 28
# Ackley Evals 39100: Best = 2.028237, Length = 28
# Ackley Evals 40100: Best = 2.028237, Length = 28
# Ackley Evals 41100: Best = 1.922465, Length = 31
# Ackley Evals 42100: Best = 1.867151, Length = 30
# Ackley Evals 43100: Best = 1.867151, Length = 30
# Ackley Evals 44100: Best = 1.867151, Length = 30
# Ackley Evals 45100: Best = 1.744665, Length = 29
# Ackley Evals 46100: Best = 1.577589, Length = 28
# Ackley Evals 47100: Best = 1.577589, Length = 28
# Ackley Evals 48100: Best = 1.553552, Length = 28
# Ackley Evals 49100: Best = 1.553552, Length = 28
# Ackley Evals 50100: Best = 1.553552, Length = 28
# Ackley Evals 51100: Best = 1.460210, Length = 29
# Ackley Evals 52100: Best = 1.154982, Length = 28
# Ackley Evals 53100: Best = 1.153388, Length = 28
# Ackley Evals 54100: Best = 1.055892, Length = 29
# Ackley Evals 55100: Best = 0.848683, Length = 28
# Ackley Evals 56100: Best = 0.848683, Length = 28
# Ackley Evals 57100: Best = 0.763780, Length = 29
# Ackley Evals 58100: Best = 0.763780, Length = 29
# Ackley Evals 59100: Best = 0.763780, Length = 29
# Ackley Evals 60100: Best = 0.702651, Length = 30
# Ackley Evals 61100: Best = 0.677992, Length = 29
# Ackley Evals 62100: Best = 0.649701, Length = 28
# Ackley Evals 63100: Best = 0.600147, Length = 30
# Ackley Evals 64100: Best = 0.582071, Length = 29
# Ackley Evals 65100: Best = 0.582071, Length = 29
# Ackley Evals 66100: Best = 0.567615, Length = 28
# Ackley Evals 67100: Best = 0.567615, Length = 28
# Ackley Evals 68100: Best = 0.559034, Length = 28
# Ackley Evals 69100: Best = 0.559034, Length = 28
# Ackley Evals 70100: Best = 0.559034, Length = 28
# Ackley Evals 71100: Best = 0.538433, Length = 30
# Ackley Evals 72100: Best = 0.498759, Length = 30
# Ackley Evals 73100: Best = 0.437483, Length = 32
# Ackley Evals 74100: Best = 0.405553, Length = 32
# Ackley Evals 75100: Best = 0.394005, Length = 31
# Ackley Evals 76100: Best = 0.394005, Length = 31
# Ackley Evals 77100: Best = 0.393602, Length = 32
# Ackley Evals 78100: Best = 0.290286, Length = 30
# Ackley Evals 79100: Best = 0.282800, Length = 28
# Ackley Evals 80100: Best = 0.271265, Length = 31
# Ackley Evals 81100: Best = 0.238107, Length = 32
# Ackley Evals 82100: Best = 0.238107, Length = 32
# Ackley Evals 83100: Best = 0.238107, Length = 32
# Ackley Evals 84100: Best = 0.235685, Length = 31
# Ackley Evals 85100: Best = 0.225157, Length = 30
# Ackley Evals 86100: Best = 0.206849, Length = 31
# Ackley Evals 87100: Best = 0.206849, Length = 31
# Ackley Evals 88100: Best = 0.199631, Length = 31
# Ackley Evals 89100: Best = 0.196962, Length = 31
# Ackley Evals 90100: Best = 0.176368, Length = 29
# Ackley Evals 91100: Best = 0.166633, Length = 30
# Ackley Evals 92100: Best = 0.166633, Length = 30
# Ackley Evals 93100: Best = 0.166254, Length = 30
# Ackley Evals 94100: Best = 0.166254, Length = 30
# Ackley Evals 95100: Best = 0.163006, Length = 31
# Ackley Evals 96100: Best = 0.159465, Length = 28
# Ackley Evals 97100: Best = 0.153070, Length = 30
# Ackley Evals 98100: Best = 0.090115, Length = 31
# Ackley Evals 99100: Best = 0.087084, Length = 30
# Ackley Evals 100: Best = 5.392906, Length = 31
# Ackley Evals 1100: Best = 4.618106, Length = 28
# Ackley Evals 2100: Best = 4.324004, Length = 30
# Ackley Evals 3100: Best = 4.119577, Length = 30
# Ackley Evals 4100: Best = 3.839803, Length = 30
# Ackley Evals 5100: Best = 3.839803, Length = 30
# Ackley Evals 6100: Best = 3.062788, Length = 31
# Ackley Evals 7100: Best = 2.869296, Length = 29
# Ackley Evals 8100: Best = 2.869296, Length = 29
# Ackley Evals 9100: Best = 2.858300, Length = 29
# Ackley Evals 10100: Best = 2.858300, Length = 29
# Ackley Evals 11100: Best = 2.683786, Length = 28
# Ackley Evals 12100: Best = 2.616199, Length = 28
# Ackley Evals 13100: Best = 2.540118, Length = 28
# Ackley Evals 14100: Best = 2.540118, Length = 28
# Ackley Evals 15100: Best = 2.465109, Length = 28
# Ackley Evals 16100: Best = 2.377275, Length = 28
# Ackley Evals 17100: Best = 2.211029, Length = 29
# Ackley Evals 18100: Best = 2.211029, Length = 29
# Ackley Evals 19100: Best = 2.211029, Length = 29
# Ackley Evals 20100: Best = 2.127266, Length = 29
# Ackley Evals 21100: Best = 2.127266, Length = 29
# Ackley Evals 22100: Best = 2.127266, Length = 29
# Ackley Evals 23100: Best = 1.696173, Length = 28
# Ackley Evals 24100: Best = 1.657656, Length = 29
# Ackley Evals 25100: Best = 1.657656, Length = 29
# Ackley Evals 26100: Best = 1.492816, Length = 31
# Ackley Evals 27100: Best = 1.263783, Length = 28
# Ackley Evals 28100: Best = 1.263783, Length = 28
# Ackley Evals 29100: Best = 1.263783, Length = 28
# Ackley Evals 30100: Best = 1.263783, Length = 28
# Ackley Evals 31100: Best = 1.263783, Length = 28
# Ackley Evals 32100: Best = 1.263783, Length = 28
# Ackley Evals 33100: Best = 1.263783, Length = 28
# Ackley Evals 34100: Best = 1.263783, Length = 28
# Ackley Evals 35100: Best = 1.263783, Length = 28
# Ackley Evals 36100: Best = 1.252513, Length = 28
# Ackley Evals 37100: Best = 1.252513, Length = 28
# Ackley Evals 38100: Best = 1.227758, Length = 28
# Ackley Evals 39100: Best = 1.227758, Length = 28
# Ackley Evals 40100: Best = 1.227758, Length = 28
# Ackley Evals 41100: Best = 1.227758, Length = 28
# Ackley Evals 42100: Best = 1.227758, Length = 28
# Ackley Evals 43100: Best = 1.227758, Length = 28
# Ackley Evals 44100: Best = 1.227758, Length = 28
# Ackley Evals 45100: Best = 1.221192, Length = 28
# Ackley Evals 46100: Best = 1.194776, Length = 29
# Ackley Evals 47100: Best = 1.171101, Length = 29
# Ackley Evals 48100: Best = 1.144506, Length = 30
# Ackley Evals 49100: Best = 1.113982, Length = 30
# Ackley Evals 50100: Best = 1.113982, Length = 30
# Ackley Evals 51100: Best = 0.983083, Length = 29
# Ackley Evals 52100: Best = 0.983083, Length = 29
# Ackley Evals 53100: Best = 0.983083, Length = 29
# Ackley Evals 54100: Best = 0.956782, Length = 28
# Ackley Evals 55100: Best = 0.956782, Length = 28
# Ackley Evals 56100: Best = 0.896323, Length = 31
# Ackley Evals 57100: Best = 0.896323, Length = 31
# Ackley Evals 58100: Best = 0.872493, Length = 28
# Ackley Evals 59100: Best = 0.823048, Length = 28
# Ackley Evals 60100: Best = 0.765709, Length = 28
# Ackley Evals 61100: Best = 0.747122, Length = 29
# Ackley Evals 62100: Best = 0.655820, Length = 28
# Ackley Evals 63100: Best = 0.655820, Length = 28
# Ackley Evals 64100: Best = 0.655820, Length = 28
# Ackley Evals 65100: Best = 0.655820, Length = 28
# Ackley Evals 66100: Best = 0.610566, Length = 31
# Ackley Evals 67100: Best = 0.474903, Length = 28
# Ackley Evals 68100: Best = 0.474903, Length = 28
# Ackley Evals 69100: Best = 0.463311, Length = 29
# Ackley Evals 70100: Best = 0.453141, Length = 28
# Ackley Evals 71100: Best = 0.445754, Length = 28
# Ackley Evals 72100: Best = 0.445754, Length = 28
# Ackley Evals 73100: Best = 0.445754, Length = 28
# Ackley Evals 74100: Best = 0.359299, Length = 29
# Ackley Evals 75100: Best = 0.359299, Length = 29
# Ackley Evals 76100: Best = 0.358553, Length = 28
# Ackley Evals 77100: Best = 0.358553, Length = 28
# Ackley Evals 78100: Best = 0.357019, Length = 28
# Ackley Evals 79100: Best = 0.342671, Length = 28
# Ackley Evals 80100: Best = 0.342671, Length = 28
# Ackley Evals 81100: Best = 0.320725, Length = 32
# Ackley Evals 82100: Best = 0.314654, Length = 31
# Ackley Evals 83100: Best = 0.299294, Length = 28
# Ackley Evals 84100: Best = 0.290876, Length = 30
# Ackley Evals 85100: Best = 0.283767, Length = 28
# Ackley Evals 86100: Best = 0.271020, Length = 28
# Ackley Evals 87100: Best = 0.248232, Length = 29
# Ackley Evals 88100: Best = 0.248232, Length = 29
# Ackley Evals 89100: Best = 0.247274, Length = 28
# Ackley Evals 90100: Best = 0.228619, Length = 32
# Ackley Evals 91100: Best = 0.225562, Length = 31
# Ackley Evals 92100: Best = 0.218905, Length = 30
# Ackley Evals 93100: Best = 0.199913, Length = 31
# Ackley Evals 94100: Best = 0.198183, Length = 30
# Ackley Evals 95100: Best = 0.180729, Length = 31
# Ackley Evals 96100: Best = 0.119601, Length = 30
# Ackley Evals 97100: Best = 0.116183, Length = 28
# Ackley Evals 98100: Best = 0.111896, Length = 28
# Ackley Evals 99100: Best = 0.093273, Length = 28
# Ackley Evals 100: Best = 5.479355, Length = 28
# Ackley Evals 1100: Best = 4.891155, Length = 30
# Ackley Evals 2100: Best = 4.459016, Length = 29
# Ackley Evals 3100: Best = 4.420426, Length = 29
# Ackley Evals 4100: Best = 4.300995, Length = 29
# Ackley Evals 5100: Best = 4.025169, Length = 28
# Ackley Evals 6100: Best = 3.683756, Length = 29
# Ackley Evals 7100: Best = 3.301305, Length = 31
# Ackley Evals 8100: Best = 3.181028, Length = 31
# Ackley Evals 9100: Best = 3.147067, Length = 28
# Ackley Evals 10100: Best = 3.071096, Length = 28
# Ackley Evals 11100: Best = 2.991034, Length = 28
# Ackley Evals 12100: Best = 2.951977, Length = 32
# Ackley Evals 13100: Best = 2.879898, Length = 31
# Ackley Evals 14100: Best = 2.759510, Length = 29
# Ackley Evals 15100: Best = 2.759510, Length = 29
# Ackley Evals 16100: Best = 2.645029, Length = 28
# Ackley Evals 17100: Best = 2.645029, Length = 28
# Ackley Evals 18100: Best = 2.421708, Length = 29
# Ackley Evals 19100: Best = 2.421708, Length = 29
# Ackley Evals 20100: Best = 2.421708, Length = 29
# Ackley Evals 21100: Best = 2.421708, Length = 29
# Ackley Evals 22100: Best = 2.421708, Length = 29
# Ackley Evals 23100: Best = 2.421708, Length = 29
# Ackley Evals 24100: Best = 2.358130, Length = 29
# Ackley Evals 25100: Best = 2.358130, Length = 29
# Ackley Evals 26100: Best = 2.071948, Length = 32
# Ackley Evals 27100: Best = 1.211352, Length = 30
# Ackley Evals 28100: Best = 0.962599, Length = 29
# Ackley Evals 29100: Best = 0.567325, Length = 28
# Ackley Evals 30100: Best = 0.567325, Length = 28
# Ackley Evals 31100: Best = 0.567325, Length = 28
# Ackley Evals 32100: Best = 0.567325, Length = 28
# Ackley Evals 33100: Best = 0.567325, Length = 28
# Ackley Evals 34100: Best = 0.567325, Length = 28
# Ackley Evals 35100: Best = 0.561549, Length = 31
# Ackley Evals 36100: Best = 0.561549, Length = 31
# Ackley Evals 37100: Best = 0.561549, Length = 31
# Ackley Evals 38100: Best = 0.561549, Length = 31
# Ackley Evals 39100: Best = 0.561549, Length = 31
# Ackley Evals 40100: Best = 0.561549, Length = 31
# Ackley Evals 41100: Best = 0.561549, Length = 31
# Ackley Evals 42100: Best = 0.561549, Length = 31
# Ackley Evals 43100: Best = 0.542771, Length = 30
# Ackley Evals 44100: Best = 0.542771, Length = 30
# Ackley Evals 45100: Best = 0.441423, Length = 29
# Ackley Evals 46100: Best = 0.441423, Length = 29
# Ackley Evals 47100: Best = 0.441423, Length = 29
# Ackley Evals 48100: Best = 0.431010, Length = 28
# Ackley Evals 49100: Best = 0.429269, Length = 28
# Ackley Evals 50100: Best = 0.427688, Length = 28
# Ackley Evals 51100: Best = 0.427688, Length = 28
# Ackley Evals 52100: Best = 0.427688, Length = 28
# Ackley Evals 53100: Best = 0.427688, Length = 28
# Ackley Evals 54100: Best = 0.412161, Length = 28
# Ackley Evals 55100: Best = 0.409159, Length = 29
# Ackley Evals 56100: Best = 0.390385, Length = 28
# Ackley Evals 57100: Best = 0.373981, Length = 32
# Ackley Evals 58100: Best = 0.364492, Length = 30
# Ackley Evals 59100: Best = 0.333063, Length = 30
# Ackley Evals 60100: Best = 0.274533, Length = 30
# Ackley Evals 61100: Best = 0.231951, Length = 29
# Ackley Evals 62100: Best = 0.225941, Length = 28
# Ackley Evals 63100: Best = 0.220780, Length = 29
# Ackley Evals 64100: Best = 0.220780, Length = 29
# Ackley Evals 65100: Best = 0.188468, Length = 28
# Ackley Evals 66100: Best = 0.188468, Length = 28
# Ackley Evals 67100: Best = 0.188468, Length = 28
# Ackley Evals 68100: Best = 0.188468, Length = 28
# Ackley Evals 69100: Best = 0.173653, Length = 29
# Ackley Evals 70100: Best = 0.173653, Length = 29
# Ackley Evals 71100: Best = 0.173653, Length = 29
# Ackley Evals 72100: Best = 0.171605, Length = 32
# Ackley Evals 73100: Best = 0.160738, Length = 30
# Ackley Evals 74100: Best = 0.160738, Length = 30
# Ackley Evals 75100: Best = 0.149337, Length = 30
# Ackley Evals 76100: Best = 0.144353, Length = 29
# Ackley Evals 77100: Best = 0.144353, Length = 29
# Ackley Evals 78100: Best = 0.144072, Length = 28
# Ackley Evals 79100: Best = 0.144072, Length = 28
# Ackley Evals 80100: Best = 0.144072, Length = 28
# Ackley Evals 81100: Best = 0.144072, Length = 28
# Ackley Evals 82100: Best = 0.139721, Length = 32
# Ackley Evals 83100: Best = 0.139721, Length = 32
# Ackley Evals 84100: Best = 0.124752, Length = 30
# Ackley Evals 85100: Best = 0.112709, Length = 31
# Ackley Evals 86100: Best = 0.111952, Length = 29
# Ackley Evals 87100: Best = 0.111531, Length = 28
# Ackley Evals 88100: Best = 0.110189, Length = 32
# Ackley Evals 89100: Best = 0.091813, Length = 28
# Ackley Evals 90100: Best = 0.091813, Length = 28
# Ackley Evals 91100: Best = 0.089761, Length = 32
# Ackley Evals 92100: Best = 0.061139, Length = 29
# Ackley Evals 93100: Best = 0.049387, Length = 28
# Ackley Evals 94100: Best = 0.049387, Length = 28
# Ackley Evals 95100: Best = 0.048304, Length = 28
# Ackley Evals 96100: Best = 0.048304, Length = 28
# Ackley Evals 97100: Best = 0.039103, Length = 29
# Ackley Evals 98100: Best = 0.035361, Length = 28
# Ackley Evals 99100: Best = 0.034202, Length = 31
# Ackley Evals 100: Best = 5.236046, Length = 30
# Ackley Evals 1100: Best = 4.590651, Length = 28
# Ackley Evals 2100: Best = 4.343461, Length = 28
# Ackley Evals 3100: Best = 4.161149, Length = 28
# Ackley Evals 4100: Best = 4.050826, Length = 28
# Ackley Evals 5100: Best = 3.591134, Length = 28
# Ackley Evals 6100: Best = 3.530000, Length = 29
# Ackley Evals 7100: Best = 3.530000, Length = 29
# Ackley Evals 8100: Best = 3.530000, Length = 29
# Ackley Evals 9100: Best = 3.399641, Length = 28
# Ackley Evals 10100: Best = 3.396511, Length = 28
# Ackley Evals 11100: Best = 3.375903, Length = 28
# Ackley Evals 12100: Best = 3.347049, Length = 29
# Ackley Evals 13100: Best = 3.297805, Length = 28
# Ackley Evals 14100: Best = 3.252723, Length = 29
# Ackley Evals 15100: Best = 3.198844, Length = 29
# Ackley Evals 16100: Best = 3.180601, Length = 31
# Ackley Evals 17100: Best = 3.134878, Length = 32
# Ackley Evals 18100: Best = 2.669094, Length = 31
# Ackley Evals 19100: Best = 2.669094, Length = 31
# Ackley Evals 20100: Best = 2.669094, Length = 31
# Ackley Evals 21100: Best = 2.669094, Length = 31
# Ackley Evals 22100: Best = 2.669094, Length = 31
# Ackley Evals 23100: Best = 2.599271, Length = 30
# Ackley Evals 24100: Best = 2.599271, Length = 30
# Ackley Evals 25100: Best = 2.386128, Length = 30
# Ackley Evals 26100: Best = 2.386128, Length = 30
# Ackley Evals 27100: Best = 2.386128, Length = 30
# Ackley Evals 28100: Best = 2.325927, Length = 30
# Ackley Evals 29100: Best = 2.237069, Length = 32
# Ackley Evals 30100: Best = 2.209657, Length = 32
# Ackley Evals 31100: Best = 2.172700, Length = 32
# Ackley Evals 32100: Best = 2.059023, Length = 32
# Ackley Evals 33100: Best = 2.059023, Length = 32
# Ackley Evals 34100: Best = 2.008360, Length = 32
# Ackley Evals 35100: Best = 2.008360, Length = 32
# Ackley Evals 36100: Best = 1.919063, Length = 28
# Ackley Evals 37100: Best = 1.814630, Length = 31
# Ackley Evals 38100: Best = 1.814630, Length = 31
# Ackley Evals 39100: Best = 1.814630, Length = 31
# Ackley Evals 40100: Best = 1.773748, Length = 29
# Ackley Evals 41100: Best = 1.577102, Length = 29
# Ackley Evals 42100: Best = 1.577102, Length = 29
# Ackley Evals 43100: Best = 1.577102, Length = 29
# Ackley Evals 44100: Best = 1.552281, Length = 28
# Ackley Evals 45100: Best = 1.516461, Length = 28
# Ackley Evals 46100: Best = 1.516461, Length = 28
# Ackley Evals 47100: Best = 1.473789, Length = 29
# Ackley Evals 48100: Best = 1.473789, Length = 29
# Ackley Evals 49100: Best = 1.473789, Length = 29
# Ackley Evals 50100: Best = 1.223799, Length = 30
# Ackley Evals 51100: Best = 1.223789, Length = 30
# Ackley Evals 52100: Best = 1.209682, Length = 29
# Ackley Evals 53100: Best = 1.198934, Length = 29
# Ackley Evals 54100: Best = 0.910674, Length = 29
# Ackley Evals 55100: Best = 0.838241, Length = 28
# Ackley Evals 56100: Best = 0.838241, Length = 28
# Ackley Evals 57100: Best = 0.810348, Length = 28
# Ackley Evals 58100: Best = 0.729110, Length = 28
# Ackley Evals 59100: Best = 0.729110, Length = 28
# Ackley Evals 60100: Best = 0.729110, Length = 28
# Ackley Evals 61100: Best = 0.729110, Length = 28
# Ackley Evals 62100: Best = 0.692705, Length = 28
# Ackley Evals 63100: Best = 0.692705, Length = 28
# Ackley Evals 64100: Best = 0.680731, Length = 28
# Ackley Evals 65100: Best = 0.680731, Length = 28
# Ackley Evals 66100: Best = 0.678684, Length = 28
# Ackley Evals 67100: Best = 0.678684, Length = 28
# Ackley Evals 68100: Best = 0.673014, Length = 28
# Ackley Evals 69100: Best = 0.670873, Length = 28
# Ackley Evals 70100: Best = 0.665570, Length = 28
# Ackley Evals 71100: Best = 0.654402, Length = 29
# Ackley Evals 72100: Best = 0.644322, Length = 30
# Ackley Evals 73100: Best = 0.589447, Length = 28
# Ackley Evals 74100: Best = 0.589447, Length = 28
# Ackley Evals 75100: Best = 0.589447, Length = 28
# Ackley Evals 76100: Best = 0.589447, Length = 28
# Ackley Evals 77100: Best = 0.586452, Length = 28
# Ackley Evals 78100: Best = 0.519349, Length = 28
# Ackley Evals 79100: Best = 0.519349, Length = 28
# Ackley Evals 80100: Best = 0.492240, Length = 28
# Ackley Evals 81100: Best = 0.492240, Length = 28
# Ackley Evals 82100: Best = 0.412884, Length = 31
# Ackley Evals 83100: Best = 0.351622, Length = 31
# Ackley Evals 84100: Best = 0.342559, Length = 30
# Ackley Evals 85100: Best = 0.342559, Length = 30
# Ackley Evals 86100: Best = 0.296193, Length = 29
# Ackley Evals 87100: Best = 0.247425, Length = 30
# Ackley Evals 88100: Best = 0.237488, Length = 32
# Ackley Evals 89100: Best = 0.237488, Length = 32
# Ackley Evals 90100: Best = 0.142410, Length = 31
# Ackley Evals 91100: Best = 0.142003, Length = 30
# Ackley Evals 92100: Best = 0.125166, Length = 28
# Ackley Evals 93100: Best = 0.125166, Length = 28
# Ackley Evals 94100: Best = 0.118788, Length = 31
# Ackley Evals 95100: Best = 0.093221, Length = 28
# Ackley Evals 96100: Best = 0.091046, Length = 28
# Ackley Evals 97100: Best = 0.085585, Length = 32
# Ackley Evals 98100: Best = 0.081388, Length = 31
# Ackley Evals 99100: Best = 0.068042, Length = 30
# Ackley Evals 100: Best = 5.218296, Length = 31
# Ackley Evals 1100: Best = 4.541909, Length = 32
# Ackley Evals 2100: Best = 4.341761, Length = 28
# Ackley Evals 3100: Best = 4.277314, Length = 29
# Ackley Evals 4100: Best = 3.992638, Length = 30
# Ackley Evals 5100: Best = 3.682540, Length = 29
# Ackley Evals 6100: Best = 3.641022, Length = 32
# Ackley Evals 7100: Best = 3.458532, Length = 32
# Ackley Evals 8100: Best = 3.442390, Length = 31
# Ackley Evals 9100: Best = 3.303767, Length = 29
# Ackley Evals 10100: Best = 3.303767, Length = 29
# Ackley Evals 11100: Best = 3.203473, Length = 29
# Ackley Evals 12100: Best = 3.113006, Length = 29
# Ackley Evals 13100: Best = 3.097555, Length = 29
# Ackley Evals 14100: Best = 2.847235, Length = 31
# Ackley Evals 15100: Best = 2.769135, Length = 31
# Ackley Evals 16100: Best = 2.769135, Length = 31
# Ackley Evals 17100: Best = 2.712256, Length = 30
# Ackley Evals 18100: Best = 2.712256, Length = 30
# Ackley Evals 19100: Best = 2.652538, Length = 31
# Ackley Evals 20100: Best = 2.570598, Length = 30
# Ackley Evals 21100: Best = 2.534673, Length = 31
# Ackley Evals 22100: Best = 2.389209, Length = 31
# Ackley Evals 23100: Best = 2.346272, Length = 30
# Ackley Evals 24100: Best = 2.346272, Length = 30
# Ackley Evals 25100: Best = 2.239864, Length = 30
# Ackley Evals 26100: Best = 2.080117, Length = 29
# Ackley Evals 27100: Best = 1.810888, Length = 31
# Ackley Evals 28100: Best = 1.728491, Length = 28
# Ackley Evals 29100: Best = 1.709260, Length = 28
# Ackley Evals 30100: Best = 1.709260, Length = 28
# Ackley Evals 31100: Best = 1.582637, Length = 28
# Ackley Evals 32100: Best = 1.582637, Length = 28
# Ackley Evals 33100: Best = 1.276948, Length = 29
# Ackley Evals 34100: Best = 1.247652, Length = 29
# Ackley Evals 35100: Best = 1.207869, Length = 29
# Ackley Evals 36100: Best = 1.207869, Length = 29
# Ackley Evals 37100: Best = 1.094069, Length = 29
# Ackley Evals 38100: Best = 1.013629, Length = 29
# Ackley Evals 39100: Best = 0.995624, Length = 29
# Ackley Evals 40100: Best = 0.973419, Length = 29
# Ackley Evals 41100: Best = 0.936556, Length = 29
# Ackley Evals 42100: Best = 0.936556, Length = 29
# Ackley Evals 43100: Best = 0.936556, Length = 29
# Ackley Evals 44100: Best = 0.924323, Length = 29
# Ackley Evals 45100: Best = 0.917326, Length = 30
# Ackley Evals 46100: Best = 0.917326, Length = 30
# Ackley Evals 47100: Best = 0.917326, Length = 30
# Ackley Evals 48100: Best = 0.917326, Length = 30
# Ackley Evals 49100: Best = 0.897732, Length = 31
# Ackley Evals 50100: Best = 0.897732, Length = 31
# Ackley Evals 51100: Best = 0.897732, Length = 31
# Ackley Evals 52100: Best = 0.858613, Length = 30
# Ackley Evals 53100: Best = 0.712456, Length = 30
# Ackley Evals 54100: Best = 0.708462, Length = 30
# Ackley Evals 55100: Best = 0.708462, Length = 30
# Ackley Evals 56100: Best = 0.707952, Length = 29
# Ackley Evals 57100: Best = 0.699836, Length = 28
# Ackley Evals 58100: Best = 0.688135, Length = 29
# Ackley Evals 59100: Best = 0.677832, Length = 28
# Ackley Evals 60100: Best = 0.677832, Length = 28
# Ackley Evals 61100: Best = 0.587429, Length = 32
# Ackley Evals 62100: Best = 0.587429, Length = 32
# Ackley Evals 63100: Best = 0.520289, Length = 31
# Ackley Evals 64100: Best = 0.520289, Length = 31
# Ackley Evals 65100: Best = 0.520289, Length = 31
# Ackley Evals 66100: Best = 0.477818, Length = 30
# Ackley Evals 67100: Best = 0.460132, Length = 30
# Ackley Evals 68100: Best = 0.454030, Length = 29
# Ackley Evals 69100: Best = 0.444937, Length = 30
# Ackley Evals 70100: Best = 0.386917, Length = 32
# Ackley Evals 71100: Best = 0.353640, Length = 31
# Ackley Evals 72100: Best = 0.352101, Length = 30
# Ackley Evals 73100: Best = 0.341204, Length = 30
# Ackley Evals 74100: Best = 0.341204, Length = 30
# Ackley Evals 75100: Best = 0.324139, Length = 28
# Ackley Evals 76100: Best = 0.262443, Length = 28
# Ackley Evals 77100: Best = 0.247208, Length = 32
# Ackley Evals 78100: Best = 0.239402, Length = 31
# Ackley Evals 79100: Best = 0.239402, Length = 31
# Ackley Evals 80100: Best = 0.173410, Length = 30
# Ackley Evals 81100: Best = 0.132722, Length = 29
# Ackley Evals 82100: Best = 0.131536, Length = 28
# Ackley Evals 83100: Best = 0.131536, Length = 28
# Ackley Evals 84100: Best = 0.131536, Length = 28
# Ackley Evals 85100: Best = 0.130561, Length = 29
# Ackley Evals 86100: Best = 0.124149, Length = 32
# Ackley Evals 87100: Best = 0.120784, Length = 28
# Ackley Evals 88100: Best = 0.116161, Length = 31
# Ackley Evals 89100: Best = 0.113455, Length = 31
# Ackley Evals 90100: Best = 0.111374, Length = 30
# Ackley Evals 91100: Best = 0.090957, Length = 30
# Ackley Evals 92100: Best = 0.083961, Length = 29
# Ackley Evals 93100: Best = 0.083298, Length = 28
# Ackley Evals 94100: Best = 0.083298, Length = 28
# Ackley Evals 95100: Best = 0.083298, Length = 28
# Ackley Evals 96100: Best = 0.081310, Length = 29
# Ackley Evals 97100: Best = 0.075173, Length = 28
# Ackley Evals 98100: Best = 0.066898, Length = 32
# Ackley Evals 99100: Best = 0.065739, Length = 29
# Ackley Evals 100: Best = 5.305894, Length = 28
# Ackley Evals 1100: Best = 4.798013, Length = 28
# Ackley Evals 2100: Best = 4.780057, Length = 28
# Ackley Evals 3100: Best = 4.624472, Length = 28
# Ackley Evals 4100: Best = 4.302727, Length = 30
# Ackley Evals 5100: Best = 3.920938, Length = 32
# Ackley Evals 6100: Best = 3.883661, Length = 29
# Ackley Evals 7100: Best = 3.877861, Length = 29
# Ackley Evals 8100: Best = 3.877861, Length = 29
# Ackley Evals 9100: Best = 3.631247, Length = 28
# Ackley Evals 10100: Best = 3.631247, Length = 28
# Ackley Evals 11100: Best = 3.631247, Length = 28
# Ackley Evals 12100: Best = 3.631247, Length = 28
# Ackley Evals 13100: Best = 3.451729, Length = 28
# Ackley Evals 14100: Best = 3.451729, Length = 28
# Ackley Evals 15100: Best = 3.302267, Length = 29
# Ackley Evals 16100: Best = 3.252669, Length = 28
# Ackley Evals 17100: Best = 3.240735, Length = 28
# Ackley Evals 18100: Best = 3.169694, Length = 28
# Ackley Evals 19100: Best = 2.934045, Length = 28
# Ackley Evals 20100: Best = 2.317562, Length = 30
# Ackley Evals 21100: Best = 2.298185, Length = 28
# Ackley Evals 22100: Best = 2.267077, Length = 32
# Ackley Evals 23100: Best = 2.160547, Length = 30
# Ackley Evals 24100: Best = 2.160547, Length = 30
# Ackley Evals 25100: Best = 2.160547, Length = 30
# Ackley Evals 26100: Best = 2.153882, Length = 30
# Ackley Evals 27100: Best = 2.126409, Length = 29
# Ackley Evals 28100: Best = 2.126409, Length = 29
# Ackley Evals 29100: Best = 2.057001, Length = 29
# Ackley Evals 30100: Best = 2.016742, Length = 30
# Ackley Evals 31100: Best = 2.016742, Length = 30
# Ackley Evals 32100: Best = 1.828003, Length = 29
# Ackley Evals 33100: Best = 1.828003, Length = 29
# Ackley Evals 34100: Best = 1.828003, Length = 29
# Ackley Evals 35100: Best = 1.828003, Length = 29
# Ackley Evals 36100: Best = 1.584467, Length = 28
# Ackley Evals 37100: Best = 1.399099, Length = 29
# Ackley Evals 38100: Best = 1.234981, Length = 28
# Ackley Evals 39100: Best = 1.234981, Length = 28
# Ackley Evals 40100: Best = 1.234981, Length = 28
# Ackley Evals 41100: Best = 1.234981, Length = 28
# Ackley Evals 42100: Best = 1.234981, Length = 28
# Ackley Evals 43100: Best = 1.218399, Length = 28
# Ackley Evals 44100: Best = 1.046992, Length = 32
# Ackley Evals 45100: Best = 0.943373, Length = 29
# Ackley Evals 46100: Best = 0.943373, Length = 29
# Ackley Evals 47100: Best = 0.943373, Length = 29
# Ackley Evals 48100: Best = 0.943373, Length = 29
# Ackley Evals 49100: Best = 0.928827, Length = 28
# Ackley Evals 50100: Best = 0.928827, Length = 28
# Ackley Evals 51100: Best = 0.928827, Length = 28
# Ackley Evals 52100: Best = 0.803181, Length = 28
# Ackley Evals 53100: Best = 0.803181, Length = 28
# Ackley Evals 54100: Best = 0.803181, Length = 28
# Ackley Evals 55100: Best = 0.803181, Length = 28
# Ackley Evals 56100: Best = 0.803181, Length = 28
# Ackley Evals 57100: Best = 0.562752, Length = 28
# Ackley Evals 58100: Best = 0.562752, Length = 28
# Ackley Evals 59100: Best = 0.562752, Length = 28
# Ackley Evals 60100: Best = 0.562752, Length = 28
# Ackley Evals 61100: Best = 0.562752, Length = 28
# Ackley Evals 62100: Best = 0.562752, Length = 28
# Ackley Evals 63100: Best = 0.562752, Length = 28
# Ackley Evals 64100: Best = 0.549958, Length = 29
# Ackley Evals 65100: Best = 0.549958, Length = 29
# Ackley Evals 66100: Best = 0.483660, Length = 28
# Ackley Evals 67100: Best = 0.463528, Length = 30
# Ackley Evals 68100: Best = 0.440833, Length = 30
# Ackley Evals 69100: Best = 0.440833, Length = 30
# Ackley Evals 70100: Best = 0.440833, Length = 30
# Ackley Evals 71100: Best = 0.440833, Length = 30
# Ackley Evals 72100: Best = 0.401842, Length = 29
# Ackley Evals 73100: Best = 0.368980, Length = 30
# Ackley Evals 74100: Best = 0.342275, Length = 28
# Ackley Evals 75100: Best = 0.317952, Length = 28
# Ackley Evals 76100: Best = 0.317952, Length = 28
# Ackley Evals 77100: Best = 0.317952, Length = 28
# Ackley Evals 78100: Best = 0.315534, Length = 28
# Ackley Evals 79100: Best = 0.304979, Length = 28
# Ackley Evals 80100: Best = 0.304979, Length = 28
# Ackley Evals 81100: Best = 0.292763, Length = 28
# Ackley Evals 82100: Best = 0.292763, Length = 28
# Ackley Evals 83100: Best = 0.292763, Length = 28
# Ackley Evals 84100: Best = 0.284096, Length = 31
# Ackley Evals 85100: Best = 0.281433, Length = 29
# Ackley Evals 86100: Best = 0.280598, Length = 28
# Ackley Evals 87100: Best = 0.229225, Length = 28
# Ackley Evals 88100: Best = 0.221167, Length = 28
# Ackley Evals 89100: Best = 0.221167, Length = 28
# Ackley Evals 90100: Best = 0.208794, Length = 32
# Ackley Evals 91100: Best = 0.174800, Length = 30
# Ackley Evals 92100: Best = 0.169200, Length = 32
# Ackley Evals 93100: Best = 0.155865, Length = 30
# Ackley Evals 94100: Best = 0.152772, Length = 31
# Ackley Evals 95100: Best = 0.152765, Length = 28
# Ackley Evals 96100: Best = 0.149893, Length = 30
# Ackley Evals 97100: Best = 0.136549, Length = 31
# Ackley Evals 98100: Best = 0.135369, Length = 31
# Ackley Evals 99100: Best = 0.102979, Length = 28
# Ackley Evals 100: Best = 5.559837, Length = 32
# Ackley Evals 1100: Best = 5.077995, Length = 30
# Ackley Evals 2100: Best = 4.540381, Length = 28
# Ackley Evals 3100: Best = 4.267031, Length = 28
# Ackley Evals 4100: Best = 3.550495, Length = 30
# Ackley Evals 5100: Best = 3.550495, Length = 30
# Ackley Evals 6100: Best = 3.172576, Length = 30
# Ackley Evals 7100: Best = 3.071701, Length = 28
# Ackley Evals 8100: Best = 3.070803, Length = 28
# Ackley Evals 9100: Best = 3.070803, Length = 28
# Ackley Evals 10100: Best = 2.783102, Length = 28
# Ackley Evals 11100: Best = 2.783102, Length = 28
# Ackley Evals 12100: Best = 2.783102, Length = 28
# Ackley Evals 13100: Best = 2.781124, Length = 28
# Ackley Evals 14100: Best = 2.644933, Length = 28
# Ackley Evals 15100: Best = 2.581459, Length = 28
# Ackley Evals 16100: Best = 2.581459, Length = 28
# Ackley Evals 17100: Best = 2.552939, Length = 29
# Ackley Evals 18100: Best = 2.511879, Length = 29
# Ackley Evals 19100: Best = 2.511879, Length = 29
# Ackley Evals 20100: Best = 2.497143, Length = 28
# Ackley Evals 21100: Best = 2.364950, Length = 29
# Ackley Evals 22100: Best = 2.329436, Length = 29
# Ackley Evals 23100: Best = 2.067427, Length = 32
# Ackley Evals 24100: Best = 2.063400, Length = 31
# Ackley Evals 25100: Best = 1.939890, Length = 29
# Ackley Evals 26100: Best = 1.743991, Length = 32
# Ackley Evals 27100: Best = 1.742318, Length = 32
# Ackley Evals 28100: Best = 1.742318, Length = 32
# Ackley Evals 29100: Best = 1.742318, Length = 32
# Ackley Evals 30100: Best = 1.742318, Length = 32
# Ackley Evals 31100: Best = 1.741235, Length = 32
# Ackley Evals 32100: Best = 1.635630, Length = 28
# Ackley Evals 33100: Best = 1.635630, Length = 28
# Ackley Evals 34100: Best = 1.630918, Length = 28
# Ackley Evals 35100: Best = 1.630918, Length = 28
# Ackley Evals 36100: Best = 1.630918, Length = 28
# Ackley Evals 37100: Best = 1.630918, Length = 28
# Ackley Evals 38100: Best = 1.605874, Length = 29
# Ackley Evals 39100: Best = 1.605021, Length = 29
# Ackley Evals 40100: Best = 1.605021, Length = 29
# Ackley Evals 41100: Best = 1.605021, Length = 29
# Ackley Evals 42100: Best = 1.605021, Length = 29
# Ackley Evals 43100: Best = 1.605021, Length = 29
# Ackley Evals 44100: Best = 1.476069, Length = 28
# Ackley Evals 45100: Best = 1.476069, Length = 28
# Ackley Evals 46100: Best = 1.476069, Length = 28
# Ackley Evals 47100: Best = 1.476069, Length = 28
# Ackley Evals 48100: Best = 1.329264, Length = 28
# Ackley Evals 49100: Best = 1.305272, Length = 31
# Ackley Evals 50100: Best = 1.247711, Length = 28
# Ackley Evals 51100: Best = 1.247711, Length = 28
# Ackley Evals 52100: Best = 1.247711, Length = 28
# Ackley Evals 53100: Best = 0.752825, Length = 28
# Ackley Evals 54100: Best = 0.752825, Length = 28
# Ackley Evals 55100: Best = 0.752825, Length = 28
# Ackley Evals 56100: Best = 0.752825, Length = 28
# Ackley Evals 57100: Best = 0.724926, Length = 28
# Ackley Evals 58100: Best = 0.719587, Length = 29
# Ackley Evals 59100: Best = 0.698687, Length = 28
# Ackley Evals 60100: Best = 0.693048, Length = 29
# Ackley Evals 61100: Best = 0.693048, Length = 29
# Ackley Evals 62100: Best = 0.689132, Length = 28
# Ackley Evals 63100: Best = 0.689132, Length = 28
# Ackley Evals 64100: Best = 0.674346, Length = 31
# Ackley Evals 65100: Best = 0.640241, Length = 31
# Ackley Evals 66100: Best = 0.621195, Length = 31
# Ackley Evals 67100: Best = 0.547277, Length = 31
# Ackley Evals 68100: Best = 0.528540, Length = 31
# Ackley Evals 69100: Best = 0.463313, Length = 31
# Ackley Evals 70100: Best = 0.459581, Length = 29
# Ackley Evals 71100: Best = 0.446947, Length = 28
# Ackley Evals 72100: Best = 0.446947, Length = 28
# Ackley Evals 73100: Best = 0.446947, Length = 28
# Ackley Evals 74100: Best = 0.370236, Length = 29
# Ackley Evals 75100: Best = 0.332257, Length = 28
# Ackley Evals 76100: Best = 0.332257, Length = 28
# Ackley Evals 77100: Best = 0.307605, Length = 28
# Ackley Evals 78100: Best = 0.307605, Length = 28
# Ackley Evals 79100: Best = 0.307605, Length = 28
# Ackley Evals 80100: Best = 0.303417, Length = 28
# Ackley Evals 81100: Best = 0.292267, Length = 28
# Ackley Evals 82100: Best = 0.277814, Length = 29
# Ackley Evals 83100: Best = 0.275039, Length = 30
# Ackley Evals 84100: Best = 0.275039, Length = 30
# Ackley Evals 85100: Best = 0.208216, Length = 31
# Ackley Evals 86100: Best = 0.176029, Length = 28
# Ackley Evals 87100: Best = 0.176029, Length = 28
# Ackley Evals 88100: Best = 0.176029, Length = 28
# Ackley Evals 89100: Best = 0.171872, Length = 29
# Ackley Evals 90100: Best = 0.168181, Length = 31
# Ackley Evals 91100: Best = 0.161958, Length = 31
# Ackley Evals 92100: Best = 0.161958, Length = 31
# Ackley Evals 93100: Best = 0.161044, Length = 30
# Ackley Evals 94100: Best = 0.156375, Length = 28
# Ackley Evals 95100: Best = 0.156375, Length = 28
# Ackley Evals 96100: Best = 0.154525, Length = 30
# Ackley Evals 97100: Best = 0.147328, Length = 28
# Ackley Evals 98100: Best = 0.147328, Length = 28
# Ackley Evals 99100: Best = 0.117635, Length = 31
# Ackley Evals 100: Best = 5.362770, Length = 32
# Ackley Evals 1100: Best = 4.381183, Length = 30
# Ackley Evals 2100: Best = 4.251030, Length = 32
# Ackley Evals 3100: Best = 3.748637, Length = 29
# Ackley Evals 4100: Best = 3.493100, Length = 28
# Ackley Evals 5100: Best = 3.374953, Length = 28
# Ackley Evals 6100: Best = 3.100296, Length = 28
# Ackley Evals 7100: Best = 3.100296, Length = 28
# Ackley Evals 8100: Best = 2.882606, Length = 28
# Ackley Evals 9100: Best = 2.775102, Length = 28
# Ackley Evals 10100: Best = 2.759065, Length = 28
# Ackley Evals 11100: Best = 2.759065, Length = 28
# Ackley Evals 12100: Best = 2.759065, Length = 28
# Ackley Evals 13100: Best = 2.736589, Length = 28
# Ackley Evals 14100: Best = 2.729306, Length = 28
# Ackley Evals 15100: Best = 2.679550, Length = 29
# Ackley Evals 16100: Best = 2.679550, Length = 29
# Ackley Evals 17100: Best = 2.565582, Length = 29
# Ackley Evals 18100: Best = 2.412118, Length = 29
# Ackley Evals 19100: Best = 2.412118, Length = 29
# Ackley Evals 20100: Best = 2.368796, Length = 28
# Ackley Evals 21100: Best = 2.368796, Length = 28
# Ackley Evals 22100: Best = 2.366234, Length = 28
# Ackley Evals 23100: Best = 2.352696, Length = 28
# Ackley Evals 24100: Best = 2.352696, Length = 28
# Ackley Evals 25100: Best = 2.352696, Length = 28
# Ackley Evals 26100: Best = 2.352696, Length = 28
# Ackley Evals 27100: Best = 2.258763, Length = 28
# Ackley Evals 28100: Best = 2.258763, Length = 28
# Ackley Evals 29100: Best = 2.258763, Length = 28
# Ackley Evals 30100: Best = 2.236231, Length = 32
# Ackley Evals 31100: Best = 2.153958, Length = 31
# Ackley Evals 32100: Best = 2.065922, Length = 28
# Ackley Evals 33100: Best = 2.059604, Length = 30
# Ackley Evals 34100: Best = 2.005715, Length = 32
# Ackley Evals 35100: Best = 1.946562, Length = 32
# Ackley Evals 36100: Best = 1.946562, Length = 32
# Ackley Evals 37100: Best = 1.880642, Length = 32
# Ackley Evals 38100: Best = 1.805340, Length = 28
# Ackley Evals 39100: Best = 1.796372, Length = 28
# Ackley Evals 40100: Best = 1.775748, Length = 28
# Ackley Evals 41100: Best = 1.775748, Length = 28
# Ackley Evals 42100: Best = 1.775748, Length = 28
# Ackley Evals 43100: Best = 1.771801, Length = 28
# Ackley Evals 44100: Best = 1.771801, Length = 28
# Ackley Evals 45100: Best = 1.771801, Length = 28
# Ackley Evals 46100: Best = 1.728640, Length = 28
# Ackley Evals 47100: Best = 1.689158, Length = 29
# Ackley Evals 48100: Best = 1.408361, Length = 28
# Ackley Evals 49100: Best = 1.408361, Length = 28
# Ackley Evals 50100: Best = 1.398342, Length = 28
# Ackley Evals 51100: Best = 1.398342, Length = 28
# Ackley Evals 52100: Best = 1.174679, Length = 28
# Ackley Evals 53100: Best = 1.174679, Length = 28
# Ackley Evals 54100: Best = 1.174679, Length = 28
# Ackley Evals 55100: Best = 1.174679, Length = 28
# Ackley Evals 56100: Best = 1.114215, Length = 28
# Ackley Evals 57100: Best = 1.114215, Length = 28
# Ackley Evals 58100: Best = 1.114215, Length = 28
# Ackley Evals 59100: Best = 1.114215, Length = 28
# Ackley Evals 60100: Best = 1.114215, Length = 28
# Ackley Evals 61100: Best = 1.114215, Length = 28
# Ackley Evals 62100: Best = 1.114215, Length = 28
# Ackley Evals 63100: Best = 1.068430, Length = 28
# Ackley Evals 64100: Best = 1.059179, Length = 28
# Ackley Evals 65100: Best = 1.012725, Length = 28
# Ackley Evals 66100: Best = 0.981246, Length = 28
# Ackley Evals 67100: Best = 0.981246, Length = 28
# Ackley Evals 68100: Best = 0.828472, Length = 30
# Ackley Evals 69100: Best = 0.745194, Length = 28
# Ackley Evals 70100: Best = 0.745194, Length = 28
# Ackley Evals 71100: Best = 0.726058, Length = 28
# Ackley Evals 72100: Best = 0.726058, Length = 28
# Ackley Evals 73100: Best = 0.716427, Length = 29
# Ackley Evals 74100: Best = 0.643824, Length = 28
# Ackley Evals 75100: Best = 0.641390, Length = 28
# Ackley Evals 76100: Best = 0.641390, Length = 28
# Ackley Evals 77100: Best = 0.597690, Length = 31
# Ackley Evals 78100: Best = 0.575153, Length = 30
# Ackley Evals 79100: Best = 0.513205, Length = 32
# Ackley Evals 80100: Best = 0.491050, Length = 30
# ...
# SantaFe Evals 98100: Best = -31.000000, Length = 100
# SantaFe Evals 99100: Best = -31.000000, Length = 100
# SantaFe Evals 100: Best = -5.000000, Length = 99
# SantaFe Evals 1100: Best = -16.000000, Length = 100
# SantaFe Evals 2100: Best = -22.000000, Length = 99
# SantaFe Evals 3100: Best = -22.000000, Length = 99
# SantaFe Evals 4100: Best = -22.000000, Length = 99
# SantaFe Evals 5100: Best = -22.000000, Length = 99
# SantaFe Evals 6100: Best = -22.000000, Length = 99
# SantaFe Evals 7100: Best = -22.000000, Length = 99
# SantaFe Evals 8100: Best = -22.000000, Length = 99
# SantaFe Evals 9100: Best = -23.000000, Length = 100
# SantaFe Evals 10100: Best = -23.000000, Length = 100
# SantaFe Evals 11100: Best = -23.000000, Length = 100
# SantaFe Evals 12100: Best = -23.000000, Length = 100
# SantaFe Evals 13100: Best = -23.000000, Length = 100
# SantaFe Evals 14100: Best = -23.000000, Length = 100
# SantaFe Evals 15100: Best = -23.000000, Length = 100
# SantaFe Evals 16100: Best = -23.000000, Length = 100
# SantaFe Evals 17100: Best = -23.000000, Length = 100
# SantaFe Evals 18100: Best = -23.000000, Length = 100
# SantaFe Evals 19100: Best = -23.000000, Length = 100
# SantaFe Evals 20100: Best = -23.000000, Length = 100
# SantaFe Evals 21100: Best = -23.000000, Length = 100
# SantaFe Evals 22100: Best = -23.000000, Length = 100
# SantaFe Evals 23100: Best = -23.000000, Length = 100
# SantaFe Evals 24100: Best = -23.000000, Length = 100
# SantaFe Evals 25100: Best = -23.000000, Length = 100
# SantaFe Evals 26100: Best = -23.000000, Length = 100
# SantaFe Evals 27100: Best = -23.000000, Length = 100
# SantaFe Evals 28100: Best = -23.000000, Length = 100
# SantaFe Evals 29100: Best = -23.000000, Length = 100
# SantaFe Evals 30100: Best = -23.000000, Length = 100
# SantaFe Evals 31100: Best = -23.000000, Length = 100
# SantaFe Evals 32100: Best = -23.000000, Length = 100
# SantaFe Evals 33100: Best = -23.000000, Length = 100
# SantaFe Evals 34100: Best = -23.000000, Length = 100
# SantaFe Evals 35100: Best = -23.000000, Length = 100
# SantaFe Evals 36100: Best = -23.000000, Length = 100
# SantaFe Evals 37100: Best = -23.000000, Length = 100
# SantaFe Evals 38100: Best = -23.000000, Length = 100
# SantaFe Evals 39100: Best = -23.000000, Length = 100
# SantaFe Evals 40100: Best = -23.000000, Length = 100
# SantaFe Evals 41100: Best = -23.000000, Length = 100
# SantaFe Evals 42100: Best = -23.000000, Length = 100
# SantaFe Evals 43100: Best = -23.000000, Length = 100
# SantaFe Evals 44100: Best = -24.000000, Length = 99
# SantaFe Evals 45100: Best = -24.000000, Length = 99
# SantaFe Evals 46100: Best = -24.000000, Length = 99
# SantaFe Evals 47100: Best = -25.000000, Length = 100
# SantaFe Evals 48100: Best = -25.000000, Length = 100
# SantaFe Evals 49100: Best = -28.000000, Length = 99
# SantaFe Evals 50100: Best = -28.000000, Length = 99
# SantaFe Evals 51100: Best = -28.000000, Length = 99
# SantaFe Evals 52100: Best = -28.000000, Length = 99
# SantaFe Evals 53100: Best = -31.000000, Length = 100
# SantaFe Evals 54100: Best = -31.000000, Length = 100
# SantaFe Evals 55100: Best = -31.000000, Length = 100
# SantaFe Evals 56100: Best = -32.000000, Length = 99
# SantaFe Evals 57100: Best = -32.000000, Length = 99
# SantaFe Evals 58100: Best = -35.000000, Length = 100
# SantaFe Evals 59100: Best = -36.000000, Length = 100
# SantaFe Evals 60100: Best = -36.000000, Length = 100
# SantaFe Evals 61100: Best = -36.000000, Length = 100
# SantaFe Evals 62100: Best = -36.000000, Length = 100
# SantaFe Evals 63100: Best = -36.000000, Length = 100
# SantaFe Evals 64100: Best = -36.000000, Length = 100
# SantaFe Evals 65100: Best = -36.000000, Length = 100
# SantaFe Evals 66100: Best = -36.000000, Length = 100
# SantaFe Evals 67100: Best = -36.000000, Length = 100
# SantaFe Evals 68100: Best = -36.000000, Length = 100
# SantaFe Evals 69100: Best = -36.000000, Length = 100
# SantaFe Evals 70100: Best = -36.000000, Length = 100
# SantaFe Evals 71100: Best = -36.000000, Length = 100
# SantaFe Evals 72100: Best = -36.000000, Length = 100
# SantaFe Evals 73100: Best = -36.000000, Length = 100
# SantaFe Evals 74100: Best = -36.000000, Length = 100
# SantaFe Evals 75100: Best = -36.000000, Length = 100
# SantaFe Evals 76100: Best = -36.000000, Length = 100
# SantaFe Evals 77100: Best = -36.000000, Length = 100
# SantaFe Evals 78100: Best = -36.000000, Length = 100
# SantaFe Evals 79100: Best = -36.000000, Length = 100
# SantaFe Evals 80100: Best = -36.000000, Length = 100
# SantaFe Evals 81100: Best = -36.000000, Length = 100
# SantaFe Evals 82100: Best = -36.000000, Length = 100
# SantaFe Evals 83100: Best = -39.000000, Length = 100
# SantaFe Evals 84100: Best = -39.000000, Length = 100
# SantaFe Evals 85100: Best = -39.000000, Length = 100
# SantaFe Evals 86100: Best = -39.000000, Length = 100
# SantaFe Evals 87100: Best = -39.000000, Length = 100
# SantaFe Evals 88100: Best = -39.000000, Length = 100
# SantaFe Evals 89100: Best = -39.000000, Length = 100
# SantaFe Evals 90100: Best = -43.000000, Length = 100
# SantaFe Evals 91100: Best = -44.000000, Length = 100
# SantaFe Evals 92100: Best = -44.000000, Length = 100
# SantaFe Evals 93100: Best = -46.000000, Length = 100
# SantaFe Evals 94100: Best = -46.000000, Length = 100
# SantaFe Evals 95100: Best = -46.000000, Length = 100
# SantaFe Evals 96100: Best = -46.000000, Length = 100
# SantaFe Evals 97100: Best = -46.000000, Length = 100
# SantaFe Evals 98100: Best = -46.000000, Length = 100
# SantaFe Evals 99100: Best = -46.000000, Length = 100
# SantaFe Evals 100: Best = -9.000000, Length = 100
# SantaFe Evals 1100: Best = -13.000000, Length = 100
# SantaFe Evals 2100: Best = -19.000000, Length = 99
# SantaFe Evals 3100: Best = -19.000000, Length = 99
# SantaFe Evals 4100: Best = -19.000000, Length = 99
# SantaFe Evals 5100: Best = -19.000000, Length = 99
# SantaFe Evals 6100: Best = -19.000000, Length = 99
# SantaFe Evals 7100: Best = -19.000000, Length = 99
# SantaFe Evals 8100: Best = -19.000000, Length = 99
# SantaFe Evals 9100: Best = -19.000000, Length = 99
# SantaFe Evals 10100: Best = -19.000000, Length = 99
# SantaFe Evals 11100: Best = -19.000000, Length = 99
# SantaFe Evals 12100: Best = -19.000000, Length = 99
# SantaFe Evals 13100: Best = -19.000000, Length = 99
# SantaFe Evals 14100: Best = -19.000000, Length = 99
# SantaFe Evals 15100: Best = -19.000000, Length = 99
# SantaFe Evals 16100: Best = -19.000000, Length = 99
# SantaFe Evals 17100: Best = -19.000000, Length = 99
# SantaFe Evals 18100: Best = -19.000000, Length = 99
# SantaFe Evals 19100: Best = -19.000000, Length = 99
# SantaFe Evals 20100: Best = -19.000000, Length = 99
# SantaFe Evals 21100: Best = -19.000000, Length = 99
# SantaFe Evals 22100: Best = -19.000000, Length = 99
# SantaFe Evals 23100: Best = -19.000000, Length = 99
# SantaFe Evals 24100: Best = -19.000000, Length = 99
# SantaFe Evals 25100: Best = -19.000000, Length = 99
# SantaFe Evals 26100: Best = -19.000000, Length = 99
# SantaFe Evals 27100: Best = -19.000000, Length = 99
# SantaFe Evals 28100: Best = -19.000000, Length = 99
# SantaFe Evals 29100: Best = -19.000000, Length = 99
# SantaFe Evals 30100: Best = -19.000000, Length = 99
# SantaFe Evals 31100: Best = -19.000000, Length = 99
# SantaFe Evals 32100: Best = -19.000000, Length = 99
# SantaFe Evals 33100: Best = -19.000000, Length = 99
# SantaFe Evals 34100: Best = -19.000000, Length = 99
# SantaFe Evals 35100: Best = -20.000000, Length = 99
# SantaFe Evals 36100: Best = -20.000000, Length = 99
# SantaFe Evals 37100: Best = -20.000000, Length = 99
# SantaFe Evals 38100: Best = -20.000000, Length = 99
# SantaFe Evals 39100: Best = -20.000000, Length = 99
# SantaFe Evals 40100: Best = -20.000000, Length = 99
# SantaFe Evals 41100: Best = -20.000000, Length = 99
# SantaFe Evals 42100: Best = -22.000000, Length = 100
# SantaFe Evals 43100: Best = -22.000000, Length = 100
# SantaFe Evals 44100: Best = -22.000000, Length = 100
# SantaFe Evals 45100: Best = -25.000000, Length = 100
# SantaFe Evals 46100: Best = -27.000000, Length = 100
# SantaFe Evals 47100: Best = -27.000000, Length = 100
# SantaFe Evals 48100: Best = -28.000000, Length = 100
# SantaFe Evals 49100: Best = -28.000000, Length = 100
# SantaFe Evals 50100: Best = -29.000000, Length = 100
# SantaFe Evals 51100: Best = -29.000000, Length = 100
# SantaFe Evals 52100: Best = -29.000000, Length = 100
# SantaFe Evals 53100: Best = -29.000000, Length = 100
# SantaFe Evals 54100: Best = -29.000000, Length = 100
# SantaFe Evals 55100: Best = -29.000000, Length = 100
# SantaFe Evals 56100: Best = -32.000000, Length = 100
# SantaFe Evals 57100: Best = -32.000000, Length = 100
# SantaFe Evals 58100: Best = -32.000000, Length = 100
# SantaFe Evals 59100: Best = -32.000000, Length = 100
# SantaFe Evals 60100: Best = -32.000000, Length = 100
# SantaFe Evals 61100: Best = -32.000000, Length = 100
# SantaFe Evals 62100: Best = -34.000000, Length = 100
# SantaFe Evals 63100: Best = -34.000000, Length = 100
# SantaFe Evals 64100: Best = -34.000000, Length = 100
# SantaFe Evals 65100: Best = -34.000000, Length = 100
# SantaFe Evals 66100: Best = -34.000000, Length = 100
# SantaFe Evals 67100: Best = -34.000000, Length = 100
# SantaFe Evals 68100: Best = -34.000000, Length = 100
# SantaFe Evals 69100: Best = -34.000000, Length = 100
# SantaFe Evals 70100: Best = -34.000000, Length = 100
# SantaFe Evals 71100: Best = -34.000000, Length = 100
# SantaFe Evals 72100: Best = -34.000000, Length = 100
# SantaFe Evals 73100: Best = -34.000000, Length = 100
# SantaFe Evals 74100: Best = -34.000000, Length = 100
# SantaFe Evals 75100: Best = -34.000000, Length = 100
# SantaFe Evals 76100: Best = -34.000000, Length = 100
# SantaFe Evals 77100: Best = -34.000000, Length = 100
# SantaFe Evals 78100: Best = -34.000000, Length = 100
# SantaFe Evals 79100: Best = -34.000000, Length = 100
# SantaFe Evals 80100: Best = -34.000000, Length = 100
# SantaFe Evals 81100: Best = -34.000000, Length = 100
# SantaFe Evals 82100: Best = -34.000000, Length = 100
# SantaFe Evals 83100: Best = -34.000000, Length = 100
# SantaFe Evals 84100: Best = -34.000000, Length = 100
# SantaFe Evals 85100: Best = -34.000000, Length = 100
# SantaFe Evals 86100: Best = -34.000000, Length = 100
# SantaFe Evals 87100: Best = -34.000000, Length = 100
# SantaFe Evals 88100: Best = -34.000000, Length = 100
# SantaFe Evals 89100: Best = -34.000000, Length = 100
# SantaFe Evals 90100: Best = -34.000000, Length = 100
# SantaFe Evals 91100: Best = -34.000000, Length = 100
# SantaFe Evals 92100: Best = -34.000000, Length = 100
# SantaFe Evals 93100: Best = -34.000000, Length = 100
# SantaFe Evals 94100: Best = -34.000000, Length = 100
# SantaFe Evals 95100: Best = -34.000000, Length = 100
# SantaFe Evals 96100: Best = -34.000000, Length = 100
# SantaFe Evals 97100: Best = -34.000000, Length = 100
# SantaFe Evals 98100: Best = -34.000000, Length = 100
# SantaFe Evals 99100: Best = -34.000000, Length = 100
# SantaFe Evals 100: Best = -4.000000, Length = 100
# SantaFe Evals 1100: Best = -14.000000, Length = 100
# SantaFe Evals 2100: Best = -19.000000, Length = 99
# SantaFe Evals 3100: Best = -19.000000, Length = 99
# SantaFe Evals 4100: Best = -22.000000, Length = 100
# SantaFe Evals 5100: Best = -24.000000, Length = 100
# SantaFe Evals 6100: Best = -24.000000, Length = 100
# SantaFe Evals 7100: Best = -24.000000, Length = 100
# SantaFe Evals 8100: Best = -24.000000, Length = 100
# SantaFe Evals 9100: Best = -24.000000, Length = 100
# SantaFe Evals 10100: Best = -24.000000, Length = 100
# SantaFe Evals 11100: Best = -24.000000, Length = 100
# SantaFe Evals 12100: Best = -24.000000, Length = 100
# SantaFe Evals 13100: Best = -24.000000, Length = 100
# SantaFe Evals 14100: Best = -24.000000, Length = 100
# SantaFe Evals 15100: Best = -24.000000, Length = 100
# SantaFe Evals 16100: Best = -24.000000, Length = 100
# SantaFe Evals 17100: Best = -24.000000, Length = 100
# SantaFe Evals 18100: Best = -24.000000, Length = 100
# SantaFe Evals 19100: Best = -25.000000, Length = 100
# SantaFe Evals 20100: Best = -25.000000, Length = 100
# SantaFe Evals 21100: Best = -27.000000, Length = 99
# SantaFe Evals 22100: Best = -29.000000, Length = 99
# SantaFe Evals 23100: Best = -29.000000, Length = 99
# SantaFe Evals 24100: Best = -29.000000, Length = 99
# SantaFe Evals 25100: Best = -29.000000, Length = 99
# SantaFe Evals 26100: Best = -29.000000, Length = 99
# SantaFe Evals 27100: Best = -29.000000, Length = 99
# SantaFe Evals 28100: Best = -29.000000, Length = 99
# SantaFe Evals 29100: Best = -29.000000, Length = 99
# SantaFe Evals 30100: Best = -29.000000, Length = 99
# SantaFe Evals 31100: Best = -29.000000, Length = 99
# SantaFe Evals 32100: Best = -29.000000, Length = 99
# SantaFe Evals 33100: Best = -29.000000, Length = 99
# SantaFe Evals 34100: Best = -31.000000, Length = 100
# SantaFe Evals 35100: Best = -31.000000, Length = 100
# SantaFe Evals 36100: Best = -31.000000, Length = 100
# SantaFe Evals 37100: Best = -31.000000, Length = 100
# SantaFe Evals 38100: Best = -31.000000, Length = 100
# SantaFe Evals 39100: Best = -31.000000, Length = 100
# SantaFe Evals 40100: Best = -31.000000, Length = 100
# SantaFe Evals 41100: Best = -31.000000, Length = 100
# SantaFe Evals 42100: Best = -31.000000, Length = 100
# SantaFe Evals 43100: Best = -31.000000, Length = 100
# SantaFe Evals 44100: Best = -31.000000, Length = 100
# SantaFe Evals 45100: Best = -31.000000, Length = 100
# SantaFe Evals 46100: Best = -31.000000, Length = 100
# SantaFe Evals 47100: Best = -31.000000, Length = 100
# SantaFe Evals 48100: Best = -31.000000, Length = 100
# SantaFe Evals 49100: Best = -31.000000, Length = 100
# SantaFe Evals 50100: Best = -31.000000, Length = 100
# SantaFe Evals 51100: Best = -31.000000, Length = 100
# SantaFe Evals 52100: Best = -31.000000, Length = 100
# SantaFe Evals 53100: Best = -31.000000, Length = 100
# SantaFe Evals 54100: Best = -31.000000, Length = 100
# SantaFe Evals 55100: Best = -31.000000, Length = 100
# SantaFe Evals 56100: Best = -31.000000, Length = 100
# SantaFe Evals 57100: Best = -31.000000, Length = 100
# SantaFe Evals 58100: Best = -31.000000, Length = 100
# SantaFe Evals 59100: Best = -31.000000, Length = 100
# SantaFe Evals 60100: Best = -31.000000, Length = 100
# SantaFe Evals 61100: Best = -31.000000, Length = 100
# SantaFe Evals 62100: Best = -31.000000, Length = 100
# SantaFe Evals 63100: Best = -31.000000, Length = 100
# SantaFe Evals 64100: Best = -31.000000, Length = 100
# SantaFe Evals 65100: Best = -31.000000, Length = 100
# SantaFe Evals 66100: Best = -31.000000, Length = 100
# SantaFe Evals 67100: Best = -31.000000, Length = 100
# SantaFe Evals 68100: Best = -31.000000, Length = 100
# SantaFe Evals 69100: Best = -31.000000, Length = 100
# SantaFe Evals 70100: Best = -31.000000, Length = 100
# SantaFe Evals 71100: Best = -31.000000, Length = 100
# SantaFe Evals 72100: Best = -31.000000, Length = 100
# SantaFe Evals 73100: Best = -31.000000, Length = 100
# SantaFe Evals 74100: Best = -31.000000, Length = 100
# SantaFe Evals 75100: Best = -31.000000, Length = 100
# SantaFe Evals 76100: Best = -31.000000, Length = 100
# SantaFe Evals 77100: Best = -31.000000, Length = 100
# SantaFe Evals 78100: Best = -31.000000, Length = 100
# SantaFe Evals 79100: Best = -31.000000, Length = 100
# SantaFe Evals 80100: Best = -31.000000, Length = 100
# SantaFe Evals 81100: Best = -31.000000, Length = 100
# SantaFe Evals 82100: Best = -31.000000, Length = 100
# SantaFe Evals 83100: Best = -31.000000, Length = 100
# SantaFe Evals 84100: Best = -31.000000, Length = 100
# SantaFe Evals 85100: Best = -31.000000, Length = 100
# SantaFe Evals 86100: Best = -31.000000, Length = 100
# SantaFe Evals 87100: Best = -31.000000, Length = 100
# SantaFe Evals 88100: Best = -32.000000, Length = 98
# SantaFe Evals 89100: Best = -33.000000, Length = 99
# SantaFe Evals 90100: Best = -33.000000, Length = 99
# SantaFe Evals 91100: Best = -33.000000, Length = 99
# SantaFe Evals 92100: Best = -33.000000, Length = 99
# SantaFe Evals 93100: Best = -33.000000, Length = 99
# SantaFe Evals 94100: Best = -33.000000, Length = 99
# SantaFe Evals 95100: Best = -33.000000, Length = 99
# SantaFe Evals 96100: Best = -33.000000, Length = 99
# SantaFe Evals 97100: Best = -33.000000, Length = 99
# SantaFe Evals 98100: Best = -33.000000, Length = 99
# SantaFe Evals 99100: Best = -33.000000, Length = 99
# Results written to GA_Variable_results_20250521_165813\GA_Variable_results.csv
