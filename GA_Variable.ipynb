# %%
import random
import numpy as np
import time
import math
import uuid
import csv
import os
from math import cos, exp, sqrt, pi

# %%
POP_SIZE = 100
N_EVALS = 100000
N_REPLICATES = 30
MIN_LEN = 3
MAX_LEN = 100
gene_low, gene_high = -2.0, 2.0

time_str = time.strftime('%Y%m%d_%H%M%S')
out_dir = f'GA_Variable_results_{time_str}'
os.makedirs(out_dir, exist_ok=True)
csv_summary = os.path.join(out_dir, 'GA_Variable_results.csv')
csv_history = os.path.join(out_dir, 'GA_Variable_history.csv')

# %%
def mkPenalizer(d_target, lam=10, deadzone=2):
    def _pen(ind):
        dev = abs(len(ind) - d_target)
        return 0 if dev <= deadzone else lam * dev
    return _pen

def loadSantaFeMap(path='santafe_trail.txt'):
    world_rows = []
    start_x = start_y = None
    with open(path) as f:
        for y, line in enumerate(f):
            row = []
            for x, c in enumerate(line.rstrip("\n")):
                if c == '#':
                    row.append(1)
                elif c in ('.','S'):
                    row.append(0)
                    if c == 'S':
                        start_x, start_y = x, y
                else:
                    continue
            if row:
                world_rows.append(row)
    if not world_rows:
        raise ValueError(f'No valid rows in Santa Fe map: {path}')
    H = len(world_rows)
    W = len(world_rows[0])
    for r in world_rows:
        if len(r) != W:
            raise ValueError('Inconsistent row lengths in Santa Fe map')
    world = [c for row in world_rows for c in row]
    if start_x is None or start_y is None:
        start_x = start_y = 0
    return world, W, H, start_x, start_y

world, W, H, START_X, START_Y = loadSantaFeMap()

# %%
def generateInd():
    length = random.randint(MIN_LEN, MAX_LEN)
    return [random.uniform(gene_low, gene_high) for _ in range(length)]

def initPop():
    return [generateInd() for _ in range(POP_SIZE)]

# %%
def sphere(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: sum(x**2 for x in ind) + pen(ind)

def rastrigin(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    return lambda ind: 10*len(ind) + sum(x**2 - 10*cos(2*pi*x) for x in ind) + pen(ind)

def griewank(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sum_sq = sum(x**2 for x in ind)
        prod_cos = np.prod([cos(x/sqrt(i+1)) for i,x in enumerate(ind)])
        return 1 + sum_sq/4000.0 - prod_cos + pen(ind)
    return f

def ackley(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        d = len(ind)
        sum_sq = sum(x**2 for x in ind)
        sum_cos = sum(cos(2*pi*x) for x in ind)
        term1 = -20 * exp(-0.2 * sqrt(sum_sq/d))
        term2 = -exp(sum_cos/d)
        return term1 + term2 + 20 + math.e + pen(ind)
    return f

def koza(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    x_vals = np.linspace(-1,1,20)
    def f(ind):
        err = 0.0
        for x in x_vals:
            y_t = x**4 + x**3 + x**2 + x
            y_p = sum(w*(x**i) for i,w in enumerate(ind))
            err += (y_p - y_t)**2
        return err + pen(ind)
    return f

def knapsack(d_target, lam, items, capacity):
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        sel = [int(round(x))%2 for x in ind[:len(items)]]
        w_sum = sum(w for (w,v),s in zip(items, sel) if s)
        v_sum = sum(v for (w,v),s in zip(items, sel) if s)
        over = max(0, w_sum - capacity)
        return -v_sum + 1000*over + pen(ind)
    return f

def parity(N, lam):
    d_target = 2**N
    pen = mkPenalizer(d_target, lam)
    def f(ind):
        table = [int(round(x))%2 for x in ind[:d_target]]
        errs = 0
        for i in range(d_target):
            target = bin(i).count('1') % 2
            if i < len(table):
                if table[i] != target:
                    errs += 1
            else:
                errs += 1
        return errs + pen(ind)
    return f

def santaFe(d_target, lam):
    pen = mkPenalizer(d_target, lam)
    def f(ind, max_steps=400):
        direction = 0
        x,y = START_X, START_Y
        food = 0
        visited = world.copy()
        idx = lambda xx,yy: (yy%H)*W + (xx%W)
        for i in range(min(len(ind), max_steps)):
            if visited[idx(x,y)] == 1:
                food += 1
                visited[idx(x,y)] = 0
            action = int(abs(ind[i])) % 3
            if action == 0:
                dx,dy = [(0,1),(1,0),(0,-1),(-1,0)][direction]
                x += dx; y += dy
            elif action == 1:
                direction = (direction + 1) % 4
            else:
                direction = (direction - 1) % 4
        return -food + pen(ind)
    return f

# %%
def tournamentSelection(pop, fit, k=3):
    sel = random.sample(pop, k)
    return min(sel, key=fit)

def rankSelection(pop, fit):
    spop = sorted(pop, key=fit)
    probs = np.linspace(1,0.1,POP_SIZE)
    probs /= probs.sum()
    return spop[np.random.choice(POP_SIZE, p=probs)]

def crossover(p1, p2, p_cross):
    if random.random() > p_cross:
        return p1[:], p2[:]
    cut1 = random.randint(1, len(p1)-1)
    cut2 = random.randint(1, len(p2)-1)
    c1 = p1[:cut1] + p2[cut2:]
    c2 = p2[:cut2] + p1[cut1:]
    for c in (c1,c2):
        while len(c) < MIN_LEN:
            c.append(random.uniform(gene_low, gene_high))
    return c1[:MAX_LEN], c2[:MAX_LEN]

def mutate(ind, p_mut):
    ind = ind[:]
    if random.random() < 0.3:
        if random.random() < 0.5 and len(ind) < MAX_LEN:
            ind.append(random.uniform(gene_low, gene_high))
        elif len(ind) > MIN_LEN:
            del ind[random.randrange(len(ind))]
    for i in range(len(ind)):
        if random.random() < p_mut:
            ind[i] += random.gauss(0,0.5)
            ind[i] = max(min(ind[i], gene_high), gene_low)
    return ind

# %%
def runGA(fit_func, name, selection='rank'):
    pop = initPop()
    evals = 0
    best_hist = []
    while evals < N_EVALS:
        new_pop = []
        gen_idx = len(best_hist)
        p_mut = 0.05 * (1 - gen_idx/(N_EVALS/POP_SIZE))
        p_cross = 0.8 * (1 - 0.5*gen_idx/(N_EVALS/POP_SIZE))
        elite = min(pop, key=fit_func)
        new_pop.append(elite)
        while len(new_pop) < POP_SIZE:
            if selection=='tournament':
                p1 = tournamentSelection(pop, fit_func)
                p2 = tournamentSelection(pop, fit_func)
            else:
                p1 = rankSelection(pop, fit_func)
                p2 = rankSelection(pop, fit_func)
            c1, c2 = crossover(p1,p2,p_cross)
            new_pop.append(mutate(c1,p_mut))
            if len(new_pop) < POP_SIZE:
                new_pop.append(mutate(c2,p_mut))
        pop = sorted(new_pop, key=fit_func)[:POP_SIZE]
        evals += POP_SIZE
        best = fit_func(elite)
        best_hist.append((evals, best))
        if gen_idx % 10 == 0:
            print(f'{name} Evals {evals}: Best = {best:.6f}, Len = {len(elite)}')
    return elite, best_hist

# %%
with open(csv_summary, 'w', newline='') as fs, open(csv_history, 'w', newline='') as fh:
    writer_sum = csv.DictWriter(fs, fieldnames=['run_id','benchmark','replicate','seed','best','len_final','cpu_s'])
    writer_hist = csv.DictWriter(fh, fieldnames=['run_id','benchmark','replicate','seed','evals','fitness'])
    writer_sum.writeheader()
    writer_hist.writeheader()

    tmp_items = [(random.randint(1,20), random.randint(10,100)) for _ in range(20)]
    benchmarks = {
        #'Sphere': sphere(30,10),
        #'Rastrigin': rastrigin(30,10),
        #'Griewank': griewank(30,10),
        'Ackley': ackley(30,10),
        'Koza': koza(10,10),
        'Knapsack': knapsack(20,0,tmp_items,50),
        'Parity': parity(6,10),
        'SantaFe': santaFe(100,10)
    }

    for name, func in benchmarks.items():
        if name == 'Ackley':
            N_REPLICATES = 13
        else:
            N_REPLICATES = 30
        for rep in range(N_REPLICATES):
            seed = random.randint(0,2**31-1)
            random.seed(seed)
            np.random.seed(seed)
            start = time.perf_counter()
            best_ind, history = runGA(func, name, selection='rank')
            cpu = time.perf_counter() - start
            run_id = uuid.uuid4()
            best_val = round(func(best_ind),6)
            writer_sum.writerow({
                'run_id': run_id,
                'benchmark': name,
                'replicate': rep,
                'seed': seed,
                'best': best_val,
                'len_final': len(best_ind),
                'cpu_s': round(cpu,4)
            })
            for ev, fitval in history:
                writer_hist.writerow({
                    'run_id': run_id,
                    'benchmark': name,
                    'replicate': rep,
                    'seed': seed,
                    'evals': ev,
                    'fitness': fitval
                })

print(f'Results written to {csv_summary} and history to {csv_history}')
# Out:
# Ackley Evals 100: Best = 5.273211, Len = 28
# Ackley Evals 1100: Best = 4.900826, Len = 30
# Ackley Evals 2100: Best = 4.760422, Len = 29
# Ackley Evals 3100: Best = 4.591233, Len = 28
# Ackley Evals 4100: Best = 4.180802, Len = 29
# Ackley Evals 5100: Best = 4.156643, Len = 28
# Ackley Evals 6100: Best = 4.085023, Len = 29
# Ackley Evals 7100: Best = 3.892520, Len = 29
# Ackley Evals 8100: Best = 3.821765, Len = 29
# Ackley Evals 9100: Best = 3.780349, Len = 29
# Ackley Evals 10100: Best = 3.780349, Len = 29
# Ackley Evals 11100: Best = 3.594735, Len = 29
# Ackley Evals 12100: Best = 3.594735, Len = 29
# Ackley Evals 13100: Best = 3.594735, Len = 29
# Ackley Evals 14100: Best = 3.536787, Len = 29
# Ackley Evals 15100: Best = 3.470279, Len = 31
# Ackley Evals 16100: Best = 3.373875, Len = 30
# Ackley Evals 17100: Best = 3.259877, Len = 28
# Ackley Evals 18100: Best = 3.218639, Len = 32
# Ackley Evals 19100: Best = 3.149877, Len = 32
# Ackley Evals 20100: Best = 3.017092, Len = 31
# Ackley Evals 21100: Best = 3.017092, Len = 31
# Ackley Evals 22100: Best = 2.916390, Len = 29
# Ackley Evals 23100: Best = 2.834998, Len = 30
# Ackley Evals 24100: Best = 2.668108, Len = 30
# Ackley Evals 25100: Best = 2.666737, Len = 30
# Ackley Evals 26100: Best = 2.604164, Len = 29
# Ackley Evals 27100: Best = 2.604164, Len = 29
# Ackley Evals 28100: Best = 2.602660, Len = 29
# Ackley Evals 29100: Best = 2.592329, Len = 29
# Ackley Evals 30100: Best = 2.435511, Len = 29
# Ackley Evals 31100: Best = 2.240514, Len = 31
# Ackley Evals 32100: Best = 2.240514, Len = 31
# Ackley Evals 33100: Best = 2.122760, Len = 29
# Ackley Evals 34100: Best = 1.992872, Len = 29
# Ackley Evals 35100: Best = 1.969365, Len = 29
# Ackley Evals 36100: Best = 1.573584, Len = 29
# Ackley Evals 37100: Best = 1.573584, Len = 29
# Ackley Evals 38100: Best = 1.573584, Len = 29
# Ackley Evals 39100: Best = 1.573584, Len = 29
# Ackley Evals 40100: Best = 1.504514, Len = 28
# Ackley Evals 41100: Best = 1.504514, Len = 28
# Ackley Evals 42100: Best = 1.392433, Len = 28
# Ackley Evals 43100: Best = 1.350925, Len = 29
# Ackley Evals 44100: Best = 1.350925, Len = 29
# Ackley Evals 45100: Best = 1.286291, Len = 29
# Ackley Evals 46100: Best = 1.286291, Len = 29
# Ackley Evals 47100: Best = 1.286291, Len = 29
# Ackley Evals 48100: Best = 1.241330, Len = 28
# Ackley Evals 49100: Best = 1.241330, Len = 28
# Ackley Evals 50100: Best = 1.241330, Len = 28
# Ackley Evals 51100: Best = 0.974969, Len = 30
# Ackley Evals 52100: Best = 0.936922, Len = 30
# Ackley Evals 53100: Best = 0.917121, Len = 29
# Ackley Evals 54100: Best = 0.917121, Len = 29
# Ackley Evals 55100: Best = 0.874259, Len = 29
# Ackley Evals 56100: Best = 0.867771, Len = 30
# Ackley Evals 57100: Best = 0.804817, Len = 29
# Ackley Evals 58100: Best = 0.780011, Len = 29
# Ackley Evals 59100: Best = 0.727526, Len = 28
# Ackley Evals 60100: Best = 0.718544, Len = 28
# Ackley Evals 61100: Best = 0.718544, Len = 28
# Ackley Evals 62100: Best = 0.689775, Len = 28
# Ackley Evals 63100: Best = 0.684575, Len = 28
# Ackley Evals 64100: Best = 0.684575, Len = 28
# Ackley Evals 65100: Best = 0.667059, Len = 28
# Ackley Evals 66100: Best = 0.667059, Len = 28
# Ackley Evals 67100: Best = 0.667059, Len = 28
# Ackley Evals 68100: Best = 0.651007, Len = 28
# Ackley Evals 69100: Best = 0.651007, Len = 28
# Ackley Evals 70100: Best = 0.637378, Len = 28
# Ackley Evals 71100: Best = 0.637378, Len = 28
# Ackley Evals 72100: Best = 0.637378, Len = 28
# Ackley Evals 73100: Best = 0.637378, Len = 28
# Ackley Evals 74100: Best = 0.606534, Len = 30
# Ackley Evals 75100: Best = 0.606534, Len = 30
# Ackley Evals 76100: Best = 0.606534, Len = 30
# Ackley Evals 77100: Best = 0.606534, Len = 30
# Ackley Evals 78100: Best = 0.521423, Len = 31
# Ackley Evals 79100: Best = 0.521423, Len = 31
# Ackley Evals 80100: Best = 0.521423, Len = 31
# Ackley Evals 81100: Best = 0.520888, Len = 30
# Ackley Evals 82100: Best = 0.455680, Len = 29
# Ackley Evals 83100: Best = 0.452242, Len = 28
# Ackley Evals 84100: Best = 0.452242, Len = 28
# Ackley Evals 85100: Best = 0.438066, Len = 31
# Ackley Evals 86100: Best = 0.403604, Len = 28
# Ackley Evals 87100: Best = 0.385155, Len = 32
# Ackley Evals 88100: Best = 0.374812, Len = 31
# Ackley Evals 89100: Best = 0.270596, Len = 32
# Ackley Evals 90100: Best = 0.270596, Len = 32
# Ackley Evals 91100: Best = 0.255858, Len = 31
# Ackley Evals 92100: Best = 0.252357, Len = 31
# Ackley Evals 93100: Best = 0.240117, Len = 30
# Ackley Evals 94100: Best = 0.238046, Len = 29
# Ackley Evals 95100: Best = 0.214614, Len = 29
# Ackley Evals 96100: Best = 0.191109, Len = 28
# Ackley Evals 97100: Best = 0.187395, Len = 28
# Ackley Evals 98100: Best = 0.140189, Len = 30
# Ackley Evals 99100: Best = 0.133775, Len = 29
# Ackley Evals 100: Best = 5.216773, Len = 29
# Ackley Evals 1100: Best = 4.720106, Len = 30
# Ackley Evals 2100: Best = 4.671451, Len = 29
# Ackley Evals 3100: Best = 4.385294, Len = 28
# Ackley Evals 4100: Best = 4.191352, Len = 29
# Ackley Evals 5100: Best = 4.115448, Len = 29
# Ackley Evals 6100: Best = 3.623821, Len = 32
# Ackley Evals 7100: Best = 3.623821, Len = 32
# Ackley Evals 8100: Best = 3.376029, Len = 28
# Ackley Evals 9100: Best = 3.376029, Len = 28
# Ackley Evals 10100: Best = 3.280701, Len = 28
# Ackley Evals 11100: Best = 3.194068, Len = 29
# Ackley Evals 12100: Best = 3.194068, Len = 29
# Ackley Evals 13100: Best = 3.194068, Len = 29
# Ackley Evals 14100: Best = 3.154387, Len = 29
# Ackley Evals 15100: Best = 3.004250, Len = 30
# Ackley Evals 16100: Best = 3.000856, Len = 30
# Ackley Evals 17100: Best = 2.758454, Len = 30
# Ackley Evals 18100: Best = 2.642725, Len = 30
# Ackley Evals 19100: Best = 2.642725, Len = 30
# Ackley Evals 20100: Best = 2.546258, Len = 29
# Ackley Evals 21100: Best = 2.546258, Len = 29
# Ackley Evals 22100: Best = 2.546258, Len = 29
# Ackley Evals 23100: Best = 2.546258, Len = 29
# Ackley Evals 24100: Best = 2.546258, Len = 29
# Ackley Evals 25100: Best = 2.546258, Len = 29
# Ackley Evals 26100: Best = 2.289052, Len = 30
# Ackley Evals 27100: Best = 2.250024, Len = 28
# Ackley Evals 28100: Best = 2.134959, Len = 28
# Ackley Evals 29100: Best = 2.134959, Len = 28
# Ackley Evals 30100: Best = 2.134959, Len = 28
# Ackley Evals 31100: Best = 2.126426, Len = 29
# Ackley Evals 32100: Best = 2.126426, Len = 29
# Ackley Evals 33100: Best = 2.089258, Len = 30
# Ackley Evals 34100: Best = 2.020544, Len = 28
# Ackley Evals 35100: Best = 1.960879, Len = 28
# Ackley Evals 36100: Best = 1.888342, Len = 30
# Ackley Evals 37100: Best = 1.721440, Len = 29
# Ackley Evals 38100: Best = 1.721440, Len = 29
# Ackley Evals 39100: Best = 1.721440, Len = 29
# Ackley Evals 40100: Best = 1.666183, Len = 28
# Ackley Evals 41100: Best = 1.472012, Len = 29
# Ackley Evals 42100: Best = 1.472012, Len = 29
# Ackley Evals 43100: Best = 1.472012, Len = 29
# Ackley Evals 44100: Best = 1.425737, Len = 28
# Ackley Evals 45100: Best = 1.425737, Len = 28
# Ackley Evals 46100: Best = 1.401694, Len = 31
# Ackley Evals 47100: Best = 1.390843, Len = 30
# Ackley Evals 48100: Best = 1.386451, Len = 29
# Ackley Evals 49100: Best = 1.384711, Len = 29
# Ackley Evals 50100: Best = 1.371979, Len = 28
# Ackley Evals 51100: Best = 0.949152, Len = 28
# Ackley Evals 52100: Best = 0.908435, Len = 30
# Ackley Evals 53100: Best = 0.908435, Len = 30
# Ackley Evals 54100: Best = 0.768588, Len = 31
# Ackley Evals 55100: Best = 0.768588, Len = 31
# Ackley Evals 56100: Best = 0.724945, Len = 31
# Ackley Evals 57100: Best = 0.690647, Len = 28
# Ackley Evals 58100: Best = 0.690647, Len = 28
# Ackley Evals 59100: Best = 0.675562, Len = 28
# Ackley Evals 60100: Best = 0.670493, Len = 28
# Ackley Evals 61100: Best = 0.668305, Len = 28
# Ackley Evals 62100: Best = 0.668305, Len = 28
# Ackley Evals 63100: Best = 0.668305, Len = 28
# Ackley Evals 64100: Best = 0.585162, Len = 28
# Ackley Evals 65100: Best = 0.585162, Len = 28
# Ackley Evals 66100: Best = 0.585162, Len = 28
# Ackley Evals 67100: Best = 0.585162, Len = 28
# Ackley Evals 68100: Best = 0.581228, Len = 28
# Ackley Evals 69100: Best = 0.556562, Len = 28
# Ackley Evals 70100: Best = 0.556562, Len = 28
# Ackley Evals 71100: Best = 0.495421, Len = 28
# Ackley Evals 72100: Best = 0.479330, Len = 30
# Ackley Evals 73100: Best = 0.325513, Len = 29
# Ackley Evals 74100: Best = 0.317399, Len = 31
# Ackley Evals 75100: Best = 0.303102, Len = 30
# Ackley Evals 76100: Best = 0.282688, Len = 29
# Ackley Evals 77100: Best = 0.282688, Len = 29
# Ackley Evals 78100: Best = 0.245471, Len = 31
# Ackley Evals 79100: Best = 0.245471, Len = 31
# Ackley Evals 80100: Best = 0.205111, Len = 31
# Ackley Evals 81100: Best = 0.197794, Len = 30
# Ackley Evals 82100: Best = 0.185350, Len = 29
# Ackley Evals 83100: Best = 0.184362, Len = 28
# Ackley Evals 84100: Best = 0.167528, Len = 28
# Ackley Evals 85100: Best = 0.167528, Len = 28
# Ackley Evals 86100: Best = 0.165345, Len = 29
# Ackley Evals 87100: Best = 0.165345, Len = 29
# Ackley Evals 88100: Best = 0.160633, Len = 31
# Ackley Evals 89100: Best = 0.153084, Len = 28
# Ackley Evals 90100: Best = 0.152070, Len = 28
# Ackley Evals 91100: Best = 0.146937, Len = 31
# Ackley Evals 92100: Best = 0.137426, Len = 29
# Ackley Evals 93100: Best = 0.132440, Len = 28
# Ackley Evals 94100: Best = 0.122363, Len = 32
# Ackley Evals 95100: Best = 0.112866, Len = 30
# Ackley Evals 96100: Best = 0.105470, Len = 29
# Ackley Evals 97100: Best = 0.102921, Len = 28
# Ackley Evals 98100: Best = 0.094455, Len = 30
# Ackley Evals 99100: Best = 0.091622, Len = 32
# Ackley Evals 100: Best = 5.487921, Len = 28
# Ackley Evals 1100: Best = 4.544222, Len = 28
# Ackley Evals 2100: Best = 4.426361, Len = 30
# Ackley Evals 3100: Best = 3.989748, Len = 30
# Ackley Evals 4100: Best = 3.820759, Len = 30
# Ackley Evals 5100: Best = 3.732686, Len = 29
# Ackley Evals 6100: Best = 3.676757, Len = 29
# Ackley Evals 7100: Best = 3.074155, Len = 29
# Ackley Evals 8100: Best = 3.014210, Len = 29
# Ackley Evals 9100: Best = 2.924611, Len = 29
# Ackley Evals 10100: Best = 2.639641, Len = 29
# Ackley Evals 11100: Best = 2.440095, Len = 28
# Ackley Evals 12100: Best = 2.440095, Len = 28
# Ackley Evals 13100: Best = 2.440095, Len = 28
# Ackley Evals 14100: Best = 2.392590, Len = 28
# Ackley Evals 15100: Best = 2.392590, Len = 28
# Ackley Evals 16100: Best = 2.392590, Len = 28
# Ackley Evals 17100: Best = 2.392590, Len = 28
# Ackley Evals 18100: Best = 2.392590, Len = 28
# Ackley Evals 19100: Best = 2.383252, Len = 28
# Ackley Evals 20100: Best = 2.343791, Len = 29
# Ackley Evals 21100: Best = 2.050200, Len = 28
# Ackley Evals 22100: Best = 1.998955, Len = 29
# Ackley Evals 23100: Best = 1.998955, Len = 29
# Ackley Evals 24100: Best = 1.998121, Len = 29
# Ackley Evals 25100: Best = 1.998121, Len = 29
# Ackley Evals 26100: Best = 1.953982, Len = 29
# Ackley Evals 27100: Best = 1.716578, Len = 29
# Ackley Evals 28100: Best = 1.716578, Len = 29
# Ackley Evals 29100: Best = 1.694076, Len = 29
# Ackley Evals 30100: Best = 1.694076, Len = 29
# Ackley Evals 31100: Best = 1.694076, Len = 29
# Ackley Evals 32100: Best = 1.619896, Len = 29
# Ackley Evals 33100: Best = 1.527872, Len = 28
# Ackley Evals 34100: Best = 1.512789, Len = 28
# Ackley Evals 35100: Best = 1.512789, Len = 28
# Ackley Evals 36100: Best = 1.512789, Len = 28
# Ackley Evals 37100: Best = 1.512789, Len = 28
# Ackley Evals 38100: Best = 1.334651, Len = 30
# Ackley Evals 39100: Best = 1.334651, Len = 30
# Ackley Evals 40100: Best = 1.334651, Len = 30
# Ackley Evals 41100: Best = 1.280851, Len = 30
# Ackley Evals 42100: Best = 1.280851, Len = 30
# Ackley Evals 43100: Best = 1.280851, Len = 30
# Ackley Evals 44100: Best = 1.261089, Len = 30
# Ackley Evals 45100: Best = 1.261089, Len = 30
# Ackley Evals 46100: Best = 0.784947, Len = 30
# Ackley Evals 47100: Best = 0.725960, Len = 29
# Ackley Evals 48100: Best = 0.725960, Len = 29
# Ackley Evals 49100: Best = 0.725960, Len = 29
# Ackley Evals 50100: Best = 0.725960, Len = 29
# Ackley Evals 51100: Best = 0.701489, Len = 28
# Ackley Evals 52100: Best = 0.701489, Len = 28
# Ackley Evals 53100: Best = 0.701489, Len = 28
# Ackley Evals 54100: Best = 0.674813, Len = 28
# Ackley Evals 55100: Best = 0.664565, Len = 30
# Ackley Evals 56100: Best = 0.633369, Len = 28
# Ackley Evals 57100: Best = 0.586833, Len = 31
# Ackley Evals 58100: Best = 0.579636, Len = 29
# Ackley Evals 59100: Best = 0.579636, Len = 29
# Ackley Evals 60100: Best = 0.550557, Len = 31
# Ackley Evals 61100: Best = 0.532011, Len = 31
# Ackley Evals 62100: Best = 0.532011, Len = 31
# Ackley Evals 63100: Best = 0.529041, Len = 30
# Ackley Evals 64100: Best = 0.529041, Len = 30
# Ackley Evals 65100: Best = 0.491166, Len = 30
# Ackley Evals 66100: Best = 0.491166, Len = 30
# Ackley Evals 67100: Best = 0.491166, Len = 30
# Ackley Evals 68100: Best = 0.462915, Len = 29
# Ackley Evals 69100: Best = 0.462915, Len = 29
# Ackley Evals 70100: Best = 0.437330, Len = 29
# Ackley Evals 71100: Best = 0.437330, Len = 29
# Ackley Evals 72100: Best = 0.418993, Len = 28
# Ackley Evals 73100: Best = 0.418993, Len = 28
# Ackley Evals 74100: Best = 0.418993, Len = 28
# Ackley Evals 75100: Best = 0.418993, Len = 28
# Ackley Evals 76100: Best = 0.418993, Len = 28
# Ackley Evals 77100: Best = 0.413243, Len = 28
# Ackley Evals 78100: Best = 0.413243, Len = 28
# Ackley Evals 79100: Best = 0.410314, Len = 28
# Ackley Evals 80100: Best = 0.410314, Len = 28
# Ackley Evals 81100: Best = 0.410314, Len = 28
# Ackley Evals 82100: Best = 0.345401, Len = 28
# Ackley Evals 83100: Best = 0.318716, Len = 28
# Ackley Evals 84100: Best = 0.250351, Len = 30
# Ackley Evals 85100: Best = 0.245931, Len = 29
# Ackley Evals 86100: Best = 0.245931, Len = 29
# Ackley Evals 87100: Best = 0.245931, Len = 29
# Ackley Evals 88100: Best = 0.218053, Len = 30
# Ackley Evals 89100: Best = 0.203018, Len = 29
# Ackley Evals 90100: Best = 0.203018, Len = 29
# Ackley Evals 91100: Best = 0.160480, Len = 29
# Ackley Evals 92100: Best = 0.122668, Len = 28
# Ackley Evals 93100: Best = 0.122668, Len = 28
# Ackley Evals 94100: Best = 0.119300, Len = 29
# Ackley Evals 95100: Best = 0.115184, Len = 31
# Ackley Evals 96100: Best = 0.097002, Len = 29
# Ackley Evals 97100: Best = 0.096847, Len = 28
# Ackley Evals 98100: Best = 0.096847, Len = 28
# Ackley Evals 99100: Best = 0.086284, Len = 32
# Ackley Evals 100: Best = 5.195836, Len = 30
# Ackley Evals 1100: Best = 5.014016, Len = 29
# Ackley Evals 2100: Best = 4.827421, Len = 28
# Ackley Evals 3100: Best = 4.790429, Len = 28
# Ackley Evals 4100: Best = 4.357773, Len = 29
# Ackley Evals 5100: Best = 4.272745, Len = 31
# Ackley Evals 6100: Best = 4.176877, Len = 31
# Ackley Evals 7100: Best = 4.097473, Len = 31
# Ackley Evals 8100: Best = 3.967750, Len = 30
# Ackley Evals 9100: Best = 3.897914, Len = 28
# Ackley Evals 10100: Best = 3.813980, Len = 28
# Ackley Evals 11100: Best = 3.813980, Len = 28
# Ackley Evals 12100: Best = 3.567140, Len = 29
# Ackley Evals 13100: Best = 3.567140, Len = 29
# Ackley Evals 14100: Best = 3.521595, Len = 31
# Ackley Evals 15100: Best = 3.521595, Len = 31
# Ackley Evals 16100: Best = 3.369147, Len = 30
# Ackley Evals 17100: Best = 3.332973, Len = 31
# Ackley Evals 18100: Best = 3.332973, Len = 31
# Ackley Evals 19100: Best = 3.315334, Len = 28
# Ackley Evals 20100: Best = 3.315334, Len = 28
# Ackley Evals 21100: Best = 3.315334, Len = 28
# Ackley Evals 22100: Best = 3.237863, Len = 31
# Ackley Evals 23100: Best = 2.953173, Len = 28
# Ackley Evals 24100: Best = 2.953173, Len = 28
# Ackley Evals 25100: Best = 2.930193, Len = 32
# Ackley Evals 26100: Best = 2.930193, Len = 32
# Ackley Evals 27100: Best = 2.850933, Len = 29
# Ackley Evals 28100: Best = 2.727392, Len = 29
# Ackley Evals 29100: Best = 2.517469, Len = 28
# Ackley Evals 30100: Best = 2.368639, Len = 28
# Ackley Evals 31100: Best = 2.364296, Len = 28
# Ackley Evals 32100: Best = 2.340503, Len = 28
# Ackley Evals 33100: Best = 2.340503, Len = 28
# Ackley Evals 34100: Best = 2.340503, Len = 28
# Ackley Evals 35100: Best = 2.295204, Len = 29
# Ackley Evals 36100: Best = 2.037033, Len = 29
# Ackley Evals 37100: Best = 2.037033, Len = 29
# Ackley Evals 38100: Best = 2.037033, Len = 29
# Ackley Evals 39100: Best = 2.014073, Len = 29
# Ackley Evals 40100: Best = 1.977599, Len = 28
# Ackley Evals 41100: Best = 1.977599, Len = 28
# Ackley Evals 42100: Best = 1.977599, Len = 28
# Ackley Evals 43100: Best = 1.951428, Len = 28
# Ackley Evals 44100: Best = 1.865797, Len = 28
# Ackley Evals 45100: Best = 1.865797, Len = 28
# Ackley Evals 46100: Best = 1.865797, Len = 28
# Ackley Evals 47100: Best = 1.865797, Len = 28
# Ackley Evals 48100: Best = 1.865797, Len = 28
# Ackley Evals 49100: Best = 1.862487, Len = 28
# Ackley Evals 50100: Best = 1.862108, Len = 28
# Ackley Evals 51100: Best = 1.822759, Len = 28
# Ackley Evals 52100: Best = 1.822759, Len = 28
# Ackley Evals 53100: Best = 1.822759, Len = 28
# Ackley Evals 54100: Best = 1.822759, Len = 28
# Ackley Evals 55100: Best = 1.716885, Len = 30
# Ackley Evals 56100: Best = 1.573284, Len = 30
# Ackley Evals 57100: Best = 1.573284, Len = 30
# Ackley Evals 58100: Best = 1.573284, Len = 30
# Ackley Evals 59100: Best = 1.573284, Len = 30
# Ackley Evals 60100: Best = 1.573284, Len = 30
# Ackley Evals 61100: Best = 1.568989, Len = 30
# Ackley Evals 62100: Best = 1.549989, Len = 30
# Ackley Evals 63100: Best = 1.549989, Len = 30
# Ackley Evals 64100: Best = 1.472084, Len = 30
# Ackley Evals 65100: Best = 1.374785, Len = 32
# Ackley Evals 66100: Best = 1.374785, Len = 32
# Ackley Evals 67100: Best = 0.790379, Len = 29
# Ackley Evals 68100: Best = 0.787822, Len = 29
# Ackley Evals 69100: Best = 0.787483, Len = 29
# Ackley Evals 70100: Best = 0.787483, Len = 29
# Ackley Evals 71100: Best = 0.766144, Len = 31
# Ackley Evals 72100: Best = 0.766144, Len = 31
# Ackley Evals 73100: Best = 0.565708, Len = 28
# Ackley Evals 74100: Best = 0.565708, Len = 28
# Ackley Evals 75100: Best = 0.565708, Len = 28
# Ackley Evals 76100: Best = 0.550669, Len = 30
# Ackley Evals 77100: Best = 0.464785, Len = 30
# Ackley Evals 78100: Best = 0.464785, Len = 30
# Ackley Evals 79100: Best = 0.352165, Len = 30
# Ackley Evals 80100: Best = 0.348081, Len = 28
# Ackley Evals 81100: Best = 0.322114, Len = 29
# Ackley Evals 82100: Best = 0.322114, Len = 29
# Ackley Evals 83100: Best = 0.304833, Len = 31
# Ackley Evals 84100: Best = 0.290480, Len = 29
# Ackley Evals 85100: Best = 0.290480, Len = 29
# Ackley Evals 86100: Best = 0.282621, Len = 32
# Ackley Evals 87100: Best = 0.282621, Len = 32
# Ackley Evals 88100: Best = 0.264503, Len = 28
# Ackley Evals 89100: Best = 0.256601, Len = 30
# Ackley Evals 90100: Best = 0.246757, Len = 30
# Ackley Evals 91100: Best = 0.234808, Len = 29
# Ackley Evals 92100: Best = 0.223874, Len = 29
# Ackley Evals 93100: Best = 0.211500, Len = 29
# Ackley Evals 94100: Best = 0.174519, Len = 28
# Ackley Evals 95100: Best = 0.174519, Len = 28
# Ackley Evals 96100: Best = 0.151227, Len = 30
# Ackley Evals 97100: Best = 0.133283, Len = 30
# Ackley Evals 98100: Best = 0.125540, Len = 30
# Ackley Evals 99100: Best = 0.111888, Len = 28
# Ackley Evals 100: Best = 5.048261, Len = 30
# Ackley Evals 1100: Best = 4.847313, Len = 31
# Ackley Evals 2100: Best = 4.338106, Len = 29
# Ackley Evals 3100: Best = 4.338106, Len = 29
# Ackley Evals 4100: Best = 4.206653, Len = 29
# Ackley Evals 5100: Best = 3.923526, Len = 32
# Ackley Evals 6100: Best = 3.904473, Len = 32
# Ackley Evals 7100: Best = 3.767724, Len = 32
# Ackley Evals 8100: Best = 3.641449, Len = 31
# Ackley Evals 9100: Best = 3.622766, Len = 30
# Ackley Evals 10100: Best = 3.618274, Len = 30
# Ackley Evals 11100: Best = 3.344511, Len = 30
# Ackley Evals 12100: Best = 3.297102, Len = 30
# Ackley Evals 13100: Best = 3.281327, Len = 31
# Ackley Evals 14100: Best = 3.207197, Len = 31
# Ackley Evals 15100: Best = 3.207197, Len = 31
# Ackley Evals 16100: Best = 3.160766, Len = 31
# Ackley Evals 17100: Best = 3.142202, Len = 31
# Ackley Evals 18100: Best = 3.042692, Len = 29
# Ackley Evals 19100: Best = 3.017811, Len = 29
# Ackley Evals 20100: Best = 2.936418, Len = 28
# Ackley Evals 21100: Best = 2.936418, Len = 28
# Ackley Evals 22100: Best = 2.907927, Len = 28
# Ackley Evals 23100: Best = 2.750589, Len = 29
# Ackley Evals 24100: Best = 2.718513, Len = 29
# Ackley Evals 25100: Best = 2.718513, Len = 29
# Ackley Evals 26100: Best = 2.621402, Len = 28
# Ackley Evals 27100: Best = 2.486551, Len = 29
# Ackley Evals 28100: Best = 2.297307, Len = 28
# Ackley Evals 29100: Best = 2.294088, Len = 28
# Ackley Evals 30100: Best = 2.294088, Len = 28
# Ackley Evals 31100: Best = 2.284835, Len = 29
# Ackley Evals 32100: Best = 2.244840, Len = 28
# Ackley Evals 33100: Best = 2.214015, Len = 28
# Ackley Evals 34100: Best = 2.181374, Len = 28
# Ackley Evals 35100: Best = 1.956311, Len = 28
# Ackley Evals 36100: Best = 1.950551, Len = 28
# Ackley Evals 37100: Best = 1.834476, Len = 28
# Ackley Evals 38100: Best = 1.834476, Len = 28
# Ackley Evals 39100: Best = 1.834476, Len = 28
# Ackley Evals 40100: Best = 1.829919, Len = 28
# Ackley Evals 41100: Best = 1.710616, Len = 29
# Ackley Evals 42100: Best = 1.710616, Len = 29
# Ackley Evals 43100: Best = 1.661202, Len = 29
# Ackley Evals 44100: Best = 1.408449, Len = 28
# Ackley Evals 45100: Best = 1.407512, Len = 28
# Ackley Evals 46100: Best = 1.393699, Len = 28
# Ackley Evals 47100: Best = 1.322159, Len = 30
# Ackley Evals 48100: Best = 1.322159, Len = 30
# Ackley Evals 49100: Best = 1.278644, Len = 30
# Ackley Evals 50100: Best = 1.232871, Len = 30
# Ackley Evals 51100: Best = 1.051931, Len = 30
# Ackley Evals 52100: Best = 1.051931, Len = 30
# Ackley Evals 53100: Best = 1.002024, Len = 32
# Ackley Evals 54100: Best = 0.998022, Len = 31
# Ackley Evals 55100: Best = 0.936639, Len = 29
# Ackley Evals 56100: Best = 0.837345, Len = 31
# Ackley Evals 57100: Best = 0.780222, Len = 29
# Ackley Evals 58100: Best = 0.762536, Len = 28
# Ackley Evals 59100: Best = 0.762536, Len = 28
# Ackley Evals 60100: Best = 0.757683, Len = 28
# Ackley Evals 61100: Best = 0.757683, Len = 28
# Ackley Evals 62100: Best = 0.757683, Len = 28
# Ackley Evals 63100: Best = 0.757683, Len = 28
# Ackley Evals 64100: Best = 0.757683, Len = 28
# Ackley Evals 65100: Best = 0.757683, Len = 28
# Ackley Evals 66100: Best = 0.757683, Len = 28
# Ackley Evals 67100: Best = 0.757683, Len = 28
# Ackley Evals 68100: Best = 0.757683, Len = 28
# Ackley Evals 69100: Best = 0.757683, Len = 28
# Ackley Evals 70100: Best = 0.683774, Len = 28
# Ackley Evals 71100: Best = 0.643292, Len = 32
# Ackley Evals 72100: Best = 0.619422, Len = 32
# Ackley Evals 73100: Best = 0.572250, Len = 31
# Ackley Evals 74100: Best = 0.557836, Len = 29
# Ackley Evals 75100: Best = 0.493529, Len = 28
# Ackley Evals 76100: Best = 0.493529, Len = 28
# Ackley Evals 77100: Best = 0.481923, Len = 29
# Ackley Evals 78100: Best = 0.479244, Len = 28
# Ackley Evals 79100: Best = 0.468018, Len = 29
# Ackley Evals 80100: Best = 0.463195, Len = 30
# Ackley Evals 81100: Best = 0.426810, Len = 31
# Ackley Evals 82100: Best = 0.425402, Len = 30
# Ackley Evals 83100: Best = 0.425402, Len = 30
# Ackley Evals 84100: Best = 0.405881, Len = 32
# Ackley Evals 85100: Best = 0.250538, Len = 31
# Ackley Evals 86100: Best = 0.250538, Len = 31
# Ackley Evals 87100: Best = 0.214541, Len = 30
# Ackley Evals 88100: Best = 0.207862, Len = 29
# Ackley Evals 89100: Best = 0.201055, Len = 29
# Ackley Evals 90100: Best = 0.155847, Len = 28
# Ackley Evals 91100: Best = 0.155847, Len = 28
# Ackley Evals 92100: Best = 0.142363, Len = 30
# Ackley Evals 93100: Best = 0.131490, Len = 31
# Ackley Evals 94100: Best = 0.131490, Len = 31
# Ackley Evals 95100: Best = 0.131490, Len = 31
# Ackley Evals 96100: Best = 0.123685, Len = 32
# Ackley Evals 97100: Best = 0.112346, Len = 31
# Ackley Evals 98100: Best = 0.082378, Len = 29
# Ackley Evals 99100: Best = 0.067272, Len = 32
# Ackley Evals 100: Best = 6.146844, Len = 28
# Ackley Evals 1100: Best = 5.039711, Len = 29
# Ackley Evals 2100: Best = 4.938797, Len = 29
# Ackley Evals 3100: Best = 4.604976, Len = 29
# Ackley Evals 4100: Best = 4.530609, Len = 29
# Ackley Evals 5100: Best = 4.115459, Len = 28
# Ackley Evals 6100: Best = 4.006771, Len = 29
# Ackley Evals 7100: Best = 3.905571, Len = 28
# Ackley Evals 8100: Best = 3.772192, Len = 29
# Ackley Evals 9100: Best = 3.611092, Len = 29
# Ackley Evals 10100: Best = 3.437493, Len = 31
# Ackley Evals 11100: Best = 3.271383, Len = 29
# Ackley Evals 12100: Best = 3.165660, Len = 31
# Ackley Evals 13100: Best = 2.902881, Len = 32
# Ackley Evals 14100: Best = 2.816366, Len = 32
# Ackley Evals 15100: Best = 2.716383, Len = 32
# Ackley Evals 16100: Best = 2.521644, Len = 30
# Ackley Evals 17100: Best = 2.441082, Len = 30
# Ackley Evals 18100: Best = 2.426602, Len = 29
# Ackley Evals 19100: Best = 2.140801, Len = 30
# Ackley Evals 20100: Best = 2.056333, Len = 29
# Ackley Evals 21100: Best = 2.056333, Len = 29
# Ackley Evals 22100: Best = 2.056333, Len = 29
# Ackley Evals 23100: Best = 2.056333, Len = 29
# Ackley Evals 24100: Best = 2.056333, Len = 29
# Ackley Evals 25100: Best = 1.956202, Len = 29
# Ackley Evals 26100: Best = 1.772012, Len = 32
# Ackley Evals 27100: Best = 1.772012, Len = 32
# Ackley Evals 28100: Best = 1.743379, Len = 32
# Ackley Evals 29100: Best = 1.743379, Len = 32
# Ackley Evals 30100: Best = 1.648958, Len = 32
# Ackley Evals 31100: Best = 1.648958, Len = 32
# Ackley Evals 32100: Best = 1.617653, Len = 32
# Ackley Evals 33100: Best = 1.617653, Len = 32
# Ackley Evals 34100: Best = 1.603709, Len = 31
# Ackley Evals 35100: Best = 1.603709, Len = 31
# Ackley Evals 36100: Best = 1.516544, Len = 28
# Ackley Evals 37100: Best = 1.281802, Len = 29
# Ackley Evals 38100: Best = 1.272537, Len = 28
# Ackley Evals 39100: Best = 1.271117, Len = 29
# Ackley Evals 40100: Best = 1.216174, Len = 29
# Ackley Evals 41100: Best = 1.171749, Len = 29
# Ackley Evals 42100: Best = 1.149292, Len = 30
# Ackley Evals 43100: Best = 0.996123, Len = 28
# Ackley Evals 44100: Best = 0.980507, Len = 28
# Ackley Evals 45100: Best = 0.980507, Len = 28
# Ackley Evals 46100: Best = 0.928893, Len = 28
# Ackley Evals 47100: Best = 0.928893, Len = 28
# Ackley Evals 48100: Best = 0.791014, Len = 28
# Ackley Evals 49100: Best = 0.791014, Len = 28
# Ackley Evals 50100: Best = 0.791014, Len = 28
# Ackley Evals 51100: Best = 0.791014, Len = 28
# Ackley Evals 52100: Best = 0.791014, Len = 28
# Ackley Evals 53100: Best = 0.791014, Len = 28
# Ackley Evals 54100: Best = 0.791014, Len = 28
# Ackley Evals 55100: Best = 0.783555, Len = 28
# Ackley Evals 56100: Best = 0.783555, Len = 28
# Ackley Evals 57100: Best = 0.783555, Len = 28
# Ackley Evals 58100: Best = 0.783555, Len = 28
# Ackley Evals 59100: Best = 0.783555, Len = 28
# Ackley Evals 60100: Best = 0.783555, Len = 28
# Ackley Evals 61100: Best = 0.783555, Len = 28
# Ackley Evals 62100: Best = 0.780793, Len = 28
# Ackley Evals 63100: Best = 0.765269, Len = 28
# Ackley Evals 64100: Best = 0.653125, Len = 32
# Ackley Evals 65100: Best = 0.617862, Len = 32
# Ackley Evals 66100: Best = 0.617862, Len = 32
# Ackley Evals 67100: Best = 0.617862, Len = 32
# Ackley Evals 68100: Best = 0.596672, Len = 32
# Ackley Evals 69100: Best = 0.548504, Len = 29
# Ackley Evals 70100: Best = 0.548504, Len = 29
# Ackley Evals 71100: Best = 0.548504, Len = 29
# Ackley Evals 72100: Best = 0.548504, Len = 29
# Ackley Evals 73100: Best = 0.454195, Len = 29
# Ackley Evals 74100: Best = 0.454195, Len = 29
# Ackley Evals 75100: Best = 0.454195, Len = 29
# Ackley Evals 76100: Best = 0.414115, Len = 30
# Ackley Evals 77100: Best = 0.336889, Len = 28
# Ackley Evals 78100: Best = 0.336889, Len = 28
# Ackley Evals 79100: Best = 0.293068, Len = 29
# Ackley Evals 80100: Best = 0.279684, Len = 28
# Ackley Evals 81100: Best = 0.277386, Len = 28
# Ackley Evals 82100: Best = 0.277386, Len = 28
# Ackley Evals 83100: Best = 0.277386, Len = 28
# Ackley Evals 84100: Best = 0.235342, Len = 29
# Ackley Evals 85100: Best = 0.234974, Len = 28
# Ackley Evals 86100: Best = 0.204797, Len = 32
# Ackley Evals 87100: Best = 0.199904, Len = 32
# Ackley Evals 88100: Best = 0.169744, Len = 31
# Ackley Evals 89100: Best = 0.158740, Len = 29
# Ackley Evals 90100: Best = 0.158740, Len = 29
# Ackley Evals 91100: Best = 0.151627, Len = 29
# Ackley Evals 92100: Best = 0.144620, Len = 29
# Ackley Evals 93100: Best = 0.111266, Len = 30
# Ackley Evals 94100: Best = 0.111266, Len = 30
# Ackley Evals 95100: Best = 0.093134, Len = 28
# Ackley Evals 96100: Best = 0.083608, Len = 28
# Ackley Evals 97100: Best = 0.080301, Len = 30
# Ackley Evals 98100: Best = 0.071538, Len = 29
# Ackley Evals 99100: Best = 0.066586, Len = 29
# Ackley Evals 100: Best = 5.705139, Len = 32
# Ackley Evals 1100: Best = 5.036712, Len = 30
# Ackley Evals 2100: Best = 4.639320, Len = 29
# Ackley Evals 3100: Best = 4.249151, Len = 30
# Ackley Evals 4100: Best = 3.633373, Len = 31
# Ackley Evals 5100: Best = 3.633373, Len = 31
# Ackley Evals 6100: Best = 3.633373, Len = 31
# Ackley Evals 7100: Best = 3.532704, Len = 32
# Ackley Evals 8100: Best = 3.499850, Len = 32
# Ackley Evals 9100: Best = 3.499850, Len = 32
# Ackley Evals 10100: Best = 3.499850, Len = 32
# Ackley Evals 11100: Best = 3.499850, Len = 32
# Ackley Evals 12100: Best = 3.499850, Len = 32
# Ackley Evals 13100: Best = 3.396661, Len = 32
# Ackley Evals 14100: Best = 3.353501, Len = 31
# Ackley Evals 15100: Best = 3.353501, Len = 31
# Ackley Evals 16100: Best = 3.353501, Len = 31
# Ackley Evals 17100: Best = 3.279032, Len = 32
# Ackley Evals 18100: Best = 3.238364, Len = 32
# Ackley Evals 19100: Best = 3.150744, Len = 30
# Ackley Evals 20100: Best = 3.150744, Len = 30
# Ackley Evals 21100: Best = 3.150744, Len = 30
# Ackley Evals 22100: Best = 3.076013, Len = 29
# Ackley Evals 23100: Best = 3.076013, Len = 29
# Ackley Evals 24100: Best = 3.062095, Len = 29
# Ackley Evals 25100: Best = 2.999443, Len = 29
# Ackley Evals 26100: Best = 2.999443, Len = 29
# Ackley Evals 27100: Best = 2.979566, Len = 29
# Ackley Evals 28100: Best = 2.979566, Len = 29
# Ackley Evals 29100: Best = 2.807313, Len = 28
# Ackley Evals 30100: Best = 2.807313, Len = 28
# Ackley Evals 31100: Best = 2.776683, Len = 28
# Ackley Evals 32100: Best = 2.643557, Len = 31
# Ackley Evals 33100: Best = 2.545814, Len = 30
# Ackley Evals 34100: Best = 2.545814, Len = 30
# Ackley Evals 35100: Best = 2.502413, Len = 30
# Ackley Evals 36100: Best = 2.404890, Len = 31
# Ackley Evals 37100: Best = 2.404890, Len = 31
# Ackley Evals 38100: Best = 2.251888, Len = 30
# Ackley Evals 39100: Best = 2.251888, Len = 30
# Ackley Evals 40100: Best = 1.995724, Len = 28
# Ackley Evals 41100: Best = 1.995724, Len = 28
# Ackley Evals 42100: Best = 1.995724, Len = 28
# Ackley Evals 43100: Best = 1.936389, Len = 28
# Ackley Evals 44100: Best = 1.785765, Len = 28
# Ackley Evals 45100: Best = 1.784017, Len = 28
# Ackley Evals 46100: Best = 1.784017, Len = 28
# Ackley Evals 47100: Best = 1.725211, Len = 28
# Ackley Evals 48100: Best = 1.718898, Len = 28
# Ackley Evals 49100: Best = 1.718898, Len = 28
# Ackley Evals 50100: Best = 1.587595, Len = 29
# Ackley Evals 51100: Best = 1.358313, Len = 29
# Ackley Evals 52100: Best = 1.358313, Len = 29
# Ackley Evals 53100: Best = 1.358313, Len = 29
# Ackley Evals 54100: Best = 1.358313, Len = 29
# Ackley Evals 55100: Best = 1.254782, Len = 30
# Ackley Evals 56100: Best = 1.111757, Len = 29
# Ackley Evals 57100: Best = 1.111757, Len = 29
# Ackley Evals 58100: Best = 1.111757, Len = 29
# Ackley Evals 59100: Best = 1.080556, Len = 28
# Ackley Evals 60100: Best = 1.080556, Len = 28
# Ackley Evals 61100: Best = 1.080556, Len = 28
# Ackley Evals 62100: Best = 1.080556, Len = 28
# Ackley Evals 63100: Best = 1.080556, Len = 28
# Ackley Evals 64100: Best = 0.845934, Len = 28
# Ackley Evals 65100: Best = 0.626232, Len = 29
# Ackley Evals 66100: Best = 0.626232, Len = 29
# Ackley Evals 67100: Best = 0.624735, Len = 29
# Ackley Evals 68100: Best = 0.617703, Len = 28
# Ackley Evals 69100: Best = 0.617698, Len = 28
# Ackley Evals 70100: Best = 0.617698, Len = 28
# Ackley Evals 71100: Best = 0.609943, Len = 28
# Ackley Evals 72100: Best = 0.609943, Len = 28
# Ackley Evals 73100: Best = 0.609943, Len = 28
# Ackley Evals 74100: Best = 0.559263, Len = 29
# Ackley Evals 75100: Best = 0.492554, Len = 28
# Ackley Evals 76100: Best = 0.470631, Len = 28
# Ackley Evals 77100: Best = 0.470631, Len = 28
# Ackley Evals 78100: Best = 0.468844, Len = 28
# Ackley Evals 79100: Best = 0.468844, Len = 28
# Ackley Evals 80100: Best = 0.468844, Len = 28
# Ackley Evals 81100: Best = 0.389220, Len = 28
# Ackley Evals 82100: Best = 0.385634, Len = 31
# Ackley Evals 83100: Best = 0.377874, Len = 30
# Ackley Evals 84100: Best = 0.336744, Len = 29
# Ackley Evals 85100: Best = 0.336744, Len = 29
# Ackley Evals 86100: Best = 0.335046, Len = 28
# Ackley Evals 87100: Best = 0.335046, Len = 28
# Ackley Evals 88100: Best = 0.323184, Len = 28
# Ackley Evals 89100: Best = 0.323184, Len = 28
# Ackley Evals 90100: Best = 0.323184, Len = 28
# Ackley Evals 91100: Best = 0.318628, Len = 30
# Ackley Evals 92100: Best = 0.318628, Len = 30
# Ackley Evals 93100: Best = 0.264363, Len = 31
# Ackley Evals 94100: Best = 0.264363, Len = 31
# Ackley Evals 95100: Best = 0.255795, Len = 29
# Ackley Evals 96100: Best = 0.250648, Len = 28
# Ackley Evals 97100: Best = 0.250648, Len = 28
# Ackley Evals 98100: Best = 0.222959, Len = 28
# Ackley Evals 99100: Best = 0.212558, Len = 28
# Ackley Evals 100: Best = 5.805152, Len = 31
# Ackley Evals 1100: Best = 5.077962, Len = 28
# Ackley Evals 2100: Best = 4.886962, Len = 31
# Ackley Evals 3100: Best = 4.445829, Len = 28
# Ackley Evals 4100: Best = 3.759903, Len = 32
# Ackley Evals 5100: Best = 3.759903, Len = 32
# Ackley Evals 6100: Best = 3.759903, Len = 32
# Ackley Evals 7100: Best = 3.521637, Len = 32
# Ackley Evals 8100: Best = 3.350055, Len = 30
# Ackley Evals 9100: Best = 3.164073, Len = 32
# Ackley Evals 10100: Best = 3.070468, Len = 29
# Ackley Evals 11100: Best = 3.001948, Len = 28
# Ackley Evals 12100: Best = 2.737034, Len = 29
# Ackley Evals 13100: Best = 2.737034, Len = 29
# Ackley Evals 14100: Best = 2.659164, Len = 28
# Ackley Evals 15100: Best = 2.579436, Len = 29
# Ackley Evals 16100: Best = 2.514511, Len = 31
# Ackley Evals 17100: Best = 2.202772, Len = 30
# Ackley Evals 18100: Best = 1.891285, Len = 30
# Ackley Evals 19100: Best = 1.891285, Len = 30
# Ackley Evals 20100: Best = 1.891285, Len = 30
# Ackley Evals 21100: Best = 1.891285, Len = 30
# Ackley Evals 22100: Best = 1.863107, Len = 29
# Ackley Evals 23100: Best = 1.863107, Len = 29
# Ackley Evals 24100: Best = 1.863107, Len = 29
# Ackley Evals 25100: Best = 1.779918, Len = 29
# Ackley Evals 26100: Best = 1.779918, Len = 29
# Ackley Evals 27100: Best = 1.779918, Len = 29
# Ackley Evals 28100: Best = 1.652082, Len = 29
# Ackley Evals 29100: Best = 1.583596, Len = 31
# Ackley Evals 30100: Best = 1.583596, Len = 31
# Ackley Evals 31100: Best = 1.583596, Len = 31
# Ackley Evals 32100: Best = 1.583596, Len = 31
# Ackley Evals 33100: Best = 1.583596, Len = 31
# Ackley Evals 34100: Best = 1.476869, Len = 28
# Ackley Evals 35100: Best = 1.455961, Len = 28
# Ackley Evals 36100: Best = 1.455961, Len = 28
# Ackley Evals 37100: Best = 1.455961, Len = 28
# Ackley Evals 38100: Best = 1.455961, Len = 28
# Ackley Evals 39100: Best = 1.455961, Len = 28
# Ackley Evals 40100: Best = 1.455961, Len = 28
# Ackley Evals 41100: Best = 1.455961, Len = 28
# Ackley Evals 42100: Best = 1.448121, Len = 29
# Ackley Evals 43100: Best = 1.448121, Len = 29
# Ackley Evals 44100: Best = 1.448121, Len = 29
# Ackley Evals 45100: Best = 1.448121, Len = 29
# Ackley Evals 46100: Best = 1.207053, Len = 29
# Ackley Evals 47100: Best = 1.207053, Len = 29
# Ackley Evals 48100: Best = 1.143643, Len = 29
# Ackley Evals 49100: Best = 1.143643, Len = 29
# Ackley Evals 50100: Best = 0.946015, Len = 29
# Ackley Evals 51100: Best = 0.932795, Len = 29
# Ackley Evals 52100: Best = 0.836404, Len = 28
# Ackley Evals 53100: Best = 0.833446, Len = 29
# Ackley Evals 54100: Best = 0.833446, Len = 29
# Ackley Evals 55100: Best = 0.833446, Len = 29
# Ackley Evals 56100: Best = 0.746073, Len = 31
# Ackley Evals 57100: Best = 0.746073, Len = 31
# Ackley Evals 58100: Best = 0.734287, Len = 31
# Ackley Evals 59100: Best = 0.734287, Len = 31
# Ackley Evals 60100: Best = 0.734287, Len = 31
# Ackley Evals 61100: Best = 0.722776, Len = 31
# Ackley Evals 62100: Best = 0.710299, Len = 31
# Ackley Evals 63100: Best = 0.642365, Len = 30
# Ackley Evals 64100: Best = 0.542893, Len = 29
# Ackley Evals 65100: Best = 0.424399, Len = 28
# Ackley Evals 66100: Best = 0.424399, Len = 28
# Ackley Evals 67100: Best = 0.424399, Len = 28
# Ackley Evals 68100: Best = 0.424399, Len = 28
# Ackley Evals 69100: Best = 0.406799, Len = 31
# Ackley Evals 70100: Best = 0.343845, Len = 29
# Ackley Evals 71100: Best = 0.332460, Len = 29
# Ackley Evals 72100: Best = 0.332460, Len = 29
# Ackley Evals 73100: Best = 0.329867, Len = 28
# Ackley Evals 74100: Best = 0.329867, Len = 28
# Ackley Evals 75100: Best = 0.329867, Len = 28
# Ackley Evals 76100: Best = 0.323422, Len = 29
# Ackley Evals 77100: Best = 0.316255, Len = 28
# Ackley Evals 78100: Best = 0.316255, Len = 28
# Ackley Evals 79100: Best = 0.316255, Len = 28
# Ackley Evals 80100: Best = 0.316255, Len = 28
# Ackley Evals 81100: Best = 0.289066, Len = 28
# Ackley Evals 82100: Best = 0.284717, Len = 32
# Ackley Evals 83100: Best = 0.279297, Len = 32
# Ackley Evals 84100: Best = 0.275775, Len = 32
# Ackley Evals 85100: Best = 0.275775, Len = 32
# Ackley Evals 86100: Best = 0.270854, Len = 31
# Ackley Evals 87100: Best = 0.255001, Len = 28
# Ackley Evals 88100: Best = 0.255001, Len = 28
# Ackley Evals 89100: Best = 0.247694, Len = 32
# Ackley Evals 90100: Best = 0.203235, Len = 32
# Ackley Evals 91100: Best = 0.203018, Len = 29
# Ackley Evals 92100: Best = 0.169710, Len = 28
# Ackley Evals 93100: Best = 0.169710, Len = 28
# Ackley Evals 94100: Best = 0.155378, Len = 32
# Ackley Evals 95100: Best = 0.155378, Len = 32
# Ackley Evals 96100: Best = 0.155378, Len = 32
# Ackley Evals 97100: Best = 0.134627, Len = 28
# Ackley Evals 98100: Best = 0.123501, Len = 29
# Ackley Evals 99100: Best = 0.120613, Len = 31
# Ackley Evals 100: Best = 5.391574, Len = 31
# Ackley Evals 1100: Best = 4.868139, Len = 31
# Ackley Evals 2100: Best = 4.686356, Len = 29
# Ackley Evals 3100: Best = 4.401166, Len = 29
# Ackley Evals 4100: Best = 4.146125, Len = 32
# Ackley Evals 5100: Best = 3.972362, Len = 30
# Ackley Evals 6100: Best = 3.724383, Len = 30
# Ackley Evals 7100: Best = 3.335715, Len = 30
# Ackley Evals 8100: Best = 3.140033, Len = 30
# Ackley Evals 9100: Best = 3.071129, Len = 31
# Ackley Evals 10100: Best = 2.965564, Len = 31
# Ackley Evals 11100: Best = 2.728564, Len = 30
# Ackley Evals 12100: Best = 2.719509, Len = 30
# Ackley Evals 13100: Best = 2.714801, Len = 29
# Ackley Evals 14100: Best = 2.599344, Len = 28
# Ackley Evals 15100: Best = 2.369259, Len = 28
# Ackley Evals 16100: Best = 2.369259, Len = 28
# Ackley Evals 17100: Best = 2.334015, Len = 28
# Ackley Evals 18100: Best = 2.332024, Len = 28
# Ackley Evals 19100: Best = 2.332024, Len = 28
# Ackley Evals 20100: Best = 2.332024, Len = 28
# Ackley Evals 21100: Best = 2.332024, Len = 28
# Ackley Evals 22100: Best = 2.332024, Len = 28
# Ackley Evals 23100: Best = 2.330307, Len = 28
# Ackley Evals 24100: Best = 2.330307, Len = 28
# Ackley Evals 25100: Best = 2.330307, Len = 28
# Ackley Evals 26100: Best = 2.330307, Len = 28
# Ackley Evals 27100: Best = 2.267528, Len = 28
# Ackley Evals 28100: Best = 2.255212, Len = 28
# Ackley Evals 29100: Best = 2.255212, Len = 28
# Ackley Evals 30100: Best = 2.137332, Len = 28
# Ackley Evals 31100: Best = 1.948349, Len = 28
# Ackley Evals 32100: Best = 1.948349, Len = 28
# Ackley Evals 33100: Best = 1.776970, Len = 28
# Ackley Evals 34100: Best = 1.762802, Len = 28
# Ackley Evals 35100: Best = 1.738438, Len = 28
# Ackley Evals 36100: Best = 1.660311, Len = 28
# Ackley Evals 37100: Best = 1.660311, Len = 28
# Ackley Evals 38100: Best = 1.660311, Len = 28
# Ackley Evals 39100: Best = 1.648338, Len = 29
# Ackley Evals 40100: Best = 1.648338, Len = 29
# Ackley Evals 41100: Best = 1.648338, Len = 29
# Ackley Evals 42100: Best = 1.403038, Len = 31
# Ackley Evals 43100: Best = 1.403038, Len = 31
# Ackley Evals 44100: Best = 1.403038, Len = 31
# Ackley Evals 45100: Best = 1.394699, Len = 31
# Ackley Evals 46100: Best = 1.158208, Len = 31
# Ackley Evals 47100: Best = 1.158208, Len = 31
# Ackley Evals 48100: Best = 1.158208, Len = 31
# Ackley Evals 49100: Best = 1.080689, Len = 30
# Ackley Evals 50100: Best = 1.080689, Len = 30
# Ackley Evals 51100: Best = 1.080689, Len = 30
# Ackley Evals 52100: Best = 1.080689, Len = 30
# Ackley Evals 53100: Best = 0.975379, Len = 29
# Ackley Evals 54100: Best = 0.975379, Len = 29
# Ackley Evals 55100: Best = 0.870330, Len = 28
# Ackley Evals 56100: Best = 0.870330, Len = 28
# Ackley Evals 57100: Best = 0.847735, Len = 28
# Ackley Evals 58100: Best = 0.835908, Len = 29
# Ackley Evals 59100: Best = 0.835908, Len = 29
# Ackley Evals 60100: Best = 0.775848, Len = 29
# Ackley Evals 61100: Best = 0.764705, Len = 32
# Ackley Evals 62100: Best = 0.698444, Len = 31
# Ackley Evals 63100: Best = 0.698444, Len = 31
# Ackley Evals 64100: Best = 0.698444, Len = 31
# Ackley Evals 65100: Best = 0.674777, Len = 31
# Ackley Evals 66100: Best = 0.600404, Len = 28
# Ackley Evals 67100: Best = 0.500480, Len = 29
# Ackley Evals 68100: Best = 0.453544, Len = 28
# Ackley Evals 69100: Best = 0.453544, Len = 28
# Ackley Evals 70100: Best = 0.453544, Len = 28
# Ackley Evals 71100: Best = 0.446439, Len = 31
# Ackley Evals 72100: Best = 0.446439, Len = 31
# Ackley Evals 73100: Best = 0.446439, Len = 31
# Ackley Evals 74100: Best = 0.446439, Len = 31
# Ackley Evals 75100: Best = 0.434227, Len = 32
# Ackley Evals 76100: Best = 0.434227, Len = 32
# Ackley Evals 77100: Best = 0.434227, Len = 32
# Ackley Evals 78100: Best = 0.386414, Len = 29
# Ackley Evals 79100: Best = 0.329889, Len = 28
# Ackley Evals 80100: Best = 0.329889, Len = 28
# Ackley Evals 81100: Best = 0.329889, Len = 28
# Ackley Evals 82100: Best = 0.329889, Len = 28
# Ackley Evals 83100: Best = 0.288357, Len = 28
# Ackley Evals 84100: Best = 0.288357, Len = 28
# Ackley Evals 85100: Best = 0.272402, Len = 28
# Ackley Evals 86100: Best = 0.269157, Len = 28
# Ackley Evals 87100: Best = 0.269157, Len = 28
# Ackley Evals 88100: Best = 0.250432, Len = 28
# Ackley Evals 89100: Best = 0.233902, Len = 28
# Ackley Evals 90100: Best = 0.233902, Len = 28
# Ackley Evals 91100: Best = 0.216372, Len = 32
# Ackley Evals 92100: Best = 0.188371, Len = 28
# Ackley Evals 93100: Best = 0.188371, Len = 28
# Ackley Evals 94100: Best = 0.156102, Len = 29
# Ackley Evals 95100: Best = 0.151829, Len = 28
# Ackley Evals 96100: Best = 0.151829, Len = 28
# Ackley Evals 97100: Best = 0.142931, Len = 31
# Ackley Evals 98100: Best = 0.137838, Len = 29
# Ackley Evals 99100: Best = 0.110917, Len = 30
# Ackley Evals 100: Best = 5.387377, Len = 28
# Ackley Evals 1100: Best = 4.957389, Len = 30
# Ackley Evals 2100: Best = 4.494719, Len = 31
# Ackley Evals 3100: Best = 4.397824, Len = 30
# Ackley Evals 4100: Best = 4.032049, Len = 29
# Ackley Evals 5100: Best = 3.918176, Len = 31
# Ackley Evals 6100: Best = 3.820128, Len = 31
# Ackley Evals 7100: Best = 3.677529, Len = 29
# Ackley Evals 8100: Best = 3.500542, Len = 30
# Ackley Evals 9100: Best = 3.500542, Len = 30
# Ackley Evals 10100: Best = 3.368211, Len = 30
# Ackley Evals 11100: Best = 3.270990, Len = 31
# Ackley Evals 12100: Best = 3.224280, Len = 30
# Ackley Evals 13100: Best = 3.155384, Len = 29
# Ackley Evals 14100: Best = 3.087412, Len = 31
# Ackley Evals 15100: Best = 3.084802, Len = 31
# Ackley Evals 16100: Best = 2.995435, Len = 31
# Ackley Evals 17100: Best = 2.838690, Len = 32
# Ackley Evals 18100: Best = 2.838690, Len = 32
# Ackley Evals 19100: Best = 2.779671, Len = 32
# Ackley Evals 20100: Best = 2.553826, Len = 31
# Ackley Evals 21100: Best = 2.443825, Len = 31
# Ackley Evals 22100: Best = 2.443825, Len = 31
# Ackley Evals 23100: Best = 2.443825, Len = 31
# Ackley Evals 24100: Best = 2.354839, Len = 31
# Ackley Evals 25100: Best = 2.171617, Len = 30
# Ackley Evals 26100: Best = 1.998331, Len = 28
# Ackley Evals 27100: Best = 1.987202, Len = 28
# Ackley Evals 28100: Best = 1.987202, Len = 28
# Ackley Evals 29100: Best = 1.987202, Len = 28
# Ackley Evals 30100: Best = 1.897121, Len = 30
# Ackley Evals 31100: Best = 1.864461, Len = 31
# Ackley Evals 32100: Best = 1.864461, Len = 31
# Ackley Evals 33100: Best = 1.764868, Len = 29
# Ackley Evals 34100: Best = 1.764868, Len = 29
# Ackley Evals 35100: Best = 1.764868, Len = 29
# Ackley Evals 36100: Best = 1.656410, Len = 28
# Ackley Evals 37100: Best = 1.656410, Len = 28
# Ackley Evals 38100: Best = 1.656410, Len = 28
# Ackley Evals 39100: Best = 1.582637, Len = 28
# Ackley Evals 40100: Best = 1.582637, Len = 28
# Ackley Evals 41100: Best = 1.582637, Len = 28
# Ackley Evals 42100: Best = 1.582637, Len = 28
# Ackley Evals 43100: Best = 1.479445, Len = 29
# Ackley Evals 44100: Best = 1.383917, Len = 30
# Ackley Evals 45100: Best = 1.344316, Len = 29
# Ackley Evals 46100: Best = 1.344316, Len = 29
# Ackley Evals 47100: Best = 1.344316, Len = 29
# Ackley Evals 48100: Best = 1.344316, Len = 29
# Ackley Evals 49100: Best = 1.344316, Len = 29
# Ackley Evals 50100: Best = 1.344316, Len = 29
# Ackley Evals 51100: Best = 1.171430, Len = 28
# Ackley Evals 52100: Best = 1.132702, Len = 30
# Ackley Evals 53100: Best = 1.083001, Len = 30
# Ackley Evals 54100: Best = 0.994597, Len = 29
# Ackley Evals 55100: Best = 0.994597, Len = 29
# Ackley Evals 56100: Best = 0.761656, Len = 28
# Ackley Evals 57100: Best = 0.761656, Len = 28
# Ackley Evals 58100: Best = 0.761656, Len = 28
# Ackley Evals 59100: Best = 0.761656, Len = 28
# Ackley Evals 60100: Best = 0.747111, Len = 28
# Ackley Evals 61100: Best = 0.747111, Len = 28
# Ackley Evals 62100: Best = 0.747111, Len = 28
# Ackley Evals 63100: Best = 0.744756, Len = 28
# Ackley Evals 64100: Best = 0.744756, Len = 28
# Ackley Evals 65100: Best = 0.710658, Len = 28
# Ackley Evals 66100: Best = 0.710658, Len = 28
# Ackley Evals 67100: Best = 0.626372, Len = 28
# Ackley Evals 68100: Best = 0.472968, Len = 28
# Ackley Evals 69100: Best = 0.472968, Len = 28
# Ackley Evals 70100: Best = 0.472968, Len = 28
# Ackley Evals 71100: Best = 0.461293, Len = 28
# Ackley Evals 72100: Best = 0.452451, Len = 28
# Ackley Evals 73100: Best = 0.451665, Len = 30
# Ackley Evals 74100: Best = 0.414692, Len = 32
# Ackley Evals 75100: Best = 0.414692, Len = 32
# Ackley Evals 76100: Best = 0.381330, Len = 31
# Ackley Evals 77100: Best = 0.376135, Len = 32
# Ackley Evals 78100: Best = 0.372746, Len = 31
# Ackley Evals 79100: Best = 0.372746, Len = 31
# Ackley Evals 80100: Best = 0.344822, Len = 32
# Ackley Evals 81100: Best = 0.271064, Len = 30
# Ackley Evals 82100: Best = 0.236356, Len = 29
# Ackley Evals 83100: Best = 0.230591, Len = 28
# Ackley Evals 84100: Best = 0.230591, Len = 28
# Ackley Evals 85100: Best = 0.226707, Len = 31
# Ackley Evals 86100: Best = 0.226309, Len = 30
# Ackley Evals 87100: Best = 0.226306, Len = 29
# Ackley Evals 88100: Best = 0.215701, Len = 28
# Ackley Evals 89100: Best = 0.206540, Len = 28
# Ackley Evals 90100: Best = 0.204873, Len = 31
# Ackley Evals 91100: Best = 0.158948, Len = 32
# Ackley Evals 92100: Best = 0.141942, Len = 31
# Ackley Evals 93100: Best = 0.140023, Len = 30
# Ackley Evals 94100: Best = 0.131204, Len = 28
# Ackley Evals 95100: Best = 0.112669, Len = 28
# Ackley Evals 96100: Best = 0.111001, Len = 30
# Ackley Evals 97100: Best = 0.083624, Len = 30
# Ackley Evals 98100: Best = 0.071072, Len = 30
# Ackley Evals 99100: Best = 0.061758, Len = 32
# Ackley Evals 100: Best = 5.413962, Len = 31
# Ackley Evals 1100: Best = 4.904608, Len = 28
# Ackley Evals 2100: Best = 4.574327, Len = 30
# Ackley Evals 3100: Best = 4.521605, Len = 30
# Ackley Evals 4100: Best = 4.216350, Len = 29
# Ackley Evals 5100: Best = 3.983478, Len = 30
# Ackley Evals 6100: Best = 3.983478, Len = 30
# Ackley Evals 7100: Best = 3.953272, Len = 28
# Ackley Evals 8100: Best = 3.765142, Len = 28
# Ackley Evals 9100: Best = 3.705883, Len = 29
# Ackley Evals 10100: Best = 3.705883, Len = 29
# Ackley Evals 11100: Best = 3.651344, Len = 31
# Ackley Evals 12100: Best = 3.651344, Len = 31
# Ackley Evals 13100: Best = 3.550319, Len = 30
# Ackley Evals 14100: Best = 3.521887, Len = 28
# Ackley Evals 15100: Best = 3.433088, Len = 29
# Ackley Evals 16100: Best = 3.404961, Len = 30
# Ackley Evals 17100: Best = 3.332160, Len = 30
# Ackley Evals 18100: Best = 3.110645, Len = 32
# Ackley Evals 19100: Best = 3.090281, Len = 31
# Ackley Evals 20100: Best = 3.090281, Len = 31
# Ackley Evals 21100: Best = 2.982812, Len = 31
# Ackley Evals 22100: Best = 2.938267, Len = 30
# Ackley Evals 23100: Best = 2.938267, Len = 30
# Ackley Evals 24100: Best = 2.938267, Len = 30
# Ackley Evals 25100: Best = 2.938267, Len = 30
# Ackley Evals 26100: Best = 2.807196, Len = 29
# Ackley Evals 27100: Best = 2.807196, Len = 29
# Ackley Evals 28100: Best = 2.807196, Len = 29
# Ackley Evals 29100: Best = 2.764983, Len = 31
# Ackley Evals 30100: Best = 2.659301, Len = 29
# Ackley Evals 31100: Best = 2.568616, Len = 29
# Ackley Evals 32100: Best = 2.543043, Len = 28
# Ackley Evals 33100: Best = 2.467530, Len = 28
# Ackley Evals 34100: Best = 2.300445, Len = 29
# Ackley Evals 35100: Best = 2.264288, Len = 28
# Ackley Evals 36100: Best = 2.191722, Len = 28
# Ackley Evals 37100: Best = 2.191722, Len = 28
# Ackley Evals 38100: Best = 2.166981, Len = 28
# Ackley Evals 39100: Best = 2.166981, Len = 28
# Ackley Evals 40100: Best = 2.104639, Len = 31
# Ackley Evals 41100: Best = 2.092877, Len = 31
# Ackley Evals 42100: Best = 2.092877, Len = 31
# Ackley Evals 43100: Best = 1.737139, Len = 28
# Ackley Evals 44100: Best = 1.734814, Len = 28
# Ackley Evals 45100: Best = 1.697519, Len = 30
# ...
# Koza Evals 1100: Best = 2.577358, Len = 8
# Koza Evals 2100: Best = 1.336685, Len = 8
# Koza Evals 3100: Best = 0.662218, Len = 9
# Koza Evals 4100: Best = 0.662218, Len = 9
# Koza Evals 5100: Best = 0.662218, Len = 9
# Koza Evals 6100: Best = 0.647407, Len = 11
# Koza Evals 7100: Best = 0.165669, Len = 11
# Koza Evals 8100: Best = 0.165669, Len = 11
# Koza Evals 9100: Best = 0.165669, Len = 11
# Koza Evals 10100: Best = 0.165669, Len = 11
# Koza Evals 11100: Best = 0.165669, Len = 11
# Koza Evals 12100: Best = 0.123841, Len = 11
# Koza Evals 13100: Best = 0.123841, Len = 11
# Koza Evals 14100: Best = 0.123841, Len = 11
# Koza Evals 15100: Best = 0.123841, Len = 11
# Koza Evals 16100: Best = 0.111648, Len = 8
# Koza Evals 17100: Best = 0.074795, Len = 9
# Koza Evals 18100: Best = 0.074795, Len = 9
# Koza Evals 19100: Best = 0.074795, Len = 9
# Koza Evals 20100: Best = 0.074795, Len = 9
# Koza Evals 21100: Best = 0.025358, Len = 9
# Koza Evals 22100: Best = 0.025358, Len = 9
# Koza Evals 23100: Best = 0.025358, Len = 9
# Koza Evals 24100: Best = 0.025358, Len = 9
# Koza Evals 25100: Best = 0.025358, Len = 9
# Koza Evals 26100: Best = 0.025358, Len = 9
# Koza Evals 27100: Best = 0.025358, Len = 9
# Koza Evals 28100: Best = 0.025358, Len = 9
# Koza Evals 29100: Best = 0.025358, Len = 9
# Koza Evals 30100: Best = 0.025358, Len = 9
# Koza Evals 31100: Best = 0.025358, Len = 9
# Koza Evals 32100: Best = 0.025358, Len = 9
# Koza Evals 33100: Best = 0.025358, Len = 9
# Koza Evals 34100: Best = 0.025358, Len = 9
# Koza Evals 35100: Best = 0.024842, Len = 9
# Koza Evals 36100: Best = 0.024842, Len = 9
# Koza Evals 37100: Best = 0.024842, Len = 9
# Koza Evals 38100: Best = 0.024842, Len = 9
# Koza Evals 39100: Best = 0.023936, Len = 9
# Koza Evals 40100: Best = 0.023936, Len = 9
# Koza Evals 41100: Best = 0.022590, Len = 9
# Koza Evals 42100: Best = 0.022590, Len = 9
# Koza Evals 43100: Best = 0.022590, Len = 9
# Koza Evals 44100: Best = 0.022590, Len = 9
# Koza Evals 45100: Best = 0.022590, Len = 9
# Koza Evals 46100: Best = 0.022590, Len = 9
# Koza Evals 47100: Best = 0.022590, Len = 9
# Koza Evals 48100: Best = 0.022590, Len = 9
# Koza Evals 49100: Best = 0.022590, Len = 9
# Koza Evals 50100: Best = 0.022590, Len = 9
# Koza Evals 51100: Best = 0.022590, Len = 9
# Koza Evals 52100: Best = 0.022590, Len = 9
# Koza Evals 53100: Best = 0.022590, Len = 9
# Koza Evals 54100: Best = 0.022590, Len = 9
# Koza Evals 55100: Best = 0.022590, Len = 9
# Koza Evals 56100: Best = 0.022590, Len = 9
# Koza Evals 57100: Best = 0.022590, Len = 9
# Koza Evals 58100: Best = 0.022590, Len = 9
# Koza Evals 59100: Best = 0.022590, Len = 9
# Koza Evals 60100: Best = 0.022590, Len = 9
# Koza Evals 61100: Best = 0.022590, Len = 9
# Koza Evals 62100: Best = 0.022590, Len = 9
# Koza Evals 63100: Best = 0.020504, Len = 9
# Koza Evals 64100: Best = 0.020504, Len = 9
# Koza Evals 65100: Best = 0.020504, Len = 9
# Koza Evals 66100: Best = 0.020504, Len = 9
# Koza Evals 67100: Best = 0.020504, Len = 9
# Koza Evals 68100: Best = 0.020504, Len = 9
# Koza Evals 69100: Best = 0.020504, Len = 9
# Koza Evals 70100: Best = 0.020504, Len = 9
# Koza Evals 71100: Best = 0.020504, Len = 9
# Koza Evals 72100: Best = 0.020504, Len = 9
# Koza Evals 73100: Best = 0.020504, Len = 9
# Koza Evals 74100: Best = 0.020504, Len = 9
# Koza Evals 75100: Best = 0.020504, Len = 9
# Koza Evals 76100: Best = 0.020317, Len = 9
# Koza Evals 77100: Best = 0.020317, Len = 9
# Koza Evals 78100: Best = 0.020317, Len = 9
# Koza Evals 79100: Best = 0.020317, Len = 9
# Koza Evals 80100: Best = 0.020317, Len = 9
# Koza Evals 81100: Best = 0.020317, Len = 9
# Koza Evals 82100: Best = 0.020317, Len = 9
# Koza Evals 83100: Best = 0.020317, Len = 9
# Koza Evals 84100: Best = 0.020317, Len = 9
# Koza Evals 85100: Best = 0.020317, Len = 9
# Koza Evals 86100: Best = 0.020317, Len = 9
# Koza Evals 87100: Best = 0.020295, Len = 9
# Koza Evals 88100: Best = 0.020295, Len = 9
# Koza Evals 89100: Best = 0.020295, Len = 9
# Koza Evals 90100: Best = 0.020295, Len = 9
# Koza Evals 91100: Best = 0.020295, Len = 9
# Koza Evals 92100: Best = 0.020295, Len = 9
# Koza Evals 93100: Best = 0.020295, Len = 9
# Koza Evals 94100: Best = 0.020295, Len = 9
# Koza Evals 95100: Best = 0.020295, Len = 9
# Koza Evals 96100: Best = 0.018341, Len = 10
# Koza Evals 97100: Best = 0.018341, Len = 10
# Koza Evals 98100: Best = 0.018341, Len = 10
# Koza Evals 99100: Best = 0.018341, Len = 10
# Koza Evals 100: Best = 28.180099, Len = 11
# Koza Evals 1100: Best = 5.479806, Len = 8
# Koza Evals 2100: Best = 1.036426, Len = 12
# Koza Evals 3100: Best = 0.706002, Len = 12
# Koza Evals 4100: Best = 0.306623, Len = 9
# Koza Evals 5100: Best = 0.292226, Len = 9
# Koza Evals 6100: Best = 0.292226, Len = 9
# Koza Evals 7100: Best = 0.161940, Len = 9
# Koza Evals 8100: Best = 0.161940, Len = 9
# Koza Evals 9100: Best = 0.161940, Len = 9
# Koza Evals 10100: Best = 0.161940, Len = 9
# Koza Evals 11100: Best = 0.161940, Len = 9
# Koza Evals 12100: Best = 0.161940, Len = 9
# Koza Evals 13100: Best = 0.161176, Len = 9
# Koza Evals 14100: Best = 0.161176, Len = 9
# Koza Evals 15100: Best = 0.161176, Len = 9
# Koza Evals 16100: Best = 0.161176, Len = 9
# Koza Evals 17100: Best = 0.161176, Len = 9
# Koza Evals 18100: Best = 0.161176, Len = 9
# Koza Evals 19100: Best = 0.161176, Len = 9
# Koza Evals 20100: Best = 0.161176, Len = 9
# Koza Evals 21100: Best = 0.161176, Len = 9
# Koza Evals 22100: Best = 0.161176, Len = 9
# Koza Evals 23100: Best = 0.161176, Len = 9
# Koza Evals 24100: Best = 0.161176, Len = 9
# Koza Evals 25100: Best = 0.161176, Len = 9
# Koza Evals 26100: Best = 0.160385, Len = 9
# Koza Evals 27100: Best = 0.160385, Len = 9
# Koza Evals 28100: Best = 0.160385, Len = 9
# Koza Evals 29100: Best = 0.160385, Len = 9
# Koza Evals 30100: Best = 0.160385, Len = 9
# Koza Evals 31100: Best = 0.160385, Len = 9
# Koza Evals 32100: Best = 0.160385, Len = 9
# Koza Evals 33100: Best = 0.160385, Len = 9
# Koza Evals 34100: Best = 0.160385, Len = 9
# Koza Evals 35100: Best = 0.160385, Len = 9
# Koza Evals 36100: Best = 0.144126, Len = 9
# Koza Evals 37100: Best = 0.144126, Len = 9
# Koza Evals 38100: Best = 0.095561, Len = 11
# Koza Evals 39100: Best = 0.095561, Len = 11
# Koza Evals 40100: Best = 0.095561, Len = 11
# Koza Evals 41100: Best = 0.089590, Len = 11
# Koza Evals 42100: Best = 0.089590, Len = 11
# Koza Evals 43100: Best = 0.085292, Len = 12
# Koza Evals 44100: Best = 0.085292, Len = 12
# Koza Evals 45100: Best = 0.081870, Len = 12
# Koza Evals 46100: Best = 0.081870, Len = 12
# Koza Evals 47100: Best = 0.081870, Len = 12
# Koza Evals 48100: Best = 0.081870, Len = 12
# Koza Evals 49100: Best = 0.081870, Len = 12
# Koza Evals 50100: Best = 0.081870, Len = 12
# Koza Evals 51100: Best = 0.081870, Len = 12
# Koza Evals 52100: Best = 0.081870, Len = 12
# Koza Evals 53100: Best = 0.081870, Len = 12
# Koza Evals 54100: Best = 0.081870, Len = 12
# Koza Evals 55100: Best = 0.081870, Len = 12
# Koza Evals 56100: Best = 0.081870, Len = 12
# Koza Evals 57100: Best = 0.081870, Len = 12
# Koza Evals 58100: Best = 0.081611, Len = 12
# Koza Evals 59100: Best = 0.081611, Len = 12
# Koza Evals 60100: Best = 0.081611, Len = 12
# Koza Evals 61100: Best = 0.081611, Len = 12
# Koza Evals 62100: Best = 0.081611, Len = 12
# Koza Evals 63100: Best = 0.081611, Len = 12
# Koza Evals 64100: Best = 0.081611, Len = 12
# Koza Evals 65100: Best = 0.081611, Len = 12
# Koza Evals 66100: Best = 0.081611, Len = 12
# Koza Evals 67100: Best = 0.075153, Len = 9
# Koza Evals 68100: Best = 0.075153, Len = 9
# Koza Evals 69100: Best = 0.075153, Len = 9
# Koza Evals 70100: Best = 0.063411, Len = 10
# Koza Evals 71100: Best = 0.063411, Len = 10
# Koza Evals 72100: Best = 0.044167, Len = 10
# Koza Evals 73100: Best = 0.044167, Len = 10
# Koza Evals 74100: Best = 0.043033, Len = 10
# Koza Evals 75100: Best = 0.043033, Len = 10
# Koza Evals 76100: Best = 0.021287, Len = 10
# Koza Evals 77100: Best = 0.021287, Len = 10
# Koza Evals 78100: Best = 0.021287, Len = 10
# Koza Evals 79100: Best = 0.021287, Len = 10
# Koza Evals 80100: Best = 0.021287, Len = 10
# Koza Evals 81100: Best = 0.021287, Len = 10
# Koza Evals 82100: Best = 0.021287, Len = 10
# Koza Evals 83100: Best = 0.021287, Len = 10
# Koza Evals 84100: Best = 0.016900, Len = 10
# Koza Evals 85100: Best = 0.016900, Len = 10
# Koza Evals 86100: Best = 0.016900, Len = 10
# Koza Evals 87100: Best = 0.016900, Len = 10
# Koza Evals 88100: Best = 0.016900, Len = 10
# Koza Evals 89100: Best = 0.016900, Len = 10
# Koza Evals 90100: Best = 0.016900, Len = 10
# Koza Evals 91100: Best = 0.016900, Len = 10
# Koza Evals 92100: Best = 0.016900, Len = 10
# Koza Evals 93100: Best = 0.016900, Len = 10
# Koza Evals 94100: Best = 0.016900, Len = 10
# Koza Evals 95100: Best = 0.016900, Len = 10
# Koza Evals 96100: Best = 0.016900, Len = 10
# Koza Evals 97100: Best = 0.016900, Len = 10
# Koza Evals 98100: Best = 0.016854, Len = 10
# Koza Evals 99100: Best = 0.016854, Len = 10
# Koza Evals 100: Best = 13.482527, Len = 10
# Koza Evals 1100: Best = 0.686384, Len = 11
# Koza Evals 2100: Best = 0.686384, Len = 11
# Koza Evals 3100: Best = 0.613736, Len = 12
# Koza Evals 4100: Best = 0.613736, Len = 12
# Koza Evals 5100: Best = 0.613736, Len = 12
# Koza Evals 6100: Best = 0.572487, Len = 8
# Koza Evals 7100: Best = 0.572487, Len = 8
# Koza Evals 8100: Best = 0.572487, Len = 8
# Koza Evals 9100: Best = 0.455699, Len = 8
# Koza Evals 10100: Best = 0.275310, Len = 9
# Koza Evals 11100: Best = 0.275310, Len = 9
# Koza Evals 12100: Best = 0.275310, Len = 9
# Koza Evals 13100: Best = 0.275310, Len = 9
# Koza Evals 14100: Best = 0.253872, Len = 10
# Koza Evals 15100: Best = 0.253872, Len = 10
# Koza Evals 16100: Best = 0.253872, Len = 10
# Koza Evals 17100: Best = 0.253872, Len = 10
# Koza Evals 18100: Best = 0.253872, Len = 10
# Koza Evals 19100: Best = 0.253872, Len = 10
# Koza Evals 20100: Best = 0.201949, Len = 10
# Koza Evals 21100: Best = 0.201949, Len = 10
# Koza Evals 22100: Best = 0.201949, Len = 10
# Koza Evals 23100: Best = 0.201949, Len = 10
# Koza Evals 24100: Best = 0.201949, Len = 10
# Koza Evals 25100: Best = 0.191090, Len = 10
# Koza Evals 26100: Best = 0.191090, Len = 10
# Koza Evals 27100: Best = 0.129853, Len = 8
# Koza Evals 28100: Best = 0.129853, Len = 8
# Koza Evals 29100: Best = 0.129853, Len = 8
# Koza Evals 30100: Best = 0.129853, Len = 8
# Koza Evals 31100: Best = 0.080110, Len = 10
# Koza Evals 32100: Best = 0.080110, Len = 10
# Koza Evals 33100: Best = 0.080110, Len = 10
# Koza Evals 34100: Best = 0.080110, Len = 10
# Koza Evals 35100: Best = 0.080110, Len = 10
# Koza Evals 36100: Best = 0.080110, Len = 10
# Koza Evals 37100: Best = 0.080110, Len = 10
# Koza Evals 38100: Best = 0.080110, Len = 10
# Koza Evals 39100: Best = 0.080110, Len = 10
# Koza Evals 40100: Best = 0.080110, Len = 10
# Koza Evals 41100: Best = 0.080110, Len = 10
# Koza Evals 42100: Best = 0.080110, Len = 10
# Koza Evals 43100: Best = 0.080110, Len = 10
# Koza Evals 44100: Best = 0.080110, Len = 10
# Koza Evals 45100: Best = 0.080110, Len = 10
# Koza Evals 46100: Best = 0.080110, Len = 10
# Koza Evals 47100: Best = 0.080110, Len = 10
# Koza Evals 48100: Best = 0.080110, Len = 10
# Koza Evals 49100: Best = 0.080110, Len = 10
# Koza Evals 50100: Best = 0.080110, Len = 10
# Koza Evals 51100: Best = 0.080110, Len = 10
# Koza Evals 52100: Best = 0.080110, Len = 10
# Koza Evals 53100: Best = 0.080110, Len = 10
# Koza Evals 54100: Best = 0.080110, Len = 10
# Koza Evals 55100: Best = 0.080110, Len = 10
# Koza Evals 56100: Best = 0.080110, Len = 10
# Koza Evals 57100: Best = 0.080110, Len = 10
# Koza Evals 58100: Best = 0.080110, Len = 10
# Koza Evals 59100: Best = 0.080110, Len = 10
# Koza Evals 60100: Best = 0.080110, Len = 10
# Koza Evals 61100: Best = 0.080110, Len = 10
# Koza Evals 62100: Best = 0.080110, Len = 10
# Koza Evals 63100: Best = 0.080110, Len = 10
# Koza Evals 64100: Best = 0.080110, Len = 10
# Koza Evals 65100: Best = 0.080110, Len = 10
# Koza Evals 66100: Best = 0.080110, Len = 10
# Koza Evals 67100: Best = 0.060383, Len = 10
# Koza Evals 68100: Best = 0.060383, Len = 10
# Koza Evals 69100: Best = 0.060383, Len = 10
# Koza Evals 70100: Best = 0.059793, Len = 10
# Koza Evals 71100: Best = 0.059793, Len = 10
# Koza Evals 72100: Best = 0.056979, Len = 10
# Koza Evals 73100: Best = 0.056979, Len = 10
# Koza Evals 74100: Best = 0.056979, Len = 10
# Koza Evals 75100: Best = 0.056979, Len = 10
# Koza Evals 76100: Best = 0.056979, Len = 10
# Koza Evals 77100: Best = 0.047888, Len = 11
# Koza Evals 78100: Best = 0.043098, Len = 10
# Koza Evals 79100: Best = 0.043098, Len = 10
# Koza Evals 80100: Best = 0.030610, Len = 10
# Koza Evals 81100: Best = 0.030610, Len = 10
# Koza Evals 82100: Best = 0.013326, Len = 11
# Koza Evals 83100: Best = 0.013326, Len = 11
# Koza Evals 84100: Best = 0.013326, Len = 11
# Koza Evals 85100: Best = 0.013326, Len = 11
# Koza Evals 86100: Best = 0.013326, Len = 11
# Koza Evals 87100: Best = 0.012963, Len = 11
# Koza Evals 88100: Best = 0.012963, Len = 11
# Koza Evals 89100: Best = 0.012963, Len = 11
# Koza Evals 90100: Best = 0.012963, Len = 11
# Koza Evals 91100: Best = 0.012963, Len = 11
# Koza Evals 92100: Best = 0.012963, Len = 11
# Koza Evals 93100: Best = 0.012963, Len = 11
# Koza Evals 94100: Best = 0.012963, Len = 11
# Koza Evals 95100: Best = 0.012963, Len = 11
# Koza Evals 96100: Best = 0.012963, Len = 11
# Koza Evals 97100: Best = 0.012963, Len = 11
# Koza Evals 98100: Best = 0.012963, Len = 11
# Koza Evals 99100: Best = 0.012963, Len = 11
# Koza Evals 100: Best = 24.401118, Len = 11
# Koza Evals 1100: Best = 1.960067, Len = 9
# Koza Evals 2100: Best = 0.580379, Len = 9
# Koza Evals 3100: Best = 0.475848, Len = 10
# Koza Evals 4100: Best = 0.416383, Len = 8
# Koza Evals 5100: Best = 0.170673, Len = 8
# Koza Evals 6100: Best = 0.170673, Len = 8
# Koza Evals 7100: Best = 0.170673, Len = 8
# Koza Evals 8100: Best = 0.170673, Len = 8
# Koza Evals 9100: Best = 0.170519, Len = 8
# Koza Evals 10100: Best = 0.170519, Len = 8
# Koza Evals 11100: Best = 0.155532, Len = 8
# Koza Evals 12100: Best = 0.155532, Len = 8
# Koza Evals 13100: Best = 0.155532, Len = 8
# Koza Evals 14100: Best = 0.155532, Len = 8
# Koza Evals 15100: Best = 0.155532, Len = 8
# Koza Evals 16100: Best = 0.155532, Len = 8
# Koza Evals 17100: Best = 0.155532, Len = 8
# Koza Evals 18100: Best = 0.155532, Len = 8
# Koza Evals 19100: Best = 0.155532, Len = 8
# Koza Evals 20100: Best = 0.155532, Len = 8
# Koza Evals 21100: Best = 0.155532, Len = 8
# Koza Evals 22100: Best = 0.155532, Len = 8
# Koza Evals 23100: Best = 0.155532, Len = 8
# Koza Evals 24100: Best = 0.155532, Len = 8
# Koza Evals 25100: Best = 0.155532, Len = 8
# Koza Evals 26100: Best = 0.155532, Len = 8
# Koza Evals 27100: Best = 0.155532, Len = 8
# Koza Evals 28100: Best = 0.155532, Len = 8
# Koza Evals 29100: Best = 0.155342, Len = 8
# Koza Evals 30100: Best = 0.155342, Len = 8
# Koza Evals 31100: Best = 0.153491, Len = 9
# Koza Evals 32100: Best = 0.153491, Len = 9
# Koza Evals 33100: Best = 0.153491, Len = 9
# Koza Evals 34100: Best = 0.153491, Len = 9
# Koza Evals 35100: Best = 0.153491, Len = 9
# Koza Evals 36100: Best = 0.146890, Len = 9
# Koza Evals 37100: Best = 0.146890, Len = 9
# Koza Evals 38100: Best = 0.146890, Len = 9
# Koza Evals 39100: Best = 0.146890, Len = 9
# Koza Evals 40100: Best = 0.146890, Len = 9
# Koza Evals 41100: Best = 0.146890, Len = 9
# Koza Evals 42100: Best = 0.146890, Len = 9
# Koza Evals 43100: Best = 0.146890, Len = 9
# Koza Evals 44100: Best = 0.146890, Len = 9
# Koza Evals 45100: Best = 0.146890, Len = 9
# Koza Evals 46100: Best = 0.146890, Len = 9
# Koza Evals 47100: Best = 0.146890, Len = 9
# Koza Evals 48100: Best = 0.140359, Len = 9
# Koza Evals 49100: Best = 0.137916, Len = 8
# Koza Evals 50100: Best = 0.137916, Len = 8
# Koza Evals 51100: Best = 0.137916, Len = 8
# Koza Evals 52100: Best = 0.137916, Len = 8
# Koza Evals 53100: Best = 0.137916, Len = 8
# Koza Evals 54100: Best = 0.135825, Len = 8
# Koza Evals 55100: Best = 0.135825, Len = 8
# Koza Evals 56100: Best = 0.135825, Len = 8
# Koza Evals 57100: Best = 0.135825, Len = 8
# Koza Evals 58100: Best = 0.135825, Len = 8
# Koza Evals 59100: Best = 0.135825, Len = 8
# Koza Evals 60100: Best = 0.135825, Len = 8
# Koza Evals 61100: Best = 0.135825, Len = 8
# Koza Evals 62100: Best = 0.135825, Len = 8
# Koza Evals 63100: Best = 0.135825, Len = 8
# Koza Evals 64100: Best = 0.129454, Len = 9
# Koza Evals 65100: Best = 0.129454, Len = 9
# Koza Evals 66100: Best = 0.129454, Len = 9
# Koza Evals 67100: Best = 0.129454, Len = 9
# Koza Evals 68100: Best = 0.129276, Len = 10
# Koza Evals 69100: Best = 0.129276, Len = 10
